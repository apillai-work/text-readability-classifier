# %% [markdown]
# # Using a Convolutional Neural Network for Text Readability Classification
#
# Code cells have been individually cited via comments wherever third-party code has been referred to or implemented, and a citation list has been added at the bottom of this notebook in Harvard style referencing.

# %% [markdown]
# ### Project Overview:
#
# The purpose of this project is to create a text readability classifier (inspired by the flesch kincaid readability tests) that determines whether a piece of text is easy or hard to read. I shall be making use of english textbooks from South-East Asian / Middle Eastern areas as datasets. Since most readability classifiers use data from the United Kingdom / United States in their model, I thought it would be interesting to approach this problem using data from non-western regions to see if they could predict readability scores accurately for english phrases across the world. After building the classifier, I shall test it on speech / interview transcripts of various politicians as a use case to get a bit more insight into their speaking styles.

# %% [markdown]
# ### Project Aim:
#
# 1) To construct a model that allows writers to have more control over their writing, so that they could structure their work according to their intended audience.

# %% [markdown]
# ### Installing and Importing the Required Libraries:

# %%
import numpy as np  
from keras.preprocessing import sequence    
from keras.models import Sequential      
from keras.layers import Dense, Dropout, Activation   
from keras.layers import Conv1D, GlobalMaxPooling1D
from gensim.models.keyedvectors import KeyedVectors
from nltk.tokenize.casual import casual_tokenize
from gensim.models import KeyedVectors
from sklearn.model_selection import train_test_split
import pandas as pd
from random import shuffle
import regex as re
from cleantext import clean
from nltk import word_tokenize
import textstat
# Out:
# Since the GPL-licensed package `unidecode` is not installed, using Python's `unicodedata` package which yields worse results.

# %% [markdown]
# ### Selection of Data:
#
# For this project, I'm using English textbooks of varying grades from different countries. I found all of them on [Library Genesis](https://www.libgen.is/) and since they were PDF files, I then converted them to text files using [Zamzar File Converter](https://www.zamzar.com/). I initially tried using python modules for this task like PDF Miner and PyPDF, but kept running into errors as most of the code I found on StackOverflow was not suitable with the latest version of Python.
#
# For this notebook, I have used a **grade two textbook from Indonesia and a grade six textbook from the Islamic State.** The former can be found [here](https://libgen.is/book/index.php?md5=42EEC448F886A2790FC9AE5A2526F0C4), and the latter can be found [here](https://libgen.is/search.php?req=islamic+state+english&open=0&res=25&view=simple&phrase=1&column=def). I thought it would be interesting to see how the classifiers are performing when textbooks from two different regions are used, and if the possible propoganda in the textbook from the Islamic State affects how phrases shall be classified during testing.

# %% [markdown]
# ### Preprocessing the Data:
#
# I've used Regex and the Clean-Text Library to prepare the data before the classification task. I defined a 'read_and_clean' function to read any given text file and clean the data in it, whilst replacing the line-breaks according to every condition (as described in the comments) as the text files for this task aren't following a particular pattern with grammar since it was converted from an image-heavy PDF. After that, I'm splitting the sentence after every full stop ('.') and avoiding any sentences with less than two words as it won't be of much use.

# %%
def remove(text):
    text = re.sub(r"#\S+", " ", text) #remove hashtags
    text = re.sub(r"https*\S+", " ", text) #remove URLs
    text = re.sub(r'\w*\d+\w*', '', text) #remove numbers 
    text = re.sub(r'[^a-zA-Z0-9\n\?!\.]', ' ', text) #remove special characters
    text= text.strip(" ")
    text = text.strip(".")
    return text

# %%
# read the file and clean it.
def read_and_clean(file_name):
# read the file
    fs = open(file_name, 'r') 
    book1 = fs.read()
# convert it to . if 2 or more line breaks are together
    book1 = re.sub(r"\n{2,}",". ", book1)
# convert it to . if 2 or more spaces are together
    book1 = re.sub(r"\s{2,}",". ", book1)
# convert a single line break to space if it is followed by a small letter
    book1 = re.sub(r"\n{1}(?=\s[a-z])"," ", book1)
# convert a single line break to space if it is followed by a space and small letter
    book1 = re.sub(r"\n{1}(?=[a-z])"," ", book1)
# convert all remaining line breaks to .
    book1 = re.sub(r"\n",". ", book1)
    total = []
    
    clean(book1,
        no_line_breaks=True) # https://pypi.org/project/clean-text/
    
# split the sentence based on .
    for i in book1.split(". "):
# clean it using above function
        clean_text = remove(i)
# convert the sentence to a list of words and check the length. if it is greater then 2, then consider it a sentence
        if len(word_tokenize(clean_text)) >2:
            total.append(clean_text)
# return the final list
    return total

# %% [markdown]
# ### Labelling the Data and Calling the Functions:

# %%
# read the grade one file
grade_one_sentence = read_and_clean("../data/gradetwoindo.txt")

# %%
label = 0
new_examples1 = []
for i in grade_one_sentence:  
    if len(word_tokenize(i)) >2:
        new_examples1 = new_examples1 + [[i, label]]

# %%
new_examples1 = new_examples1[2000:]

# %%
new_examples1
# Out:
# [['What do you think on the picture tells you about?', 0],
#  ['Is it a legend  myth  or fabel?', 0],
#  ['Where do you think the story happened?', 0],
#  ['Listen to a short story from the tape and  ll in the blanks', 0],
#  ['The Two Friends and the Bear', 0],
#  ['John and James were two friends who were crossing', 0],
#  ['Suddenly  they hit a huge black', 0],
#  ['Imagine how terri ed they were', 0],
#  ['They tried to run but the bear', 0],
#  ['managed to climb up into a tree but', 0],
#  ['fell to the ground and pretended to be dead', 0],
#  ['He knew that a bear will only attack something if it is', 0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['The bear  him all over  while the man tried to hold his breath as best he could  hoping that the animal would not discover the pretence',
#   0],
#  ['Finally  the bear must have thought that the man really was', 0],
#  ['Finally  the danger over  John came down from the tree and asked his friend   Well  what did the bear',
#   0],
#  ['into your ear?', 0],
#  ['It would be good if you fell from the tree and pretended to be dead with me!',
#   0],
#  ['Adapted from   and More Fairy Tales', 0],
#  ['Coca cola is a carbonated soft drink sold in stores  restaurants and vending machines in more than  countries',
#   0],
#  ['It is produced by the coca cola company and is often referred to simply as Coke',
#   0],
#  ['The  rst cocacola recipe was invented in Columbus  Georgia at a drugstore by John Stith',
#   0],
#  ['Pemberton claimed coca cola cured many diseases  including morphine addiction  dyspepsia  neurasthenia  headache and impotance',
#   0],
#  ['When launched coca cola s two key ingredients were cocaine and caffeine',
#   0],
#  ['The cocaine was derived from the coca leave and the caffeine from Kola nutscoca cola  the  K  in Kola was replaced with  C  for marketing purposes ',
#   0],
#  ['Listen to your teacher carefully', 0],
#  ['Then  decide whether the following statements are true  T  or false  F ',
#   0],
#  ['John and James were two friends', 0],
#  ['They hit a huge stone in the mountain', 0],
#  ['They tried to run but the bear chased them', 0],
#  ['John fell to the ground', 0],
#  ['James pretended to be dead', 0],
#  ['The bear smelled the stone', 0],
#  ['Pronounce It!', 0],
#  ['nv  te  n', 0],
#  ['Answer the following question by choosing a  b  c or d based on the text',
#   0],
#  ['X   I want to take my pill', 0],
#  ['Y   Sure! A minute  please', 0],
#  ['Do you want some? b', 0],
#  ['Can you get me a glass of water  please? c', 0],
#  ['Can you take me to the doctor  please? d', 0],
#  ['Will you buy it for me  please?', 0],
#  ['Taken from  en.wikipedia.org', 0],
#  ['live friend rich catch invitation', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Taken from Ujian Nasional Bahasa Inggris  ', 0],
#  ['In this section  you will learn how to', 0],
#  ['express the expressions for asking  giving  and disagreeing with opinions',
#   0],
#  ['express the expressions for asking and giving agreement', 0],
#  ['express the expressions for asking  giving  and rejecting a help', 0],
#  ['express the expressions for asking  offering  giving  and rejecting an item',
#   0],
#  ['express the expressions for responding to a statement', 0],
#  ['retell a narrative text', 0],
#  ['respond to a short functional text in the form of brochure', 0],
#  ['After learning the lesson in this section  you are expected to be able to',
#   0],
#  ['express how to ask  give  and decline opinions correctly', 0],
#  ['express how to give agreement correctly', 0],
#  ['express how to ask  give  and reject help correctly', 0],
#  ['express how to ask  offer  give  and reject an item correctly', 0],
#  ['express how to respond to a statement correctly', 0],
#  ['retell a narrative text correctly', 0],
#  ['understand how to respond to a short functional text in the form of brochure',
#   0],
#  ['What s your opinion about using the internet?', 0],
#  ['Complete these dialogues with suitable expressions provided', 0],
#  ['What do you think about our new friend  Anita?', 0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['Do you have an opinion on the Aceh tragedy?', 0],
#  ['What do you think about the story?', 0],
#  ['What do you think about symphony orchestra?', 0],
#  ['I think it s terrible because it can be dangerous to humans too', 0],
#  ['I think she s so beautiful', 0],
#  ['I m sorry  I haven t read it', 0],
#  ['I don t know', 0],
#  ['I hardly ever listen to symphony orchestra', 0],
#  ['I think the Internet is very useful', 0],
#  ['Act out the dialogue with your friend', 0],
#  ['Pay attention to the italic sentences', 0],
#  ['Maylie   Hi  Maylie', 0],
#  ['How is it going today?', 0],
#  ['Alisa   Oh  hi  Maylie', 0],
#  ['Well  to tell you the truth I m quite sleepy now', 0],
#  ['Maylie   Yeah  I noticed that you have been yawning', 0],
#  ['What did you do last night?', 0],
#  ['Alisa   I stayed up late last night', 0],
#  ['I watched a new', 0],
#  ['lm on DVD  Troy', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Maylie   So  how was it?', 0],
#  ['Alisa   It s a cool  lm', 0],
#  ['Brad Pitt was so lovely', 0],
#  ['How about you? What do you think about it?', 0],
#  ['Maylie   I didn t like it', 0],
#  ['I think it s boring', 0],
#  ['Follow up Activity', 0],
#  ['What is your favourite movie? Give your opinion about the movie', 0],
#  ['Share your favourite movie with your friend and make them interested in watching it',
#   0],
#  ['Watching movies together with your friends can be fun', 0],
#  ['Complete and practise the following dialogues', 0],
#  ['Yup  it s good', 0],
#  ['I think the picture is beautiful', 0],
#  ['Do you think playing football when it s raining is a good idea?', 0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['Do you think these shoes are all right?', 0],
#  ['I think you should wear another costume to the costume party', 0],
#  ['Act out the following dialogue with your friend', 0],
#  ['Then  identify the expressions used', 0],
#  ['Ami   It s almost  p.m', 0],
#  ['How about going to the cafe', 0],
#  ['I m hungry', 0],
#  ['Are you?', 0],
#  ['Ari   A little bit', 0],
#  ['Ami   Listen! After having our dinner we ll go for a play', 0],
#  ['Do you agree?', 0],
#  ['Ari   Why not? That s a good idea', 0],
#  ['How about  The', 0],
#  ['East Side Story ', 0],
#  ['Ami   Great! I ll treat you', 0],
#  ['Ari   Thanks a lot', 0],
#  ['to older people or a stranger', 0],
#  ['to older people or a stranger', 0],
#  ['To ask for agreement  you could use these expressions', 0],
#  ['Do you agree?', 0],
#  ['Would you agree with ...?', 0],
#  ['  wouldn t you say?', 0],
#  ['You can use these expressions to give an agreement', 0],
#  ['That s a good idea', 0],
#  ['Well  that s settled', 0],
#  ['We seem to be saying the same thing', 0],
#  ['You can use these expressions to respond to a statement', 0],
#  ['Why not?', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Study the following situation carefully', 0],
#  ['In the bookstore  you and your friend are discussing which book that you must buy',
#   0],
#  ['The followings are some expressions that you and your friend may say', 0],
#  ['Come on  I m confused', 0],
#  ['Which book must I buy?', 0],
#  ['Don t be so confused', 0],
#  ['Would you agree if I choose this book?', 0],
#  ['Of course not', 0],
#  ['I can t agree with you', 0],
#  ['That book is quite expensive', 0],
#  ['What about this one?', 0],
#  ['No  I disagree with you', 0],
#  ['That s not a good book', 0],
#  ['Some say the author imitates from another book', 0],
#  ['I m so tired', 0],
#  ['Just help me to choose  I know you re the expert', 0],
#  ['But give me one with a reasonable price', 0],
#  ['Work in pairs', 0],
#  ['Compose a good dialogue from the situation in Practice  and practise it',
#   0],
#  ['Look at the picture and answer the questions orally', 0],
#  ['Need some help  Tedi?', 0],
#  ['Yes  of course', 0],
#  ['Could you take these?', 0],
#  ['What do you see in the picture?', 0],
#  ['Who needs some help?', 0],
#  ['What does his friend say?', 0],
#  ['What does he say to respond to the offer?', 0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['Act out the dialogue with your friends', 0],
#  ['Pay attention to the italic sentences', 0],
#  ['Nadine  Fitri  and Dara are friends', 0],
#  ['They are preparing', 0],
#  ['Andre s party', 0],
#  ['Nadine   Fitri  please go to the shop and buy a kilo of sugar', 0],
#  ['We have to bake a cake for Andre s party', 0],
#  ['Let me shut down my computer', 0],
#  ['Nadine   Dara  Can you take thirty plates from the cupboard?', 0],
#  ['Sure  Do you want the pink plates  the blue plates  or the purple plates?',
#   0],
#  ['Nadine   Take the pink and the purple plates', 0],
#  ['Do you want some forks and spoons?', 0],
#  ['Nadine   Yes  Please', 0],
#  ['You re busy baking the cake  Nadine', 0],
#  ['Can I help you?', 0],
#  ['Nadine   No  thanks', 0],
#  ['It s almost done', 0],
#  ['to older people or a stranger', 0],
#  ['to older people or a stranger', 0],
#  ['to older people or a stranger', 0],
#  ['You can use these expressions to ask for a help', 0],
#  ['Can you help me?', 0],
#  ['Would you mind if I ask your help to ', 0],
#  ['I do apologize  but would you kindly helping me to', 0],
#  ['?  do something', 0],
#  ['You can use these expressions to offer help', 0],
#  ['What can I do to help ...?', 0],
#  ['May I help you?', 0],
#  ['May I be assistance?', 0],
#  ['You can use these expressions to give help to someone', 0],
#  ['You look like you could do with some help ', 0],
#  ['You can use these expressions to decline someone s help', 0],
#  ['That s very kind of you  but ', 0],
#  ['To ask for an item  you could use these expressions', 0],
#  ['Can I have ...?', 0],
#  ['Would you be so kind to give me ...?', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Give your response to the following situations', 0],
#  ['Could you be kindly helping me with this heavy bag?', 0],
#  ['You say you will be glad to help', 0],
#  ['Can I help you taking that books upstair?', 0],
#  ['You refuse Desry s help politely', 0],
#  ['Mrs Trihatmojo   Young man  can you show me the way to the travel agency?',
#   0],
#  ['You say you will help her until she reaches the travel agency', 0],
#  ['Let me help you to cook that vegetables', 0],
#  ['You accept your sister s help with pleasure', 0],
#  ['Work in pairs', 0],
#  ['Make a dialogue using the expression of asking  giving and refusing a help and practise them in front of the class',
#   0],
#  ['Look at the picture', 0],
#  ['Then  answer these questions orally', 0],
#  ['Source   Bedtime Stories', 0],
#  ['What is in the picture?', 0],
#  ['Have you ever read a story about them?', 0],
#  ['What other stories have you read?', 0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['Read the following text with good pronunciation', 0],
#  ['Once upon a time there lived two best friends  the hare and the tortoise',
#   0],
#  ['They liked to race against each other  but the hare always won', 0],
#  ['One day  the hare asked the tortoise to race down to the beach', 0],
#  ['The tortoise refused  he said that he will loose anyway', 0],
#  ['The hare replied in a kind voice that he felt sorry about it', 0],
#  ['But the next day  the hare found a way to race the tortoise that would be fair and lots of fun too',
#   0],
#  ['He asked the tortoise to come with him', 0],
#  ['The tortoise was slowly plodding over the sandhill towards the beach', 0],
#  ['Now the two friends can race against each other all day and something tells me that the tortoise might win this time',
#   0],
#  ['Adapted from  Bedtime Stories', 0],
#  ['Retell the story about the hare and the tortoise in your own words', 0],
#  ['Some questions below will help you', 0],
#  ['Work with your partner', 0],
#  ['Find the Indonesian translations for these words and spell them out', 0],
#  ['Use a dictionary to help you', 0],
#  ['Who were the two friends?', 0],
#  ['What did the hare ask the tortoise?', 0],
#  ['What happened next?', 0],
#  ['How did the hare  nd a way to race?', 0],
#  ['How was the end of the story?', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['best race always win beach refused loose sorry', 0],
#  ['Retell your favourite story to your friend', 0],
#  ['Look and study the following brochure and dialogue', 0],
#  ['Good news for bookworms', 0],
#  ['Pay only   for a set of story books in English and', 0],
#  ['All books written by our internal writers', 0],
#  ['If you buy now  you get   discount on your purchases!', 0],
#  ['Don t miss this fantastic offer!', 0],
#  ['Source  CD Images', 0],
#  ['Don t miss this great offer!', 0],
#  ['A set of the most read children s stories written by both local and foreign writers',
#   0],
#  ['Get  fteen books for only  ', 0],
#  ['Available at all bookstores', 0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['Dad   Have you decided  which set of books you want to buy?', 0],
#  ['Didi   Both sets look interesting', 0],
#  ['Famous Fables are written in English while Favourite Stories are written in both languages',
#   0],
#  ['Dad   You get a set of twelve books for   when you buy Favourite Stories',
#   0],
#  ['Didi   But if I buy Famous Fables  I can get a discount on my next purchase',
#   0],
#  ['Fill in the blanks to help Didi choosing a set of books', 0],
#  ['Write a paragraph about the book you want to buy', 0],
#  ['Then share it with your friend in front of the class', 0],
#  ['Which set of books would you buy? Give reasons based on the following points',
#   0],
#  ['price number of books writers offer', 0],
#  ['I would choose', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['In this section  you will learn how to', 0],
#  ['read a narrative text', 0],
#  ['identify the structure of a narrative text', 0],
#  ['After learning the lesson in this section  you are expected to be able to',
#   0],
#  ['read and understand the structure of a narrative text', 0],
#  ['Answer the following questions orally', 0],
#  ['You can make friends over the Internet', 0],
#  ['Just log on to this web site  www.friendster.com', 0],
#  ['Source  maspaulus. les.wordpress.com', 0],
#  ['Do you have a best friend?', 0],
#  ['What kind of friend do you want to have?', 0],
#  ['What is your best friend like?', 0],
#  ['Match the words in column A with their meanings in column B', 0],
#  ['friendly to others like very much people with of the highest social class unexpectedly  all of a sudden',
#   0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['persuaded urge sneak blast', 0],
#  ['cannot move or escape cause to do something by discussion recommend to do something move quietly and secretly big explosion person who works in a household for wages',
#   0],
#  ['Read the following text aloud', 0],
#  ['The Prince and His Best Friends', 0],
#  ['Once upon a time  there lived a kind young prince named Jonathan', 0],
#  ['He was loved  and adored by his people', 0],
#  ['His two close friends were Peter Piper  the servant of the palace and Franklin Greedy  the son of an Aristocrat',
#   0],
#  ['One day  The Prince  Peter Piper  and Franklin', 0],
#  ['Greedy were walking through the forest', 0],
#  ['Suddenly a group of bandits attacked the three boys near an old house', 0],
#  ['They entered the old house and blockaded the gate and doors', 0],
#  ['The three boys were trapped inside the house', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Franklin was very terri ed and asked the Prince to surrender immediately  but Peter was not afraid',
#   0],
#  ['He urged and supported the Prince not to give up', 0],
#  ['Prince decided not to surrender because he realised that he would become a hostage for the bandits to ask for ransom to his father  but Franklin was scared and wanted to make a deal  it made Peter suspicious about Franklin s behaviour',
#   0],
#  ['So he quietly made up a plan for him and the Prince to escape', 0],
#  ['Early at dawn  Franklin opened the front gate and unlocked the doors', 0],
#  ['The bandits entered the house in search of the Prince', 0],
#  ['When they came to the room where the Prince was supposed to be sleeping  no one was there',
#   0],
#  ['Suddenly they heard a horse running outside the house and saw over the window that',
#   0],
#  ['Peter Piper and the Prince were riding away on one of the bandit s horses',
#   0],
#  ['It turns out  Peter Piper sneaked out of the house and waited in the yard  while the Prince was hiding behind the house',
#   0],
#  ['The bandits were very angry at', 0],
#  ['Franklin and took him with them while the Prince and Peter went safely going back to the Capital',
#   0],
#  ['A narrative text is an imaginative story to entertain people', 0],
#  ['Work with your partner', 0],
#  ['Ask your partner these questions', 0],
#  ['What is the meaning of friendship to you?', 0],
#  ['What would you do if your friend betrays you?', 0],
#  ['What would you do if one of your friends was in trouble?', 0],
#  ['Answer the following questions based on the story in', 0],
#  ['What kind of person was Prince Jonathan?', 0],
#  ['Who were Prince Jonathan s friends?', 0],
#  ['What happened when the Prince and his two friends were walking in the forest?',
#   0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['Why did Franklin try to persuade the Prince to surrender?', 0],
#  ['What did Peter Piper do when Franklin tried to persuade the Prince to surrender?',
#   0],
#  ['Why did Franklin sneak out to meet the bandits  leader?', 0],
#  ['Did the Prince manage to escape from the bandits?', 0],
#  ['After you read the story  what did you think of the', 0],
#  ['Prince s friends?', 0],
#  ['Decide whether these statements are true  T  or false  F ', 0],
#  ['The young Prince was hated by his people', 0],
#  ['The young Prince was kind to others', 0],
#  ['The Prince had two best friends', 0],
#  ['Both of the Prince s friends were rich people', 0],
#  ['When the bandits attacked  they hurried back to the castle', 0],
#  ['The Prince and his friends hid in an old house', 0],
#  ['The Prince didn t want to surrender', 0],
#  ['Franklin made an agreement with the bandits', 0],
#  ['The bandits managed to enter the house by breaking the front door', 0],
#  ['The Prince and Peter managed to escape but Franklin didn t', 0],
#  ['Complete this paragraph with the past tense of the verbs in the box', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Once upon a time  two bandits  an old lady', 0],
#  ['near the old bridge over the river', 0],
#  ['The robbery  shopping and  toward the', 0],
#  ['The old lady  bridge', 0],
#  ['When she was near the bridge  two bandits', 0],
#  ['toward her and  her purse', 0],
#  ['and they it', 0],
#  ['Then  they through the forest', 0],
#  ['Find the words that go together', 0],
#  ['to knock to iron to keep to join to perform to play to accept to be to bake to answer',
#   0],
#  ['one s word a club a play clothes at the door in love bread an instrument the questions an invitation',
#   0],
#  ['G r a m m a r Stage', 0],
#  ['Simple Past Tense  Regular Verbs', 0],
#  ['Simple Past Tense is used to describe an event that happened and ended in the past',
#   0],
#  ['Regular verbs form their past tense by adding  d or  ed to the base form',
#   0],
#  ['Observe the following examples', 0],
#  ['Mantu lived in a village deep in the jungle', 0],
#  ['They moved to a bigger house', 0],
#  ['We loved him very much', 0],
#  ['The form of simple Past Tense is', 0],
#  ['Subject   Verb   ed    Object', 0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['Change the following regular verbs into their past forms', 0],
#  ['lie describe cry try stop prefer like control manage look', 0],
#  ['Change the words in the brackets into simple past form', 0],
#  ['I  stay  there for an hour', 0],
#  ['The singer  sing   ve new songs at the concert last week', 0],
#  ['My sister  have  four Barbie dolls', 0],
#  ['But now she has none', 0],
#  ['AC Milan  win  the Champions League in ', 0],
#  ['Mother  buy  me a new pair of shoes', 0],
#  ['Mr Hartawan  become  the president of the company when he was  years old',
#   0],
#  ['In this section  you will learn how to', 0],
#  ['write a good narrative text', 0],
#  ['write the characteristics of narrative text', 0],
#  ['After learning the lesson in this section  you are expected to be able to',
#   0],
#  ['write a good narrative text correctly', 0],
#  ['write the characteristics of narrative text correctly', 0],
#  ['Answer the following questions', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Have you ever written a story?', 0],
#  ['Have you ever tried to write a story in English?', 0],
#  ['Read the following story', 0],
#  ['Mantu s Little Elephant', 0],
#  ['Source   Bedtime Stories', 0],
#  ['Little Mantu lived in a village deep in the jungle where elephants helped the men with their work',
#   0],
#  ['These elephants were so big and strong', 0],
#  ['They could lift up the heaviest logs with their trunks and toss them high in the air',
#   0],
#  ['Now  Mantu had an elephant of his very own', 0],
#  ['His name was Opie', 0],
#  ['He was just a baby and Mantu loved him very much', 0],
#  ['Mantu whispered to Opie s ear that someday he would become the biggest  strongest and bravest elephant in the jungle',
#   0],
#  ['The other elephants heard this', 0],
#  ['They began to laugh and made rude noises with their trunks', 0],
#  ['We re so big and tall  but you re so small', 0],
#  ['You re nothing at all   said one of the big elephants', 0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['Mantu looked up at the huge elephant with a mishievous glint in his eye',
#   0],
#  ['You re so tall and can see far away', 0],
#  ['We can see what is happening down here in the jungle', 0],
#  ['In fact  we would be the  rst to see any slithering snakes that may be a danger',
#   0],
#  ['After hearing the word snakes  the elephants screeched and off they gwents thundering in fright',
#   0],
#  ['Did I say there were snakes?  giggled Mantu', 0],
#  ['I don t think so   smiled Opie', 0],
#  ['Mantu then climbed upon his little friend s back and went home to the village to tell everyone about the foolish elephants',
#   0],
#  ['Adapted from   Bedtime Stories', 0],
#  ['Narrative is to amuse  entertain and to deal with an actual or vicarious experience in different ways',
#   0],
#  ['Narrative deals with problematic events which lead to a crisis or turning point of some kind  which in turn',
#   0],
#  ['nds a resolution', 0],
#  ['It is about the opening paragraph where the characters of the story are introduced',
#   0],
#  ['Example   Little Mantu lived in a village deep in the jungle where elephants helped the men with their work',
#   0],
#  ['Where the problems in the story developed', 0],
#  ['Example   Now  Mantu had an elephant of his very own', 0],
#  ['His name was Opie', 0],
#  ['Where the problems in the story is solved', 0],
#  ['Example   Mantu then climbed upon his little friend s back and went home to the village',
#   0],
#  ['Answer the following questions', 0],
#  ['Where did Little Mantu live?', 0],
#  ['Who was his best friend?', 0],
#  ['What did Mantu whisper in Opie s ear?', 0],
#  ['What made the huge elephant run away?', 0],
#  ['Rewrite the story in Practice  with your own words', 0],
#  ['Share it with the class', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Arrange these paragraphs into a good story', 0],
#  ['The Singer and the Dolphin', 0],
#  ['These are some tips on being a good friend', 0],
#  ['Treat your friends the way you want to be treated', 0],
#  ['Keep secrets that are told to you', 0],
#  ['Pay attention when your friend is talking', 0],
#  ['Keep your promises', 0],
#  ['Share things with your friend', 0],
#  ['Source   Fairy Tales and More', 0],
#  ['Arion did not put up a struggle  instead he asked only that he be allowed to sing one last song',
#   0],
#  ['His wish was granted and the sailors were so enchanted by his voice that they were hardly aware of what happened next',
#   0],
#  ['At the  rst notes of his song  a dolphin swam alongside  attracted by the beautiful music',
#   0],
#  ['Immediately Arion jumped overboard onto the dolphin s back and was carried back across the sea',
#   0],
#  ['In memory of this event  a statue  of a young man on the back of a dolphin  was erected in the port of',
#   0],
#  ['This statue is still there today', 0],
#  ['Arion was one of the most famous singers in the ancient world', 0],
#  ['On one occasion he won an important festival in Sicily  and as his prize he received so many jewels and golden cups that he was obliged to hire a ship to carry them all home to Corinth',
#   0],
#  ['When the ship  nally reached port in Corinth  the wicked sailors began to tell everyone that there had been a storm  during which the famous singer had been lost at sea',
#   0],
#  ['They were struck dumb with amazement  however  when Arion arrived with a company of soldiers to arrest them',
#   0],
#  ['Unfortunately  this huge treasure made the sailors very jealous  and in order to have it for themselves  they attacked the singer and were about to throw him overboard',
#   0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['Work in pairs and study the following picture', 0],
#  ['Write a narrative story that is suitable for the picture', 0],
#  ['Source  mysparkling. les.wordpress.com', 0],
#  ['Write a narrative story of your own', 0],
#  ['Use the following clues to help you', 0],
#  ['Decide where the story is begun', 0],
#  ['Create some characters for good and bad side', 0],
#  ['Create the story con ict', 0],
#  ['Give the solution how the story is ended', 0],
#  ['Retell the story you have arranged with your own words', 0],
#  ['Share it with your friends', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['The Friend Test', 0],
#  ['Below are three questions that will tell you', 0],
#  ['what kind of friend you are.  Answer these questions with your friend', 0],
#  ['Remember that each answer has a point', 0],
#  ['If you have  nished  look at the results part for your score', 0],
#  ['After you finish  check your answers on the next page  then match your score with the descriptions given',
#   0],
#  ['Source  ayiedyary. les.wordpress', 0],
#  ['If your friend tells you a secret that isn t bad but you promised not to tell anyone  do you',
#   0],
#  ['A   tell everyone?', 0],
#  ['B   keep the promise?', 0],
#  ['If you know your friend is planning to cheat on a test  do you', 0],
#  ['A   tell your teacher?', 0],
#  ['B   let your friend cheat?', 0],
#  ['C   help your friend study for the test so he she won t feel he she needs to cheat?',
#   0],
#  ['If your friend tells you a secret and it may be dangerous for him  her  do you',
#   0],
#  ['A   tell a trusted adult?', 0],
#  ['B   keep it a secret?', 0],
#  ['C   tell your friends?', 0],
#  ['Check your answer', 0],
#  ['If your score is', 0],
#  ['It means that you are a best friend', 0],
#  ['You know how to act like a true friend', 0],
#  ['Remember that a friend in need is a friend indeed', 0],
#  ['If your score is  or', 0],
#  ['It means that you are merely just a friend because you have some feeling of apathy towards your friend',
#   0],
#  ['If your score is  or', 0],
#  ['It means that you have to change yourself  because you don t have any feelings at all towards your friend',
#   0],
#  ['Remember if you want to make lots of friends  just treat them the way you want to be treated',
#   0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['What can I do for you?', 0],
#  ['May I help you?', 0],
#  ['Giving and refusing opinions', 0],
#  ['In my opinion ', 0],
#  ['Genre of text  Narrative', 0],
#  ['Social function  To amuse  entertain and to deal with actual or vicarious experiences in different ways',
#   0],
#  ['orientation  sets the scene and introduces the participants', 0],
#  ['evaluation  optional   a step back to evaluate the plight', 0],
#  ['complication  a crisis arises', 0],
#  ['resolution  the crisis is resolved  for better or worse', 0],
#  ['Once upon a time there lived two best friends  the hare and the tortoise',
#   0],
#  ['Grammar  Simple Past Tense   Regular Verbs', 0],
#  ['Mantu lived in a village deep in the jungle', 0],
#  ['They moved to a bigger house', 0],
#  ['L earning Review', 0],
#  ['After studying all subjects in this chapter  answer the following questions',
#   0],
#  ['What will you say to give an opinion?', 0],
#  ['What will you say if you want to ask for an opinion?', 0],
#  ['What do you say to ask for help?', 0],
#  ['What will you say if you want to give help to someone?', 0],
#  ['What will you say if someone offers you help and you want to reject it?',
#   0],
#  ['What do you say to ask for an item or something from someone?', 0],
#  ['What do you say to offer an item to someone?', 0],
#  ['What will you say if you want to give an item to someone?', 0],
#  ['What do you say to ask for someone s agreement?', 0],
#  ['What will you say if you want to give an agreement?', 0],
#  ['If you  nd some dif culties while answering the questions  you can learn the subjects once more or you may consult your teacher',
#   0],
#  ['English in Focus for Grade VIII', 0],
#  ['Source  Stockbyt e', 0],
#  ['Materials You Are Going to Learn in This Chapter', 0],
#  ['Listening to the expressions for starting  extending  and ending a conversation on the phone',
#   0],
#  ['Listening to the expressions for giving attention to the speaker', 0],
#  ['Listening to a recount text', 0],
#  ['Listening to a short functional text in the form of diary', 0],
#  ['Responding to a recount text', 0],
#  ['Starting  extending  and ending a conversation on the phone', 0],
#  ['Giving attention to the speaker', 0],
#  ['Reading aloud a recount text', 0],
#  ['Identifying characteristic of a recount text', 0],
#  ['Writing a recount text', 0],
#  ['Writing a short functional text in the form of letter', 0],
#  ['In this section  you will learn how to', 0],
#  ['listen to the expressions for starting  extending  and ending a conversation on the phone',
#   0],
#  ['listen to the expressions for giving attention to the speaker', 0],
#  ['listen a recount text', 0],
#  ['listen a short functional text in the form of diary', 0],
#  ['After learning the lesson in this section  you are expected to be able to',
#   0],
#  ['listen to the expressions for starting  extending  and ending a conversation on the phone',
#   0],
#  ['listen to the expressions for giving attention to the speaker', 0],
#  ['listen a recount text', 0],
#  ['Answer these questions', 0],
#  ['What will you say to start a conversation?', 0],
#  ['If your friend looks sick  what do you say to show your attention?', 0],
#  ['Listen to the dialogue from the tape and  ll in the blanks', 0],
#  ['Saskia is seeing her doctor to talk about her condition', 0],
#  ['Saskia   Good afternoon  Doctor', 0],
#  ['Please sit down', 0],
#  ['Tell me what s your problem?', 0],
#  ['Saskia   Well  it  yesterday  Doctor', 0],
#  ['I had a fever and headache all day', 0],
#  ['Doctor   OK  let me  you  rst', 0],
#  ['After a while ', 0],
#  ['Saskia   So  doctor  how is it?', 0],
#  ['Doctor   It s  serious', 0],
#  ['You ve caught a cold', 0],
#  ['I suggest you to take a rest tomorrow and don t drink some cold', 0],
#  ['You may not eat fried food also for a while', 0],
#  ['Saskia   All right  Doctor', 0],
#  ['Whatever you say', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Work with your partners', 0],
#  ['Identify the expressions of giving advice in the dialogue in Practice ', 0],
#  ['Pronounce It!', 0],
#  ['fi v  r', 0],
#  ['z m n', 0],
#  ['Work with your partner', 0],
#  ['Look at the picture  then  answer these questions', 0],
#  ['Where do you think the boy in the picture is?', 0],
#  ['What happened to the boy?', 0],
#  ['What treatment does he have?', 0],
#  ['Listen to your teacher reading the following dialogue', 0],
#  ['May I speak to Eric?', 0],
#  ['This is Eric', 0],
#  ['Who s speaking?', 0],
#  ['This is Andre', 0],
#  ['I just want to tell you that I can t go the bookstore with you today', 0],
#  ['Tell me what s wrong?', 0],
#  ['Well  my brother is being treated in the hospital for dengue fever', 0],
#  ['So I have to stay in the hospital today', 0],
#  ['Oh I m sorry to hear that', 0],
#  ['I hope your brother will get well soon', 0],
#  ['I hope so', 0],
#  ['Listen to some questions from the tape about the dialogue in Practice ', 0],
#  ['Listen to your teacher reading a text', 0],
#  ['Work with your partner to complete the text', 0],
#  ['My name is Andre', 0],
#  ['I am fourteen years old', 0],
#  ['I have a little brother', 0],
#  ['His name is Andy', 0],
#  ['He is four years younger than me', 0],
#  ['Two days ago Andy had a', 0],
#  ['My mother tried to lower the fever by giving him some', 0],
#  ['However  the next day  his fever had still not gone down', 0],
#  ['So she took Andy to the', 0],
#  ['In the hospital  the doctor', 0],
#  ['he said that Andy had', 0],
#  ['My mother was very worried  my father tried to calm her down because', 0],
#  ['Andy s  was not very bad', 0],
#  ['There is still hope   said the doctor to my mother', 0],
#  ['Every day  the doctor', 0],
#  ['Andy and gave him the proper  and medicine', 0],
#  ['Finally a week after  Andy s fever had gone down', 0],
#  ['The doctor told us that the critical time had passed and Andy could go home as soon as possible',
#   0],
#  ['English in Focus for Grade VIII', 0],
#  ['Listen to the text in Practice  once again', 0],
#  ['Then  answer these questions', 0],
#  ['How old is Andre?', 0],
#  ['What is Andre s little brother s name?', 0],
#  ['How old is Andy s brother?', 0],
#  ['When did Andy get fever?', 0],
#  ['What did Andy s mother do?', 0],
#  ['What did the doctor say about Andy?', 0],
#  ['What did the doctor do to cure Andy?', 0],
#  ['What do you think we should do to prevent dengue fever?', 0],
#  ['Listen to your teacher reading Beni s diary', 0],
#  ['When I got up  I felt ill  I went back to bed', 0],
#  ['Mum called the doctor', 0],
#  ['But he couldn t come  because he was ill  too', 0],
#  ['The doctor came at  o clock', 0],
#  ['He wrote a prescription for some medicine', 0],
#  ['Mum bought it in the drugstore', 0],
#  ['It was horrible', 0],
#  ['Dad bought me a model aeroplane', 0],
#  ['I read the instructions  but I couldn t make it  because the dog ate the glue',
#   0],
#  ['Mum took the dog to the vet', 0],
#  ['I took my medicine again', 0],
#  ['Listen to some questions about Beni s diary', 0],
#  ['Then choose a  b  c  or d for the correct answer', 0],
#  ['He was ill', 0],
#  ['He called the doctor', 0],
#  ['He went back to bed', 0],
#  ['His mum came to his house', 0],
#  ['The doctor was away', 0],
#  ['The doctor was sick', 0],
#  ['The doctor was busy', 0],
#  ['The doctor was on the way', 0],
#  ['The doctor wrote a prescription', 0],
#  ['The doctor came to Beni s house', 0],
#  ['The doctor went to the shop', 0],
#  ['The doctor bought him some medicines', 0],
#  ['From his mother', 0],
#  ['From his father', 0],
#  ['From his grandfather', 0],
#  ['From his doctor', 0],
#  ['Pay attention to the dialogues', 0],
#  ['When did they happen according to the Practice ?', 0],
#  ['I feel ill', 0],
#  ['Go back to bed  then', 0],
#  ['Good morning  Doctor', 0],
#  ['Don t eat that  you stupid dog!', 0],
#  ['Where are you going  Mum?', 0],
#  ['I m taking the dog to the vet', 0],
#  ['Here you are  Ben', 0],
#  ['You can make your aeroplane', 0],
#  ['Come on  Bento', 0],
#  ['It s good for you', 0],
#  ['Can you write a letter for school  please?', 0],
#  ['Follow up Activity', 0],
#  ['Write your daily activities for the next month in a diary', 0],
#  ['Write down the interesting things that happen everyday', 0],
#  ['Share your interesting memories that happen during the in a month with your friends',
#   0],
#  ['English in Focus for Grade VIII', 0],
#  ['In this section  you will learn how to', 0],
#  ['retell a recount text', 0],
#  ['use the expressions for starting  extending  and ending a conversation on the phone',
#   0],
#  ['use the expressions for giving attention to the speaker', 0],
#  ['After learning the lesson in this section  you are expected to be able to',
#   0],
#  ['retell a recount text', 0],
#  ['understand how to start  extend  and end a conversation on the phone', 0],
#  ['understand how to give attention to the speaker', 0],
#  ['Act the dialogues with your friend', 0],
#  ['Polo  can you help me  please?', 0],
#  ['Sure! What s wrong  Ane? You look sick', 0],
#  ['I ve got a headache  and my body feels cold', 0],
#  ['What? Here  I have a thermometer', 0],
#  ['Let me check your temperature', 0],
#  ['You have a fever  your temperature is quite high', 0],
#  ['I suggest you to see a doctor', 0],
#  ['Coky  can you do me a favour  please?', 0],
#  ['Coky   Of course  what can I do for you?', 0],
#  ['Could you buy some medicine for me? I m not feeling well', 0],
#  ['Coky   I think you ve caught cold', 0],
#  ['Don t worry', 0],
#  ['I ll buy you some medicine', 0],
#  ['Answer the following questions based on the dialogues', 0],
#  ['What happen to Ane in dialogue ?', 0],
#  ['What does Polo do for Ane?', 0],
#  ['What does Coky do for Yeni?', 0],
#  ['These expressions can be used to give attention to someone', 0],
#  ['Tell me what s wrong?', 0],
#  ['It s okay', 0],
#  ['Don t worry', 0],
#  ['Would you like any help?', 0],
#  ['You look in trouble  may I help you  Sir Ma am?', 0],
#  ['to older people or a stranger', 0],
#  ['Complete these dialogues using your own words', 0],
#  ['You ask your friend to come inside your home', 0],
#  ['Your friend feels so sick', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['It s raining heavily outside', 0],
#  ['I feel so sick', 0],
#  ['Practise the following monologue', 0],
#  ['I went to Rahman s house yesterday to do homework', 0],
#  ['I went there with Dodi', 0],
#  ['After  nishing the homework  Rahman made rujak', 0],
#  ['Rahman likes spicy food  so he made it very spicy', 0],
#  ['Actually  I am not used to eating spicy food  but yesterday I could not restrain myself from eating it',
#   0],
#  ['The rujak was very tasty  although it was spicy', 0],
#  ['I ate it too much', 0],
#  ['The next morning I got stomachache and I could not go to school', 0],
#  ['Answer the following questions orally', 0],
#  ['When did the writer go to Rahman s house?', 0],
#  ['Why did the writer go to there?', 0],
#  ['Whom did the writer go with?', 0],
#  ['Who made rujak?', 0],
#  ['Why did the writer not go to school the next morning?', 0],
#  ['Write your own story about bad experience', 0],
#  ['Retell it to your friend', 0],
#  ['Follow the clues below to start arranging your story', 0],
#  ['Remember your most unforgetable bad experience in the past', 0],
#  ['Tell your friend when  where  how it was happened', 0],
#  ['Tell how you can get through the problem', 0],
#  ['What was the moral from your bad experience?', 0],
#  ['Look at the pictures and answer the following questions', 0],
#  ['I see you later', 0],
#  ['Hello  how are you?', 0],
#  ['What are the two people in the pictures doing?', 0],
#  ['What do you think they say to start the conversation?', 0],
#  ['What do you think they say to end the conversation?', 0],
#  ['Act out the following phone conversation with your friend', 0],
#  ['Pay attention to the expressions in italics', 0],
#  ['Yeyen   Hello  Mia', 0],
#  ['This is Diane', 0],
#  ['May I speak to Andre', 0],
#  ['Mia   I m sorry but he s gone out', 0],
#  ['Would you like to leave a message?', 0],
#  ['Please tell Viktor that I won t be able to come for taekwondo practice this afternoon',
#   0],
#  ['I ve sprained my ankle', 0],
#  ['Please tell him to inform Mr Suroso that I can t have the practice for at least a week',
#   0],
#  ['Mia   Oh  I m sorry to hear that', 0],
#  ['I hope your ankle gets better soon', 0],
#  ['Yeyen   Thank you  Mia', 0],
#  ['Mia   Hold on  please', 0],
#  ['Have you seen a doctor?', 0],
#  ['Yeyen   I haven t', 0],
#  ['I don t think it s that bad', 0],
#  ['Mia   I think you d better go to the doctor to check your ankle', 0],
#  ['Yeyen   Thanks for the advice  Mia', 0],
#  ['See you then', 0],
#  ['Mia   You re welcome', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['You can use the expressions to start a conversation on phone', 0],
#  ['Can I speak to ', 0],
#  ['May I speak to ', 0],
#  ['You can use the expressions to extend a conversation on phone', 0],
#  ['Hold on  please', 0],
#  ['By the way', 0],
#  ['You can use the expressions to end a conversation', 0],
#  ['See you then', 0],
#  ['I ll call you later', 0],
#  ['See you again  Sir Ma am', 0],
#  ['Thank you very much', 0],
#  ['to older people or a stranger', 0],
#  ['to older people or a stranger', 0],
#  ['to older people or a stranger', 0],
#  ['Work in pairs', 0],
#  ['Make and practise a phone conversation', 0],
#  ['Use some of the expressions you have just studied', 0],
#  ['G r a m m a r Stage', 0],
#  ['Study the following example', 0],
#  ['Tom has just come back from a music concert', 0],
#  ['His sister  Nina  asks about the concert', 0],
#  ['Nina   Hi  Tom', 0],
#  ['How was the concert?', 0],
#  ['Tom   Hi  Nina', 0],
#  ['Yes  it was great', 0],
#  ['You should go and see their second performance', 0],
#  ['Nina   Wow  really? I ll go and see it then', 0],
#  ['Tom gives advice to Nina to go and see the concert', 0],
#  ['You should go means that it would be a good thing to do', 0],
#  ['We use should  do  when we say what we think it is a good thing to do or the right thing to do',
#   0],
#  ['Give the advice to your friends based on the situation given', 0],
#  ['Use should or shouldn t', 0],
#  ['Your friend is always coughing because he drinks ice too much', 0],
#  ['Advise him to stop drinking ice', 0],
#  ['Your friend has a bad toothache', 0],
#  ['Advise him to go to the dentist as soon as possible', 0],
#  ['In this section  you will learn how to', 0],
#  ['read aloud a recount text', 0],
#  ['identify characteristics of a recount text', 0],
#  ['After learning the lesson in this section  you are expected to be able to',
#   0],
#  ['read aloud a recount text correctly', 0],
#  ['identify characteristics of a recount text correctly', 0],
#  ['Look at the picture and answer the questions', 0],
#  ['Discuss with your partner', 0],
#  ['Then continue to read the following text', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Do you know who Louis Pasteur was?', 0],
#  ['What was his nationality?', 0],
#  ['What did Louis Pasteur do to improve medical science?', 0],
#  ['My Personal Experience', 0],
#  ['Check this web site to get information about health  medicine  and disease',
#   0],
#  ['www.dechacare.com info sehat.com', 0],
#  ['When I was in junior high school  I was not a very diligent student', 0],
#  ['In fact  I was quite lazy', 0],
#  ['I hated all the subjects that I took during school  especially science', 0],
#  ['For me science was very dif cult', 0],
#  ['It was hard for me to remember the chemical processes  physics calculations  and biological processes',
#   0],
#  ['Once  my teacher grounded me in the library because I did not do my Biology homework',
#   0],
#  ['The teacher asked me to read several books and make a summary about them',
#   0],
#  ['When I was browsing the shelves  I found a book entitled  The inventors of Medicine',
#   0],
#  ['OK  this is a start', 0],
#  ['I took it out then began reading it', 0],
#  ['I learned from the book about Edward Jenner', 0],
#  ['He was an English doctor who found the cure for smallpox', 0],
#  ['The next one was Louis Pasteur', 0],
#  ['His interest in bacteria led him to discover the treatments for rabies and anthrax',
#   0],
#  ['Just like Pasteur  Robert Koch s experiments on bacteria also proved that tuberculosis can be spread to others by contact',
#   0],
#  ['Finally  there was Alexander Flemming  a', 0],
#  ['British bacteriologist who found the  rst antibiotic and penicillin', 0],
#  ['After I read the book  I realised that science is useful for human kind',
#   0],
#  ['By studying  we can discover things that can help human kind', 0],
#  ['Therefore  since that moment', 0],
#  ['I managed to change my behaviour and became a doctor', 0],
#  ['Read the text in Practice  again', 0],
#  ['Then  answer the following questions', 0],
#  ['When did the story take place?', 0],
#  ['Was the writer a diligent student?', 0],
#  ['What lessons did the writer hate?', 0],
#  ['What was the title of the book that the writer read?', 0],
#  ['Who were mentioned in the book? Who were they?', 0],
#  ['What happened to the writer after he read the book?', 0],
#  ['Characteristics of Recount Text', 0],
#  ['A recount text is a text that telling the reader about one story  action or activity',
#   0],
#  ['Its goal is to entertaining or informing the reader', 0],
#  ['Orientation tells who was involved  what happened  where the events took place  and when it happened',
#   0],
#  ['Example   When I was in junior high school  I was not a very diligent student',
#   0],
#  ['English in Focus for Grade VIII', 0],
#  ['Decide whether these statements are true  T  or false  F ', 0],
#  ['Events  event  and   tell what happened and in what sequence', 0],
#  ['Example   Once  my teacher grounded me in the library because I did not do my Biology homework',
#   0],
#  ['Reorientation consists of optional closure of events  ending', 0],
#  ['Example   After I read the book  I realised that science is useful for human kind',
#   0],
#  ['The features are including Who? Where? When?', 0],
#  ['Why?  noun or pronoun  and past tense', 0],
#  ['Examples   I  at home  last night  a book  I took', 0],
#  ['The writer was a lazy student when he was in junior high school', 0],
#  ['The writer was grounded because he didn t do his', 0],
#  ['The writer was told to make a book review', 0],
#  ['He looked for the books in a bookstore', 0],
#  ['He found a book about medical health', 0],
#  ['Read aloud the following text after your teacher', 0],
#  ['Pay attention to his her punctuation  wordstress and pause', 0],
#  ['My Football Experience', 0],
#  ['When I was in junior high school  I really loved football', 0],
#  ['Every Saturday afternoon I practised in school  eld with my team and my coach',
#   0],
#  ['They were strong and smart players', 0],
#  ['My coach  Mr Sentana was a kind person', 0],
#  ['But  while he was coaching us  he was very discipline', 0],
#  ['He would grounded anyone who came late and not obeyed the team s rules', 0],
#  ['With Mr Sentana  our team won many tournament in many big cities', 0],
#  ['Our team named after our school', 0],
#  ['Team  from SMP   and we had many fans too  you know', 0],
#  ['Ohh  that was so cool', 0],
#  ['Now  I still love football and have a team too', 0],
#  ['But  my parents warn me to pay attention more to my study  football just for hobby',
#   0],
#  ['Work in pairs', 0],
#  ['Identify the characteristics of the text in Practice ', 0],
#  ['How many diseases can you  nd? Do this in your exercise book', 0],
#  ['Read the following words after your teacher', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['cough headache diabetes smallpox measles malaria fever cancer', 0],
#  ['da   bi ti z', 0],
#  ['sm  lp k', 0],
#  ['m  le r', 0],
#  ['In this section  you will learn how to', 0],
#  ['follow the stages of writing a recount text', 0],
#  ['write a short functional text', 0],
#  ['After learning the lesson in this section  you are expected to be able to',
#   0],
#  ['understand and write a recount text', 0],
#  ['understand and write a short functional text', 0],
#  ['Answer these following questions', 0],
#  ['Have you ever written a letter?', 0],
#  ['Have you ever written a letter about an experience?', 0],
#  ['Do you have a penpal?', 0],
#  ['Study the dialogue and the letter', 0],
#  ['I was in bed for three days', 0],
#  ['I had  u', 0],
#  ['You weren t at school last week  Andrew', 0],
#  ['Were you ill?', 0],
#  ['What was the matter?', 0],
#  ['Are you all right now?', 0],
#  ['Yes  thank you', 0],
#  ['Here s a letter from my mum', 0],
#  ['Jalan Genuk Krajan', 0],
#  ['Dear Miss Titik', 0],
#  ['Andra wasn t at school last week  because he was ill', 0],
#  ['He had  u', 0],
#  ['Here some letters from the students  parents', 0],
#  ['Dear Miss Titik', 0],
#  ['Selina wasn t at school yesterday  because she was at the dentist', 0],
#  ['She had a toothache', 0],
#  ['Dear Miss Titik', 0],
#  ['Benu wasn t at school last Friday  because he was ill', 0],
#  ['He had a temperature and a sore throat', 0],
#  ['Answer the questions based on the dialogue and the letter', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Who wasn t at school last week?', 0],
#  ['Was he ill last week?', 0],
#  ['What was the matter with him?', 0],
#  ['Is he ill now?', 0],
#  ['Who wrote the letter for Miss Titik?', 0],
#  ['Do this project', 0],
#  ['Classroom Survey  Illness', 0],
#  ['Make a project on medicine', 0],
#  ['Here s your  rst task', 0],
#  ['Find out who wasn t at school in your group last week because they were ill',
#   0],
#  ['No  I wasn t', 0],
#  ['Were you at school on Wednesday', 0],
#  ['Write about your group', 0],
#  ['Tuesday Wednesday Thursday', 0],
#  ['Report the results of your survey in front of the class', 0],
#  ['Do the following project', 0],
#  ['Was anyone ill in your group last week?', 0],
#  ['Write their letter to the teacher', 0],
#  ['Stick it into your Project book', 0],
#  ['Study the following example of a letter', 0],
#  ['orientation orientation event', 0],
#  ['Hello Paula  how are you? It s been a month since I last heard from you',
#   0],
#  ['Well  I just wanted to tell you that I was in a hospital last week', 0],
#  ['According to the doctor  I was infected by dengue fever', 0],
#  ['At  rst  I felt my body became weak then I fainted when I was studying in the classroom',
#   0],
#  ['Then  I was taken to the hospital because of the high fever', 0],
#  ['At the hospital  I was brought into the emergency unit', 0],
#  ['The doctor immediately gave some treatment', 0],
#  ['Finally  I had to stay there for one week', 0],
#  ['Everyday the doctor kept me on a drip', 0],
#  ['At the seventh day  my condition was getting better', 0],
#  ['After the  nal check  the doctor gave me permission to go home', 0],
#  ['Now  I m okay and because of my illness  I am now more careful about keeping in my house clean especially my room  I don t want to get the same illness again',
#   0],
#  ['OK  I think that s all from me  write to me soon ok?', 0],
#  ['Orientation  Information about what  who  where  or when written in a letter',
#   0],
#  ['Events  Events that happened in the past', 0],
#  ['They are conveyed in a sequential pattern', 0],
#  ['Closing  a conclusion on the events', 0],
#  ['Write a letter in the form of recount about your past experience when you were ill or when you were treated in a hospital',
#   0],
#  ['English in Focus for Grade VIII', 0],
#  ['Enrich Your Knowledge', 0],
#  ['These are the things that you can  nd in', 0],
#  ['a First Aid Kit box', 0],
#  ['adhesive tape bandage tweezers cotton', 0],
#  ['antiseptics scissors alcohol', 0],
#  ['Source  www. delux  rstaid.com', 0],
#  ['To cover wounds', 0],
#  ['To pick up things', 0],
#  ['To clean the wounds', 0],
#  ['To cut things', 0],
#  ['To apply antiseptic with', 0],
#  ['To cover wounds with antiseptics', 0],
#  ['To cure infections', 0],
#  ['Find out what they are used for', 0],
#  ['Copy and  ll in the following box into your exercise book', 0],
#  ['Name of Tool', 0],
#  ['If you encounter an emergency situation  you have to use the  rst aid kit to prevent further danger',
#   0],
#  ['Now  decide which things you have to use in order to prevent the following emergency situations',
#   0],
#  ['Your mother cuts herself when she is cutting the vegetables', 0],
#  ['Your little brother falls off his bicycle', 0],
#  ['One of your friends has a thorn slip inside one of his or her', 0],
#  ['A man s hand gets stuck in the door', 0],
#  ['Now his hand is bleeding', 0],
#  ['A boy has bruises on his knee because he hit his knee on the table', 0],
#  ['If I were you  I d ', 0],
#  ['if I were you', 0],
#  ['You d better not ', 0],
#  ['I wouldn t recommend ', 0],
#  ['Offering  accepting  and declining an offer', 0],
#  ['Would you like ...?', 0],
#  ['Not for me  thank you', 0],
#  ['Genre of text  Recount', 0],
#  ['Social function   to give the audience a description of what occurred and when it occurred to retell events for the purpose of informing or entertaining',
#   0],
#  ['Generic structure  orientation  the setting and introduce participants events in time order  tell what happened  in what sequence reorientation  optional closure of events ending',
#   0],
#  ['I went to my Beni s house yesterday to do a homework', 0],
#  ['I went there with Dodi', 0],
#  ['Grammar  Modal s  should', 0],
#  ['Nina   Hi  Tomi', 0],
#  ['How was the concert?', 0],
#  ['Tomi   Hi  Nina', 0],
#  ['Yes  it was great', 0],
#  ['You should go and see their second performance', 0],
#  ['Nina   Wow  really? I ll go and see it then', 0],
#  ['L earning Review', 0],
#  ['After studying all subjects in this chapter  answer the following questions',
#   0],
#  ['What have you learnt in this chapter?', 0],
#  ['What do you say to start a conversation on the phone?', 0],
#  ['What do you say to extend a conversation on the phone?', 0],
#  ['What will you say if you want to end a conversation on the phone?', 0],
#  ['What will you say if you want to give attention to the speaker?', 0],
#  ['If you  nd some dif culties while answering the questions  you can learn the subjects once more or you may consult your teacher',
#   0],
#  ['English in Focus for Grade VIII', 0],
#  ['Share Your Story', 0],
#  ['Materials You Are Going to Learn in This Chapter', 0],
#  ['Listening to the expressions for asking  giving  and denying information',
#   0],
#  ['Listening to the expressions for starting  extending  and ending a conversation',
#   0],
#  ['Listening to the narrative texts', 0],
#  ['Asking  giving  and denying information', 0],
#  ['Starting  extending  and ending a conversation', 0],
#  ['Responding to narrative monologue', 0],
#  ['Reading narrative text', 0],
#  ['Identifying characteristics of narrative text', 0],
#  ['Reading an advertisement', 0],
#  ['Writing a narrative text', 0],
#  ['Writing a short functional text in the form of weather chart', 0],
#  ...]

# %%
# read the grade ten file
grade_ten_sentence = read_and_clean("../data/gradesixis.txt")

# %%
label = 1
new_examples2 = []
for i in grade_ten_sentence:  
    if len(word_tokenize(i))>2:
        new_examples2 = new_examples2 + [[i, label]]

# %%
new_examples2 = new_examples2[18:]

# %%
new_examples2
# Out:
# [['Do you find any differences between As and Bs speakers?', 1],
#  ['A boy is carrying heavy bags', 1],
#  ['A  Can you help me  brother please?', 1],
#  ['A man needs someone to close the car s door', 1],
#  ['A  I wonder if you could close the door', 1],
#  ['Now look at the box below and check your answers', 1],
#  ['The first speakers   As   express situations to ask someone to do something  whereas the second speakers   Bs   express the agreement to do something',
#   1],
#  ['Study the rules below of asking someone to do something and their response',
#   1],
#  ['Can you   please?  the agreement for it is   certainly', 1],
#  ['I wonder if you could   ', 1],
#  ['the agreement is    Sure', 1],
#  ['Would you mind   v  ing?   the agreement is    Not at all', 1],
#  ['Could you   infinitive  ', 1],
#  ['please?  the agreement is   Of course', 1],
#  ['Work in pairs', 1],
#  ['Ask someone to do something and say the response', 1],
#  ['A  Can you open that window  please?', 1],
#  ['A  I wonder if you could open that window  please', 1],
#  ['B  No  of course not', 1],
#  ['A  Would you mind opening that window  please?', 1],
#  ['B  Not at all', 1],
#  ['A  Could you open that window  please?', 1],
#  ['B  Yes  of course', 1],
#  ['Now make similar situations', 1],
#  ['Ask someone to repair your broken car b', 1],
#  ['Ask someone to explain the meaning of a verse in the Quran', 1],
#  ['Ask someone to carry a sofa', 1],
#  ['Ask someone to clean my gun', 1],
#  ['Write similar dialogue as in  ask about the following situations  a', 1],
#  ['Ask someone to give you a lift b', 1],
#  ['Ask someone to explain the meaning of one of Mohammad s hadeeth', 1],
#  ['Ask someone to deliver the box to his neighbour', 1],
#  ['Before you start', 1],
#  ['What do you do when you have a flu?', 1],
#  ['Do you prefer herbal to chemical medicine?', 1],
#  ['Look at the pictures and match them with the health problems below  e.g',
#   1],
#  ['I have a headache', 1],
#  ['I burnt my hand on the heater', 1],
#  ['I need to sit down', 1],
#  ['My arms hurt', 1],
#  ['I lifted heavy boxes', 1],
#  ['I have muscles ache', 1],
#  ['I have a stomach ache', 1],
#  ['I have a sore throat', 1],
#  ['I have eaten too much  I feel sick', 1],
#  ['I feel dizzy', 1],
#  ['I can t stop sneezing  I think I ve caught a cold', 1],
#  ['I have a temperature  diarrhea and fever', 1],
#  ['Which health problems don t you find in the pictures?', 1],
#  ['What do you say to those people who are suffering from health problems?',
#   1],
#  ['A  I have a headache', 1],
#  ['B  You should take a painkiller', 1],
#  ['Now look at the problems in  and do similar dialogues', 1],
#  ['Look at the chart below and suggest the treatment for each diseases  make use of the treatment list below',
#   1],
#  ['Diseases the flu  influenza  a cold food poisoning', 1],
#  ['Symptoms cold  sneeze  headache etc', 1],
#  ['cough  fever  pain in muscles etc', 1],
#  ['vomit  headache  temperature etc', 1],
#  ['rest in bed', 1],
#  ['take a decongestant', 1],
#  ['drink herbal tea', 1],
#  ['eat very little food', 1],
#  ['eat fruit and vegetables', 1],
#  ['Add other diseases to the chart ', 1],
#  ['Have you ever had a medical problem? In no more than  words write a short story about that',
#   1],
#  ['Before you start', 1],
#  ['Have you ever had a food poisoning? What did you do?', 1],
#  ['Read this paragraph and fill in the blanks with the diseases from the box',
#   1],
#  ['If you have a stomach ache  nausea  and diarrhea  you may have', 1],
#  ['Rest in bed  drink herbal tea  and don t eat very much', 1],
#  ['If the symptoms continue  see your doctor', 1],
#  ['You need some antibiotics', 1],
#  ['The symptoms of                are often nausea  fever  and abdominal pain  especially on the right side',
#   1],
#  ['See a doctor immediately  because you may need surgery!              is a virus  so antibiotics won t help',
#   1],
#  ['The symptoms are aching muscles  headache  fever  and sometimes sneezing',
#   1],
#  ['Rest in bed  drink fluids  and take aspirin.             is similar to influenza  but usually less severe',
#   1],
#  ['The symptoms are usually sneezing  coughing  headache  and sometimes fever',
#   1],
#  ['If necessary  take a decongestant', 1],
#  ['is a type of headache  but there are usually less severe', 1],
#  ['The symptoms are usually other symptoms', 1],
#  ['You may have nausea and vision problems  and you may be extremely sensitive to light and noise',
#   1],
#  ['If the problem is very severe or frequent  you may need to see a doctor to get some medicine',
#   1],
#  ['Grammar builder   must  may  might  can t  for deductions', 1],
#  ['Note  For deduction  can t and must are opposites  e.g', 1],
#  ['It can t be appendicitis  so it must be food poisoning', 1],
#  ['Say the short dialogue and then answer the questions', 1],
#  ['A  I have a stomach ache', 1],
#  ['I might have appendicitis', 1],
#  ['B  You can t have appendicitis because you don t have a fever.it may be something you ate',
#   1],
#  ['A  If I m not better tomorrow  then it must be appendicitis', 1],
#  ['Which of the verbs  might  can t  may and must in the dialogue above expresses a possibility?',
#   1],
#  ['Which one expresses a strong positive probability?', 1],
#  ['Which one expresses a strong negative probability?', 1],
#  ['Complete these two conversations using may  might  must  or can t', 1],
#  ['A  Who is she? She talks like a doctor', 1],
#  ['But she            be a doctorshe s too young', 1],
#  ['B  She           be a medical student obviously', 1],
#  ['A  Not necessarily', 1],
#  ['She          be a nurse  or the daughter of a doctor', 1],
#  ['A  I can t sleep at night', 1],
#  ['It          be the coffee I m drinking  or possibly', 1],
#  ['I m worrying about work', 1],
#  ['B  It          be the worry  no question about it', 1],
#  ['How much coffee do you drink?', 1],
#  ['A  Two or three cups a day', 1],
#  ['That s nothing', 1],
#  ['It          be that', 1],
#  ['The Open University', 1],
#  ['Before you start', 1],
#  ['Is it possible to get Islamic Khlafa again?', 1],
#  ['How do Muslims feel towards Khil fah?', 1],
#  ['Read the text carefully and check your answers in', 1],
#  ['he revival of Khil fahh  which was announced by the spokesman for Islamic State  Sheikh Abu Mohammed Al Adnani on the first of',
#   1],
#  ['Ramadan  H  surprised the true Muslims and shocked the nonMuslims all over the world',
#   1],
#  ['eal announcement of Khil fah surprised the true Muslims positively and made the people inside the Waliyats of Islamic State feel pleased and proud whereas the Muslims outside the Islamic',
#   1],
#  ['State have become eager to immigrate to it', 1],
#  ['Because they have been under the rule of tawaghits since the collapse of Othmani Khil fah in',
#   1],
#  ['Now it is time for Real Islam  Sharia and Sunni  to take the ruling of', 1],
#  ['Islamic State over', 1],
#  ['The revival of Khil fah means we are walking towards the right path of satisfying Allah who orders us to leave all sorts of governing people except applying Sharia and Sunni',
#   1],
#  ['That is the true way to get happiness in both lives  here in the world and in the Day of',
#   1],
#  ['n the other side  the announcement of Khil fah shocked the nonMuslims  such as jews  Christians  rafiddah  other sorts of kufar and tawaghits negatively',
#   1],
#  ['All together announced their coalition publicly to fight the Islamic State',
#   1],
#  ['The big question is  WHY?', 1],
#  ['Because all of them deeply know that the path of applying Khil fah means the end of them altogether sooner or later',
#   1],
#  ['inally  it can be said that the revival of Khil fah amazed true', 1],
#  ['Muslims who were inside or outside the Islamic State whereas it upset and troubled the non Muslims all over the world',
#   1],
#  ['Read the text again and answer the questions below', 1],
#  ['Who announced the revival of Khil fah? b', 1],
#  ['How was the reaction of the announcement of Khil fah on both', 1],
#  ['Muslims and non Muslims? c', 1],
#  ['What does the revival of Khil fah mean? d', 1],
#  ['Do you think that applying Khil fah is the right way in life? e', 1],
#  ['Why are all the non Muslims and tawgheed afraid of the announcement of Khil fah?',
#   1],
#  ['Match the words with their meaning', 1],
#  ['an unexpected event  or the feeling caused by something unexpected happening',
#   1],
#  ['to fall down suddenly because of pressure or having no strength or support',
#   1],
#  ['when something becomes more active or popular again', 1],
#  ['wanting very much to do or have something  especially something interesting or enjoyable',
#   1],
#  ['a sudden  unexpected and usually unpleasant event or experience', 1],
#  ['Summarize the text of  The Announcement of Khil fah  in no more than', 1],
#  ['Fill in the blanks with words taken from the box  independent disabled a',
#   1],
#  ['of the students come from the country side', 1],
#  ['He was          in the accident', 1],
#  ['It is just a short                  from here to the university', 1],
#  ['A lot of               workers work in their factory', 1],
#  ['All lecturers are                  ', 1],
#  ['He left school with two              ', 1],
#  ['We wanted to create an           learner', 1],
#  ['Make a conversation asking someone to do something and show the agreement in these situations',
#   1],
#  ['ask someone to repair your bike b', 1],
#  ['ask someone to explain the meaning of one of the Messenger s hadeith  peace be upon him  c',
#   1],
#  ['ask someone to carry a heavy box d', 1],
#  ['ask someone to show you where to rent a car', 1],
#  ['Guess the illness! Make use of the words in the box below', 1],
#  ['food poisoning cold appendicitis', 1],
#  ['A  I have a temperature  diarrhea and fever', 1],
#  ['B  I think you ve got a              ', 1],
#  ['A  My stomach is aching too much', 1],
#  ['B  I think you ve got a             ', 1],
#  ['A  I can t stop sneezing  and I have a sore throat', 1],
#  ['B  I think you ve got a              ', 1],
#  ['Complete these two conversations using may  may not  might  might not must  or can t',
#   1],
#  ['You re expecting Ahmed to ring', 1],
#  ['The phone rings', 1],
#  ['There is a knock at the door', 1],
#  ['Your mother says it might be Ali  but you know Ali is on holiday', 1],
#  ['It             be Ali', 1],
#  ['Your brother is looking for his bag', 1],
#  ['You think it s possible that it s in the living room', 1],
#  ['It               be in the living room', 1],
#  ['They re speaking Arabic', 1],
#  ['They              be foreigners', 1],
#  ['Their bed room lights are off', 1],
#  ['They             be asleep', 1],
#  ['It s very cold here', 1],
#  ['The heating                be on', 1],
#  ['She s passed her driving test', 1],
#  ['She              be happy', 1],
#  ['fluency  n.  stomach ache  n.  sneeze  n.  painkiller  n.  symptoms  n.  poisoning  n.  appendicitis  n.  migraine  n.  decongestant  n.  nausea  n.  abdominal  adj.  qualifications  n.  impaired  adj.  respiratory  n.  circulation  n.  digestive  n.  nervous  adj.  sensory  adj.  detect  v.  sore throat  n.  foreigner  n',
#   1],
#  ['Reciting the Quran', 1],
#  ['Reciting the Quran', 1],
#  ['Importance of Second  Foreign', 1],
#  ['Fluency    Before you start', 1],
#  ['Don t mention it', 1],
#  ['When do you say a sentence like that?', 1],
#  ['The dialogue below is in wrong order', 1],
#  ['First  number it in the right order and then work in pairs', 1],
#  ['Big thank for you Mum a', 1],
#  ['Shopper  Thanks a lot', 1],
#  ['Shop assistant  How about Sahih Al Bukhari? c', 1],
#  ['Shop assistant  Can I help you  brother? Are you looking for something in particular?  d',
#   1],
#  ['Shopper  That s great idea', 1],
#  ['Thanks  can you wrap it for me?', 1],
#  ['Shop assistant  Don t mention it', 1],
#  ['Shopper  Yes  I am looking for a gift for my mother', 1],
#  ['I wonder if you could give me some ideas', 1],
#  ['Shop assistant  Well  what kind of things does she like? h', 1],
#  ['Shopper  She likes reading Islamic books', 1],
#  ['Shop assistant  I sure can', 1],
#  ['Check your answers in the box below', 1],
#  ['Turn it upside down', 1],
#  ['C  f  g  h  b  d  I  a  e', 1],
#  ['Check your answer in ', 1],
#  ['Answer the questions below', 1],
#  ['Is the previous dialogue formal or informal?', 1],
#  ['When do you say thank you? Tick the situation s  below', 1],
#  ['When you buy something in a store', 1],
#  ['When you get change in a shop', 1],
#  ['When you borrow your friend s pen', 1],
#  ['When your friend gives you back your book', 1],
#  ['When a waiter brings your food', 1],
#  ['When a waiter clears the table', 1],
#  ['When you get off the bus', 1],
#  ['When someone holds a door open for you', 1],
#  ['What does our Messenger say about thanking people?', 1],
#  ['If you don t say thank you  is there anything else you say? Does it vary according to the speaker s status or age?',
#   1],
#  ['There are many means of expressing  thanking  such as  a', 1],
#  ['Jazaka Allahu Khayrn', 1],
#  ['Islamic expression  b', 1],
#  ['Barak Allahu Feekum', 1],
#  ['Islamic Expression  c', 1],
#  ['Thanks a lot', 1],
#  ['That s very good of you', 1],
#  ['I appreciate it', 1],
#  ['Responding to thank', 1],
#  ['To respond to  thanking  we usually say  a', 1],
#  ['Jazakum Allah Aljanah', 1],
#  ['Islamic expression  b', 1],
#  ['Wafeekum Baraka Allah', 1],
#  ['Islamic expression  c', 1],
#  ['Don t mention it', 1],
#  ['All my pleasure', 1],
#  ['Assignment  Show how to thank someone in the situations below and the responses',
#   1],
#  ['A  Thank you very much for your help', 1],
#  ['B  Not at all', 1],
#  ['Now make use of the forms of thanking and response you learn in this lesson',
#   1],
#  ['Answer the question below', 1],
#  ['What do you say when  a', 1],
#  ['a shop assistant gives you your things you buy? b', 1],
#  ['you borrow a pen from your friend', 1],
#  ['your friend gets your book back? d', 1],
#  ['a waiter brings your food e', 1],
#  ['someone holds a door open for you?', 1],
#  ['Before you start', 1],
#  ['Do you want to go further on with your studies?', 1],
#  ['What are you going to study at university  if you go there?', 1],
#  ['Match the noun or the noun phrase to each of the following verbs  a', 1],
#  ['apply to attend enrol at obtain take study', 1],
#  ['There are five stages in the process of writing a paragraph', 1],
#  ['What does each stage mean? Study the details of each of five stages of writing a paragraph',
#   1],
#  ['Who is it for?', 1],
#  ['What is it about?', 1],
#  ['Where can I find more information?', 1],
#  ['What is the writing plan?', 1],
#  ['How many paragraphs do I need?', 1],
#  ['What information should be in each paragraph?', 1],
#  ['The first draft   writing for the writer himself', 1],
#  ['Does the first draft make sense?', 1],
#  ['Have I made any mistakes in spelling  grammar or word order?', 1],
#  ['Correct any mistakes', 1],
#  ['The final version of the paragraph   writing for the reader', 1],
#  ['Respond to the five stages of writing above and write a paragraph about joining a college you would like to',
#   1],
#  ['Write two forms of a paragraph  draft writing  write  and final writing',
#   1],
#  ['rewrite  about a topic you choose', 1],
#  ['Make use of stages of writing', 1],
#  ['Reciting the Quran', 1],
#  ['Before you start', 1],
#  ['Answer the questions below', 1],
#  ['What is the opposite of interesting? b', 1],
#  ['Is there a difference between', 1],
#  ['boring  and  bored ?', 1],
#  ['Read the text and write the adjectives which end with  ing  or', 1],
#  ['ed  in the chart below', 1],
#  ['Add similar adjectives from your own?', 1],
#  ['Every Muslim is interested in reciting the Quran', 1],
#  ['However  it is frustrating to find some people who are still away from reciting the',
#   1],
#  ['Therefore  we advise such people not to be frustrated because if they start reciting it  they ll find it very interesting',
#   1],
#  ['They ll never get bored with it', 1],
#  ['The best way of not being bored is to deeply recite the Quran now and then  because it makes you feel satisfied  convinced and relaxed',
#   1],
#  ['Read the text again and check your answers in ', 1],
#  ['Adjective ending   ing  or   ed', 1],
#  ['Adjectives ending  ing describe something that we are reacting to  outside us',
#   1],
#  ['In other word  they are used to describe the things or people that cause the feelings  e.g',
#   1],
#  ['My work was tiring', 1],
#  ['Adjectives ending   ed  describe our feelings and reactions', 1],
#  ['In other words  they talk about how we feel  e.g', 1],
#  ['It made me tired', 1],
#  ['Underline the correct word', 1],
#  ['She is not very  interested   interesting  in fashion', 1],
#  ['She prefers books', 1],
#  ['I saw a very  excited   exciting  IS DVD last night', 1],
#  ['This book is very  bored   boring', 1],
#  ['I fall asleep whenever I try to read it', 1],
#  ['We were very  frightened   frightening  when our car broke down in the desert',
#   1],
#  ['He is a very  interested   interesting  person', 1],
#  ['He has lots of great stories to tell', 1],
#  ['Choose the right adjective', 1],
#  ['That little boy always wants more to eat', 1],
#  ['He s never             ', 1],
#  ['satisfying   satisfied  b', 1],
#  ['The assistant manager lost his job because everybody was', 1],
#  ['by his lies', 1],
#  ['disgusting   disgusted  c', 1],
#  ['When we got back to town  we saw the            damage done by the crusade plane bombing',
#   1],
#  ['worrying   worried  d', 1],
#  ['The last IS DVDs were              exciting   excited  Everyone was really',
#   1],
#  ['exciting   excited  Everyone was', 1],
#  ['at the speed of those fighters in the battle', 1],
#  ['Importance of Second   Foreign Language', 1],
#  ['Before you start', 1],
#  ['How many languages do you know?', 1],
#  ['What is the mental benefit of learning a foreign language?', 1],
#  ['Read the article and answer the questions on the next page', 1],
#  ['A recent study says that speaking two languages can help old people to keep mentally active',
#   1],
#  ['Young people learning a second or a foreign language can keep them mentally active when they get older',
#   1],
#  ['A group of researchers at one university carried out some experiments', 1],
#  ['Then they asked  people between the ages of  and  to do them', 1],
#  ['From the tests  the researchers found out that people who can speak two languages are good at thinking fast',
#   1],
#  ['The group carried out different experiments and concluded that being bilingual can help old people to think quickly',
#   1],
#  ['The group thinks that speaking different languages is very good for you and your brain',
#   1],
#  ['Half of the people who did the tests came from', 1],
#  ['Indonesia and only spoke their mother tongue', 1],
#  ['The other half came from', 1],
#  ['India and could speak English and a language called Tamil', 1],
#  ['The group tested the two halves in vocabulary skills and mathematics ability',
#   1],
#  ['They checked how fast the people did the activity', 1],
#  ['The ones who spoke two languages did the exercises quickly and well', 1],
#  ['The people who spoke only one language weren t as good', 1],
#  ['Learning a second or foreign language when we are young can help us when we are old',
#   1],
#  ['Leaning in general can certainly help the brain to stay active', 1],
#  ['What did the study show? b', 1],
#  ['Who did the test? c', 1],
#  ['Are people who can speak two languages good and fast in different activities? d',
#   1],
#  ['Where are the two halves from? e', 1],
#  ['What did the researchers conclude from doing different experiments? f', 1],
#  ['What is the effect of learning on the brain?', 1],
#  ['Match the words in list A with their meaning in list B', 1],
#  ['List A discover bilingual mental investigate active', 1],
#  ['always ready to do things', 1],
#  ['relating to the mind', 1],
#  ['find out something', 1],
#  ['able to speak two languages', 1],
#  ['Fill in the blanks with words from the box  make the necessary changes', 1],
#  ['active carry out', 1],
#  ['Keep reciting and memorizing the Quran help your', 1],
#  ['to be active', 1],
#  ['Scientists have             many experiments on two types of animals', 1],
#  ['Her physical and           health had got better', 1],
#  ['Don t shake hands with a            woman', 1],
#  ['Muslims always take a more          role in life', 1],
#  ['In no more than  words summarize the article  Importance of Foreign', 1],
#  ['Language    mention the most important points', 1],
#  ['Fill in the blanks with words or phrases taken from the box below', 1],
#  ['bilingual experiments active', 1],
#  ['My grandfather is very                for his age', 1],
#  ['I have come to the                that he is very brilliant', 1],
#  ['They did               on rats to test the drug', 1],
#  ['I have got a                dictionary', 1],
#  ['Safety procedures at the airport are currently under             ', 1],
#  ['They demanded that Ali should bring a                 photo', 1],
#  ['Fill in the blanks with adjectives which end with   ed  or', 1],
#  ['It was a very            day', 1],
#  ['This programme is very', 1],
#  ['I saw a very             sight last year', 1],
#  ['Yasser was             when he was asked to address a word', 1],
#  ['There are many ways to express thanks', 1],
#  ['Respond to the following situations as Muslims and English people', 1],
#  ['Thank you very much for your great help', 1],
#  ['Thanks a lot for your cooperation', 1],
#  ['Jazaka Allahu Khayrn', 1],
#  ['Barak Allah Feekum', 1],
#  ['That s very good of you', 1],
#  ['I appreciate it', 1],
#  ['Write in no more than  words about the importance of foreign   second language',
#   1],
#  ['Follow the steps of writing  Think  Organize', 1],
#  ['Write  Edit Rewrite', 1],
#  ['Make use of the Writing Stages in lesson  to write a paragraph', 1],
#  ['Vocabulary attend  v', 1],
#  ['Tariq bin Ziyad', 1],
#  ['Latitudes and Longitudes', 1],
#  ['From Al Rraqqa to Nigeria', 1],
#  ['Tariq bin Ziyad', 1],
#  ['Fluency     Make Yourself at Home', 1],
#  ['Before you start', 1],
#  ['What do you do if you receive a card like this?', 1],
#  ['Would you like sending a card like this?', 1],
#  ['Abo Omar invites you for dinner at AlSalam Rest', 1],
#  ['At   next Friday', 1],
#  ['Making  accepting  and refusing invitations', 1],
#  ['Look at this dialogue and decide where the sentences in the box go', 1],
#  ['Then we could go on to your parents', 1],
#  ['At about eight o clock', 1],
#  ['That s a great idea!', 1],
#  ['Would you like to go?', 1],
#  ['We re already going out that evening', 1],
#  ['Amar  I just got this invitation from Ali and Ahmed', 1],
#  ['They re having a barbecue next weekend with some friends', 1],
#  ['Salman  Oh  I m sorry  but we can t', 1],
#  ['We re going to my parents for dinner', 1],
#  ['Amar  Oh  of course! What time do your parents expect us to be there?', 1],
#  ['Amar  Why don t we go and see Ali and Salman on our way just for an hour?                             ',
#   1],
#  ['Work in pairs and act out the dialogue', 1],
#  ['Discuss your answers to the following questions', 1],
#  ['In your Wilaya  are people hospitable to brothers in Islam at their homes? b',
#   1],
#  ['How does the host make the invitation  by letter  by phone  or in person? c',
#   1],
#  ['How do you reply to the invitation? Do you have to reply immediately? d',
#   1],
#  ['If not  how long can you wait before replying? e', 1],
#  ['Can you take your friend or your partner? f', 1],
#  ['What time is usually a dinner invitation? g', 1],
#  ['What time should you arrive?', 1],
#  ['Look at this formal invitation and answer the questions', 1],
#  ['Professor Omar invites', 1],
#  ['Khalid Azzam and guests to dinner at home on Friday  at    p.m', 1],
#  ['Who is the invitation for?', 1],
#  ['What is it for?', 1],
#  ['What time should the guests arrive?', 1],
#  ['What should they do when they know if they can go?', 1],
#  ['Study the function s table', 1],
#  ['Would you like to have dinner with us?', 1],
#  ['How about having a cup of tea with me?', 1],
#  ['Let s go out for a meal', 1],
#  ['Are you free for lunch on Friday?', 1],
#  ['Why don t you go for a picnic on Sunday?', 1],
#  ['I d love to', 1],
#  ['Thank you that would be great!', 1],
#  ['That s a great idea', 1],
#  ['I am very pleased to accept your kind invitation', 1],
#  ['I m sorry  but I m going out that evening', 1],
#  ['No  I can t make it', 1],
#  ['I regret that I am unable to accept as I ve got another engagement', 1],
#  ['Make two invitations and then accept the first one and refuse the second one',
#   1],
#  ['Latitudes and Longitudes', 1],
#  ['Before you start', 1],
#  ['What is this figure about?', 1],
#  ['Read the text below and label the figure with words from the text', 1],
#  ['Where is Raqqa city? Where is Mosul city? Where is Sirte city? We can locate any city on Earth by using latitudes and longitudes lines',
#   1],
#  ['Using these lines can give us the position of any place on the Earth', 1],
#  ['Where do the lines of latitude run around? They run around the Earth', 1],
#  ['What are latitude and longitude lines? Latitude lines are the position north or south of the equator measured from  to   whereas longitude lines are the distances of places east or west of an imaginary lines from the top to the bottom of the Earth  measured in degrees',
#   1],
#  ['The most important line of longitude is the Greenwich Meridian     which runs through London',
#   1],
#  ['GMT  Greenwich Mean Time  an international time  is taken from this line',
#   1],
#  ['So where is Raqqa city? It is on latitude  north and longitude  west', 1],
#  ['Mosul is also on  north  but on  east  whereas Sirte is on latitude  and longitude  east',
#   1],
#  ['Look at the table and answer the questions', 1],
#  ['New Delhi  India', 1],
#  ['Washington  D.C.  USA', 1],
#  ['Wellington  New Zealand', 1],
#  ['How many columns are there in the table above?', 1],
#  ['What does this table show?', 1],
#  ['What is the measurement unit of the second and the third columns?', 1],
#  ['Which city is the nearest to the equator?', 1],
#  ['Where does such information come from?', 1],
#  ['Discuss the questions below', 1],
#  ['Do you find the table difficult to understand?', 1],
#  ['Is this table easy to understand?', 1],
#  ['How do you improve such tables?', 1],
#  ['Fill in the blanks with words from the box', 1],
#  ['equator latitude longitude located position imaginary a', 1],
#  ['The distance between east and west is called', 1],
#  ['The USA victory against IS is set in an             story', 1],
#  ['Sudan and Singapore lie on the', 1],
#  ['Our camp is                among heavy trees', 1],
#  ['At these                the sun does not rise at all on winter days', 1],
#  ['If you want to see your           check that on Google Earth', 1],
#  ['Look at the table in the lesson  and write about the cities mentioned in it showing the latitude and longitude lines for each city',
#   1],
#  ['Write no more than  words', 1],
#  ['Start like this', 1],
#  ['Tokyo city  which is in Japan  locates on latitude  N  and longitude', 1],
#  ['From Raqqa to Nigeria', 1],
#  ['Before you start', 1],
#  ['Look at the two answers of the question  which one is correct?', 1],
#  ['What are you doing tomorrow?', 1],
#  ['I will travel to Asham', 1],
#  ['I am travelling to Asham', 1],
#  ['Read the text below and then answer the questions', 1],
#  ['Are there any differences between the italic verbs?', 1],
#  ['Mustafa is travelling from Raqqa to Nigeria to see his uncle', 1],
#  ['Mohammad  who joins Buko Haram there  tomorrow', 1],
#  ['He is staying with him for two weeks', 1],
#  ['The mobile phone is ringing now', 1],
#  ['Ali  Assalam Alaykum', 1],
#  ['How are you?', 1],
#  ['Mustafa  Waalaykum Assalam Ali', 1],
#  ['How are you  too', 1],
#  ['Ali  Would you like to come with me to watch the applying stone limit on a couple of adultery in the city centre this afternoon?',
#   1],
#  ['Mustafa   Oh! That s good idea', 1],
#  ['I ll meet you now and I will bring my wallet', 1],
#  ['I am going to exchange some money I need them in my way to', 1],
#  ['I ll see you then', 1],
#  ['Look at the example below  write similar ones', 1],
#  ['Make use of the prompts below', 1],
#  ['a decision taken at the moment b', 1],
#  ['a promise c', 1],
#  ['am going to exchange', 1],
#  ['a plan carried out by the help of others d', 1],
#  ['a plan in the mind of the speaker', 1],
#  ['Example  The form  is travelling  is a plan can be carried out by the help of others',
#   1],
#  ['Now check your answers in ', 1],
#  ['Complete the sentences with the forms  be   doing  will   infinitive or be   going to   infinitive',
#   1],
#  ['What are you            do  tomorrow?', 1],
#  ['I              visit  my grandfather', 1],
#  ['Look at those heavy clouds', 1],
#  ['What would you like to do in the future? I             work  as an engineer',
#   1],
#  ['I think they          carry out  the mission for us next week', 1],
#  ['I ve got a headache', 1],
#  ['I            bring  you an aspirin', 1],
#  ['Put each verb in brackets into a form of will  going to or present continuous',
#   1],
#  ['More than one answer may be possible', 1],
#  ['Have you heard the news? Salman            join  Al Usrah army', 1],
#  ['Sorry to keep you waiting', 1],
#  ['I  not be               long', 1],
#  ['According to weather news  it  snow                    tomorrow', 1],
#  ['I m sorry I can t meet you tonight', 1],
#  ['I  go out                with my parents to visit my grandfather', 1],
#  ['Our teacher  give              us a test next week', 1],
#  ['Tariq bin Ziyad', 1],
#  ['Before you start', 1],
#  ['Where did the word  Gibraltar  come from?', 1],
#  ['What was the original name of Spain?', 1],
#  ['Islamic armies reached what is called nowadays Morocco in the year  AD', 1],
#  ['They were not able to go further west because of the Atlantic', 1],
#  ['They decided to go to the north towards Andalusia  which is called Spain nowadays',
#   1],
#  ['The Muslim leader  Tariq Bin Ziyad  led the', 1],
#  ['Islamic armies across the strait of Gibraltar', 1],
#  ['They conquered Toledo which was the capital of Andalusia at that time', 1],
#  ['Muslims ruled it for several hundred years', 1],
#  ['Cordoba was as beautiful city as Baghdad and Damascus when it was ruled by Abdul Rahman Al Nasir  who left his noticeable figure prints on various fields',
#   1],
#  ['His greatest achievement was in building a great masjid which its ruins still exist today',
#   1],
#  ['Muslims made beautiful gardens and planted various farms', 1],
#  ['They paved roads which were clear and lit at night', 1],
#  ['They set up the first paper factories in Europe', 1],
#  ['The University of Cordoba was a good example of higher learning process',
#   1],
#  ['Muslims placed the cornerstone of the scientific developments which guided the world to progress and build civilization',
#   1],
#  ['Muslims showed an excellent ruling of', 1],
#  ['Andalusia for several centuries', 1],
#  ['Answer the following questions  a', 1],
#  ['Where did the Islamic armies reach in ?', 1],
#  ['Who is Tariq bin Ziyad?', 1],
#  ['Why didn t they go further west?', 1],
#  ['How long did Muslims rule Andalusia?', 1],
#  ['What did Muslims do in Spain?', 1],
#  ['Fill in the blanks', 1],
#  ['The Muslim armies reached         in the year          ', 1],
#  ['They were not able to go further west because of          ', 1],
#  ['The Muslims captured           which was the capital of Spain', 1],
#  ['The Muslim ruled Spain for            ', 1],
#  ['Cordoba was as beautiful as             and             ', 1],
#  ['Muslims paved roads which were          and          at night', 1],
#  ['Write T if the statement is true and F in not  a', 1],
#  ['The Muslims could not reach Morocco because of the ocean', 1],
#  ['The Muslims were led by Tariq bin Ziyad', 1],
#  ['The Muslims ruled Spain for several days', 1],
#  ['The Muslim guided the world to progress and civilization', 1],
#  ['Match the words with their meaning', 1],
#  ['to take control of foreign land b', 1],
#  ['arrange or organize c', 1],
#  ['something of great importance d', 1],
#  ['the pattern of curved lines on figure or thumb e', 1],
#  ['something is spoilt or destroyed f', 1],
#  ['to succeed in finishing something', 1],
#  ['In no more than  words summarize the article about  Tariq bin', 1],
#  ['Fill in the blanks with words from the box', 1],
#  ['People who commit              in Islamic State are stoned', 1],
#  ['There are three             in this article  all talk about jihad', 1],
#  ['We are really happy to accept your', 1],
#  ['Our               was to isolate the enemies  supporting lines over the bridge',
#   1],
#  ['Many soldiers were killed during the           of fire', 1],
#  ['Match the words with their meaning', 1],
#  ['the lowest part of something', 1],
#  ['an imaginary line drawn around the middle of the Earth', 1],
#  ['the amount of space between two places', 1],
#  ['something which created by and exist in mind', 1],
#  ['Look at the invitation card on the right and then answer the questions', 1],
#  ['Mohammad Amar invites a', 1],
#  ['Who invites his guests? b', 1],
#  ['What is the invitation for? c', 1],
#  ['Where is the invitation?', 1],
#  ['you our dearest guests for his son dinner s wedding at home on', 1],
#  ['Now you receive this invitation card  what would you say if you accept it? But your brother apologizes for the invitation  what does he say?',
#   1],
#  ['Correct the verbs in the sentences below', 1],
#  ['Do you think Omar is going to get the job? b', 1],
#  ['Look! It s', 1],
#  ['We will be late', 1],
#  ['What will you do tomorrow? d', 1],
#  ['They are probably arriving at  o clock', 1],
#  ['She is opening the newspaper', 1],
#  ['She will read the article', 1],
#  ['I go swimming next Friday', 1],
#  ['Would you like to come? g', 1],
#  ['The weather news says it is rainy tomorrow', 1],
#  ['In no more than  words write a paragraph about an Islamic character', 1],
#  ['Vocabulary latitude  n', 1],
#  ['How can you remember?', 1],
#  ['A good night sleep', 1],
#  ['How can you remember?', 1],
#  ['Asking for directions', 1],
#  ['Before you start', 1],
#  ['Look at those two children in the photo', 1],
#  ['What are they talking about?', 1],
#  ['Do you usually ask people for things?', 1],
#  ['Work the dialogue in pairs', 1],
#  ['Then answer the question', 1],
#  ['Official  Assalam Alaykum', 1],
#  ['Can I see your ticket  please?', 1],
#  ['Passenger  Waalykum Alsalam', 1],
#  ['Here you are', 1],
#  ['Official  Is that your luggage?', 1],
#  ['Official  Window or aisle?', 1],
#  ['Passenger  I ll have an aisle seat  please', 1],
#  ['Official  There you go  brother .Here s your pass', 1],
#  ['Boarding begins at seven o clock', 1],
#  ['Passenger  And what gate does it leave from?', 1],
#  ['Official  Sixteen  brother', 1],
#  ['Passenger  And how do I get to gate sixteen?', 1],
#  ['Official  Go along here and follow the signs for   Departure  ', 1],
#  ['You ll see the gate number when you go through into the lounge', 1],
#  ['Official  Have a nice day  brother', 1],
#  ['Where do you think the dialogue is taking place?', 1],
#  ['Tick the right answer  a  b or c  a', 1],
#  ['at police station', 1],
#  ['at an airport', 1],
#  ['Study the function s table', 1],
#  ['Asking for directions', 1],
#  ['How do I get to the hospital?', 1],
#  ['I m looking for the train station', 1],
#  ['Excuse me  Could you tell me where the bus station is?', 1],
#  ['Giving directions and describing position', 1],
#  ['Go up   Go down   Go along this street', 1],
#  ['Go straight ahead', 1],
#  ['Go to the end of the street', 1],
#  ['Turn left   Turn right', 1],
#  ['It s at the intersection', 1],
#  ['Take the first  second turn on the left   on the right', 1],
#  ['It s four blocks up   down on your left', 1],
#  ['Asking for travel information', 1],
#  ['Where do I get a car to Asham?', 1],
#  ['What platform does the train to Raqqa leave from?', 1],
#  ['What gate does the plane to Al  Madinah leave from?', 1],
#  ['How long does the flight to Pakistan take?', 1],
#  ['How much is a trip to Tripoli?', 1],
#  ['What does it cost to get to the peninsula of Arabs by taxi?', 1],
#  ['Where do I get the connection to Halab?', 1],
#  ['What s the quickest way to get across town?', 1],
#  ['How far is it to Dramadi from here?', 1],
#  ['Look at the map', 1],
#  ['Make use of the map and write a conversation asking about police station  hospital  bus stop  petrol station  school   suq   library',
#   1],
#  ['A  Excuse me', 1],
#  ['How can I get the library?', 1],
#  ['B  Go along this street', 1],
#  ['Go to the end of the street', 1],
#  ['The library will be on your left  next to the bank', 1],
#  ['A  Thank you very much', 1],
#  ['B  You re welcome', 1],
#  ['Now make similar conversations', 1],
#  ['Look at the map in  and write two different conversations asking about places such as zoo  metro  grocery store etc',
#   1],
#  ['Before you start', 1],
#  ['Which transportation method do you prefer? Why?', 1],
#  ['What do we call the vehicle which can move over land or sea?', 1],
#  ['There are many means of transportations  such as bus  car  motorbike  train  boat  ferry  plane  ambulance  bike  helicopter  coach  tram  ship  yacht  spaceship  lorry  hovercraft  moped  taxi etc',
#   1],
#  ['Match the photos you find with some of the words above', 1],
#  ['Can you add other means of transportation?', 1],
#  ['Everyone can use any of those means of transportations except one which is used by very specialized people',
#   1],
#  ['What is it  guess?', 1],
#  ['Classify the means of transportation into three groups  land  sea and air',
#   1],
#  ['Work in pairs', 1],
#  ['Follow the example', 1],
#  ['A  What is the vehicle which is used to carry goods by road?', 1],
#  ['B  Is it small or large?', 1],
#  ['A  It is large', 1],
#  ['B  I think it is a truck', 1],
#  ['What about the small one?', 1],
#  ['B  I think it is a pick up truck', 1],
#  ['Now make similar dialogue', 1],
#  ['Make use of the following information', 1],
#  ['a vehicle spends a lot of time on motorways carrying people from one place to another',
#   1],
#  ['it has no roof and often goes faster than a car', 1],
#  ['it takes people to hospital', 1],
#  ['it take people around or work or student to school', 1],
#  ['it carries a few people in the air', 1],
#  ['it travels on top of the water', 1],
#  ['it travels about  kilometer per hour  kph', 1],
#  ['it travels on rails', 1],
#  ['a lot of families own it', 1],
#  ['it travel quite slowly and it takes people across water', 1],
#  ['it goes long journeys across water  it carries people and goods', 1],
#  ['it has two wheels  carries only one person and has a very small engine', 1],
#  ['it runs on rails and it has several carriages', 1],
#  ['Write ten sentences using the adverbs of frequency  always  usually  sometimes  often  never  ever  rarely etc.  describing various means of transportations',
#   1],
#  ['Example  I never travel by sea', 1],
#  ['A good night sleep', 1],
#  ['Before you start', 1],
#  ['Look at these two statements', 1],
#  ['What is the difference between them?', 1],
#  ['He said    I don t think so', 1],
#  ['He said  that  He didn t think so', 1],
#  ['Look at the sentences numbered below in the interview', 1],
#  ['What do we call each one?', 1],
#  ['Abdullah     Do you think sleep is a waste of time for teenagers? Dr', 1],
#  ['Abdullah said      I don t think so.   Teenagers should take enough sleep to grow healthy and stay strong',
#   1],
#  ['Interviewer   What do you advise the teenagers who stay up late?', 1],
#  ['Abdullah said     Go to bed at the same time every night.   Don t do anything exciting before bed  instead recite some verses from the',
#   1],
#  ['Quran.  Now you know what to do before sleeping  you will feel much better in the morning',
#   1],
#  ['Finally  we can say that sleep is not a waste of time', 1],
#  ['Note   I don t think so.  Is called direct speech', 1],
#  ['When we often tell people what other people have said  it is called reported or indirect speech  e.g',
#   1],
#  ['Abdullah said that he didn t think so', 1],
#  ['in the interview above is called  Question   No.   is', 1],
#  ['Statement  and No', 1],
#  ['is called  Request', 1],
#  ['Now check your answers in', 1],
#  ['Find other examples in the interview', 1],
#  ['I   is changed into   he      do   is changed into  did  Note', 1],
#  ['Brackets     mean that you can use  that  or not  both are correct', 1],
#  ['See more in pages', 1],
#  ['Report the statements below', 1],
#  ['He said  We sleep few hours at night.  b', 1],
#  ['He told us   I do not stay late up late', 1],
#  ['Change into indirect', 1],
#  ['He said  that  he took part in many battles against his enemy', 1],
#  ['They told us  that  they had captured several war prisoners', 1],
#  ['Look at the examples below and then change the question into reported speech',
#   1],
#  ['We asked him   What are they?', 1],
#  ['We asked him what they were', 1],
#  ['He asked him   Is it ready to use?  He asked him if it was ready to use',
#   1],
#  ['Are you still at college?  Saad asked me', 1],
#  ['I asked him   What are you reading this week?', 1],
#  ['Change the statements into reported speech', 1],
#  ['They won the match.  They said', 1],
#  ['He said   I am working outside this city.  c', 1],
#  ['We arrived home late yesterday.  They told us', 1],
#  ['She said   I will help you.  e', 1],
#  ['Salman asked Ali   Where have you been?  f', 1],
#  ['Did you remember Bakr?  he asked him', 1],
#  ['How can you remember?', 1],
#  ['Before you start', 1],
#  ['Is it important to revise the information you learn from time to time?', 1],
#  ['How long does it take to forget the information we learn?', 1],
#  ['Look at the first graph which shows the percentage of learning remembered   vertical  and the time since initial learning  horizontal',
#   1],
#  ['Three colours are used  green one which shows regular review  blue one review after ten minutes and the brown one which shows no review',
#   1],
#  ['Now read and check your answers in ', 1],
#  ['Within  hours of learning  we almost forget   of the new information and after a month only about   remains',
#   1],
#  ['The big question is how we can stop or reduce the loss of information', 1],
#  ['Simply  the answer', 1],
#  ['is reviewing regularly', 1],
#  ['Does it need to revise every day? Not necessarily  but the first revision is very important which must be after  minutes',
#   1],
#  ['If you look at the blue line how it raises memory to    but if we do not look at the information again  we will forget nearly everything over time',
#   1],
#  ['Thus  it is very important to revise regularly', 1],
#  ['If we revise after one day as shown in the graph  one month and then six months as shown in the green line  we will remember the information for ever  because the information will be now in long term memory',
#   1],
#  ['What happens while revising? Which revising hour is the best for us  first  second etc.? Which information can we remember better  the first one or the last one? When we revise for a test  for example we need nearly  hours  the information in the first and second hours will probably be remembered better than the things you revise in the last two hours',
#   1],
#  ['The reason is that we revise the information without taking break after each hour',
#   1],
#  ['We should take at least  minutes break after an hour of revising', 1],
#  ['Look at the second graph and check how much information you can remember',
#   1],
#  ['Answer the questions below', 1],
#  ['How long does it take to retain    of the new information?', 1],
#  ['What is the best way to keep the information?', 1],
#  ['Which information will be the best in a test  first hour of revising or the last hour?',
#   1],
#  ['What do advise students while revising for long hours?', 1],
#  ['Do you agree with these ideas in this topic? Why? Why not?', 1],
#  ['Write T if the statement is true  and F if it is false', 1],
#  ['We nearly forget    of the new information and after two weeks only about    remains',
#   1],
#  ['The second revision is very important which must be after  minutes', 1],
#  ['It is important to revise regularly', 1],
#  ['The best revising hour is the last one', 1],
#  ['We forget the information while revising because we do not take break', 1],
#  ['In no more than  words summarize the topic  How can we remember?', 1],
#  ['Fill in the blanks with a proper word', 1],
#  ['is a vehicle which flies over land or water', 1],
#  ['is an underground electric railway system in some cities', 1],
#  ['is a boat or ship for taking passengers and vehicles cross an area of water',
#   1],
#  ['is a large cylindrical object which moves very fast', 1],
#  ['is a long vehicle which takes groups of people on journeys', 1],
#  ['Match the words with their meanings', 1],
#  ['a particular way of doing something', 1],
#  ['to make something smaller in size  amount  degree etc', 1],
#  ['to stay in the same place', 1],
#  ['happening or doing something often', 1],
#  ['the ability to remember information  experience  people', 1],
#  ['Change into reported speech', 1],
#  ['My little brother needs to memorize Surat Baqarh  Ahmed told me', 1],
#  ['I ll be in Sham next July Insha Allah  Saad said', 1],
#  ['I have washed the car  Yusuf said', 1],
#  ['What do elephant eat?  He asked me', 1],
#  ['Where are you going?  I asked him', 1],
#  ['Is this your car?  She asked me', 1],
#  ['Did you have it with you?  I asked her', 1],
#  ['Could you help me  please?  A stranger asked me', 1],
#  ['Don t sit in the middle of the road.  My father told me', 1],
#  ['Slow down  check point ahead.  My mother warned me', 1],
#  ['Look at the map and ask and answer in pairs about   mall  masjid  petrol station',
#   1],
#  ['Look at Lesson   ex', 1],
#  ['Vocabulary transportation  n', 1],
#  ['pick up  n', 1],
#  ['Smoking is prohibited in Islam', 1],
#  ['Things I own', 1],
#  ['Speak up!', 1],
#  ['Smoking is prohibited in', 1],
#  ['Once you decide', 1],
#  ['Things I own', 1],
#  ['Before you start', 1],
#  ['What parts of speech are these words  cheap  antique  crazy  ugly?', 1],
#  ['Can you add words more from your own?', 1],
#  ['Look at the photographs', 1],
#  ['Match what these people say and write them in the small box', 1],
#  ['I was walking down town when I saw this in a shop window  and I decided to buy it that day',
#   1],
#  ['I don t have any other any antique  but it looks good in my big room', 1],
#  ['I have had it for two years now', 1],
#  ['It was expensive  but in my opinion it was not worth it because it s the most useful thing in the kitchen',
#   1],
#  ['I think this is great because I like unusual furniture', 1],
#  ['Some people say it s not very comfortable in hot weather but I don t mind',
#   1],
#  ['It s crazy  isn t it? Everyone laughs when they see it  but it works OK  and it makes me happy',
#   1],
#  ['I don t really like it all because it s old fashioned  and I prefer modern furniture',
#   1],
#  ['But I can t offered to change it and its quite useful', 1],
#  ['I can keep lots of things in it', 1],
#  ['What we call the italic words in the five texts above?', 1],
#  ['Which order of adjectives is correct  a  or b  ? a  I ve bought a lovely long black leather belt',
#   1],
#  ['b  I ve bought a lovely black long leather belt', 1],
#  ['Look at the order of adjectives in the table below and check your answer in',
#   1],
#  ['size   age   shape short   old', 1],
#  ['Add more adjectives to the table', 1],
#  ['When we use adjectives together  we put words which express opinion before words which describe the characteristics or type of what we are talking about  e.g',
#   1],
#  ['a beautiful Arabic fashion  beautiful   opinion   Arabic   nationality', 1],
#  ['The sentences below are incorrect  write them correctly', 1],
#  ['She bought a round  beautiful  Pakistani cloth', 1],
#  ['He saw an ugly  blue  wooden  little wardrobe', 1],
#  ['That is a red  new  terrible scarf', 1],
#  ['I ve got an expensive square old box', 1],
#  ['Speak up!', 1],
#  ['Before you start', 1],
#  ['What do we call the italic verbs in the dialogue below?', 1],
#  ['Is there a difference in meaning between  look for  and  search ?', 1],
#  ['Work in pairs', 1],
#  ['An interview between a boy and a presenter', 1],
#  ['Presenter  We are here today with Abdullah who had a strange experience last week',
#   1],
#  ['Abdullah  Well  I was moving up the stairs to our flat in the fifth floor',
#   1],
#  ['I saw a flame coming up to the second floor', 1],
#  ['Presenter  What were you doing at that moment?', 1],
#  ['Abdullah  I was looking down for my little brother who was at the third floor',
#   1],
#  ['Presenter  You mean that your brother was in great danger?', 1],
#  ['Abdullah  Yes  indeed', 1],
#  ['The flames speed up very quickly', 1],
#  ['No time was left out', 1],
#  ['Thanks for Allah  someone had called the fire engine and put out the fire completely',
#   1],
#  ['The verbs in italic in the interview are called multi word verbs which combine with one   or two particles',
#   1],
#  ['If the addition of the particles changes the meaning of the verb  it is usually called a phrasal verb because it has the meaning of a phrase  e.g',
#   1],
#  ['The fire engine put out the fire', 1],
#  ['Phrasal verbs are in three types', 1],
#  ['With object  Doctors look after sick people', 1],
#  ['Without object  There is a check point ahead  slow down', 1],
#  ['Within object  He gave up smoking  he gave it up forever', 1],
#  ['Now check your answers in ', 1],
#  ['Match the phrasal verbs with their meaning', 1],
#  ['Phrasal verbs a', 1],
#  ['The paper ran out  we need more', 1],
#  ['We usually look after our poor neighbours', 1],
#  ['Could you speak up? I can t hear you', 1],
#  ['The man put the device on', 1],
#  ['We have the permission to go ahead with the task', 1],
#  ['She has to give up fatty food  it s dangerous', 1],
#  ['We need to work out the total cost of the project', 1],
#  ['Everyone is looking forward to accomplishing success', 1],
#  ['To stop trying', 1],
#  ['To take care of', 1],
#  ['To start to do something', 1],
#  ['To speak in a louder voice', 1],
#  ['To feel pleased or excited', 1],
#  ['Look at the verbs in italic in the examples below and match them with the combined two or three particles',
#   1],
#  ['I m looking for my keys', 1],
#  ['Have you seen them? b', 1],
#  ['Look out! There s a motorcycle coming', 1],
#  ['The one who looks down on other people is called a snob', 1],
#  ['verb   adverb   preposition', 1],
#  ['a preposition and   or an adverb', 1],
#  ['Fill in the blanks with a proper phrasal verbs from the box', 1],
#  ['look forward to', 1],
#  ['look out onto', 1],
#  ['drop in on', 1],
#  ['I               participating one of the battles  fronts every summer', 1],
#  ['One must            his   her shoes before entering misjad', 1],
#  ['Yasir was ill with flu  but he is               it now', 1],
#  ['Let s             Omar while we are in Dirna', 1],
#  ['Al Waritheen hotel              Tigress River', 1],
#  ['Smoking is prohibited in Islam', 1],
#  ['Before you start', 1],
#  ['Where can you find such warnings?  Don t smoke!   Stop smoking!', 1],
#  ['Do you agree with those warnings? Why? Why not?', 1],
#  ['Look at the italic sentences', 1],
#  ['Don t smoke  and  Stop smoking  are sentences you may hear or read everywhere',
#   1],
#  ['Another phrase you may hear is  Stop smoking before it s too late', 1],
#  ['Firstly  smoking is prohibited in Islam based on the Messenger of Allah s hadith   peace be upon him   Hurt neither yourself nor others',
#   1],
#  ['Moreover  those warnings tell us that smoking is very dangerous', 1],
#  ['It damages your health', 1],
#  ['Warning statements are everywhere you find it on cigarette packets  it says   Leave smoking',
#   1],
#  ['It is one of the main reasons for cancer.  Such phrases are not written on food  or drink packets  yet a number of people still smoke',
#   1],
#  ['Look at the examples below and do as required', 1],
#  ['He ordered us   Stop smoking', 1],
#  ['He ordered us to stop smoking', 1],
#  ['Reported speech  b', 1],
#  ['They asked me   Would you carry these bags for me  please?', 1],
#  ['They asked me to carry those bags for him', 1],
#  ['Look at the examples  a  and  b  abovex and guess which one is formal and which one is informal',
#   1],
#  ['We use the infinitive  to do   to stay   to take etc.  in reported speech  especially with tell and ask  for orders and requests ',
#   1],
#  ['There are two methods of expressing requests  informal and formal', 1],
#  ['Example for informal', 1],
#  ['Stay in bed for a few days.  The doctor said to me', 1],
#  ['The doctor told me to stay in bed for a few days', 1],
#  ['Don t speed up  I asked the taxi driver', 1],
#  ['I asked the taxi driver not to speed up', 1],
#  ['Example for formal', 1],
#  ['Would you mind opening that door  please?  a stranger asked me', 1],
#  ['A stranger asked me to open the door', 1],
#  ['Check your answer in ', 1],
#  ['Now do the following', 1],
#  ['Could you open the door  please?  a stranger asked me', 1],
#  ['The man asked me  Don t park your car here.  c', 1],
#  ['Stop here  a man warned me', 1],
#  ['Turn the TV off  my father asked me', 1],
#  ['Change the sentences below into direct speech', 1],
#  ['You define if it is formal or informal', 1],
#  ['He asked his older brother not backbite others', 1],
#  ['She told her little sister to say the truth', 1],
#  ['A stranger asked me to open the umbrella for him', 1],
#  ['Her father told her to turn the TV off', 1],
#  ['A friend of mine warned me not to speed up', 1],
#  ['An old man asked me to carry his bags for him', 1],
#  ['Once you decide', 1],
#  ['Before you start', 1],
#  ['How do you make a decision?', 1],
#  ['Have you ever regretted a decision?', 1],
#  ['Read the text', 1],
#  ['You may need to take a decision every day  every week  every month etc', 1],
#  ['But is your decision good or not? What are the steps of good decision making? A lot of people make decisions without really thinking about them',
#   1],
#  ['They probably use their instinct and they believe that they just hope they have done the right thing',
#   1],
#  ['However  such a decision making is no good in business  or in big things in every day s life',
#   1],
#  ['Making decisions is not a moment in time  but it is process', 1],
#  ['It can be said that making decision is embodied in six process steps', 1],
#  ['Define the problem', 1],
#  ['Imagine a successful solution', 1],
#  ['Generate alternative possibilities', 1],
#  ['Evaluate the possibilities', 1],
#  ['Select the best possibility', 1],
#  ['Tell people your decision', 1],
#  ['Let s have a look at the example of the process of action', 1],
#  ['Let s define the problem first', 1],
#  ['You may come late to school', 1],
#  ['Secondly  let s imagine that the successful solution for this problem is to arrive  minutes before the first lesson',
#   1],
#  ['Now you need to generate a list of alternative possibilities  for example  take a taxi  go with your father s car  take the bus  ride your bike etc',
#   1],
#  ['You can go through those alternatives with your father or even with your friend and think of the difficulties of each alternative',
#   1],
#  ['Then it is time to select the best possibility', 1],
#  ['people around you your final decision  but remember not all your decisions are perfect even if you follow the process of taking good decisions because you forget one important thing',
#   1],
#  ['It is to follow the advice of our prophet Mohammad  peace be upon him  before taking decision  you should pray to Allah to choose for you the best alternative to take the final decision',
#   1],
#  ['Thus  the good decision should be taken after istikhara  decisions  prayer  even if you discover later on it was not a good decision  but indeed it is good for you because no one knows which one is good or bad  but Almighty Allah',
#   1],
#  ['Check your answers in ', 1],
#  ['Answer the questions below', 1],
#  ['Is it good to use instinct to take a business decision? b', 1],
#  ['What is making decision? c', 1],
#  ['How many steps one should follow before telling people his or her decision? d',
#   1],
#  ['Do you think that the six process steps are active in a decision?', 1],
#  ['Why? Why not?', 1],
#  ['Write T if the statement is true and F if it is not', 1],
#  ['Very few people make decisions without really thinking about them', 1],
#  ['It is very good to use our instinct to take a decision in big things in every day s life',
#   1],
#  ['There is no need to define the problem in taking decisions', 1],
#  ['After studying the possibilities  one should select one of them', 1],
#  ['Imagine you do not live in the Islamic State and you want to immigrate to it',
#   1],
#  ['Read the six process steps of make your decision ', 1],
#  ['Define the problem', 1],
#  ['Imagine a successful solution', 1],
#  ['Generate alternative possibilities', 1],
#  ['Evaluate the possibilities', 1],
#  ['Select the best possibility', 1],
#  ['Tell closest people your decision', 1],
#  ['Use the words in the box to complete the following sentences', 1],
#  ['It s important that young people understand the            and', 1],
#  ['effects of smoking', 1],
#  ['With the help of your dictionary  checkup the meaning of the', 1],
#  ['Wherever you go in the Islamic state  you find              people who are always willing to help',
#   1],
#  ['One should look after his            ', 1],
#  ['Write adjectives in the table below from your own', 1],
#  ['opinion a  an', 1],
#  ['size   age   shape large', 1],
#  ['Match the words with their meaning', 1],
#  ['decide instinct process generate alternative discover', 1],
#  ['to find information for the first time', 1],
#  ['offering the possibility of a choice', 1],
#  ['to represent a quality or an idea exactly', 1],
#  ['natural react or behave without thinking', 1],
#  ['a series of actions', 1],
#  ['make up your mind', 1],
#  ['Match the phrasal verbs with their meaning', 1],
#  ['to reduce the volume to stop operating to operate something to continue to care of to get better after an illness',
#   1],
#  ['Change the requests into reported speech', 1],
#  ['Don t shout  I said to my little brother', 1],
#  ['Could you help him  please?  she asked her brother', 1],
#  ['Please don t tell anyone what happened   the police said to the man', 1],
#  ['Slow down!  the old man asked him', 1],
#  ['Change the reported speech into request sentences', 1],
#  ['The teacher told them to keep silent', 1],
#  ['He asked his boss to give him a ten day leave', 1],
#  ['She told him not to leave the baby alone', 1],
#  ...]

# %% [markdown]
# ### Checking for Data Imbalance:

# %%
len(new_examples1) # when the data is balanced, the accuracy drops from 50 to 49 after 6 epochs. so leaving it unbalanced
# Out:
# 2813

# %%
len(new_examples2)
# Out:
# 1359

# %%
len(new_examples1)+len(new_examples2)
# Out:
# 4172

# %% [markdown]
# ### Checking the Readability Scores using the Textstat Library:

# %%
fs = open('../data/gradetwoindo.txt', 'r') 
bookone = fs.read()

# %%
# https://pypi.org/project/textstat/
bookonescore = round(textstat.flesch_kincaid_grade(bookone))
bookonescore
# Out:
# 4

# %%
fs = open('../data/gradesixis.txt', 'r') 
booktwo = fs.read()

# %%
# https://pypi.org/project/textstat/
booktwoscore = round(textstat.flesch_kincaid_grade(booktwo))
booktwoscore
# Out:
# 6

# %% [markdown]
# ### Organising the Labelled Data together using a Pandas Dataframe:

# %%
dataset = pd.DataFrame(columns = ["text", "label"])  
dataset = dataset.append(pd.DataFrame(new_examples2+new_examples1, columns = ["text", "label"]))

# %% [markdown]
# ### Downloading Pre-trained Vectors trained on part of Google News dataset:

# %%
# https://code.google.com/archive/p/word2vec/
# !pip install wget
import wget
import os
if not os.path.isfile("GoogleNews-vectors-negative300.bin.gz"):
    print("downloading")
    wget.download("https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz")
else:
    print("you already have it!")

# %%
embeddings_file = "../data/GoogleNews-vectors-negative300.bin.gz"
wv = KeyedVectors.load_word2vec_format(embeddings_file, binary=True, limit=200000)

# %% [markdown]
# ### Classification:

# %%
#Code Adapted from the NLP in Action book ch7 https://github.com/totalgood/nlpia
word_vectors = KeyedVectors.load_word2vec_format(embeddings_file, binary=True, limit=200000)
def tokenize_and_vectorize(dataset):
    vectorized_data = []
    for sample in dataset:
        tokens = casual_tokenize(sample)
        sample_vecs = []
        for token in tokens:
            try:
                sample_vecs.append(word_vectors[token])
            except KeyError:
                pass  # No matching token in the Google w2v vocab
        vectorized_data.append(sample_vecs)

    return vectorized_data

def pad_trunc(data, maxlen):
    """ For a given dataset pad with zero vectors or truncate to maxlen """
    new_data = []

    # Creating a vector of 0's the length of the word vectors
    zero_vector = []
    for _ in range(len(data[0][0])):
        zero_vector.append(0.0)

    for sample in data:
 
        if len(sample) > maxlen:
            temp = sample[:maxlen]
        elif len(sample) < maxlen:
            temp = sample
            additional_elems = maxlen - len(sample)
            for _ in range(additional_elems):
                temp.append(zero_vector)
        else:
            temp = sample
        new_data.append(temp)
    return new_data

# %%
features = tokenize_and_vectorize(dataset["text"].values)
x_train, x_test, y_train, y_test = train_test_split(features, dataset["label"], test_size=0.3, random_state=0)

# %%
type(x_train)
# Out:
# list

# %%
maxlen = 50
embedding_dims = 300    # Length of the token vectors for passing into the Convnet

# %%
np.array(x_train).shape,np.array(x_test).shape
# Out:
# <ipython-input-26-6dd20099d2f7>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   np.array(x_train).shape,np.array(x_test).shape
# ((2920,), (1252,))

# %%
x_train = pad_trunc(x_train, maxlen)
x_test = pad_trunc(x_test, maxlen)

# %%
type(x_train)
# Out:
# list

# %%
np.array(x_train).shape
# Out:
# (2920, 50, 300)

# %%
x_train = np.reshape(x_train, (len(x_train), maxlen, embedding_dims))
y_train = np.array(y_train)
x_train = np.reshape(x_train, (len(x_train), maxlen, embedding_dims))
y_train = np.array(y_train)
x_test = np.reshape(x_test, (len(x_test), maxlen, embedding_dims))
y_test = np.array(y_test)

# %%
np.array(x_train).shape,np.array(x_test).shape
# Out:
# ((2920, 50, 300), (1252, 50, 300))

# %%
batch_size = 32        
filters = 1           
kernel_size = 5         
hidden_dims = 10      
epochs = 6

# %% [markdown]
# ### Building the Model:

# %%
#Code Adapted from the NLP in Action book ch7 https://github.com/totalgood/nlpia
print('Build model...')
model = Sequential()

# Adding a Convolution1D, which will learn filters
# word group filters of size filter_length:
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1,
                 input_shape=(maxlen, embedding_dims)))
# Using max pooling:
model.add(GlobalMaxPooling1D())
# Adding a vanilla hidden layer:
model.add(Dense(hidden_dims))
model.add(Dropout(0.2))
model.add(Activation('relu'))
# Projecting onto a single unit output layer, and squash it with a sigmoid:
model.add(Dense(1))
model.add(Activation('sigmoid'))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
print(model.summary())
# Out:
# Build model...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 46, 1)             1501
# _________________________________________________________________
# global_max_pooling1d (Global (None, 1)                 0
# _________________________________________________________________
# dense (Dense)                (None, 10)                20
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 1,532
# Trainable params: 1,532
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# https://stackoverflow.com/questions/58636087/tensorflow-valueerror-failed-to-convert-a-numpy-array-to-a-tensor-unsupporte

x_train = np.asarray(x_train).astype(np.float32)
y_train = np.asarray(y_train).astype(np.float32)
x_test = np.asarray(x_test).astype(np.float32)
y_test = np.asarray(y_test).astype(np.float32)

# %% [markdown]
# ### Train Model:

# %%
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, y_test))
model_structure = model.to_json()
with open("cnn_model.json", "w") as json_file:
    json_file.write(model_structure)

model.save_weights("cnn_weights.h5")
print('Model saved.')
# Out:
# Epoch 1/6
# 92/92 [==============================] - 2s 15ms/step - loss: 0.6468 - accuracy: 0.6664 - val_loss: 0.6264 - val_accuracy: 0.6558
# Epoch 2/6
# 92/92 [==============================] - 1s 11ms/step - loss: 0.6050 - accuracy: 0.6733 - val_loss: 0.5996 - val_accuracy: 0.6558
# Epoch 3/6
# 92/92 [==============================] - 1s 11ms/step - loss: 0.5755 - accuracy: 0.6801 - val_loss: 0.5745 - val_accuracy: 0.6558
# Epoch 4/6
# 92/92 [==============================] - 1s 11ms/step - loss: 0.5498 - accuracy: 0.6818 - val_loss: 0.5530 - val_accuracy: 0.6558
# Epoch 5/6
# 92/92 [==============================] - 1s 12ms/step - loss: 0.5286 - accuracy: 0.6822 - val_loss: 0.5380 - val_accuracy: 0.6558
# Epoch 6/6
# 92/92 [==============================] - 1s 13ms/step - loss: 0.5067 - accuracy: 0.6822 - val_loss: 0.5238 - val_accuracy: 0.6558
# Model saved.

# %% [markdown]
# #### `(All observations and findings shall be included in the critical essay).`

# %% [markdown]
# ### Citation List:
#
#
# #### Websites:
#
# 1) Code.google.com. 2022. Google Code Archive - Word2Vec. [online] Available at: <https://code.google.com/archive/p/word2vec/> [Accessed 5 December 2021].
#
# 2) Davis, A., 2021. The fundamentals of programming - Python Video Tutorial | LinkedIn Learning, formerly Lynda.com. [online] LinkedIn. Available at: <https://www.linkedin.com/learning/programming-foundations-fundamentals-3/the-fundamentals-of-programming?autoAdvance=true&autoSkip=false&autoplay=true&resume=true&u=57077561> [Accessed 24 October 2021].
#
# 3) Dib, F., 2021. regex101: build, test, and debug regex. [online] regex101. Available at: <https://regex101.com/> [Accessed 4 December 2021].
#
# 4) GitHub. 2021. GitHub - totalgood/nlpia: Examples and libraries for "Natural Language Processing in Action" book. [online] Available at: <https://github.com/totalgood/nlpia> [Accessed 5 December 2021].
#
# 5) Libgen.is. 2021. Library Genesis. [online] Available at: <https://www.libgen.is/> [Accessed 4 November 2021].
#
# 6) McCallum, L., 2021. NLP Week 4.1 - Classification Task Notebook. [online] GitHub. Available at: <https://git.arts.ac.uk/lmccallum/nlp-21-22/blob/master/NLP%20Week%204.1%20-%20Classification%20Task.ipynb> [Accessed 16 November 2021].
#
# 7) McCallum, L., 2021. NLP Week 5.1 CNNs Notebook. [online] GitHub. Available at: <https://git.arts.ac.uk/lmccallum/nlp-21-22/blob/master/NLP%20Week%205.1%20CNNs.ipynb> [Accessed 2 December 2021].
#
# 8) Nisbet, J., 2021. Python for students - Python Video Tutorial | LinkedIn Learning, formerly Lynda.com. [online] LinkedIn. Available at: <https://www.linkedin.com/learning/python-for-students/python-for-students?autoAdvance=true&autoSkip=false&autoplay=true&resume=false&u=57077561> [Accessed 18 October 2021].
#
# 9) Portilla, J., 2021. Natural Language Processing with Python. [online] Udemy. Available at: <https://www.udemy.com/course/nlp-natural-language-processing-with-python/?ranMID=39197&ranEAID=JVFxdTr9V80&ranSiteID=JVFxdTr9V80-gIa4CDf8o_3HXX8ZIg_F1g&LSNPUBID=JVFxdTr9V80&utm_source=aff-campaign&utm_medium=udemyads> [Accessed 27 October 2021].
#
# 10) Rose, D., 2021. Artificial Intelligence Foundations: Neural Networks Video Tutorial | LinkedIn Learning, formerly Lynda.com. [online] LinkedIn. Available at: <https://www.linkedin.com/learning/artificial-intelligence-foundations-neural-networks/welcome?autoAdvance=true&autoSkip=false&autoplay=true&resume=true&u=57077561> [Accessed 6 December 2021].
#
# 11) PyPI. 2021. clean-text. [online] Available at: <https://pypi.org/project/clean-text/> [Accessed 14 November 2021].
#
# 12) PyPI. 2021. textstat. [online] Available at: <https://pypi.org/project/textstat/> [Accessed 15 November 2021].
#
# 13) Stack Abuse. 2021. Using Regex for Text Manipulation in Python. [online] Available at: <https://stackabuse.com/using-regex-for-text-manipulation-in-python/> [Accessed 16 November 2021].
#
# 14) T., Carvalho, V. and Fedor, Z., 2021. Tensorflow - ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type float). [online] Stack Overflow. Available at: <https://stackoverflow.com/questions/58636087/tensorflow-valueerror-failed-to-convert-a-numpy-array-to-a-tensor-unsupporte> [Accessed 5 December 2021].
#
# 15) Zamzar.com. 2021. Zamzar - video converter, audio converter, image converter, eBook converter. [online] Available at: <https://www.zamzar.com/> [Accessed 7 November 2021].
