# %% [markdown]
# # Using a Convolutional Neural Network for Text Readability Classification
#
# Code cells have been individually cited via comments wherever third-party code has been referred to or implemented, and a citation list has been added at the bottom of this notebook in Harvard style referencing.

# %% [markdown]
# ### Project Overview:
#
# The purpose of this project is to create a text readability classifier (inspired by the flesch kincaid readability tests) that determines whether a piece of text is easy or hard to read. I shall be making use of english textbooks from South-East Asian / Middle Eastern areas as datasets. Since most readability classifiers use data from the United Kingdom / United States in their model, I thought it would be interesting to approach this problem using data from non-western regions to see if they could predict readability scores accurately for english phrases across the world. After building the classifier, I shall test it on speech / interview transcripts of various politicians as a use case to get a bit more insight into their speaking styles.

# %% [markdown]
# ### Project Aim:
#
# 1) To construct a model that allows writers to have more control over their writing, so that they could structure their work according to their intended audience.

# %% [markdown]
# ### Installing and Importing the Required Libraries:

# %%
import numpy as np  
from keras.preprocessing import sequence    
from keras.models import Sequential      
from keras.layers import Dense, Dropout, Activation   
from keras.layers import Conv1D, GlobalMaxPooling1D
from gensim.models.keyedvectors import KeyedVectors
from nltk.tokenize.casual import casual_tokenize
from gensim.models import KeyedVectors
from sklearn.model_selection import train_test_split
import pandas as pd
from random import shuffle
import regex as re
from cleantext import clean
from nltk import word_tokenize
import textstat
#Code editted from NLPIA book ch7 https://github.com/totalgood/nlpia#
# Out:
# Since the GPL-licensed package `unidecode` is not installed, using Python's `unicodedata` package which yields worse results.

# %% [markdown]
# ### Selection of Data:
#
# For this project, I'm using English textbooks of varying grades from different countries. I found all of them on [Library Genesis](https://www.libgen.is/) and since they were PDF files, I then converted them to text files using [Zamzar File Converter](https://www.zamzar.com/). I initially tried using python modules for this task like PDF Miner and PyPDF, but kept running into errors as most of the code I found on StackOverflow was not suitable with the latest version of Python.
#
# For this notebook, I have used a **grade two textbook from Indonesia and a grade ten textbook from India.** The former can be found [here](https://libgen.is/book/index.php?md5=42EEC448F886A2790FC9AE5A2526F0C4), and the latter can be found [here](https://libgen.is/search.php?req=ncert+english&open=0&res=25&view=simple&phrase=1&column=def). The reason for doing so is to verify if the CNN classifier is performing better when given textbooks from two different regions (which turns out to be true in this case).

# %% [markdown]
# ### Preprocessing the Data:
#
# I've used Regex and the Clean-Text Library to prepare the data before the classification task. I defined a 'read_and_clean' function to read any given text file and clean the data in it, whilst replacing the line-breaks according to every condition (as described in the comments) as the text files for this task aren't following a particular pattern with grammar since it was converted from an image-heavy PDF. After that, I'm splitting the sentence after every full stop ('.') and avoiding any sentences with less than two words as it won't be of much use.

# %%
def remove(text):
    text = re.sub(r"#\S+", " ", text) #remove hashtags
    text = re.sub(r"https*\S+", " ", text) #remove URLs
    text = re.sub(r'\w*\d+\w*', '', text) #remove numbers 
    text = re.sub(r'[^a-zA-Z0-9\n\?!\.]', ' ', text) #remove special characters
    text= text.strip(" ")
    text = text.strip(".")
    return text

# %%
# read the file and clean it.
def read_and_clean(file_name):
# read the file
    fs = open(file_name, 'r') 
    book1 = fs.read()
# convert it to . if 2 or more line breaks are together
    book1 = re.sub(r"\n{2,}",". ", book1)
# convert it to . if 2 or more spaces are together
    book1 = re.sub(r"\s{2,}",". ", book1)
# convert a single line break to space if it is followed by a small letter
    book1 = re.sub(r"\n{1}(?=\s[a-z])"," ", book1)
# convert a single line break to space if it is followed by a space and small letter
    book1 = re.sub(r"\n{1}(?=[a-z])"," ", book1)
# convert all remaining line breaks to .
    book1 = re.sub(r"\n",". ", book1)
    total = []
    
    clean(book1,
        no_line_breaks=True) # https://pypi.org/project/clean-text/
    
# split the sentence based on .
    for i in book1.split(". "):
# clean it using above function
        clean_text = remove(i)
# convert the sentence to a list of words and check the length. if it is greater then 2, then consider it a sentence
        if len(word_tokenize(clean_text)) >2:
            total.append(clean_text)
# return the final list
    return total

# %% [markdown]
# ### Labelling the Data and Calling the Functions:

# %%
# read the grade one file
grade_one_sentence = read_and_clean("../data/gradetwoindo.txt")

# %%
label = 0
new_examples1 = []
for i in grade_one_sentence:  
    if len(word_tokenize(i)) >2:
        new_examples1 = new_examples1 + [[i, label]]

# %%
new_examples1 = new_examples1[2000:]

# %%
new_examples1
# Out:
# [['What do you think on the picture tells you about?', 0],
#  ['Is it a legend  myth  or fabel?', 0],
#  ['Where do you think the story happened?', 0],
#  ['Listen to a short story from the tape and  ll in the blanks', 0],
#  ['The Two Friends and the Bear', 0],
#  ['John and James were two friends who were crossing', 0],
#  ['Suddenly  they hit a huge black', 0],
#  ['Imagine how terri ed they were', 0],
#  ['They tried to run but the bear', 0],
#  ['managed to climb up into a tree but', 0],
#  ['fell to the ground and pretended to be dead', 0],
#  ['He knew that a bear will only attack something if it is', 0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['The bear  him all over  while the man tried to hold his breath as best he could  hoping that the animal would not discover the pretence',
#   0],
#  ['Finally  the bear must have thought that the man really was', 0],
#  ['Finally  the danger over  John came down from the tree and asked his friend   Well  what did the bear',
#   0],
#  ['into your ear?', 0],
#  ['It would be good if you fell from the tree and pretended to be dead with me!',
#   0],
#  ['Adapted from   and More Fairy Tales', 0],
#  ['Coca cola is a carbonated soft drink sold in stores  restaurants and vending machines in more than  countries',
#   0],
#  ['It is produced by the coca cola company and is often referred to simply as Coke',
#   0],
#  ['The  rst cocacola recipe was invented in Columbus  Georgia at a drugstore by John Stith',
#   0],
#  ['Pemberton claimed coca cola cured many diseases  including morphine addiction  dyspepsia  neurasthenia  headache and impotance',
#   0],
#  ['When launched coca cola s two key ingredients were cocaine and caffeine',
#   0],
#  ['The cocaine was derived from the coca leave and the caffeine from Kola nutscoca cola  the  K  in Kola was replaced with  C  for marketing purposes ',
#   0],
#  ['Listen to your teacher carefully', 0],
#  ['Then  decide whether the following statements are true  T  or false  F ',
#   0],
#  ['John and James were two friends', 0],
#  ['They hit a huge stone in the mountain', 0],
#  ['They tried to run but the bear chased them', 0],
#  ['John fell to the ground', 0],
#  ['James pretended to be dead', 0],
#  ['The bear smelled the stone', 0],
#  ['Pronounce It!', 0],
#  ['nv  te  n', 0],
#  ['Answer the following question by choosing a  b  c or d based on the text',
#   0],
#  ['X   I want to take my pill', 0],
#  ['Y   Sure! A minute  please', 0],
#  ['Do you want some? b', 0],
#  ['Can you get me a glass of water  please? c', 0],
#  ['Can you take me to the doctor  please? d', 0],
#  ['Will you buy it for me  please?', 0],
#  ['Taken from  en.wikipedia.org', 0],
#  ['live friend rich catch invitation', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Taken from Ujian Nasional Bahasa Inggris  ', 0],
#  ['In this section  you will learn how to', 0],
#  ['express the expressions for asking  giving  and disagreeing with opinions',
#   0],
#  ['express the expressions for asking and giving agreement', 0],
#  ['express the expressions for asking  giving  and rejecting a help', 0],
#  ['express the expressions for asking  offering  giving  and rejecting an item',
#   0],
#  ['express the expressions for responding to a statement', 0],
#  ['retell a narrative text', 0],
#  ['respond to a short functional text in the form of brochure', 0],
#  ['After learning the lesson in this section  you are expected to be able to',
#   0],
#  ['express how to ask  give  and decline opinions correctly', 0],
#  ['express how to give agreement correctly', 0],
#  ['express how to ask  give  and reject help correctly', 0],
#  ['express how to ask  offer  give  and reject an item correctly', 0],
#  ['express how to respond to a statement correctly', 0],
#  ['retell a narrative text correctly', 0],
#  ['understand how to respond to a short functional text in the form of brochure',
#   0],
#  ['What s your opinion about using the internet?', 0],
#  ['Complete these dialogues with suitable expressions provided', 0],
#  ['What do you think about our new friend  Anita?', 0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['Do you have an opinion on the Aceh tragedy?', 0],
#  ['What do you think about the story?', 0],
#  ['What do you think about symphony orchestra?', 0],
#  ['I think it s terrible because it can be dangerous to humans too', 0],
#  ['I think she s so beautiful', 0],
#  ['I m sorry  I haven t read it', 0],
#  ['I don t know', 0],
#  ['I hardly ever listen to symphony orchestra', 0],
#  ['I think the Internet is very useful', 0],
#  ['Act out the dialogue with your friend', 0],
#  ['Pay attention to the italic sentences', 0],
#  ['Maylie   Hi  Maylie', 0],
#  ['How is it going today?', 0],
#  ['Alisa   Oh  hi  Maylie', 0],
#  ['Well  to tell you the truth I m quite sleepy now', 0],
#  ['Maylie   Yeah  I noticed that you have been yawning', 0],
#  ['What did you do last night?', 0],
#  ['Alisa   I stayed up late last night', 0],
#  ['I watched a new', 0],
#  ['lm on DVD  Troy', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Maylie   So  how was it?', 0],
#  ['Alisa   It s a cool  lm', 0],
#  ['Brad Pitt was so lovely', 0],
#  ['How about you? What do you think about it?', 0],
#  ['Maylie   I didn t like it', 0],
#  ['I think it s boring', 0],
#  ['Follow up Activity', 0],
#  ['What is your favourite movie? Give your opinion about the movie', 0],
#  ['Share your favourite movie with your friend and make them interested in watching it',
#   0],
#  ['Watching movies together with your friends can be fun', 0],
#  ['Complete and practise the following dialogues', 0],
#  ['Yup  it s good', 0],
#  ['I think the picture is beautiful', 0],
#  ['Do you think playing football when it s raining is a good idea?', 0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['Do you think these shoes are all right?', 0],
#  ['I think you should wear another costume to the costume party', 0],
#  ['Act out the following dialogue with your friend', 0],
#  ['Then  identify the expressions used', 0],
#  ['Ami   It s almost  p.m', 0],
#  ['How about going to the cafe', 0],
#  ['I m hungry', 0],
#  ['Are you?', 0],
#  ['Ari   A little bit', 0],
#  ['Ami   Listen! After having our dinner we ll go for a play', 0],
#  ['Do you agree?', 0],
#  ['Ari   Why not? That s a good idea', 0],
#  ['How about  The', 0],
#  ['East Side Story ', 0],
#  ['Ami   Great! I ll treat you', 0],
#  ['Ari   Thanks a lot', 0],
#  ['to older people or a stranger', 0],
#  ['to older people or a stranger', 0],
#  ['To ask for agreement  you could use these expressions', 0],
#  ['Do you agree?', 0],
#  ['Would you agree with ...?', 0],
#  ['  wouldn t you say?', 0],
#  ['You can use these expressions to give an agreement', 0],
#  ['That s a good idea', 0],
#  ['Well  that s settled', 0],
#  ['We seem to be saying the same thing', 0],
#  ['You can use these expressions to respond to a statement', 0],
#  ['Why not?', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Study the following situation carefully', 0],
#  ['In the bookstore  you and your friend are discussing which book that you must buy',
#   0],
#  ['The followings are some expressions that you and your friend may say', 0],
#  ['Come on  I m confused', 0],
#  ['Which book must I buy?', 0],
#  ['Don t be so confused', 0],
#  ['Would you agree if I choose this book?', 0],
#  ['Of course not', 0],
#  ['I can t agree with you', 0],
#  ['That book is quite expensive', 0],
#  ['What about this one?', 0],
#  ['No  I disagree with you', 0],
#  ['That s not a good book', 0],
#  ['Some say the author imitates from another book', 0],
#  ['I m so tired', 0],
#  ['Just help me to choose  I know you re the expert', 0],
#  ['But give me one with a reasonable price', 0],
#  ['Work in pairs', 0],
#  ['Compose a good dialogue from the situation in Practice  and practise it',
#   0],
#  ['Look at the picture and answer the questions orally', 0],
#  ['Need some help  Tedi?', 0],
#  ['Yes  of course', 0],
#  ['Could you take these?', 0],
#  ['What do you see in the picture?', 0],
#  ['Who needs some help?', 0],
#  ['What does his friend say?', 0],
#  ['What does he say to respond to the offer?', 0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['Act out the dialogue with your friends', 0],
#  ['Pay attention to the italic sentences', 0],
#  ['Nadine  Fitri  and Dara are friends', 0],
#  ['They are preparing', 0],
#  ['Andre s party', 0],
#  ['Nadine   Fitri  please go to the shop and buy a kilo of sugar', 0],
#  ['We have to bake a cake for Andre s party', 0],
#  ['Let me shut down my computer', 0],
#  ['Nadine   Dara  Can you take thirty plates from the cupboard?', 0],
#  ['Sure  Do you want the pink plates  the blue plates  or the purple plates?',
#   0],
#  ['Nadine   Take the pink and the purple plates', 0],
#  ['Do you want some forks and spoons?', 0],
#  ['Nadine   Yes  Please', 0],
#  ['You re busy baking the cake  Nadine', 0],
#  ['Can I help you?', 0],
#  ['Nadine   No  thanks', 0],
#  ['It s almost done', 0],
#  ['to older people or a stranger', 0],
#  ['to older people or a stranger', 0],
#  ['to older people or a stranger', 0],
#  ['You can use these expressions to ask for a help', 0],
#  ['Can you help me?', 0],
#  ['Would you mind if I ask your help to ', 0],
#  ['I do apologize  but would you kindly helping me to', 0],
#  ['?  do something', 0],
#  ['You can use these expressions to offer help', 0],
#  ['What can I do to help ...?', 0],
#  ['May I help you?', 0],
#  ['May I be assistance?', 0],
#  ['You can use these expressions to give help to someone', 0],
#  ['You look like you could do with some help ', 0],
#  ['You can use these expressions to decline someone s help', 0],
#  ['That s very kind of you  but ', 0],
#  ['To ask for an item  you could use these expressions', 0],
#  ['Can I have ...?', 0],
#  ['Would you be so kind to give me ...?', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Give your response to the following situations', 0],
#  ['Could you be kindly helping me with this heavy bag?', 0],
#  ['You say you will be glad to help', 0],
#  ['Can I help you taking that books upstair?', 0],
#  ['You refuse Desry s help politely', 0],
#  ['Mrs Trihatmojo   Young man  can you show me the way to the travel agency?',
#   0],
#  ['You say you will help her until she reaches the travel agency', 0],
#  ['Let me help you to cook that vegetables', 0],
#  ['You accept your sister s help with pleasure', 0],
#  ['Work in pairs', 0],
#  ['Make a dialogue using the expression of asking  giving and refusing a help and practise them in front of the class',
#   0],
#  ['Look at the picture', 0],
#  ['Then  answer these questions orally', 0],
#  ['Source   Bedtime Stories', 0],
#  ['What is in the picture?', 0],
#  ['Have you ever read a story about them?', 0],
#  ['What other stories have you read?', 0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['Read the following text with good pronunciation', 0],
#  ['Once upon a time there lived two best friends  the hare and the tortoise',
#   0],
#  ['They liked to race against each other  but the hare always won', 0],
#  ['One day  the hare asked the tortoise to race down to the beach', 0],
#  ['The tortoise refused  he said that he will loose anyway', 0],
#  ['The hare replied in a kind voice that he felt sorry about it', 0],
#  ['But the next day  the hare found a way to race the tortoise that would be fair and lots of fun too',
#   0],
#  ['He asked the tortoise to come with him', 0],
#  ['The tortoise was slowly plodding over the sandhill towards the beach', 0],
#  ['Now the two friends can race against each other all day and something tells me that the tortoise might win this time',
#   0],
#  ['Adapted from  Bedtime Stories', 0],
#  ['Retell the story about the hare and the tortoise in your own words', 0],
#  ['Some questions below will help you', 0],
#  ['Work with your partner', 0],
#  ['Find the Indonesian translations for these words and spell them out', 0],
#  ['Use a dictionary to help you', 0],
#  ['Who were the two friends?', 0],
#  ['What did the hare ask the tortoise?', 0],
#  ['What happened next?', 0],
#  ['How did the hare  nd a way to race?', 0],
#  ['How was the end of the story?', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['best race always win beach refused loose sorry', 0],
#  ['Retell your favourite story to your friend', 0],
#  ['Look and study the following brochure and dialogue', 0],
#  ['Good news for bookworms', 0],
#  ['Pay only   for a set of story books in English and', 0],
#  ['All books written by our internal writers', 0],
#  ['If you buy now  you get   discount on your purchases!', 0],
#  ['Don t miss this fantastic offer!', 0],
#  ['Source  CD Images', 0],
#  ['Don t miss this great offer!', 0],
#  ['A set of the most read children s stories written by both local and foreign writers',
#   0],
#  ['Get  fteen books for only  ', 0],
#  ['Available at all bookstores', 0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['Dad   Have you decided  which set of books you want to buy?', 0],
#  ['Didi   Both sets look interesting', 0],
#  ['Famous Fables are written in English while Favourite Stories are written in both languages',
#   0],
#  ['Dad   You get a set of twelve books for   when you buy Favourite Stories',
#   0],
#  ['Didi   But if I buy Famous Fables  I can get a discount on my next purchase',
#   0],
#  ['Fill in the blanks to help Didi choosing a set of books', 0],
#  ['Write a paragraph about the book you want to buy', 0],
#  ['Then share it with your friend in front of the class', 0],
#  ['Which set of books would you buy? Give reasons based on the following points',
#   0],
#  ['price number of books writers offer', 0],
#  ['I would choose', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['In this section  you will learn how to', 0],
#  ['read a narrative text', 0],
#  ['identify the structure of a narrative text', 0],
#  ['After learning the lesson in this section  you are expected to be able to',
#   0],
#  ['read and understand the structure of a narrative text', 0],
#  ['Answer the following questions orally', 0],
#  ['You can make friends over the Internet', 0],
#  ['Just log on to this web site  www.friendster.com', 0],
#  ['Source  maspaulus. les.wordpress.com', 0],
#  ['Do you have a best friend?', 0],
#  ['What kind of friend do you want to have?', 0],
#  ['What is your best friend like?', 0],
#  ['Match the words in column A with their meanings in column B', 0],
#  ['friendly to others like very much people with of the highest social class unexpectedly  all of a sudden',
#   0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['persuaded urge sneak blast', 0],
#  ['cannot move or escape cause to do something by discussion recommend to do something move quietly and secretly big explosion person who works in a household for wages',
#   0],
#  ['Read the following text aloud', 0],
#  ['The Prince and His Best Friends', 0],
#  ['Once upon a time  there lived a kind young prince named Jonathan', 0],
#  ['He was loved  and adored by his people', 0],
#  ['His two close friends were Peter Piper  the servant of the palace and Franklin Greedy  the son of an Aristocrat',
#   0],
#  ['One day  The Prince  Peter Piper  and Franklin', 0],
#  ['Greedy were walking through the forest', 0],
#  ['Suddenly a group of bandits attacked the three boys near an old house', 0],
#  ['They entered the old house and blockaded the gate and doors', 0],
#  ['The three boys were trapped inside the house', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Franklin was very terri ed and asked the Prince to surrender immediately  but Peter was not afraid',
#   0],
#  ['He urged and supported the Prince not to give up', 0],
#  ['Prince decided not to surrender because he realised that he would become a hostage for the bandits to ask for ransom to his father  but Franklin was scared and wanted to make a deal  it made Peter suspicious about Franklin s behaviour',
#   0],
#  ['So he quietly made up a plan for him and the Prince to escape', 0],
#  ['Early at dawn  Franklin opened the front gate and unlocked the doors', 0],
#  ['The bandits entered the house in search of the Prince', 0],
#  ['When they came to the room where the Prince was supposed to be sleeping  no one was there',
#   0],
#  ['Suddenly they heard a horse running outside the house and saw over the window that',
#   0],
#  ['Peter Piper and the Prince were riding away on one of the bandit s horses',
#   0],
#  ['It turns out  Peter Piper sneaked out of the house and waited in the yard  while the Prince was hiding behind the house',
#   0],
#  ['The bandits were very angry at', 0],
#  ['Franklin and took him with them while the Prince and Peter went safely going back to the Capital',
#   0],
#  ['A narrative text is an imaginative story to entertain people', 0],
#  ['Work with your partner', 0],
#  ['Ask your partner these questions', 0],
#  ['What is the meaning of friendship to you?', 0],
#  ['What would you do if your friend betrays you?', 0],
#  ['What would you do if one of your friends was in trouble?', 0],
#  ['Answer the following questions based on the story in', 0],
#  ['What kind of person was Prince Jonathan?', 0],
#  ['Who were Prince Jonathan s friends?', 0],
#  ['What happened when the Prince and his two friends were walking in the forest?',
#   0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['Why did Franklin try to persuade the Prince to surrender?', 0],
#  ['What did Peter Piper do when Franklin tried to persuade the Prince to surrender?',
#   0],
#  ['Why did Franklin sneak out to meet the bandits  leader?', 0],
#  ['Did the Prince manage to escape from the bandits?', 0],
#  ['After you read the story  what did you think of the', 0],
#  ['Prince s friends?', 0],
#  ['Decide whether these statements are true  T  or false  F ', 0],
#  ['The young Prince was hated by his people', 0],
#  ['The young Prince was kind to others', 0],
#  ['The Prince had two best friends', 0],
#  ['Both of the Prince s friends were rich people', 0],
#  ['When the bandits attacked  they hurried back to the castle', 0],
#  ['The Prince and his friends hid in an old house', 0],
#  ['The Prince didn t want to surrender', 0],
#  ['Franklin made an agreement with the bandits', 0],
#  ['The bandits managed to enter the house by breaking the front door', 0],
#  ['The Prince and Peter managed to escape but Franklin didn t', 0],
#  ['Complete this paragraph with the past tense of the verbs in the box', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Once upon a time  two bandits  an old lady', 0],
#  ['near the old bridge over the river', 0],
#  ['The robbery  shopping and  toward the', 0],
#  ['The old lady  bridge', 0],
#  ['When she was near the bridge  two bandits', 0],
#  ['toward her and  her purse', 0],
#  ['and they it', 0],
#  ['Then  they through the forest', 0],
#  ['Find the words that go together', 0],
#  ['to knock to iron to keep to join to perform to play to accept to be to bake to answer',
#   0],
#  ['one s word a club a play clothes at the door in love bread an instrument the questions an invitation',
#   0],
#  ['G r a m m a r Stage', 0],
#  ['Simple Past Tense  Regular Verbs', 0],
#  ['Simple Past Tense is used to describe an event that happened and ended in the past',
#   0],
#  ['Regular verbs form their past tense by adding  d or  ed to the base form',
#   0],
#  ['Observe the following examples', 0],
#  ['Mantu lived in a village deep in the jungle', 0],
#  ['They moved to a bigger house', 0],
#  ['We loved him very much', 0],
#  ['The form of simple Past Tense is', 0],
#  ['Subject   Verb   ed    Object', 0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['Change the following regular verbs into their past forms', 0],
#  ['lie describe cry try stop prefer like control manage look', 0],
#  ['Change the words in the brackets into simple past form', 0],
#  ['I  stay  there for an hour', 0],
#  ['The singer  sing   ve new songs at the concert last week', 0],
#  ['My sister  have  four Barbie dolls', 0],
#  ['But now she has none', 0],
#  ['AC Milan  win  the Champions League in ', 0],
#  ['Mother  buy  me a new pair of shoes', 0],
#  ['Mr Hartawan  become  the president of the company when he was  years old',
#   0],
#  ['In this section  you will learn how to', 0],
#  ['write a good narrative text', 0],
#  ['write the characteristics of narrative text', 0],
#  ['After learning the lesson in this section  you are expected to be able to',
#   0],
#  ['write a good narrative text correctly', 0],
#  ['write the characteristics of narrative text correctly', 0],
#  ['Answer the following questions', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Have you ever written a story?', 0],
#  ['Have you ever tried to write a story in English?', 0],
#  ['Read the following story', 0],
#  ['Mantu s Little Elephant', 0],
#  ['Source   Bedtime Stories', 0],
#  ['Little Mantu lived in a village deep in the jungle where elephants helped the men with their work',
#   0],
#  ['These elephants were so big and strong', 0],
#  ['They could lift up the heaviest logs with their trunks and toss them high in the air',
#   0],
#  ['Now  Mantu had an elephant of his very own', 0],
#  ['His name was Opie', 0],
#  ['He was just a baby and Mantu loved him very much', 0],
#  ['Mantu whispered to Opie s ear that someday he would become the biggest  strongest and bravest elephant in the jungle',
#   0],
#  ['The other elephants heard this', 0],
#  ['They began to laugh and made rude noises with their trunks', 0],
#  ['We re so big and tall  but you re so small', 0],
#  ['You re nothing at all   said one of the big elephants', 0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['Mantu looked up at the huge elephant with a mishievous glint in his eye',
#   0],
#  ['You re so tall and can see far away', 0],
#  ['We can see what is happening down here in the jungle', 0],
#  ['In fact  we would be the  rst to see any slithering snakes that may be a danger',
#   0],
#  ['After hearing the word snakes  the elephants screeched and off they gwents thundering in fright',
#   0],
#  ['Did I say there were snakes?  giggled Mantu', 0],
#  ['I don t think so   smiled Opie', 0],
#  ['Mantu then climbed upon his little friend s back and went home to the village to tell everyone about the foolish elephants',
#   0],
#  ['Adapted from   Bedtime Stories', 0],
#  ['Narrative is to amuse  entertain and to deal with an actual or vicarious experience in different ways',
#   0],
#  ['Narrative deals with problematic events which lead to a crisis or turning point of some kind  which in turn',
#   0],
#  ['nds a resolution', 0],
#  ['It is about the opening paragraph where the characters of the story are introduced',
#   0],
#  ['Example   Little Mantu lived in a village deep in the jungle where elephants helped the men with their work',
#   0],
#  ['Where the problems in the story developed', 0],
#  ['Example   Now  Mantu had an elephant of his very own', 0],
#  ['His name was Opie', 0],
#  ['Where the problems in the story is solved', 0],
#  ['Example   Mantu then climbed upon his little friend s back and went home to the village',
#   0],
#  ['Answer the following questions', 0],
#  ['Where did Little Mantu live?', 0],
#  ['Who was his best friend?', 0],
#  ['What did Mantu whisper in Opie s ear?', 0],
#  ['What made the huge elephant run away?', 0],
#  ['Rewrite the story in Practice  with your own words', 0],
#  ['Share it with the class', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Arrange these paragraphs into a good story', 0],
#  ['The Singer and the Dolphin', 0],
#  ['These are some tips on being a good friend', 0],
#  ['Treat your friends the way you want to be treated', 0],
#  ['Keep secrets that are told to you', 0],
#  ['Pay attention when your friend is talking', 0],
#  ['Keep your promises', 0],
#  ['Share things with your friend', 0],
#  ['Source   Fairy Tales and More', 0],
#  ['Arion did not put up a struggle  instead he asked only that he be allowed to sing one last song',
#   0],
#  ['His wish was granted and the sailors were so enchanted by his voice that they were hardly aware of what happened next',
#   0],
#  ['At the  rst notes of his song  a dolphin swam alongside  attracted by the beautiful music',
#   0],
#  ['Immediately Arion jumped overboard onto the dolphin s back and was carried back across the sea',
#   0],
#  ['In memory of this event  a statue  of a young man on the back of a dolphin  was erected in the port of',
#   0],
#  ['This statue is still there today', 0],
#  ['Arion was one of the most famous singers in the ancient world', 0],
#  ['On one occasion he won an important festival in Sicily  and as his prize he received so many jewels and golden cups that he was obliged to hire a ship to carry them all home to Corinth',
#   0],
#  ['When the ship  nally reached port in Corinth  the wicked sailors began to tell everyone that there had been a storm  during which the famous singer had been lost at sea',
#   0],
#  ['They were struck dumb with amazement  however  when Arion arrived with a company of soldiers to arrest them',
#   0],
#  ['Unfortunately  this huge treasure made the sailors very jealous  and in order to have it for themselves  they attacked the singer and were about to throw him overboard',
#   0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['Work in pairs and study the following picture', 0],
#  ['Write a narrative story that is suitable for the picture', 0],
#  ['Source  mysparkling. les.wordpress.com', 0],
#  ['Write a narrative story of your own', 0],
#  ['Use the following clues to help you', 0],
#  ['Decide where the story is begun', 0],
#  ['Create some characters for good and bad side', 0],
#  ['Create the story con ict', 0],
#  ['Give the solution how the story is ended', 0],
#  ['Retell the story you have arranged with your own words', 0],
#  ['Share it with your friends', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['The Friend Test', 0],
#  ['Below are three questions that will tell you', 0],
#  ['what kind of friend you are.  Answer these questions with your friend', 0],
#  ['Remember that each answer has a point', 0],
#  ['If you have  nished  look at the results part for your score', 0],
#  ['After you finish  check your answers on the next page  then match your score with the descriptions given',
#   0],
#  ['Source  ayiedyary. les.wordpress', 0],
#  ['If your friend tells you a secret that isn t bad but you promised not to tell anyone  do you',
#   0],
#  ['A   tell everyone?', 0],
#  ['B   keep the promise?', 0],
#  ['If you know your friend is planning to cheat on a test  do you', 0],
#  ['A   tell your teacher?', 0],
#  ['B   let your friend cheat?', 0],
#  ['C   help your friend study for the test so he she won t feel he she needs to cheat?',
#   0],
#  ['If your friend tells you a secret and it may be dangerous for him  her  do you',
#   0],
#  ['A   tell a trusted adult?', 0],
#  ['B   keep it a secret?', 0],
#  ['C   tell your friends?', 0],
#  ['Check your answer', 0],
#  ['If your score is', 0],
#  ['It means that you are a best friend', 0],
#  ['You know how to act like a true friend', 0],
#  ['Remember that a friend in need is a friend indeed', 0],
#  ['If your score is  or', 0],
#  ['It means that you are merely just a friend because you have some feeling of apathy towards your friend',
#   0],
#  ['If your score is  or', 0],
#  ['It means that you have to change yourself  because you don t have any feelings at all towards your friend',
#   0],
#  ['Remember if you want to make lots of friends  just treat them the way you want to be treated',
#   0],
#  ['A Friend in Need Is a Friend Indeed', 0],
#  ['What can I do for you?', 0],
#  ['May I help you?', 0],
#  ['Giving and refusing opinions', 0],
#  ['In my opinion ', 0],
#  ['Genre of text  Narrative', 0],
#  ['Social function  To amuse  entertain and to deal with actual or vicarious experiences in different ways',
#   0],
#  ['orientation  sets the scene and introduces the participants', 0],
#  ['evaluation  optional   a step back to evaluate the plight', 0],
#  ['complication  a crisis arises', 0],
#  ['resolution  the crisis is resolved  for better or worse', 0],
#  ['Once upon a time there lived two best friends  the hare and the tortoise',
#   0],
#  ['Grammar  Simple Past Tense   Regular Verbs', 0],
#  ['Mantu lived in a village deep in the jungle', 0],
#  ['They moved to a bigger house', 0],
#  ['L earning Review', 0],
#  ['After studying all subjects in this chapter  answer the following questions',
#   0],
#  ['What will you say to give an opinion?', 0],
#  ['What will you say if you want to ask for an opinion?', 0],
#  ['What do you say to ask for help?', 0],
#  ['What will you say if you want to give help to someone?', 0],
#  ['What will you say if someone offers you help and you want to reject it?',
#   0],
#  ['What do you say to ask for an item or something from someone?', 0],
#  ['What do you say to offer an item to someone?', 0],
#  ['What will you say if you want to give an item to someone?', 0],
#  ['What do you say to ask for someone s agreement?', 0],
#  ['What will you say if you want to give an agreement?', 0],
#  ['If you  nd some dif culties while answering the questions  you can learn the subjects once more or you may consult your teacher',
#   0],
#  ['English in Focus for Grade VIII', 0],
#  ['Source  Stockbyt e', 0],
#  ['Materials You Are Going to Learn in This Chapter', 0],
#  ['Listening to the expressions for starting  extending  and ending a conversation on the phone',
#   0],
#  ['Listening to the expressions for giving attention to the speaker', 0],
#  ['Listening to a recount text', 0],
#  ['Listening to a short functional text in the form of diary', 0],
#  ['Responding to a recount text', 0],
#  ['Starting  extending  and ending a conversation on the phone', 0],
#  ['Giving attention to the speaker', 0],
#  ['Reading aloud a recount text', 0],
#  ['Identifying characteristic of a recount text', 0],
#  ['Writing a recount text', 0],
#  ['Writing a short functional text in the form of letter', 0],
#  ['In this section  you will learn how to', 0],
#  ['listen to the expressions for starting  extending  and ending a conversation on the phone',
#   0],
#  ['listen to the expressions for giving attention to the speaker', 0],
#  ['listen a recount text', 0],
#  ['listen a short functional text in the form of diary', 0],
#  ['After learning the lesson in this section  you are expected to be able to',
#   0],
#  ['listen to the expressions for starting  extending  and ending a conversation on the phone',
#   0],
#  ['listen to the expressions for giving attention to the speaker', 0],
#  ['listen a recount text', 0],
#  ['Answer these questions', 0],
#  ['What will you say to start a conversation?', 0],
#  ['If your friend looks sick  what do you say to show your attention?', 0],
#  ['Listen to the dialogue from the tape and  ll in the blanks', 0],
#  ['Saskia is seeing her doctor to talk about her condition', 0],
#  ['Saskia   Good afternoon  Doctor', 0],
#  ['Please sit down', 0],
#  ['Tell me what s your problem?', 0],
#  ['Saskia   Well  it  yesterday  Doctor', 0],
#  ['I had a fever and headache all day', 0],
#  ['Doctor   OK  let me  you  rst', 0],
#  ['After a while ', 0],
#  ['Saskia   So  doctor  how is it?', 0],
#  ['Doctor   It s  serious', 0],
#  ['You ve caught a cold', 0],
#  ['I suggest you to take a rest tomorrow and don t drink some cold', 0],
#  ['You may not eat fried food also for a while', 0],
#  ['Saskia   All right  Doctor', 0],
#  ['Whatever you say', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Work with your partners', 0],
#  ['Identify the expressions of giving advice in the dialogue in Practice ', 0],
#  ['Pronounce It!', 0],
#  ['fi v  r', 0],
#  ['z m n', 0],
#  ['Work with your partner', 0],
#  ['Look at the picture  then  answer these questions', 0],
#  ['Where do you think the boy in the picture is?', 0],
#  ['What happened to the boy?', 0],
#  ['What treatment does he have?', 0],
#  ['Listen to your teacher reading the following dialogue', 0],
#  ['May I speak to Eric?', 0],
#  ['This is Eric', 0],
#  ['Who s speaking?', 0],
#  ['This is Andre', 0],
#  ['I just want to tell you that I can t go the bookstore with you today', 0],
#  ['Tell me what s wrong?', 0],
#  ['Well  my brother is being treated in the hospital for dengue fever', 0],
#  ['So I have to stay in the hospital today', 0],
#  ['Oh I m sorry to hear that', 0],
#  ['I hope your brother will get well soon', 0],
#  ['I hope so', 0],
#  ['Listen to some questions from the tape about the dialogue in Practice ', 0],
#  ['Listen to your teacher reading a text', 0],
#  ['Work with your partner to complete the text', 0],
#  ['My name is Andre', 0],
#  ['I am fourteen years old', 0],
#  ['I have a little brother', 0],
#  ['His name is Andy', 0],
#  ['He is four years younger than me', 0],
#  ['Two days ago Andy had a', 0],
#  ['My mother tried to lower the fever by giving him some', 0],
#  ['However  the next day  his fever had still not gone down', 0],
#  ['So she took Andy to the', 0],
#  ['In the hospital  the doctor', 0],
#  ['he said that Andy had', 0],
#  ['My mother was very worried  my father tried to calm her down because', 0],
#  ['Andy s  was not very bad', 0],
#  ['There is still hope   said the doctor to my mother', 0],
#  ['Every day  the doctor', 0],
#  ['Andy and gave him the proper  and medicine', 0],
#  ['Finally a week after  Andy s fever had gone down', 0],
#  ['The doctor told us that the critical time had passed and Andy could go home as soon as possible',
#   0],
#  ['English in Focus for Grade VIII', 0],
#  ['Listen to the text in Practice  once again', 0],
#  ['Then  answer these questions', 0],
#  ['How old is Andre?', 0],
#  ['What is Andre s little brother s name?', 0],
#  ['How old is Andy s brother?', 0],
#  ['When did Andy get fever?', 0],
#  ['What did Andy s mother do?', 0],
#  ['What did the doctor say about Andy?', 0],
#  ['What did the doctor do to cure Andy?', 0],
#  ['What do you think we should do to prevent dengue fever?', 0],
#  ['Listen to your teacher reading Beni s diary', 0],
#  ['When I got up  I felt ill  I went back to bed', 0],
#  ['Mum called the doctor', 0],
#  ['But he couldn t come  because he was ill  too', 0],
#  ['The doctor came at  o clock', 0],
#  ['He wrote a prescription for some medicine', 0],
#  ['Mum bought it in the drugstore', 0],
#  ['It was horrible', 0],
#  ['Dad bought me a model aeroplane', 0],
#  ['I read the instructions  but I couldn t make it  because the dog ate the glue',
#   0],
#  ['Mum took the dog to the vet', 0],
#  ['I took my medicine again', 0],
#  ['Listen to some questions about Beni s diary', 0],
#  ['Then choose a  b  c  or d for the correct answer', 0],
#  ['He was ill', 0],
#  ['He called the doctor', 0],
#  ['He went back to bed', 0],
#  ['His mum came to his house', 0],
#  ['The doctor was away', 0],
#  ['The doctor was sick', 0],
#  ['The doctor was busy', 0],
#  ['The doctor was on the way', 0],
#  ['The doctor wrote a prescription', 0],
#  ['The doctor came to Beni s house', 0],
#  ['The doctor went to the shop', 0],
#  ['The doctor bought him some medicines', 0],
#  ['From his mother', 0],
#  ['From his father', 0],
#  ['From his grandfather', 0],
#  ['From his doctor', 0],
#  ['Pay attention to the dialogues', 0],
#  ['When did they happen according to the Practice ?', 0],
#  ['I feel ill', 0],
#  ['Go back to bed  then', 0],
#  ['Good morning  Doctor', 0],
#  ['Don t eat that  you stupid dog!', 0],
#  ['Where are you going  Mum?', 0],
#  ['I m taking the dog to the vet', 0],
#  ['Here you are  Ben', 0],
#  ['You can make your aeroplane', 0],
#  ['Come on  Bento', 0],
#  ['It s good for you', 0],
#  ['Can you write a letter for school  please?', 0],
#  ['Follow up Activity', 0],
#  ['Write your daily activities for the next month in a diary', 0],
#  ['Write down the interesting things that happen everyday', 0],
#  ['Share your interesting memories that happen during the in a month with your friends',
#   0],
#  ['English in Focus for Grade VIII', 0],
#  ['In this section  you will learn how to', 0],
#  ['retell a recount text', 0],
#  ['use the expressions for starting  extending  and ending a conversation on the phone',
#   0],
#  ['use the expressions for giving attention to the speaker', 0],
#  ['After learning the lesson in this section  you are expected to be able to',
#   0],
#  ['retell a recount text', 0],
#  ['understand how to start  extend  and end a conversation on the phone', 0],
#  ['understand how to give attention to the speaker', 0],
#  ['Act the dialogues with your friend', 0],
#  ['Polo  can you help me  please?', 0],
#  ['Sure! What s wrong  Ane? You look sick', 0],
#  ['I ve got a headache  and my body feels cold', 0],
#  ['What? Here  I have a thermometer', 0],
#  ['Let me check your temperature', 0],
#  ['You have a fever  your temperature is quite high', 0],
#  ['I suggest you to see a doctor', 0],
#  ['Coky  can you do me a favour  please?', 0],
#  ['Coky   Of course  what can I do for you?', 0],
#  ['Could you buy some medicine for me? I m not feeling well', 0],
#  ['Coky   I think you ve caught cold', 0],
#  ['Don t worry', 0],
#  ['I ll buy you some medicine', 0],
#  ['Answer the following questions based on the dialogues', 0],
#  ['What happen to Ane in dialogue ?', 0],
#  ['What does Polo do for Ane?', 0],
#  ['What does Coky do for Yeni?', 0],
#  ['These expressions can be used to give attention to someone', 0],
#  ['Tell me what s wrong?', 0],
#  ['It s okay', 0],
#  ['Don t worry', 0],
#  ['Would you like any help?', 0],
#  ['You look in trouble  may I help you  Sir Ma am?', 0],
#  ['to older people or a stranger', 0],
#  ['Complete these dialogues using your own words', 0],
#  ['You ask your friend to come inside your home', 0],
#  ['Your friend feels so sick', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['It s raining heavily outside', 0],
#  ['I feel so sick', 0],
#  ['Practise the following monologue', 0],
#  ['I went to Rahman s house yesterday to do homework', 0],
#  ['I went there with Dodi', 0],
#  ['After  nishing the homework  Rahman made rujak', 0],
#  ['Rahman likes spicy food  so he made it very spicy', 0],
#  ['Actually  I am not used to eating spicy food  but yesterday I could not restrain myself from eating it',
#   0],
#  ['The rujak was very tasty  although it was spicy', 0],
#  ['I ate it too much', 0],
#  ['The next morning I got stomachache and I could not go to school', 0],
#  ['Answer the following questions orally', 0],
#  ['When did the writer go to Rahman s house?', 0],
#  ['Why did the writer go to there?', 0],
#  ['Whom did the writer go with?', 0],
#  ['Who made rujak?', 0],
#  ['Why did the writer not go to school the next morning?', 0],
#  ['Write your own story about bad experience', 0],
#  ['Retell it to your friend', 0],
#  ['Follow the clues below to start arranging your story', 0],
#  ['Remember your most unforgetable bad experience in the past', 0],
#  ['Tell your friend when  where  how it was happened', 0],
#  ['Tell how you can get through the problem', 0],
#  ['What was the moral from your bad experience?', 0],
#  ['Look at the pictures and answer the following questions', 0],
#  ['I see you later', 0],
#  ['Hello  how are you?', 0],
#  ['What are the two people in the pictures doing?', 0],
#  ['What do you think they say to start the conversation?', 0],
#  ['What do you think they say to end the conversation?', 0],
#  ['Act out the following phone conversation with your friend', 0],
#  ['Pay attention to the expressions in italics', 0],
#  ['Yeyen   Hello  Mia', 0],
#  ['This is Diane', 0],
#  ['May I speak to Andre', 0],
#  ['Mia   I m sorry but he s gone out', 0],
#  ['Would you like to leave a message?', 0],
#  ['Please tell Viktor that I won t be able to come for taekwondo practice this afternoon',
#   0],
#  ['I ve sprained my ankle', 0],
#  ['Please tell him to inform Mr Suroso that I can t have the practice for at least a week',
#   0],
#  ['Mia   Oh  I m sorry to hear that', 0],
#  ['I hope your ankle gets better soon', 0],
#  ['Yeyen   Thank you  Mia', 0],
#  ['Mia   Hold on  please', 0],
#  ['Have you seen a doctor?', 0],
#  ['Yeyen   I haven t', 0],
#  ['I don t think it s that bad', 0],
#  ['Mia   I think you d better go to the doctor to check your ankle', 0],
#  ['Yeyen   Thanks for the advice  Mia', 0],
#  ['See you then', 0],
#  ['Mia   You re welcome', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['You can use the expressions to start a conversation on phone', 0],
#  ['Can I speak to ', 0],
#  ['May I speak to ', 0],
#  ['You can use the expressions to extend a conversation on phone', 0],
#  ['Hold on  please', 0],
#  ['By the way', 0],
#  ['You can use the expressions to end a conversation', 0],
#  ['See you then', 0],
#  ['I ll call you later', 0],
#  ['See you again  Sir Ma am', 0],
#  ['Thank you very much', 0],
#  ['to older people or a stranger', 0],
#  ['to older people or a stranger', 0],
#  ['to older people or a stranger', 0],
#  ['Work in pairs', 0],
#  ['Make and practise a phone conversation', 0],
#  ['Use some of the expressions you have just studied', 0],
#  ['G r a m m a r Stage', 0],
#  ['Study the following example', 0],
#  ['Tom has just come back from a music concert', 0],
#  ['His sister  Nina  asks about the concert', 0],
#  ['Nina   Hi  Tom', 0],
#  ['How was the concert?', 0],
#  ['Tom   Hi  Nina', 0],
#  ['Yes  it was great', 0],
#  ['You should go and see their second performance', 0],
#  ['Nina   Wow  really? I ll go and see it then', 0],
#  ['Tom gives advice to Nina to go and see the concert', 0],
#  ['You should go means that it would be a good thing to do', 0],
#  ['We use should  do  when we say what we think it is a good thing to do or the right thing to do',
#   0],
#  ['Give the advice to your friends based on the situation given', 0],
#  ['Use should or shouldn t', 0],
#  ['Your friend is always coughing because he drinks ice too much', 0],
#  ['Advise him to stop drinking ice', 0],
#  ['Your friend has a bad toothache', 0],
#  ['Advise him to go to the dentist as soon as possible', 0],
#  ['In this section  you will learn how to', 0],
#  ['read aloud a recount text', 0],
#  ['identify characteristics of a recount text', 0],
#  ['After learning the lesson in this section  you are expected to be able to',
#   0],
#  ['read aloud a recount text correctly', 0],
#  ['identify characteristics of a recount text correctly', 0],
#  ['Look at the picture and answer the questions', 0],
#  ['Discuss with your partner', 0],
#  ['Then continue to read the following text', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Do you know who Louis Pasteur was?', 0],
#  ['What was his nationality?', 0],
#  ['What did Louis Pasteur do to improve medical science?', 0],
#  ['My Personal Experience', 0],
#  ['Check this web site to get information about health  medicine  and disease',
#   0],
#  ['www.dechacare.com info sehat.com', 0],
#  ['When I was in junior high school  I was not a very diligent student', 0],
#  ['In fact  I was quite lazy', 0],
#  ['I hated all the subjects that I took during school  especially science', 0],
#  ['For me science was very dif cult', 0],
#  ['It was hard for me to remember the chemical processes  physics calculations  and biological processes',
#   0],
#  ['Once  my teacher grounded me in the library because I did not do my Biology homework',
#   0],
#  ['The teacher asked me to read several books and make a summary about them',
#   0],
#  ['When I was browsing the shelves  I found a book entitled  The inventors of Medicine',
#   0],
#  ['OK  this is a start', 0],
#  ['I took it out then began reading it', 0],
#  ['I learned from the book about Edward Jenner', 0],
#  ['He was an English doctor who found the cure for smallpox', 0],
#  ['The next one was Louis Pasteur', 0],
#  ['His interest in bacteria led him to discover the treatments for rabies and anthrax',
#   0],
#  ['Just like Pasteur  Robert Koch s experiments on bacteria also proved that tuberculosis can be spread to others by contact',
#   0],
#  ['Finally  there was Alexander Flemming  a', 0],
#  ['British bacteriologist who found the  rst antibiotic and penicillin', 0],
#  ['After I read the book  I realised that science is useful for human kind',
#   0],
#  ['By studying  we can discover things that can help human kind', 0],
#  ['Therefore  since that moment', 0],
#  ['I managed to change my behaviour and became a doctor', 0],
#  ['Read the text in Practice  again', 0],
#  ['Then  answer the following questions', 0],
#  ['When did the story take place?', 0],
#  ['Was the writer a diligent student?', 0],
#  ['What lessons did the writer hate?', 0],
#  ['What was the title of the book that the writer read?', 0],
#  ['Who were mentioned in the book? Who were they?', 0],
#  ['What happened to the writer after he read the book?', 0],
#  ['Characteristics of Recount Text', 0],
#  ['A recount text is a text that telling the reader about one story  action or activity',
#   0],
#  ['Its goal is to entertaining or informing the reader', 0],
#  ['Orientation tells who was involved  what happened  where the events took place  and when it happened',
#   0],
#  ['Example   When I was in junior high school  I was not a very diligent student',
#   0],
#  ['English in Focus for Grade VIII', 0],
#  ['Decide whether these statements are true  T  or false  F ', 0],
#  ['Events  event  and   tell what happened and in what sequence', 0],
#  ['Example   Once  my teacher grounded me in the library because I did not do my Biology homework',
#   0],
#  ['Reorientation consists of optional closure of events  ending', 0],
#  ['Example   After I read the book  I realised that science is useful for human kind',
#   0],
#  ['The features are including Who? Where? When?', 0],
#  ['Why?  noun or pronoun  and past tense', 0],
#  ['Examples   I  at home  last night  a book  I took', 0],
#  ['The writer was a lazy student when he was in junior high school', 0],
#  ['The writer was grounded because he didn t do his', 0],
#  ['The writer was told to make a book review', 0],
#  ['He looked for the books in a bookstore', 0],
#  ['He found a book about medical health', 0],
#  ['Read aloud the following text after your teacher', 0],
#  ['Pay attention to his her punctuation  wordstress and pause', 0],
#  ['My Football Experience', 0],
#  ['When I was in junior high school  I really loved football', 0],
#  ['Every Saturday afternoon I practised in school  eld with my team and my coach',
#   0],
#  ['They were strong and smart players', 0],
#  ['My coach  Mr Sentana was a kind person', 0],
#  ['But  while he was coaching us  he was very discipline', 0],
#  ['He would grounded anyone who came late and not obeyed the team s rules', 0],
#  ['With Mr Sentana  our team won many tournament in many big cities', 0],
#  ['Our team named after our school', 0],
#  ['Team  from SMP   and we had many fans too  you know', 0],
#  ['Ohh  that was so cool', 0],
#  ['Now  I still love football and have a team too', 0],
#  ['But  my parents warn me to pay attention more to my study  football just for hobby',
#   0],
#  ['Work in pairs', 0],
#  ['Identify the characteristics of the text in Practice ', 0],
#  ['How many diseases can you  nd? Do this in your exercise book', 0],
#  ['Read the following words after your teacher', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['cough headache diabetes smallpox measles malaria fever cancer', 0],
#  ['da   bi ti z', 0],
#  ['sm  lp k', 0],
#  ['m  le r', 0],
#  ['In this section  you will learn how to', 0],
#  ['follow the stages of writing a recount text', 0],
#  ['write a short functional text', 0],
#  ['After learning the lesson in this section  you are expected to be able to',
#   0],
#  ['understand and write a recount text', 0],
#  ['understand and write a short functional text', 0],
#  ['Answer these following questions', 0],
#  ['Have you ever written a letter?', 0],
#  ['Have you ever written a letter about an experience?', 0],
#  ['Do you have a penpal?', 0],
#  ['Study the dialogue and the letter', 0],
#  ['I was in bed for three days', 0],
#  ['I had  u', 0],
#  ['You weren t at school last week  Andrew', 0],
#  ['Were you ill?', 0],
#  ['What was the matter?', 0],
#  ['Are you all right now?', 0],
#  ['Yes  thank you', 0],
#  ['Here s a letter from my mum', 0],
#  ['Jalan Genuk Krajan', 0],
#  ['Dear Miss Titik', 0],
#  ['Andra wasn t at school last week  because he was ill', 0],
#  ['He had  u', 0],
#  ['Here some letters from the students  parents', 0],
#  ['Dear Miss Titik', 0],
#  ['Selina wasn t at school yesterday  because she was at the dentist', 0],
#  ['She had a toothache', 0],
#  ['Dear Miss Titik', 0],
#  ['Benu wasn t at school last Friday  because he was ill', 0],
#  ['He had a temperature and a sore throat', 0],
#  ['Answer the questions based on the dialogue and the letter', 0],
#  ['English in Focus for Grade VIII', 0],
#  ['Who wasn t at school last week?', 0],
#  ['Was he ill last week?', 0],
#  ['What was the matter with him?', 0],
#  ['Is he ill now?', 0],
#  ['Who wrote the letter for Miss Titik?', 0],
#  ['Do this project', 0],
#  ['Classroom Survey  Illness', 0],
#  ['Make a project on medicine', 0],
#  ['Here s your  rst task', 0],
#  ['Find out who wasn t at school in your group last week because they were ill',
#   0],
#  ['No  I wasn t', 0],
#  ['Were you at school on Wednesday', 0],
#  ['Write about your group', 0],
#  ['Tuesday Wednesday Thursday', 0],
#  ['Report the results of your survey in front of the class', 0],
#  ['Do the following project', 0],
#  ['Was anyone ill in your group last week?', 0],
#  ['Write their letter to the teacher', 0],
#  ['Stick it into your Project book', 0],
#  ['Study the following example of a letter', 0],
#  ['orientation orientation event', 0],
#  ['Hello Paula  how are you? It s been a month since I last heard from you',
#   0],
#  ['Well  I just wanted to tell you that I was in a hospital last week', 0],
#  ['According to the doctor  I was infected by dengue fever', 0],
#  ['At  rst  I felt my body became weak then I fainted when I was studying in the classroom',
#   0],
#  ['Then  I was taken to the hospital because of the high fever', 0],
#  ['At the hospital  I was brought into the emergency unit', 0],
#  ['The doctor immediately gave some treatment', 0],
#  ['Finally  I had to stay there for one week', 0],
#  ['Everyday the doctor kept me on a drip', 0],
#  ['At the seventh day  my condition was getting better', 0],
#  ['After the  nal check  the doctor gave me permission to go home', 0],
#  ['Now  I m okay and because of my illness  I am now more careful about keeping in my house clean especially my room  I don t want to get the same illness again',
#   0],
#  ['OK  I think that s all from me  write to me soon ok?', 0],
#  ['Orientation  Information about what  who  where  or when written in a letter',
#   0],
#  ['Events  Events that happened in the past', 0],
#  ['They are conveyed in a sequential pattern', 0],
#  ['Closing  a conclusion on the events', 0],
#  ['Write a letter in the form of recount about your past experience when you were ill or when you were treated in a hospital',
#   0],
#  ['English in Focus for Grade VIII', 0],
#  ['Enrich Your Knowledge', 0],
#  ['These are the things that you can  nd in', 0],
#  ['a First Aid Kit box', 0],
#  ['adhesive tape bandage tweezers cotton', 0],
#  ['antiseptics scissors alcohol', 0],
#  ['Source  www. delux  rstaid.com', 0],
#  ['To cover wounds', 0],
#  ['To pick up things', 0],
#  ['To clean the wounds', 0],
#  ['To cut things', 0],
#  ['To apply antiseptic with', 0],
#  ['To cover wounds with antiseptics', 0],
#  ['To cure infections', 0],
#  ['Find out what they are used for', 0],
#  ['Copy and  ll in the following box into your exercise book', 0],
#  ['Name of Tool', 0],
#  ['If you encounter an emergency situation  you have to use the  rst aid kit to prevent further danger',
#   0],
#  ['Now  decide which things you have to use in order to prevent the following emergency situations',
#   0],
#  ['Your mother cuts herself when she is cutting the vegetables', 0],
#  ['Your little brother falls off his bicycle', 0],
#  ['One of your friends has a thorn slip inside one of his or her', 0],
#  ['A man s hand gets stuck in the door', 0],
#  ['Now his hand is bleeding', 0],
#  ['A boy has bruises on his knee because he hit his knee on the table', 0],
#  ['If I were you  I d ', 0],
#  ['if I were you', 0],
#  ['You d better not ', 0],
#  ['I wouldn t recommend ', 0],
#  ['Offering  accepting  and declining an offer', 0],
#  ['Would you like ...?', 0],
#  ['Not for me  thank you', 0],
#  ['Genre of text  Recount', 0],
#  ['Social function   to give the audience a description of what occurred and when it occurred to retell events for the purpose of informing or entertaining',
#   0],
#  ['Generic structure  orientation  the setting and introduce participants events in time order  tell what happened  in what sequence reorientation  optional closure of events ending',
#   0],
#  ['I went to my Beni s house yesterday to do a homework', 0],
#  ['I went there with Dodi', 0],
#  ['Grammar  Modal s  should', 0],
#  ['Nina   Hi  Tomi', 0],
#  ['How was the concert?', 0],
#  ['Tomi   Hi  Nina', 0],
#  ['Yes  it was great', 0],
#  ['You should go and see their second performance', 0],
#  ['Nina   Wow  really? I ll go and see it then', 0],
#  ['L earning Review', 0],
#  ['After studying all subjects in this chapter  answer the following questions',
#   0],
#  ['What have you learnt in this chapter?', 0],
#  ['What do you say to start a conversation on the phone?', 0],
#  ['What do you say to extend a conversation on the phone?', 0],
#  ['What will you say if you want to end a conversation on the phone?', 0],
#  ['What will you say if you want to give attention to the speaker?', 0],
#  ['If you  nd some dif culties while answering the questions  you can learn the subjects once more or you may consult your teacher',
#   0],
#  ['English in Focus for Grade VIII', 0],
#  ['Share Your Story', 0],
#  ['Materials You Are Going to Learn in This Chapter', 0],
#  ['Listening to the expressions for asking  giving  and denying information',
#   0],
#  ['Listening to the expressions for starting  extending  and ending a conversation',
#   0],
#  ['Listening to the narrative texts', 0],
#  ['Asking  giving  and denying information', 0],
#  ['Starting  extending  and ending a conversation', 0],
#  ['Responding to narrative monologue', 0],
#  ['Reading narrative text', 0],
#  ['Identifying characteristics of narrative text', 0],
#  ['Reading an advertisement', 0],
#  ['Writing a narrative text', 0],
#  ['Writing a short functional text in the form of weather chart', 0],
#  ...]

# %%
# read the grade ten file
grade_ten_sentence = read_and_clean("../data/gradetenindia.txt")

# %%
label = 1
new_examples2 = []
for i in grade_ten_sentence:  
    if len(word_tokenize(i))>2:
        new_examples2 = new_examples2 + [[i, label]]

# %%
new_examples2 = new_examples2[18:]

# %%
new_examples2
# Out:
# [['Tea from Assam', 1],
#  ['ARUP KUMAR DATTA', 1],
#  ['Mijbil the Otter', 1],
#  ['Madam Rides the Bus', 1],
#  ['The Tale of Custard the Dragon', 1],
#  ['The Sermon at Benares', 1],
#  ['For Anne Gregory', 1],
#  ['WILLIAM BUTLER YEATS', 1],
#  ['They say faith can move mountains', 1],
#  ['But what should we put our faith in?', 1],
#  ['This is the question this story delicately poses', 1],
#  ['Lencho is a farmer who writes a letter to God when his crops are ruined  asking for a hundred pesos',
#   1],
#  ['Does Lencho s letter reach God? Does God send him the money?', 1],
#  ['Think what your answers to these questions would be  and guess how the story continues  before you begin to read it',
#   1],
#  ['One of the cheapest ways to send money to someone is through the post office',
#   1],
#  ['Have you ever sent or received money in this way?', 1],
#  ['Here s what you have to do', 1],
#  ['As you read the instructions discuss with your teacher in class the meanings of these words  counter  counter clerk  appropriate  acknowledgement  counterfoil record',
#   1],
#  ['Consult a dictionary if necessary', 1],
#  ['Are there words corresponding to these English words in your languages?',
#   1],
#  ['THE house   the only one in the entire valley   sat on the crest of a low hill',
#   1],
#  ['From this height one could see the river and the field of ripe corn dotted with the flowers that always promised a good harvest',
#   1],
#  ['The only thing the earth needed was a downpour or at least a shower', 1],
#  ['Throughout the morning Lencho   who knew his fields intimately   had done nothing else but see the sky towards the north east',
#   1],
#  ['Now we re really going to get some water  woman', 1],
#  ['The woman who was preparing supper  replied   Yes  God willing ', 1],
#  ['The older boys were working in the field  while the smaller ones were playing near the house until the woman called to them all   Come for dinner ',
#   1],
#  ['It was during the meal that  just as Lencho had predicted  big drops of rain began to fall',
#   1],
#  ['In the north east huge mountains of clouds could be seen approaching', 1],
#  ['The air was fresh and sweet', 1],
#  ['The man went out for no other reason than to have the pleasure of feeling the rain on his body  and when he returned he exclaimed   These aren t raindrops falling from the sky  they are new coins',
#   1],
#  ['The big drops are ten cent pieces and the little ones are fives', 1],
#  ['With a satisfied expression he regarded the field of ripe corn with its flowers  draped in a curtain of rain',
#   1],
#  ['But suddenly a strong wind began to blow and along with the rain very large hailstones began to fall',
#   1],
#  ['These truly did resemble new silver coins', 1],
#  ['The boys  exposing themselves to the rain  ran out to collect the frozen pearls',
#   1],
#  ['It s really getting bad now    exclaimed the man', 1],
#  ['I hope it passes quickly', 1],
#  ['It did not pass quickly', 1],
#  ['For an hour the hail rained on the house  the garden  the hillside  the cornfield  on the whole valley',
#   1],
#  ['The field was white  as if covered with salt', 1],
#  ['Not a leaf remained on the trees', 1],
#  ['The corn was totally destroyed', 1],
#  ['The flowers were gone from the plants', 1],
#  ['Lencho s soul was filled with sadness', 1],
#  ['When the storm had passed  he stood in the middle of the field and said to his sons   A plague of locusts would have left more than this',
#   1],
#  ['The hail has left nothing', 1],
#  ['This year we will have no corn', 1],
#  ['That night was a sorrowful one', 1],
#  ['All our work  for nothing', 1],
#  ['There s no one who can help us', 1],
#  ['We ll all go hungry this year', 1],
#  ['But in the hearts of all who lived in that solitary house in the middle of the valley  there was a single hope  help from God',
#   1],
#  ['Don t be so upset  even though this seems like a total loss', 1],
#  ['Remember  no one dies of hunger', 1],
#  ['That s what they say  no one dies of hunger', 1],
#  ['All through the night  Lencho thought only of his one hope  the help of God  whose eyes  as he had been instructed  see everything  even what is deep in one s conscience',
#   1],
#  ['Lencho was an ox of a man  working like an animal in the fields  but still he knew how to write',
#   1],
#  ['The following Sunday  at daybreak  he began to write a letter which he himself would carry to town and place in the mail',
#   1],
#  ['It was nothing less than a letter to God', 1],
#  ['God   he wrote   if you don t help me  my family and I will go hungry this year',
#   1],
#  ['I need a hundred pesos in order to sow my field again and to live until the crop comes  because the hailstorm',
#   1],
#  ['He wrote  To God  on the envelope  put the letter inside and  still troubled  went to town',
#   1],
#  ['At the post office  he placed a stamp on the letter and dropped it into the mailbox',
#   1],
#  ['One of the employees  who was a postman and also helped at the post office  went to his boss laughing heartily and showed him the letter to God',
#   1],
#  ['Never in his career as a postman had he known that address', 1],
#  ['The postmaster   a fat  amiable fellow   also broke out laughing  but almost immediately he turned serious and  tapping the letter on his desk  commented   What faith! I wish I had the faith of the man who wrote this letter',
#   1],
#  ['Starting up a correspondence with God!', 1],
#  ['So  in order not to shake the writer s faith in God  the postmaster came up with an idea  answer the letter',
#   1],
#  ['But when he opened it  it was evident that to answer it he needed something more than goodwill  ink and paper',
#   1],
#  ['But he stuck to his resolution  he asked for money from his employees  he himself gave part of his salary  and several friends of his were obliged to give something  for an act of charity ',
#   1],
#  ['It was impossible for him to gather together the hundred pesos  so he was able to send the farmer only a little more than half',
#   1],
#  ['He put the money in an envelope addressed to Lencho and with it a letter containing only a single word as a signature  God',
#   1],
#  ['The following Sunday Lencho came a bit earlier than usual to ask if there was a letter for him',
#   1],
#  ['It was the postman himself who handed the letter to him while the postmaster  experiencing the contentment of a man who has performed a good deed  looked on from his office',
#   1],
#  ['Lencho showed not the slightest surprise on seeing the money  such was his confidence   but he became angry when he counted the money',
#   1],
#  ['God could not have made a mistake  nor could he have denied Lencho what he had requested',
#   1],
#  ['Immediately  Lencho went up to the window to ask for paper and ink', 1],
#  ['On the public writing table  he started to write  with much wrinkling of his brow  caused by the effort he had to make to express his ideas',
#   1],
#  ['When he finished  he went to the window to buy a stamp which he licked and then affixed to the envelope with a blow of his fist',
#   1],
#  ['The moment the letter fell into the mailbox the postmaster went to open it',
#   1],
#  ['It said   God  Of the money that I asked for  only seventy pesos reached me',
#   1],
#  ['Send me the rest  since I need it very much', 1],
#  ['But don t send it to me through the mail because the post office employees are a bunch of crooks',
#   1],
#  ['The italicised parts of the sentences give us more information about Lencho and the woman',
#   1],
#  ['We call them relative clauses', 1],
#  ['Notice that they begin with a relative pronoun who', 1],
#  ['Other common relative pronouns are whom  whose  and which', 1],
#  ['The relative clauses in  a  and  b  above are called non defining  because we already know the identity of the person they describe',
#   1],
#  ['Lencho is a particular person  and there is a particular woman he speaks to',
#   1],
#  ['We don t need the information in the relative clause to pick these people out from a larger set',
#   1],
#  ['A non defining relative clause usually has a comma in front of it and a comma after it  some writers use a dash     instead  as in the story ',
#   1],
#  ['If the relative clause comes at the end  we just put a full stop', 1],
#  ['Dear Arti  How are you? I m sorry I haven t written for a very long time',
#   1],
#  ['I think I last sent you a birthday card in the month of September ', 1],
#  ['We have just moved house  see our new address above ', 1],
#  ['This is our new home', 1],
#  ['Sarah has just about started going to school', 1],
#  ['We have admitted her to  Little Feet  as this is very close to our new home',
#   1],
#  ['I m sitting here by the window sill  writing to you', 1],
#  ['There is a slight drizzle outside and I m reminded of the good times we had together at Bangalore last year',
#   1],
#  ['Do write back', 1],
#  ['The way a crow Shook down on me The dust of snow From a hemlock tree Has given my heart',
#   1],
#  ['A change of mood And saved some part Of a day I had rued', 1],
#  ['Some say the world will end in fire Some say in ice', 1],
#  ['From what I ve tasted of desire I hold with those who favour fire', 1],
#  ['But if it had to perish twice  I think I know enough of hate To say that for destruction ice Is also great And would suffice',
#   1],
#  ['Apartheid  is a political system that separates people according to their race',
#   1],
#  ['In this extract from his autobiography  Long Walk to Freedom  Mandela speaks about a historic occasion   the inauguration ',
#   1],
#  ['Can you guess what the occasion might be? Nelson Mandela has become South Africa s first Black President after more than three centuries of white rule',
#   1],
#  ['Mr Mandela s African National Congress  ANC  party won  of the  seats in the first democratic elections of South Africa s history',
#   1],
#  ['The inauguration ceremony took place in the Union Buildings amphitheatre in Pretoria today  attended by politicians and dignitaries from more than  countries around the world',
#   1],
#  ['Never  never again will this beautiful land experience the oppression of one by another   said Nelson Mandela in his address',
#   1],
#  ['Jubilant scenes on the streets of Pretoria followed the ceremony with blacks  whites and coloureds celebrating together',
#   1],
#  ['More than   South African men  women and children of all races sang and danced with joy',
#   1],
#  ['TENTH May dawned bright and clear', 1],
#  ['For the past few days I had been pleasantly besieged by dignitaries and world leaders who were coming to pay their respects before the inauguration',
#   1],
#  ['The inauguration would be the largest gathering ever of international leaders on South African soil',
#   1],
#  ['The ceremonies took place in the lovely sandstone amphitheatre formed by the Union Buildings in Pretoria',
#   1],
#  ['For decades this had been the seat of white supremacy  and now it was the site of a rainbow gathering of different colours and nations for the installation of South Africa s first democratic  non racial government',
#   1],
#  ['On that lovely autumn day I was accompanied by my daughter Zenani', 1],
#  ['On the podium  Mr de Klerk was first sworn in as second deputy president',
#   1],
#  ['Then Thabo Mbeki was sworn in as first deputy president', 1],
#  ['When it was my turn  I pledged to obey and uphold the Constitution and to devote myself to the wellbeing of the Republic and its people',
#   1],
#  ['To the assembled guests and the watching world  I said  Today  all of us do  by our presence here',
#   1],
#  ['confer glory and hope to newborn liberty', 1],
#  ['Out of the experience of an extraordinary human disaster that lasted too long  must be born a society of which all humanity will be proud',
#   1],
#  ['We  who were outlaws not so long ago  have today been given the rare privilege to be host to the nations of the world on our own soil',
#   1],
#  ['We thank all of our distinguished international guests for having come to take possession with the people of our country of what is  after all  a common victory for justice  for peace  for human dignity',
#   1],
#  ['We have  at last  achieved our political emancipation', 1],
#  ['We pledge ourselves to liberate all our people from the continuing bondage of poverty  deprivation  suffering  gender and other discrimination',
#   1],
#  ['Never  never  and never again shall it be that this beautiful land will again experience the oppression of one by another',
#   1],
#  ['The sun shall never set on so glorious a human achievement', 1],
#  ['Let freedom reign', 1],
#  ['God bless Africa! A few moments later we all lifted our eyes in awe as a spectacular array of South African jets  helicopters and troop carriers roared in perfect formation over the Union Buildings',
#   1],
#  ['It was not only a display of pinpoint precision and military force  but a demonstration of the military s loyalty to democracy  to a new government that had been freely and fairly elected',
#   1],
#  ['Only moments before  the highest generals of the South African defence force and police  their chests bedecked with ribbons and medals from days gone by  saluted me and pledged their loyalty',
#   1],
#  ['I was not unmindful of the fact that not so many years before they would not have saluted but arrested me',
#   1],
#  ['Finally a chevron of Impala jets left a smoke trail of the black  red  green  blue and gold of the new South African flag',
#   1],
#  ['The day was symbolised for me by the playing of our two national anthems  and the vision of whites singing  Nkosi Sikelel  iAfrika  and blacks singing  Die Stem   the old anthem of the Republic',
#   1],
#  ['Although that day neither group knew the lyrics of the anthem they once despised  they would soon know the words by heart',
#   1],
#  ['On the day of the inauguration  I was overwhelmed with a sense of history',
#   1],
#  ['In the first decade of the twentieth century  a few years after the bitter Anglo Boer war and before my own birth  the white skinned peoples of South Africa patched up their differences and erected a system of racial domination against the dark skinned peoples of their own land',
#   1],
#  ['The structure they created formed the basis of one of the harshest  most inhumane  societies the world has ever known',
#   1],
#  ['Now  in the last decade of the twentieth century  and my own eighth decade as a man  that system had been overturned forever and replaced by one that recognised the rights and freedoms of all peoples  regardless of the colour of their skin',
#   1],
#  ['That day had come about through the unimaginable sacrifices of thousands of my people  people whose suffering and courage can never be counted or repaid',
#   1],
#  ['I felt that day  as I have on so many other days  that I was simply the sum of all those African patriots who had gone before me',
#   1],
#  ['That long and noble line ended and now began again with me', 1],
#  ['I was pained that I was not able to thank them and that they were not able to see what their sacrifices had wrought',
#   1],
#  ['The policy of apartheid created a deep and lasting wound in my country and my people',
#   1],
#  ['All of us will spend many years  if not generations  recovering from that profound hurt',
#   1],
#  ['But the decades of oppression and brutality had another  unintended  effect  and that was that it produced the Oliver Tambos  the Walter Sisulus  the Chief Luthulis  the Yusuf Dadoos  the Bram Fischers  the Robert Sobukwes of our time    men of such extraordinary courage  wisdom and generosity that their like may never be known again',
#   1],
#  ['Perhaps it requires such depths of oppression to create such heights of character',
#   1],
#  ['My country is rich in the minerals and gems that lie beneath its soil  but I have always known that its greatest wealth is its people  finer and truer than the purest diamonds',
#   1],
#  ['It is from these comrades in the struggle that I learned the meaning of courage',
#   1],
#  ['Time and again  I have seen men and women risk and give their lives for an idea',
#   1],
#  ['I have seen men stand up to attacks and torture without breaking  showing a strength and resilience that defies the imagination',
#   1],
#  ['I learned that courage was not the absence of fear  but the triumph over it',
#   1],
#  ['The brave man is not he who does not feel afraid  but he who conquers that fear',
#   1],
#  ['No one is born hating another person because of the colour of his skin  or his background  or his religion',
#   1],
#  ['People must learn to hate  and if they can learn to hate  they can be taught to love  for love comes more naturally to the human heart than its opposite',
#   1],
#  ['Even in the grimmest times in prison  when my comrades and I were pushed to our limits  I would see a glimmer of humanity in one of the guards  perhaps just for a second  but it was enough to reassure me and keep me going',
#   1],
#  ['Man s goodness is a flame that can be hidden but never extinguished', 1],
#  ['In life  every man has twin obligations   obligations to his family  to his parents  to his wife and children  and he has an obligation to his people  his community  his country',
#   1],
#  ['In a civil and humane society  each man is able to fulfil those obligations according to his own inclinations and abilities',
#   1],
#  ['But in a country like South Africa  it was almost impossible for a man of my birth and colour to fulfil both of those obligations',
#   1],
#  ['In South Africa  a man of colour who attempted to live as a human being was punished and isolated',
#   1],
#  ['In South Africa  a man who tried to fulfil his duty to his people was inevitably ripped from his family and his home and was forced to live a life apart  a twilight existence of secrecy and rebellion',
#   1],
#  ['I did not in the beginning choose to place my people above my family  but in attempting to serve my people  I found that I was prevented from fulfilling my obligations as a son  a brother  a father and a husband',
#   1],
#  ['I was not born with a hunger to be free', 1],
#  ['I was born free   free in every way that I could know', 1],
#  ['Free to run in the fields near my mother s hut  free to swim in the clear stream that ran through my village  free to roast mealies under the stars and ride the broad backs of slow moving bulls',
#   1],
#  ['As long as I obeyed my father and abided by the customs of my tribe  I was not troubled by the laws of man or God',
#   1],
#  ['It was only when I began to learn that my boyhood freedom was an illusion  when I discovered as a young man that my freedom had already been taken from me  that I began to hunger for it',
#   1],
#  ['At first  as a student  I wanted freedom only for myself  the transitory freedoms of being able to stay out at night  read what I pleased and go where I chose',
#   1],
#  ['Later  as a young man in Johannesburg  I yearned for the basic and honourable freedoms of achieving my potential  of earning my keep  of marrying and having a family   the freedom not to be obstructed in a lawful life',
#   1],
#  ['But then I slowly saw that not only was I not free  but my brothers and sisters were not free',
#   1],
#  ['I saw that it was not just my freedom that was curtailed  but the freedom of everyone who looked like I did',
#   1],
#  ['That is when I joined the African National Congress  and that is when the hunger for my own freedom became the greater hunger for the freedom of my people',
#   1],
#  ['It was this desire for the freedom of my people to live their lives with dignity and selfrespect that animated my life  that transformed a frightened young man into a bold one  that drove a law abiding attorney to become a criminal  that turned a family loving husband into a man without a home  that forced a life loving man to live like a monk',
#   1],
#  ['I am no more virtuous or self sacrificing than the next man  but I found that I could not even enjoy the poor and limited freedoms I was allowed when I knew my people were not free',
#   1],
#  ['Freedom is indivisible  the chains on anyone of my people were the chains on all of them  the chains on all of my people were the chains on me',
#   1],
#  ['I knew that the oppressor must be liberated just as surely as the oppressed',
#   1],
#  ['A man who takes away another man s freedom is a prisoner of hatred  he is locked behind the bars of prejudice and narrowmindedness',
#   1],
#  ['I am not truly free if I am taking away someone else s freedom  just as surely as I am not free when my freedom is taken from me',
#   1],
#  ['The oppressed and the oppressor alike are robbed of their humanity', 1],
#  ['This poem contrasts a tiger in the zoo with the tiger in its natural habitat',
#   1],
#  ['The poem moves from the zoo to the jungle  and back again to the zoo', 1],
#  ['Read the poem silently once  and say which stanzas speak about the tiger in the zoo  and which ones speak about the tiger in the jungle',
#   1],
#  ['He stalks in his vivid stripes  The few steps of his cage  On pads of velvet quiet  In his quiet rage',
#   1],
#  ['He should be lurking in shadow  Sliding through long grass  Near the water hole  Where plump deer pass',
#   1],
#  ['He should be snarling around houses  At the jungle s edge  Baring his white fangs  his claws  Terrorising the village!',
#   1],
#  ['But he s locked in a concrete cell  His strength behind bars  Stalking the length of his cage  Ignoring visitors',
#   1],
#  ['He hears the last voice at night  The patrolling cars  And stares with his brilliant eyes  At the brilliant stars',
#   1],
#  ['His vision  from the constantly passing bars  has grown so weary that it cannot hold anything else',
#   1],
#  ['It seems to him there are a thousand bars  and behind the bars  no world',
#   1],
#  ['As he paces in cramped circles  over and over  the movement of his powerful soft strides is like a ritual dance around a centre in which a mighty will stands paralysed',
#   1],
#  ['Only at times  the curtain of the pupils lifts  quietly', 1],
#  ['An image enters in  rushes down through the tensed  arrested muscles  plunges into the heart and is gone',
#   1],
#  ['THE young seagull was alone on his ledge', 1],
#  ['His two brothers and his sister had already flown away the day before', 1],
#  ['He had been afraid to fly with them', 1],
#  ['Somehow when he had taken a little run forward to the brink of the ledge and attempted to flap his wings he became afraid',
#   1],
#  ['The great expanse of sea stretched down beneath  and it was such a long way down   miles down',
#   1],
#  ['He felt certain that his wings would never support him  so he bent his head and ran away back to the little hole under the ledge where he slept at night',
#   1],
#  ['Even when each of his brothers and his little sister  whose wings were far shorter than his own  ran to the brink  flapped their wings  and flew away  he failed to muster up courage to take that plunge which appeared to him so desperate',
#   1],
#  ['His father and mother had come around calling to him shrilly  upbraiding him  threatening to let him starve on his ledge unless he flew away',
#   1],
#  ['But for the life of him he could not move', 1],
#  ['That was twenty four hours ago', 1],
#  ['Since then nobody had come near him', 1],
#  ['The day before  all day long  he had watched his parents flying about with his brothers and sister  perfecting them in the art of flight  teaching them how to skim the waves and how to dive for fish',
#   1],
#  ['He had  in fact  seen his older brother catch his first herring and devour it  standing on a rock  while his parents circled around raising a proud cackle',
#   1],
#  ['And all the morning the whole family had walked about on the big plateau midway down the opposite cliff taunting him with his cowardice',
#   1],
#  ['The sun was now ascending the sky  blazing on his ledge that faced the south',
#   1],
#  ['He felt the heat because he had not eaten since the previous nightfall', 1],
#  ['He stepped slowly out to the brink of the ledge  and standing on one leg with the other leg hidden under his wing  he closed one eye  then the other  and pretended to be falling asleep',
#   1],
#  ['Still they took no notice of him', 1],
#  ['He saw his two brothers and his sister lying on the plateau dozing with their heads sunk into their necks',
#   1],
#  ['His father was preening the feathers on his white back', 1],
#  ['Only his mother was looking at him', 1],
#  ['She was standing on a little high hump on the plateau  her white breast thrust forward',
#   1],
#  ['Now and again  she tore at a piece of fish that lay at her feet and then scrapped each side of her beak on the rock',
#   1],
#  ['The sight of the food maddened him', 1],
#  ['How he loved to tear food that way  scrapping his beak now and again to whet it',
#   1],
#  ['Ga  ga  ga   he cried begging her to bring him some food', 1],
#  ['Gaw col ah   she screamed back derisively', 1],
#  ['But he kept calling plaintively  and after a minute or so he uttered a joyful scream',
#   1],
#  ['His mother had picked up a piece of the fish and was flying across to him with it',
#   1],
#  ['He leaned out eagerly  tapping the rock with his feet  trying to get nearer to her as she flew across',
#   1],
#  ['But when she was just opposite to him  she halted  her wings motionless  the piece of fish in her beak almost within reach of his beak',
#   1],
#  ['He waited a moment in surprise  wondering why she did not come nearer  and then  maddened by hunger  he dived at the fish',
#   1],
#  ['With a loud scream he fell outwards and downwards into space', 1],
#  ['Then a monstrous terror seized him and his heart stood still', 1],
#  ['He could hear nothing', 1],
#  ['But it only lasted a minute', 1],
#  ['The next moment he felt his wings spread outwards', 1],
#  ['The wind rushed against his breast feathers  then under his stomach  and against his wings',
#   1],
#  ['He could feel the tips of his wings cutting through the air', 1],
#  ['He was not falling headlong now', 1],
#  ['He was soaring gradually downwards and outwards', 1],
#  ['He was no longer afraid', 1],
#  ['He just felt a bit dizzy', 1],
#  ['Then he flapped his wings once and he soared upwards', 1],
#  ['Ga  ga  ga  Ga  ga  ga  Gaw col ah   his mother swooped past him  her wings making a loud noise',
#   1],
#  ['He answered her with another scream', 1],
#  ['Then his father flew over him screaming', 1],
#  ['He saw his two brothers and his sister flying around him curveting and banking and soaring and diving',
#   1],
#  ['Then he completely forgot that he had not always been able to fly  and commended himself to dive and soar and curve  shrieking shrilly',
#   1],
#  ['He was near the sea now  flying straight over it  facing straight out over the ocean',
#   1],
#  ['He saw a vast green sea beneath him  with little ridges moving over it and he turned his beak sideways and cawed amusedly',
#   1],
#  ['His parents and his brothers and sister had landed on this green flooring ahead of him',
#   1],
#  ['They were beckoning to him  calling shrilly', 1],
#  ['He dropped his legs to stand on the green sea', 1],
#  ['His legs sank into it', 1],
#  ['He screamed with fright and attempted to rise again flapping his wings', 1],
#  ['But he was tired and weak with hunger and he could not rise  exhausted by the strange exercise',
#   1],
#  ['His feet sank into the green sea  and then his belly touched it and he sank no farther',
#   1],
#  ['He was floating on it  and around him his family was screaming  praising him and their beaks were offering him scraps of dog fish',
#   1],
#  ['He had made his first flight', 1],
#  ['THE moon was coming up in the east  behind me  and stars were shining in the clear sky above me',
#   1],
#  ['There wasn t a cloud in the sky', 1],
#  ['I was happy to be alone high up above the sleeping countryside', 1],
#  ['I was flying my old Dakota aeroplane over France back to England', 1],
#  ['I was dreaming of my holiday and looking forward to being with my family',
#   1],
#  ['I looked at my watch  one thirty in the morning', 1],
#  ['I should call Paris Control soon   I thought', 1],
#  ['As I looked down past the nose of the aeroplane  I saw the lights of a big city in front of me',
#   1],
#  ['I switched on the radio and said   Paris Control  Dakota DS  here', 1],
#  ['Can you hear me? I m on my way to England', 1],
#  ['The voice from the radio answered me immediately   DS   I can hear you', 1],
#  ['You ought to turn twelve degrees west now  DS', 1],
#  ['Over.  I checked the map and the compass  switched over to my second and last fuel tank  and turned the Dakota twelve degrees west towards England',
#   1],
#  ['I ll be in time for breakfast   I thought', 1],
#  ['A good big English breakfast! Everything was going well   it was an easy flight',
#   1],
#  ['Paris was about  kilometres behind me when I saw the clouds', 1],
#  ['They looked like black mountains standing in front of me across the sky',
#   1],
#  ['I knew I could not fly up and over them  and I did not have enough fuel to fly around them to the north or south',
#   1],
#  ['I ought to go back to Paris   I thought  but I wanted to get home', 1],
#  ['I wanted that breakfast', 1],
#  ['I ll take the risk   I thought  and flew that old Dakota straight into the storm',
#   1],
#  ['Inside the clouds  everything was suddenly black', 1],
#  ['It was impossible to see anything outside the aeroplane', 1],
#  ['The old aeroplane jumped and twisted in the air', 1],
#  ['I looked at the compass', 1],
#  ['I couldn t believe my eyes  the compass was turning round and round and round',
#   1],
#  ['It was dead', 1],
#  ['It would not work! The other instruments were suddenly dead  too', 1],
#  ['I tried the radio', 1],
#  ['Paris Control? Paris Control? Can you hear me?  There was no answer', 1],
#  ['The radio was dead too', 1],
#  ['I had no radio  no compass  and I could not see where I was', 1],
#  ['I was lost in the storm', 1],
#  ['Then  in the black clouds quite near me  I saw another aeroplane', 1],
#  ['It had no lights on its wings  but I could see it flying next to me through the storm',
#   1],
#  ['I could see the pilot s face   turned towards me', 1],
#  ['I was very glad to see another person', 1],
#  ['He lifted one hand and waved', 1],
#  ['Follow me   he was saying', 1],
#  ['Follow me.   He knows that I am lost   I thought', 1],
#  ['He s trying to help me.  He turned his aeroplane slowly to the north  in front of my Dakota  so that it would be easier for me to follow him',
#   1],
#  ['I was very happy to go behind the strange aeroplane like an obedient child',
#   1],
#  ['After half an hour the strange black aeroplane was still there in front of me in the clouds',
#   1],
#  ['Now there was only enough fuel in the old Dakota s last tank to fly for five or ten minutes more',
#   1],
#  ['I was starting to feel frightened again', 1],
#  ['But then he started to go down and I followed through the storm', 1],
#  ['Suddenly I came out of the clouds and saw two long straight lines of lights in front of me',
#   1],
#  ['It was a runway! An airport! I was safe! I turned to look for my friend in the black aeroplane  but the sky was empty',
#   1],
#  ['There was nothing there', 1],
#  ['The black aeroplane was gone', 1],
#  ['I could not see it anywhere', 1],
#  ['I landed and was not sorry to walk away from the old Dakota near the control tower',
#   1],
#  ['I went and asked a woman in the control centre where I was and who the other pilot was',
#   1],
#  ['I wanted to say  Thank you', 1],
#  ['She looked at me very strangely  and then laughed', 1],
#  ['Another aeroplane? Up there in this storm? No other aeroplanes were flying tonight',
#   1],
#  ['Yours was the only one I could see on the radar.  So who helped me to arrive there safely without a compass or a radio  and without any more fuel in my tanks? Who was the pilot on the strange black aeroplane  flying in the storm  without lights?',
#   1],
#  ['This humorous poem suggests some dangerous ways to identify  or  tell   wild animals! Read it aloud  keeping to a strong and regular rhythm',
#   1],
#  ['Does  dyin  really rhyme with  lion ? Can you say it in such a way that it does? How does the poet suggest that you identify the lion and the tiger?',
#   1],
#  ['When can you do so  according to him? Do you think the words  lept  and  lep  in the third stanza are spelt correctly?',
#   1],
#  ['Why does the poet spell them like this? Do you know what a  bearhug  is? It s a friendly and strong hug   such as bears are thought to give  as they attack you!',
#   1],
#  ['Again  hyenas are thought to laugh  and crocodiles to weep   crocodile tears   as they swallow their victims',
#   1],
#  ['Are there similar expressions and popular ideas about wild animals in your own language s ? Look at the line  A novice might nonplus ',
#   1],
#  ['How would you write this  correctly ? Why is the poet s  incorrect  line better in the poem? Can you find other examples of poets taking liberties with language  either in English or in your own language s ?',
#   1],
#  ['Can you find examples of humorous poems in your own language s ? Much of the humour in the poem arises from the way language is used  although the ideas are funny as well',
#   1],
#  ['If there are particular lines in the poem that you especially like  share these with the class  speaking briefly about what it is about the ideas or the language that you like or find funny',
#   1],
#  ['A boy loses a ball', 1],
#  ['He is very upset', 1],
#  ['A ball doesn t cost much  nor is it difficult to buy another ball', 1],
#  ['Why then is the boy so upset? Read the poem to see what the poet thinks has been lost  and what the boy has to learn from the experience of losing something',
#   1],
#  ['What is the boy now  who has lost his ball  What  what is he to do?', 1],
#  ['I saw it go  Merrily bouncing  down the street  and then Merrily over   there it is in the water! No use to say  O there are other balls   An ultimate shaking grief fixes the boy As he stands rigid  trembling  staring down All his young days into the harbour where His ball went',
#   1],
#  ['I would not intrude on him  A dime  another ball  is worthless', 1],
#  ['Now He senses first responsibility In a world of possessions', 1],
#  ['People will take Balls  balls will be lost always  little boy', 1],
#  ['And no one buys a ball back', 1],
#  ['Money is external', 1],
#  ['He is learning  well behind his desperate eyes  The epistemology of loss  how to stand up Knowing what every man must one day know And most know many days  how to stand up.Anneliese Marie  Anne  Frank   June    February March   was a German   born Jewish girl who wrote while in hiding with her family and four friends in Amsterdam during the German occupation of the Netherlands in World War II',
#   1],
#  ['Her family had moved to Amsterdam after the Nazis gained power in Germany but were trapped when the Nazi occupation extended into the Netherlands',
#   1],
#  ['As persecutions against the Jewish population increased  the family went into hiding in July  in hidden rooms in her father Otto Frank s office building',
#   1],
#  ['After two years in hiding  the group was betrayed and transported to the concentration camp system where Anne died of typhus in Bergen Belsen within days of her sister  Margot Frank',
#   1],
#  ['Her father  Otto  the only survivor of the group  returned to Amsterdam after the war ended  to find that her diary had been saved',
#   1],
#  ['Convinced that it was a unique record  he took action to have it published in English under the name The Diary of a Young Girl',
#   1],
#  ['The diary was given to Anne Frank for her thirteenth birthday and chronicles the events of her life from  June  until its final entry of  August ',
#   1],
#  ['It was eventually translated from its original Dutch into many languages and became one of the world s most widely read books',
#   1],
#  ['There have also been several films  television and theatrical productions  and even an opera  based on the diary',
#   1],
#  ['Described as the work of a mature and insightful mind  the diary provides an intimate examination of daily life under Nazi occupation',
#   1],
#  ['Anne Frank has become one of the most renowned and discussed of the Holocaust victims',
#   1],
#  ['WRITING in a diary is a really strange experience for someone like me', 1],
#  ['Not only because I ve never written anything before  but also because it seems to me that later on neither I nor anyone else will be interested in the musings of a thirteen year old schoolgirl',
#   1],
#  ['Oh well  it doesn t matter', 1],
#  ['I feel like writing  and I have an even greater need to get all kinds of things off my chest',
#   1],
#  ['Paper has more patience than people.  I thought of this saying on one of those days when I was feeling a little depressed and was sitting at home with my chin in my hands  bored and listless  wondering whether to stay in or go out',
#   1],
#  ['I finally stayed where I was  brooding  Yes  paper does have more patience  and since I m not planning to let anyone else read this stiff backed notebook grandly referred to as a  diary   unless I should ever find a real friend  it probably won t make a bit of difference',
#   1],
#  ['Now I m back to the point that prompted me to keep a diary in the first place  I don t have a friend',
#   1],
#  ['Let me put it more clearly  since no one will believe that a thirteen year old girl is completely alone in the world',
#   1],
#  ['And I m not', 1],
#  ['I have loving parents and a sixteen year old sister  and there are about thirty people I can call friends',
#   1],
#  ['I have a family  loving aunts and a good home', 1],
#  ['No  on the surface I seem to have everything  except my one true friend',
#   1],
#  ['All I think about when I m with friends is having a good time', 1],
#  ['I can t bring myself to talk about anything but ordinary everyday things',
#   1],
#  ['We don t seem to be able to get any closer  and that s the problem', 1],
#  ['Maybe it s my fault that we don t confide in each other', 1],
#  ['In any case  that s just how things are  and unfortunately they re not liable to change',
#   1],
#  ['This is why I ve started the diary', 1],
#  ['To enhance the image of this long awaited friend in my imagination  I don t want to jot down the facts in this diary the way most people would do  but I want the diary to be my friend  and I m going to call this friend  Kitty ',
#   1],
#  ['Since no one would understand a word of my stories to Kitty if I were to plunge right in  I d better provide a brief sketch of my life  much as I dislike doing so',
#   1],
#  ['My father  the most adorable father I ve ever seen  didn t marry my mother until he was thirty six and she was twenty five',
#   1],
#  ['My sister  Margot  was born in Frankfurt in Germany in ', 1],
#  ['I was born on  June', 1],
#  ['I lived in Frankfurt until I was four', 1],
#  ['My father emigrated to Holland in ', 1],
#  ['My mother  Edith Hollander Frank  went with him to Holland in September  while Margot and I were sent to Aachen to stay with our grandmother',
#   1],
#  ['Margot went to Holland in December  and I followed in February  when I was plunked down on the table as a birthday present for Margot',
#   1],
#  ['I started right away at the Montessori nursery school', 1],
#  ['I stayed there until I was six  at which time I started in the first form',
#   1],
#  ['In the sixth form my teacher was Mrs Kuperus  the headmistress', 1],
#  ['At the end of the year we were both in tears as we said a heartbreaking farewell',
#   1],
#  ['In the summer of  Grandma fell ill and had to have an operation  so my birthday passed with little celebration',
#   1],
#  ['Grandma died in January', 1],
#  ['No one knows how often I think of her and still love her', 1],
#  ['This birthday celebration in  was intended to make up for the other  and Grandma s candle was lit along with the rest',
#   1],
#  ['The four of us are still doing well  and that brings me to the present date of  June   and the solemn dedication of my diary',
#   1],
#  ['Dearest Kitty  Our entire class is quaking in its boots', 1],
#  ['The reason  of course  is the forthcoming meeting in which the teachers decide who ll move up to the next form and who ll be kept back',
#   1],
#  ['Half the class is making bets', 1],
#  ['and I laugh ourselves silly at the two boys behind us  C.N', 1],
#  ['and Jacques  who have staked their entire holiday savings on their bet', 1],
#  ['From morning to night  it s  You re going to pass    No  I m not    Yes  you are    No  I m not',
#   1],
#  ['Even G. s pleading glances and my angry outbursts can t calm them down', 1],
#  ['If you ask me  there are so many dummies that about a quarter of the class should be kept back  but teachers are the most unpredictable creatures on earth',
#   1],
#  ['I m not so worried about my girlfriends and myself', 1],
#  ['We ll make it', 1],
#  ['The only subject I m not sure about is maths', 1],
#  ['Anyway  all we can do is wait', 1],
#  ['Until then  we keep telling each other not to lose heart', 1],
#  ['I get along pretty well with all my teachers', 1],
#  ['There are nine of them  seven men and two women', 1],
#  ['Mr Keesing  the old fogey who teaches maths  was annoyed with me for ages because I talked so much',
#   1],
#  ['After several warnings  he assigned me extra homework', 1],
#  ['An essay on the subject   A Chatterbox ', 1],
#  ['A chatterbox   what can you write about that? I d worry about that later  I decided',
#   1],
#  ['I jotted down the title in my notebook  tucked it in my bag and tried to keep quiet',
#   1],
#  ['That evening  after I d finished the rest of my homework  the note about the essay caught my eye',
#   1],
#  ['I began thinking about the subject while chewing the tip of my fountain pen',
#   1],
#  ['Anyone could ramble on and leave big spaces between the words  but the trick was to come up with convincing arguments to prove the necessity of talking',
#   1],
#  ['I thought and thought  and suddenly I had an idea', 1],
#  ['I wrote the three pages Mr Keesing had assigned me and was satisfied', 1],
#  ['I argued that talking is a student s trait and that I would do my best to keep it under control but that I would never be able to cure myself of the habit since my mother talked as much as I did if not more  and that there s not much you can do about inherited traits',
#   1],
#  ['Mr Keesing had a good laugh at my arguments  but when I proceeded to talk my way through the next lesson  he assigned me a second essay',
#   1],
#  ['This time it was supposed to be on  An Incorrigible Chatterbox', 1],
#  ['I handed it in  and Mr Keesing had nothing to complain about for two whole lessons',
#   1],
#  ['However  during the third lesson he d finally had enough', 1],
#  ['Anne Frank  as punishment for talking in class  write an essay entitled    Quack  Quack  Quack  Said Mistress Chatterbox ',
#   1],
#  ['The class roared', 1],
#  ['I had to laugh too  though I d nearly exhausted my ingenuity on the topic of chatterboxes',
#   1],
#  ['It was time to come up with something else  something original', 1],
#  ['My friend  Sanne  who s good at poetry  offered to help me write the essay from beginning to end in verse and I jumped for joy',
#   1],
#  ['Mr Keesing was trying to play a joke on me with this ridiculous subject  but I d make sure the joke was on him',
#   1],
#  ['I finished my poem  and it was beautiful!', 1],
#  ['It was about a mother duck and a father swan with three baby ducklings who were bitten to death by the father because they quacked too much',
#   1],
#  ['Luckily  Mr Keesing took the joke the right way', 1],
#  ['He read the poem to the class  adding his own comments  and to several other classes as well',
#   1],
#  ['Since then I ve been allowed to talk and haven t been assigned any extra homework',
#   1],
#  ['On the contrary  Mr Keesing s always making jokes these days', 1],
#  ['Notice that contracted forms are also written with an apostrophe to show a shortening of the spelling of not  would  or is as in the above example',
#   1],
#  ['Writing a diary is like speaking to oneself', 1],
#  ['Plays  and often  novels  also have speech in written form', 1],
#  ['So we usually come across contracted forms in diaries  plays and novels',
#   1],
#  ['Here is an extract adapted from a one act play', 1],
#  ['In this extract  angry neighbours who think Joe the Inventor s new spinning machine will make them lose their jobs come to destroy Joe s model of the machine',
#   1],
#  ['You ve just seen how contracted forms can make a written text sound like actual speech',
#   1],
#  ['Try to make this extract sound more like a real conversation by changing some of the verbs back into contracted forms',
#   1],
#  ['Then speak out the lines. Diary language  has some typical features such as subjectless sentences  Got up late in the morning   sentence fragments without subjects or verbs   too bad  boring  not good   contracted forms  they re  I ve  can t  didn t  etc.   and everyday expressions which people use in speech',
#   1],
#  ['Remember not to use such language in more formal kinds of writing', 1],
#  ['Anne Frank s diary became a public document after World War II', 1],
#  ['Discuss with your students diaries which became historical documents  such as Samuel Pepys s diary',
#   1],
#  ['You may draw students  attention to different types of diaries  e.g', 1],
#  ['private diary  general diary', 1],
#  ['Army officers  businessmen  doctors  executives  lawyers  motorists  police officers keep a general diary to record events that happen during the day and events that are scheduled for the day  such as appointments  meetings  things to be done  etc',
#   1],
#  ['September   Lord s Day ', 1],
#  ['Jane called us up about three in the morning  to tell us of a great fire they saw in the city',
#   1],
#  ['So I rose and slipped on my nightgown  and went to her window  and thought it to be on the backside of Marke Lane at the farthest  but being unused to such fire as followed  I thought it far enough off  and so went to bed again and to sleep',
#   1],
#  ['About seven rose again to dress myself  and then looked out of the window  and saw the fire not so much as it was and further off',
#   1],
#  ['By and by Jane comes and tells me that she hears that above  houses have been burned down tonight by the fire we saw  and that it is now burning down all Fish Street  by London Bridge',
#   1],
#  ['So I made myself ready presently  and walked to the Tower  and there got up upon one of the high places  Sir J',
#   1],
#  ['Robinson s little son going up with me  and there I did see the houses at that end of the bridge all on fire  and an infinite great fire on this and the other side of the bridge',
#   1],
#  ['Every child feels that she he is controlled and instructed not to do one thing or another',
#   1],
#  ['You too may feel that your freedom is curtailed', 1],
#  ['Write down some of the things you want to do  but your parents elders do not allow you to',
#   1],
#  ['To read the poem aloud  form pairs  each reading alternate stanzas', 1],
#  ['You are in for a surprise! How do we judge the people around us   by their money  wealth and possessions? Or is there something of more enduring value to look for in a person? This story is a sensitive account of how a poor young girl is judged by her classmates',
#   1],
#  ['Wanda Petronski is a young Polish girl who goes to school with other American children in an American town',
#   1],
#  ['These other children see Wanda as  different  in many ways', 1],
#  ['Can you guess how they treat her? Read the information in the box below',
#   1],
#  ['Find out more about this community  or about a related topic  from an encyclopedia  or the Internet',
#   1],
#  ['The first Polish immigrants arrived in America in   but the largest wave of Polish immigration occurred in the early twentieth century  when more than one million Poles migrated to the United States',
#   1],
#  ['The Polish State did not exist at that time  and the immigrants were identified according to their country of origin rather than to ethnicity',
#   1],
#  ['They were identified as Russian Poles  German Poles and Austrian Poles', 1],
#  ['One of the most notable Polish American communities is in Chicago and its suburbs  so Chicago is sometimes called the second largest  Polish  city in the world  next only to Warsaw  the capital of Poland',
#   1],
#  ['Polish Americans were sometimes discriminated against in the United States  as were the Irish  Italians  and Jews',
#   1],
#  ['According to the United States  Census    Americans of age five years and older reported Polish as the language spoken at home  which is about . per cent of the people who speak languages other than English  or . per cent of the U.S',
#   1],
# ...
#   1],
#  ['For the first twentyfour hours Mijbil was neither hostile nor friendly  he was simply aloof and indifferent  choosing to sleep on the floor as far from my bed as possible',
#   1],
#  ['The second night Mijbil came on to my bed in the small hours and remained asleep in the crook of my knees until the servant brought tea in the morning  and during the day he began to lose his apathy and take a keen  much too keen  interest in his surroundings',
#   1],
#  ['I made a body belt for him and took him on a lead to the bathroom  where for half an hour he went wild with joy in the water  plunging and rolling in it  shooting up and down the length of the bathtub underwater  and making enough slosh and splash for a hippo',
#   1],
#  ['This  I was to learn  is a characteristic of otters  every drop of water must be  so to speak  extended and spread about the place  a bowl must at once be overturned  or  if it will not be overturned  be sat in and sploshed in until it overflows',
#   1],
#  ['Water must be kept on the move and made to do things  when static it is wasted and provoking',
#   1],
#  ['Two days later  Mijbil escaped from my bedroom as I entered it  and I turned to see his tail disappearing round the bend of the corridor that led to the bathroom',
#   1],
#  ['By the time I got there he was up on the end of the bathtub and fumbling at the chromium taps with his paws',
#   1],
#  ['I watched  amazed  in less than a minute he had turned the tap far enough to produce a trickle of water  and after a moment or two achieved the full flow',
#   1],
#  ['He had been lucky to turn the tap the right way  on later occasions he would sometimes screw it up still tighter  chittering with irritation and disappointment at the tap s failure to cooperate',
#   1],
#  ['Very soon Mij would follow me without a lead and come to me when I called his name',
#   1],
#  ['He spent most of his time in play', 1],
#  ['He spent hours shuffling a rubber ball round the room like a four footed soccer player using all four feet to dribble the ball  and he could also throw it  with a powerful flick of the neck  to a surprising height and distance',
#   1],
#  ['But the real play of an otter is when he lies on his back and juggles with small objects between his paws',
#   1],
#  ['Marbles were Mij s favourite toys for this pastime  he would lie on his back rolling two or more of them up and down his wide  flat belly without ever dropping one to the floor',
#   1],
#  ['The days passed peacefully at Basra  but I dreaded the prospect of transporting Mij to England  and to Camusfearna',
#   1],
#  ['The British airline to London would not fly animals  so I booked a flight to Paris on another airline  and from there to London',
#   1],
#  ['The airline insisted that Mij should be packed into a box not more than eighteen inches square  to be carried on the floor at my feet',
#   1],
#  ['I had a box made  and an hour before we started  I put Mij into the box so that he would become accustomed to it  and left for a hurried meal',
#   1],
#  ['When I returned  there was an appalling spectacle', 1],
#  ['There was complete silence from the box  but from its airholes and chinks around the lid  blood had trickled and dried',
#   1],
#  ['I whipped off the lock and tore open the lid  and Mij  exhausted and bloodspattered  whimpered and caught at my leg',
#   1],
#  ['He had torn the lining of the box to shreds  when I removed the last of it so that there were no cutting edges left  it was just ten minutes until the time of the flight  and the airport was five miles distant',
#   1],
#  ['I put the miserable Mij back into the box  holding down the lid with my hand',
#   1],
#  ['I sat in the back of the car with the box beside me as the driver tore through the streets of Basra like a ricochetting bullet',
#   1],
#  ['The aircraft was waiting to take off  I was rushed through to it by infuriated officials',
#   1],
#  ['Luckily  the seat booked for me was at the extreme front', 1],
#  ['I covered the floor around my feet with newspapers  rang for the air hostess  and gave her a parcel of fish  for Mij  to keep in a cool place',
#   1],
#  ['I took her into my confidence about the events of the last half hour', 1],
#  ['I have retained the most profound admiration for that air hostess  she was the very queen of her kind',
#   1],
#  ['She suggested that I might prefer to have my pet on my knee  and I could have kissed her hand in the depth of my gratitude',
#   1],
#  ['But  not knowing otters  I was quite unprepared for what followed', 1],
#  ['Mij was out of the box in a flash', 1],
#  ['He disappeared at high speed down the aircraft', 1],
#  ['There were squawks and shrieks  and a woman stood up on her seat screaming out   A rat! A rat!  I caught sight of Mij s tail disappearing beneath the legs of a portly whiteturbaned Indian',
#   1],
#  ['Diving for it  I missed  but found my face covered in curry', 1],
#  ['Perhaps   said the air hostess with the most charming smile   it would be better if you resumed your seat  and I will find the animal and bring it to you.  I returned to my seat',
#   1],
#  ['I was craning my neck trying to follow the hunt when suddenly I heard from my feet a distressed chitter of recognition and welcome  and Mij bounded on to my knee and began to nuzzle my face and my neck',
#   1],
#  ['Mij and I remained in London for nearly a month', 1],
#  ['He would play for hours with a selection of toys  ping pong balls  marbles  rubber fruit  and a terrapin shell that I had brought back from his native marshes',
#   1],
#  ['With the ping pong ball he invented a game of his own which could keep him engrossed for up to half an hour at a time',
#   1],
#  ['A suitcase that I had taken to Iraq had become damaged on the journey home  so that the lid  when closed  remained at a slope from one end to the other',
#   1],
#  ['Mij discovered that if he placed the ball on the high end it would run down the length of the suitcase',
#   1],
#  ['He would dash around to the other end to ambush its arrival  hide from it  crouching  to spring up and take it by surprise  grab it and trot off with it to the high end once more',
#   1],
#  ['Outside the house I exercised him on a lead  precisely as if he had been a dog',
#   1],
#  ['Mij quickly developed certain compulsive habits on these walks in the London streets  like the rituals of children who on their way to and from school must place their feet squarely on the centre of each paving block  musttouch every seventh upright of the iron railings  or pass to the outside of every second lamp post',
#   1],
#  ['Opposite to my flat was a single storied primary school  alongwhose frontage ran a low wall some two feet high',
#   1],
#  ['On his way home  but never on his way out  Mij would tug me to this wall  jump on to it  and gallop the full length of its thirty yards  to the hopeless distraction both of pupils and of staff within',
#   1],
#  ['It is not  I suppose  in any way strange that the average Londoner should not recognise an otter  but the variety of guesses as to what kind of animal this might be came as a surprise to me',
#   1],
#  ['Otters belong to a comparatively small group of animals called Mustellines  shared by the badger  mongoose  weasel  stoat  mink and others',
#   1],
#  ['I faced a continuous barrage of conjectural questions that sprayed all the Mustellines but the otter  more random guesses hit on  a baby seal  and  a squirrel.   Is that a walrus  mister?  reduced me to giggles  and outside a dog show I heard  a hippo',
#   1],
#  ['A beaver  a bear cub  a leopard   one  apparently  that had changed its spots   and a  brontosaur   Mij was anything but an otter',
#   1],
#  ['But the question for which I awarded the highest score came from a labourer digging a hole in the street',
#   1],
#  ['I was still far from him when he laid down his tool  put his hands on his hips  and began to stare',
#   1],
#  ['As I drew nearer I saw his expression of surprise and affront  as though he would have me know that he was not one upon whom to play jokes',
#   1],
#  ['I came abreast of him  he spat  glared  and then growled out   Here  Mister   what is that supposed to be?  You have seen how Maxwell describes Mij the otter s feelings and thoughts by watching him',
#   1],
#  ['Play the game of dumb charades', 1],
#  ['Take turns to express a feeling or thought silently  through gestures', 1],
#  ['Let the class speak out their guesses about the feelings or thoughts you are trying to express',
#   1],
#  ['THERE was a girl named Valliammai who was called Valli for short', 1],
#  ['She was eight years old and very curious about things', 1],
#  ['Her favourite pastime was standing in the front doorway of her house  watching what was happening in the street outside',
#   1],
#  ['There were no playmates of her own age on her street  and this was about all she had to do',
#   1],
#  ['But for Valli  standing at the front door was every bit as enjoyable as any of the elaborate games other children played',
#   1],
#  ['Watching the street gave her many new unusual experiences', 1],
#  ['The most fascinating thing of all was the bus that travelled between her village and the nearest town',
#   1],
#  ['It passed through her street each hour  once going to the town and once coming back',
#   1],
#  ['The sight of the bus  filled each time with a new set of passengers  was a source of unending joy for Valli',
#   1],
#  ['Day after day she watched the bus  and gradually a tiny wish crept into her head and grew there  she wanted to ride on that bus  even if just once',
#   1],
#  ['This wish became stronger and stronger  until it was an overwhelming desire',
#   1],
#  ['Valli would stare wistfully at the people who got on or off the bus when it stopped at the street corner',
#   1],
#  ['Their faces would kindle in her longings  dreams  and hopes', 1],
#  ['If one of her friends happened to ride the bus and tried to describe the sights of the town to her  Valli would be too jealous to listen and would shout  in English   Proud! proud!  Neither she nor her friends really understood the meaning of the word  but they used it often as a slang expression of disapproval',
#   1],
#  ['Over many days and months Valli listened carefully to conversations between her neighbours and people who regularly used the bus  and she also asked a few discreet questions here and there',
#   1],
#  ['This way she picked up various small details about the bus journey', 1],
#  ['The town was six miles from her village', 1],
#  ['The fare was thirty paise one way    which is almost nothing at all   she heard one well dressed man say  but to Valli  who scarcely saw that much money from one month to the next  it seemed a fortune',
#   1],
#  ['The trip to the town took forty five minutes', 1],
#  ['On reaching town  if she stayed in her seat and paid another thirty paise  she could return home on the same bus',
#   1],
#  ['This meant that she could take the one o clock afternoon bus  reach the town at one forty five  and be back home by about two forty five',
#   1],
#  ['On and on went her thoughts as she calculated and recalculated  planned and replanned',
#   1],
#  ['Well  one fine spring day the afternoon bus was just on the point of leaving the village and turning into the main highway when a small voice was heard shouting   Stop the bus! Stop the bus!  And a tiny hand was raised commandingly',
#   1],
#  ['The bus slowed down to a crawl  and the conductor  sticking his head out the door  said   Hurry then! Tell whoever it is to come quickly.   It s me   shouted Valli',
#   1],
#  ['I m the one who has to get on.  By now the bus had come to a stop  and the conductor said   Oh  really! You don t say so!   Yes  I simply have to go to town   said Valli  still standing outside the bus   and here s my money.  She showed him some coins',
#   1],
#  ['Okay  okay  but first you must get on the bus   said the conductor  and he stretched out a hand to help her up',
#   1],
#  ['Never mind   she said   I can get on by myself', 1],
#  ['You don t have to help me.  The conductor was a jolly sort  fond of joking',
#   1],
#  ['Oh  please don t be angry with me  my fine madam   he said', 1],
#  ['Here  have a seat right up there in front', 1],
#  ['Everybody move aside please   make way for madam.  It was the slack time of day  and there were only six or seven passengers on the bus',
#   1],
#  ['They were all looking at Valli and laughing with the conductor', 1],
#  ['Valli was overcome with shyness', 1],
#  ['Avoiding everyone s eyes  she walked quickly to an empty seat and sat down',
#   1],
#  ['May we start now  madam?  the conductor asked  smiling', 1],
#  ['Then he blew his whistle twice  and the bus moved forward with a roar', 1],
#  ['It was a new bus  its outside painted a gleaming white with some green stripes along the sides',
#   1],
#  ['Inside  the overhead bars shone like silver', 1],
#  ['Directly in front of Valli  above the windshield  there was a beautiful clock',
#   1],
#  ['The seats were soft and luxurious', 1],
#  ['Valli devoured everything with her eyes', 1],
#  ['But when she started to look outside  she found her view cut off by a canvas blind that covered the lower part of her window',
#   1],
#  ['So she stood up on the seat and peered over the blind', 1],
#  ['The bus was now going along the bank of a canal', 1],
#  ['The road was very narrow', 1],
#  ['On one side there was the canal and  beyond it  palm trees  grassland  distant mountains  and the blue  blue sky',
#   1],
#  ['On the other side was a deep ditch and then acres and acres of green fields   green  green  green  as far as the eye could see',
#   1],
#  ['Oh  it was all so wonderful!', 1],
#  ['Suddenly she was startled by a voice', 1],
#  ['Listen  child   said the voice   you shouldn t stand like that', 1],
#  ['Sit down.  Sitting down  she looked to see who had spoken', 1],
#  ['It was an elderly man who had honestly been concerned for her  but she was annoyed by his attention',
#   1],
#  ['There s nobody here who s a child   she said haughtily', 1],
#  ['I ve paid my thirty paise like everyone else.  The conductor chimed in', 1],
#  ['Oh  sir  but this is a very grown up madam', 1],
#  ['Do you think a mere girl could pay her own fare and travel to the city all alone?  Valli shot an angry glance at the conductor and said   I am not a madam',
#   1],
#  ['Please remember that', 1],
#  ['And you ve not yet given me my ticket.   I ll remember   the conductor said  mimicking her tone',
#   1],
#  ['Everyone laughed  and gradually Valli too joined in the laughter', 1],
#  ['The conductor punched a ticket and handed it to her', 1],
#  ['Just sit back and make yourself comfortable', 1],
#  ['Why should you stand when you ve paid for a seat?   Because I want to   she answered  standing up again',
#   1],
#  ['But if you stand on the seat  you may fall and hurt yourself when the bus makes a sharp turn or hits a bump',
#   1],
#  ['That s why we want you to sit down  child', 1],
#  ['I m not a child  I tell you   she said irritably', 1],
#  ['I m eight years old.   Of course  of course', 1],
#  ['How stupid of me! Eight years   my!  The bus stopped  some new passengers got on  and the conductor got busy for a time',
#   1],
#  ['Afraid of losing her seat  Valli finally sat down', 1],
#  ['An elderly woman came and sat beside her', 1],
#  ['Are you all alone  dear?  she asked Valli as the bus started again', 1],
#  ['Valli found the woman absolutely repulsive   such big holes she had in her ear lobes  and such ugly earrings in them! And she could smell the betel nut the woman was chewing and see the betel juice that was threatening to spill over her lips at any moment',
#   1],
#  ['Ugh!   who could be sociable with such a person?  Yes  I m travelling alone   she answered curtly',
#   1],
#  ['And I ve got a ticket too.   Yes  she s on her way to town   said the conductor',
#   1],
#  ['With a thirty paise ticket.   Oh  why don t you mind your own business   said Valli',
#   1],
#  ['But she laughed all the same  and the conductor laughed too', 1],
#  ...]

# %% [markdown]
# ### Checking for Data Imbalance:

# %%
# despite the data being extremely imbalanced, it is performing better this way than when i try to balance it
len(new_examples1)
# Out:
# 2813

# %%
len(new_examples2)
# Out:
# 1140

# %%
len(new_examples1)+len(new_examples2)
# Out:
# 3953

# %% [markdown]
# ### Checking the Readability Scores using the Textstat Library:

# %%
fs = open('../data/gradetwoindo.txt', 'r') 
bookone = fs.read()

# %%
# https://pypi.org/project/textstat/
bookonescore = round(textstat.flesch_kincaid_grade(bookone))
bookonescore
# Out:
# 4

# %%
fs = open('../data/gradetenindia.txt', 'r') 
booktwo = fs.read()

# %%
# https://pypi.org/project/textstat/
booktwoscore = round(textstat.flesch_kincaid_grade(booktwo))
booktwoscore
# Out:
# 16

# %% [markdown]
# ### Organising the Labelled Data together using a Pandas Dataframe:

# %%
dataset = pd.DataFrame(columns = ["text", "label"])  
dataset = dataset.append(pd.DataFrame(new_examples2+new_examples1, columns = ["text", "label"]))

# %% [markdown]
# ### Downloading Pre-trained Vectors trained on part of Google News dataset:

# %%
# https://code.google.com/archive/p/word2vec/
# !pip install wget
import wget
import os
if not os.path.isfile("GoogleNews-vectors-negative300.bin.gz"):
    print("downloading")
    wget.download("https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz")
else:
    print("you already have it!")

# %%
embeddings_file = "../data/GoogleNews-vectors-negative300.bin.gz"
wv = KeyedVectors.load_word2vec_format(embeddings_file, binary=True, limit=200000)

# %% [markdown]
# ### Classification:

# %%
#Code Adapted from the NLP in Action book ch7 https://github.com/totalgood/nlpia
word_vectors = KeyedVectors.load_word2vec_format(embeddings_file, binary=True, limit=200000)
def tokenize_and_vectorize(dataset):
    vectorized_data = []
    for sample in dataset:
        tokens = casual_tokenize(sample)
        sample_vecs = []
        for token in tokens:
            try:
                sample_vecs.append(word_vectors[token])
            except KeyError:
                pass  # No matching token in the Google w2v vocab
        vectorized_data.append(sample_vecs)

    return vectorized_data

def pad_trunc(data, maxlen):
    """ For a given dataset pad with zero vectors or truncate to maxlen """
    new_data = []

    # Creating a vector of 0's the length of the word vectors
    zero_vector = []
    for _ in range(len(data[0][0])):
        zero_vector.append(0.0)

    for sample in data:
 
        if len(sample) > maxlen:
            temp = sample[:maxlen]
        elif len(sample) < maxlen:
            temp = sample
            additional_elems = maxlen - len(sample)
            for _ in range(additional_elems):
                temp.append(zero_vector)
        else:
            temp = sample
        new_data.append(temp)
    return new_data

# %%
features = tokenize_and_vectorize(dataset["text"].values)
x_train, x_test, y_train, y_test = train_test_split(features, dataset["label"], test_size=0.3, random_state=0)

# %%
type(x_train)
# Out:
# list

# %%
maxlen = 50
embedding_dims = 300    # Length of the token vectors for passing into the Convnet

# %%
np.array(x_train).shape,np.array(x_test).shape
# Out:
# <ipython-input-26-6dd20099d2f7>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   np.array(x_train).shape,np.array(x_test).shape
# ((2767,), (1186,))

# %%
x_train = pad_trunc(x_train, maxlen)
x_test = pad_trunc(x_test, maxlen)

# %%
type(x_train)
# Out:
# list

# %%
np.array(x_train).shape
# Out:
# (2767, 50, 300)

# %%
x_train = np.reshape(x_train, (len(x_train), maxlen, embedding_dims))
y_train = np.array(y_train)
x_train = np.reshape(x_train, (len(x_train), maxlen, embedding_dims))
y_train = np.array(y_train)
x_test = np.reshape(x_test, (len(x_test), maxlen, embedding_dims))
y_test = np.array(y_test)

# %%
np.array(x_train).shape,np.array(x_test).shape
# Out:
# ((2767, 50, 300), (1186, 50, 300))

# %%
batch_size = 32        
filters = 1           
kernel_size = 5         
hidden_dims = 10       
epochs = 6

# %% [markdown]
# ### Building the Model:

# %%
#Code Adapted from the NLP in Action book ch7 https://github.com/totalgood/nlpia
print('Build model...')
model = Sequential()

# Adding a Convolution1D, which will learn filters
# word group filters of size filter_length:
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1,
                 input_shape=(maxlen, embedding_dims)))
# Using max pooling:
model.add(GlobalMaxPooling1D())
# Adding a vanilla hidden layer:
model.add(Dense(hidden_dims))
model.add(Dropout(0.2))
model.add(Activation('relu'))
# Projecting onto a single unit output layer, and squash it with a sigmoid:
model.add(Dense(1))
model.add(Activation('sigmoid'))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
print(model.summary())
# Out:
# Build model...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 46, 1)             1501
# _________________________________________________________________
# global_max_pooling1d (Global (None, 1)                 0
# _________________________________________________________________
# dense (Dense)                (None, 10)                20
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 1,532
# Trainable params: 1,532
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# https://stackoverflow.com/questions/58636087/tensorflow-valueerror-failed-to-convert-a-numpy-array-to-a-tensor-unsupporte

x_train = np.asarray(x_train).astype(np.float32)
y_train = np.asarray(y_train).astype(np.float32)
x_test = np.asarray(x_test).astype(np.float32)
y_test = np.asarray(y_test).astype(np.float32)

# %% [markdown]
# ### Train Model:

# %%
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, y_test))
model_structure = model.to_json()
with open("cnn_model.json", "w") as json_file:
    json_file.write(model_structure)

model.save_weights("cnn_weights.h5")
print('Model saved.')
# Out:
# Epoch 1/6
# 87/87 [==============================] - 3s 18ms/step - loss: 0.6601 - accuracy: 0.6823 - val_loss: 0.6237 - val_accuracy: 0.7007
# Epoch 2/6
# 87/87 [==============================] - 1s 12ms/step - loss: 0.5967 - accuracy: 0.7109 - val_loss: 0.5848 - val_accuracy: 0.7007
# Epoch 3/6
# 87/87 [==============================] - 1s 12ms/step - loss: 0.5652 - accuracy: 0.7073 - val_loss: 0.5593 - val_accuracy: 0.7007
# Epoch 4/6
# 87/87 [==============================] - 1s 11ms/step - loss: 0.5417 - accuracy: 0.7156 - val_loss: 0.5409 - val_accuracy: 0.7007
# Epoch 5/6
# 87/87 [==============================] - 1s 11ms/step - loss: 0.5184 - accuracy: 0.7163 - val_loss: 0.5289 - val_accuracy: 0.7007
# Epoch 6/6
# 87/87 [==============================] - 1s 12ms/step - loss: 0.5074 - accuracy: 0.7163 - val_loss: 0.5177 - val_accuracy: 0.7007
# Model saved.

# %% [markdown]
# #### `(All observations and findings shall be included in the critical essay).`

# %% [markdown]
# ### Citation List:
#
#
# #### Websites:
#
# 1) Code.google.com. 2022. Google Code Archive - Word2Vec. [online] Available at: <https://code.google.com/archive/p/word2vec/> [Accessed 5 December 2021].
#
# 2) Davis, A., 2021. The fundamentals of programming - Python Video Tutorial | LinkedIn Learning, formerly Lynda.com. [online] LinkedIn. Available at: <https://www.linkedin.com/learning/programming-foundations-fundamentals-3/the-fundamentals-of-programming?autoAdvance=true&autoSkip=false&autoplay=true&resume=true&u=57077561> [Accessed 24 October 2021].
#
# 3) Dib, F., 2021. regex101: build, test, and debug regex. [online] regex101. Available at: <https://regex101.com/> [Accessed 4 December 2021].
#
# 4) GitHub. 2021. GitHub - totalgood/nlpia: Examples and libraries for "Natural Language Processing in Action" book. [online] Available at: <https://github.com/totalgood/nlpia> [Accessed 5 December 2021].
#
# 5) Libgen.is. 2021. Library Genesis. [online] Available at: <https://www.libgen.is/> [Accessed 4 November 2021].
#
# 6) McCallum, L., 2021. NLP Week 4.1 - Classification Task Notebook. [online] GitHub. Available at: <https://git.arts.ac.uk/lmccallum/nlp-21-22/blob/master/NLP%20Week%204.1%20-%20Classification%20Task.ipynb> [Accessed 16 November 2021].
#
# 7) McCallum, L., 2021. NLP Week 5.1 CNNs Notebook. [online] GitHub. Available at: <https://git.arts.ac.uk/lmccallum/nlp-21-22/blob/master/NLP%20Week%205.1%20CNNs.ipynb> [Accessed 2 December 2021].
#
# 8) Nisbet, J., 2021. Python for students - Python Video Tutorial | LinkedIn Learning, formerly Lynda.com. [online] LinkedIn. Available at: <https://www.linkedin.com/learning/python-for-students/python-for-students?autoAdvance=true&autoSkip=false&autoplay=true&resume=false&u=57077561> [Accessed 18 October 2021].
#
# 9) Portilla, J., 2021. Natural Language Processing with Python. [online] Udemy. Available at: <https://www.udemy.com/course/nlp-natural-language-processing-with-python/?ranMID=39197&ranEAID=JVFxdTr9V80&ranSiteID=JVFxdTr9V80-gIa4CDf8o_3HXX8ZIg_F1g&LSNPUBID=JVFxdTr9V80&utm_source=aff-campaign&utm_medium=udemyads> [Accessed 27 October 2021].
#
# 10) Rose, D., 2021. Artificial Intelligence Foundations: Neural Networks Video Tutorial | LinkedIn Learning, formerly Lynda.com. [online] LinkedIn. Available at: <https://www.linkedin.com/learning/artificial-intelligence-foundations-neural-networks/welcome?autoAdvance=true&autoSkip=false&autoplay=true&resume=true&u=57077561> [Accessed 6 December 2021].
#
# 11) PyPI. 2021. clean-text. [online] Available at: <https://pypi.org/project/clean-text/> [Accessed 14 November 2021].
#
# 12) PyPI. 2021. textstat. [online] Available at: <https://pypi.org/project/textstat/> [Accessed 15 November 2021].
#
# 13) Stack Abuse. 2021. Using Regex for Text Manipulation in Python. [online] Available at: <https://stackabuse.com/using-regex-for-text-manipulation-in-python/> [Accessed 16 November 2021].
#
# 14) T., Carvalho, V. and Fedor, Z., 2021. Tensorflow - ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type float). [online] Stack Overflow. Available at: <https://stackoverflow.com/questions/58636087/tensorflow-valueerror-failed-to-convert-a-numpy-array-to-a-tensor-unsupporte> [Accessed 5 December 2021].
#
# 15) Zamzar.com. 2021. Zamzar - video converter, audio converter, image converter, eBook converter. [online] Available at: <https://www.zamzar.com/> [Accessed 7 November 2021].
