# %% [markdown]
# # Using a Convolutional Neural Network for Text Readability Classification
#
# Code cells have been individually cited via comments wherever third-party code has been referred to or implemented, and a citation list has been added at the bottom of this notebook in Harvard style referencing.

# %% [markdown]
# ### Project Overview:
#
# The purpose of this project is to create a text readability classifier (inspired by the flesch kincaid readability tests) that determines whether a piece of text is easy or hard to read. I shall be making use of english textbooks from South-East Asian / Middle Eastern areas as datasets. Since most readability classifiers use data from the United Kingdom / United States in their model, I thought it would be interesting to approach this problem using data from non-western regions to see if they could predict readability scores accurately for english phrases across the world. After building the classifier, I shall test it on speech / interview transcripts of various politicians as a use case to get a bit more insight into their speaking styles.

# %% [markdown]
# ### Project Aim:
#
# 1) To construct a model that allows writers to have more control over their writing, so that they could structure their work according to their intended audience.

# %% [markdown]
# ### Installing and Importing the Required Libraries:

# %%
import numpy as np  
from keras.preprocessing import sequence 
from keras.models import Sequential 
from keras.layers import Dense, Dropout, Activation  
from keras.layers import Conv1D, GlobalMaxPooling1D
from gensim.models.keyedvectors import KeyedVectors
from nltk.tokenize.casual import casual_tokenize
from gensim.models import KeyedVectors
from sklearn.model_selection import train_test_split
import pandas as pd
from random import shuffle
import regex as re
from cleantext import clean
from nltk import word_tokenize
import textstat

# %% [markdown]
# ### Selection of Data:
#
# For this project, I'm using English textbooks of varying grades from different countries. I found all of them on [Library Genesis](https://www.libgen.is/) and since they were PDF files, I then converted them to text files using [Zamzar File Converter](https://www.zamzar.com/). I initially tried using python modules for this task like PDF Miner and PyPDF, but kept running into errors as most of the code I found on StackOverflow was not suitable with the latest version of Python.
#
# For this notebook, I have used first and tenth grade textbooks from India from the NCERT Publication, which can be found [here](https://libgen.is/search.php?req=ncert+english&open=0&res=25&view=simple&phrase=1&column=def).

# %% [markdown]
# ### Preprocessing the Data:
#
# I've used Regex and the Clean-Text Library to prepare the data before the classification task. I defined a 'read_and_clean' function to read any given text file and clean the data in it, whilst replacing the line-breaks according to every condition (as described in the comments) as the text files for this task aren't following a particular pattern with grammar since it was converted from an image-heavy PDF. After that, I'm splitting the sentence after every full stop ('.') and avoiding any sentences with less than two words as it won't be of much use.

# %%
def remove(text):
    text = re.sub(r"#\S+", " ", text) #remove hashtags
    text = re.sub(r'\w*\d+\w*', '', text) #remove numbers
    text = re.sub(r'[^a-zA-Z0-9\n\?!\.]', ' ', text) #remove special characters
    text = text.strip(" ")
    text = text.strip(".")
    return text

# %%
# read the file and clean it.
def read_and_clean(file_name):
# read the file
    fs = open(file_name, 'r') 
    book1 = fs.read()
# convert it to . if 2 or more line breaks are together
    book1 = re.sub(r"\n{2,}",". ", book1)
# convert it to . if 2 or more spaces are together
    book1 = re.sub(r"\s{2,}",". ", book1)
# convert a single line break to space if it is followed by a small letter
    book1 = re.sub(r"\n{1}(?=\s[a-z])"," ", book1)
# convert a single line break to space if it is followed by a space and small letter
    book1 = re.sub(r"\n{1}(?=[a-z])"," ", book1)
# convert all remaining line breaks to .
    book1 = re.sub(r"\n",". ", book1)
    total = []
    
    clean(book1,
        no_urls=True) #https://pypi.org/project/clean-text/

# split the sentence after every '.'
    for i in book1.split(". "):
# clean it using the above function
        clean_text = remove(i)
# convert the sentence to a list of words and check the length. if it is greater then 2, then consider it a sentence
        if len(word_tokenize(clean_text)) >2:
            total.append(clean_text)
# return the final list
    return total

# %% [markdown]
# ### Labelling the Data and Calling the Functions:

# %%
# read the grade one file
grade_one_sentence = read_and_clean("../data/gradeoneindia.txt")

# %%
label = 0
new_examples1 = []
for i in grade_one_sentence:  
    if len(word_tokenize(i)) >2:
        new_examples1 = new_examples1 + [[i, label]]

# %%
new_examples1 = new_examples1[16:] # slicing the few sentences in the beginning to remove the contents page.

# %%
new_examples1
# Out:
# [['The Tailor and his Friend', 1],
#  ['My house is red', 1],
#  ['a little house  A happy child am I', 1],
#  ['I laugh and play the whole day long  I hardly ever cry', 1],
#  ['I have a tree  a green  green tree  To shade me from the sun  And under it I often sit  When all my play is done',
#   1],
#  ['Read and match the words with the pictures', 1],
#  ['Draw a line', 1],
#  ['There are many kinds of houses', 1],
#  ['Circle the ones you have seen', 1],
#  ['Draw your house here and talk about it', 1],
#  ['The following have lost their babies', 1],
#  ['Trace along the maze using different colours and find them', 1],
#  ['One has been done for you', 1],
#  ['Once there were three little pigs Sonu  Monu and Gonu', 1],
#  ['Sonu lived in a house of straw', 1],
#  ['Monu lived in a house of sticks and One day a big bad wolf came to Sonu s house',
#   1],
#  ['He said   I will huff and puff and I will blow your house down.  So he huffed and he puffed and he blew the house down',
#   1],
#  ['Sonu ran to Monu s house', 1],
#  ['The wolf came to Monu s house', 1],
#  ['He said   I will huff and puff and I will blow your house down', 1],
#  ['So he huffed and he puffed and he blew Monu s house down', 1],
#  ['Sonu and Monu ran to Gonu s house', 1],
#  ['The wolf came to Gonu s house', 1],
#  ['He said   I will huff and puff and I will blow your house down', 1],
#  ['So he huffed and he puffed but he could not blow the brick house down', 1],
#  ['It was very strong', 1],
#  ['The wolf went away and Sonu  Monu and Gonu lived happily together in the red brick house',
#   1],
#  ['There are farm animals  water animals and jungle animals in this picture',
#   1],
#  ['Help the animals reach their homes', 1],
#  ['After my bath I try  try  try to wipe myself till I m dry  dry  dry', 1],
#  ['Hands to wipe and fingers and toes and two wet legs and a shiny nose', 1],
#  ['Just think how much less time I d take if I were a dog and could shake  shake  shake',
#   1],
#  ['Once upon a time there lived a Bubble  a Straw and a Shoe', 1],
#  ['One day they went into the forest', 1],
#  ['They came to a river', 1],
#  ['They did not know how to cross it', 1],
#  ['The Shoe said   Bubble  let us float on you', 1],
#  ['No  Shoe! Let Straw stretch himself from one bank to the other', 1],
#  ['Then we can cross the river', 1],
#  ['So  the Straw stretched himself from one bank to the other', 1],
#  ['When the Shoe jumped on the Straw  it broke', 1],
#  ['The Shoe fell into the water with a loud splash', 1],
#  ['The Bubble shook and shook with laughter and burst with a big bang', 1],
#  ['One little kitten', 1],
#  ['Two big cats', 1],
#  ['Three baby butterflies', 1],
#  ['Four big rats', 1],
#  ['Five fat fishes', 1],
#  ['Six sad seals', 1],
#  ['Seven silly seagulls', 1],
#  ['Eight happy eels', 1],
#  ['Nine nervous lizards', 1],
#  ['Ten brave bees', 1],
#  ['Eleven smelly elephants', 1],
#  ['Twelve fat fleas', 1],
#  ['With fifteen tails', 1],
#  ['There was a hen', 1],
#  ['She had two chicks  Lalu and Peelu', 1],
#  ['Lalu was red', 1],
#  ['He loved red things', 1],
#  ['Peelu was yellow', 1],
#  ['He loved yellow things', 1],
#  ['One day Lalu saw something on a plant', 1],
#  ['It was red', 1],
#  ['He ate it up', 1],
#  ['Oh  no! It was a red chilli', 1],
#  ['It was very hot', 1],
#  ['Lalu s mouth started burning', 1],
#  ['Mother Hen came running', 1],
#  ['Peelu came too', 1],
#  ['Peelu said   I ll get something for you!  Peelu brought a yellow laddu', 1],
#  ['Lalu gobbled up the laddu', 1],
#  ['His mouth stopped burning', 1],
#  ['Mother Hen and Lalu kissed Peelu', 1],
#  ['Red plus yellow is orange', 1],
#  ['Red plus blue is purple', 1],
#  ['Blue plus yellow is green', 1],
#  ['Add white to make them light', 1],
#  ['Come to me  chicks', 1],
#  ['I want you here', 1],
#  ['What do you want  mother? Look at me', 1],
#  ['Do what I do', 1],
#  ['Down and up', 1],
#  ['Up and down', 1],
#  ['Mother! Mother! I can do what you do', 1],
#  ['Look at me', 1],
#  ['Down and up', 1],
#  ['Up and down', 1],
#  ['Look at me  chicks', 1],
#  ['Do what I do', 1],
#  ['Oh! Oh! Mother! Mother! The water! The water! Percy is down  down  in the water',
#   1],
#  ['Oh! Percy  Percy! Once I saw a little bird', 1],
#  ['Come hop  hop  hop  I cried   Little bird  Will you stop  stop  stop?  I was going to the window',
#   1],
#  ['To say   How do you do?  But he shook his little tail', 1],
#  ['And away he flew', 1],
#  ['Mittu was a parrot', 1],
#  ['A green parrot with a red beak', 1],
#  ['One day Mittu was flying', 1],
#  ['He loved to fly', 1],
#  ['He looked down', 1],
#  ['He saw a big yellow mango on a tree', 1],
#  ['Mittu liked mangoes', 1],
#  ['I want to eat that yellow mango   he said', 1],
#  ['He flew down to the tree', 1],
#  ['Caw  caw  go away', 1],
#  ['This is my tree   said a voice', 1],
#  ['Mittu looked up', 1],
#  ['He saw a big black crow', 1],
#  ['Caw  caw  go  go  the crow shouted', 1],
#  ['He had a very loud voice', 1],
#  ['Mittu was afraid of the crow', 1],
#  ['He flew away', 1],
#  ['Mittu saw a red balloon', 1],
#  ['It was under a tree', 1],
#  ['He had an idea', 1],
#  ['He picked up the red balloon', 1],
#  ['He was careful not to burst it', 1],
#  ['He flew to the mango tree', 1],
#  ['The crow was sitting on the tree', 1],
#  ['Mittu went behind the tree', 1],
#  ['He pecked the balloon with his red beak', 1],
#  ['Pop!  The balloon burst', 1],
#  ['It made a loud noise', 1],
#  ['Caw!  said the crow', 1],
#  ['And he fell off the tree', 1],
#  ['Caw  caw  a big gun is after me   said the crow', 1],
#  ['He flew away', 1],
#  ['He never came back to the tree', 1],
#  ['Mittu came to the tree', 1],
#  ['He ate the big yellow mango', 1],
#  ['Yummy yummy  what a nice mango! he said', 1],
#  ['He was very happy', 1],
#  ['Clever Mittu! I climbed up on the merry go round  And it went round and round',
#   1],
#  ['I climbed up on a big brown horse  And it went up and down', 1],
#  ['Around and round  And up and down  Around and round  And up and down', 1],
#  ['I sat high up', 1],
#  ['On a big brown horse  And rode around  On the merry go round  On the merry go round',
#   1],
#  ['Have you seen a merry go round? Where have you seen it?', 1],
#  ['Listen  read and draw', 1],
#  ['One day Mohini was sitting with her grandmother', 1],
#  ['Grandmother drew a circle', 1],
#  ['Can you draw a circle  Mohini?   Yes I can.  Soon Mohini drew a circle', 1],
#  ['Now  I ll draw a ball.  Grandmother drew three lines on the circle', 1],
#  ['Mohini drew three lines on her circle', 1],
#  ['It really looked like a ball', 1],
#  ['Now let s draw a balloon.  Grandmother added a zig zag line to the circle',
#   1],
#  ['Oh! It really looks like a balloon.  Mohini clapped with joy', 1],
#  ['Mohini drew many circles  big and small circles  red  blue  green and yellow circles',
#   1],
#  ['She also added zig zag lines to these', 1],
#  ['And now there were many balloons', 1],
#  ['Can you draw something else with a circle?  asked Grandmother', 1],
#  ['Yes   said Mohini', 1],
#  ['She drew a wheel  a moon  a sun  a rabbit and her own face', 1],
#  ['If I were an apple', 1],
#  ['And grew on a tree  I think I d drop down', 1],
#  ['On a nice boy like me', 1],
#  ['I wouldn t stay there', 1],
#  ['Giving nobody joy  I d fall down at once', 1],
#  ['And say   Eat me  my boy!  A little bird sees', 1],
#  ['Ripe fruit on our tree', 1],
#  ['And eats a tasty berry', 1],
#  ['The bird flies tall', 1],
#  ['And a berry seed falls', 1],
#  ['The rains have come', 1],
#  ['Hurry! let s run', 1],
#  ['Clouds  rain and sun', 1],
#  ['Our plant is born  a little one', 1],
#  ['Now a tree  With branches long  Crows and bird song  Crawling ants and spiders  webs  Caterpillars with tiny legs  Rich green leaves  life aplenty',
#   1],
#  ['The tree has fruit  Some big  some small  Let us pluck them', 1],
#  ['But do not fall!', 1],
#  ['Strong branches  With pretty swings  Our beautiful tree has so many things',
#   1],
#  ['Crows perch  squirrels run  And see the monkeys having fun! Yes  I can climb',
#   1],
#  ['Yes  I can pluck', 1],
#  ['Yes  I can catch', 1],
#  ['Yes  I can jump', 1],
#  ['One day Murali ate a mango', 1],
#  ['He threw the seed behind his house', 1],
#  ['Many months later  he saw a plant', 1],
#  ['He watered the plant every day', 1],
#  ['The plant grew into a big mango tree', 1],
#  ['Every summer  many mangoes grow on it', 1],
#  ['Now  Murali s children eat the mangoes', 1],
#  ['I often sit and wish that I', 1],
#  ['Could be a kite up in the sky  And ride upon the breeze and go', 1],
#  ['Whichever way I chanced to blow', 1],
#  ['Sundari was a big red  white and blue kite', 1],
#  ['When Bobby made her she smiled at him', 1],
#  ['You are beautiful and I will call you Sundari   he said', 1],
#  ['One day  Bobby took Sundari to the fair', 1],
#  ['The band was playing and everyone was smiling', 1],
#  ['Bobby looked for an open space where he could run and fly his kite', 1],
#  ['Sundari looked too', 1],
#  ['Out in the grass ran Bobby  holding up his kite as high as he could', 1],
#  ['Puff! The wind came along', 1],
#  ['Sundari started to fly up! But she could not go very high', 1],
#  ['A little dog was holding on to her long tail', 1],
#  ['It was in his mouth', 1],
#  ['A merry go round was playing a happy little tune', 1],
#  ['It was carrying lots of boys and girls round and round on its wooden animals',
#   1],
#  ['Bobby shooed the dog away', 1],
#  ['We ll try again   Bobby said', 1],
#  ['This time Sundari leaped up in the air', 1],
#  ['She tugged hard', 1],
#  ['Oh  how she wanted Bobby to let go of her string! She gave a big tug', 1],
#  ['Bobby had to let her go', 1],
#  ['Wheee!  cried Sundari', 1],
#  ['Now I can fly as high as I please!', 1],
#  ['And away she went', 1],
#  ['She flew up  up  up in the air', 1],
#  ['I am a little turtle I crawl so slow  I carry my house Wherever I go', 1],
#  ['When I get tired', 1],
#  ['I put in my head  My legs and my tail  And I go to bed', 1],
#  ['A tiger was dozing under a tree', 1],
#  ['A mosquito came buzzing by', 1],
#  ['The tiger said   Hey! Mosquito! Go away!  The mosquito said   Why should I go away? I am not afraid of you!  The tiger was angry',
#   1],
#  ['He hit out with his paw', 1],
#  ['The mosquito flew off', 1],
#  ['The paw struck his own cheek', 1],
#  ['The blow scraped his cheek', 1],
#  ['It began to bleed', 1],
#  ['The mosquito buzzed away', 1],
#  ['The tiger struck with his other paw', 1],
#  ['The mosquito flew off', 1],
#  ['This time  too  he hit himself', 1],
#  ['The tiger was helpless', 1],
#  ['The mosquito continued to buzz', 1],
#  ['The tiger got up and quietly walked away', 1],
#  ['The mosquito called out after him   Don t be so proud  my friend', 1],
#  ['Everyone is great in his own way!  It is hot', 1],
#  ['The sky is blue', 1],
#  ['A little cloud comes looking for you', 1],
#  ['More clouds come', 1],
#  ['They bring rain', 1],
#  ['Sing and dance', 1],
#  ['It s cool again! It was raining outside', 1],
#  ['Anandi was fast asleep dreaming of rainbows', 1],
#  ['She woke up to look out of her window', 1],
#  ['There was a huge  bright rainbow across a clear blue sky', 1],
#  ['Anandi ran out to the garden with Milli  her favourite cat', 1],
#  ['Anandi loved to draw and paint', 1],
#  ['Today  she wanted to paint the flowers of her garden with the colours of the rainbow',
#   1],
#  ['She coloured one flower with the violet  and another with the indigo of the rainbow',
#   1],
#  ['One with the blue and leaves with the green', 1],
#  ['One with the orange', 1],
#  ['One with the red', 1],
#  ['But she left the yellow so that the Sun may look bright and gay', 1],
#  ['And lo! There were beautiful flowers all over the garden', 1],
#  ['The Sun was up there shining in its yellow glory', 1],
#  ['After giving colours to the flowers and the Sun  the rainbow was gone', 1],
#  ['Kalu the tailor had a shop near the river', 1],
#  ['He made colourful pants and shirts for children', 1],
#  ['Appu the elephant was his friend', 1],
#  ['Appu came to his shop everyday', 1],
#  ['Kalu gave him many nice things to eat', 1],
#  ['One day Kalu wanted to play a trick', 1],
#  ['He did not give Appu anything to eat', 1],
#  ['He took out his needle instead and pricked Appu s trunk', 1],
#  ['Appu ran away in pain', 1],
#  ['Two days later Appu came down to the river and filled his trunk with water',
#   1],
#  ['He reached Kalu s shop and threw water everywhere', 1],
#  ['All the new clothes became wet', 1],
#  ['Appu shook his trunk and said  An elephant never forgets.  Kalu said   I am sorry  Appu',
#   1],
#  ['Let s be friends again.  Kalu and Appu became good friends', 1]]

# %%
# read the grade ten file
grade_ten_sentence = read_and_clean("../data/gradetenindia.txt")

# %%
label = 1
new_examples2 = []
for i in grade_ten_sentence:  
    if len(word_tokenize(i))>2:
        new_examples2 = new_examples2 + [[i, label]]

# %%
# new_examples2 = new_examples2[17:] # slicing the few sentences in the beginning to remove the contents page.

# %%
new_examples2 = new_examples2[500:] # slicing further to avoid overfitting due to data imbalance

# %%
new_examples2
# Out:
# [['They often waited for Wanda Petronski   to have fun with her', 10],
#  ['Most of the children in Room Thirteen didn t have names like that', 10],
#  ['They had names easy to say  like Thomas  Smith or Allen', 10],
#  ['There was one boy named Bounce  Willie Bounce  and people thought that was funny  but not funny in the same way that Petronski was',
#   10],
#  ['Wanda didn t have any friends', 10],
#  ['She came to school alone and went home alone', 10],
#  ['She always wore a faded blue dress that didn t hang right', 10],
#  ['It was clean  but it looked as though it had never been ironed properly',
#   10],
#  ['She didn t have any friends  but a lot of girls talked to her', 10],
#  ['Sometimes  they surrounded her in the school yard as she stood watching the little girls play hopscotch on the worn hard ground',
#   10],
#  ['Wanda   Peggy would say in a most courteous manner as though she were talking to Miss Mason',
#   10],
#  ['Wanda   she d say  giving one of her friends a nudge   tell us', 10],
#  ['How many dresses did you say you had hanging up in your closet?', 10],
#  ['A hundred   Wanda would say', 10],
#  ['A hundred!  exclaimed all the little girls incredulously  and the little ones would stop playing hopscotch and listen',
#   10],
#  ['Yeah  a hundred  all lined up   said Wanda', 10],
#  ['Then her thin lips drew together in silence', 10],
#  ['What are they like? All silk  I bet   said Peggy', 10],
#  ['Yeah  all silk  all colours.   Velvet  too?', 10],
#  ['Yeah  velvet too', 10],
#  ['A hundred dresses   Wanda would repeat stolidly', 10],
#  ['All lined up in my closet.  Then they d let her go', 10],
#  ['And then before she d gone very far  they couldn t help bursting into shrieks and peals of laughter',
#   10],
#  ['A hundred dresses! Obviously  the only dress Wanda had was the blue one she wore every day',
#   10],
#  ['So why did she say she had a hundred? What a story!', 10],
#  ['How many shoes did you say you had?   Sixty pairs', 10],
#  ['All lined up in my closet.  Cries of exaggerated politeness greeted this',
#   10],
#  ['All alike?   Oh  no', 10],
#  ['Every pair is different', 10],
#  ['All lined up.  Peggy  who had thought up this game  and Maddie  her inseparable friend  were always the last to leave',
#   10],
#  ['Finally Wanda would move up the street  her eyes dull and her mouth closed  hitching her left shoulder every now and then in the funny way she had  finishing the walk to school alone',
#   10],
#  ['Peggy was not really cruel', 10],
#  ['She protected small children from bullies', 10],
#  ['And she cried for hours if she saw an animal mistreated', 10],
#  ['If anybody had said to her   Don t you think that is a cruel way to treat Wanda?  she would have been very surprised',
#   10],
#  ['Cruel? Why did the girl say she had a hundred dresses? Anybody could tell that that was a lie',
#   10],
#  ['Why did she want to lie? And she wasn t just an ordinary person  else why did she have a name like that? Anyway they never made her cry',
#   10],
#  ['As for Maddie  this business of asking Wanda every day how many dresses and how many hats and how many this and that she had was bothering her',
#   10],
#  ['Maddie was poor herself', 10],
#  ['She usually wore somebody s hand me down clothes', 10],
#  ['Thank goodness  she didn t live up on Boggins Heights or have a funny name',
#   10],
#  ['Sometimes  when Peggy was asking Wanda those questions in that mocking polite voice  Maddie felt embarrassed and studied the marbles in the palm of her hand  rolling them around and saying nothing herself',
#   10],
#  ['Not that she felt sorry for Wanda  exactly', 10],
#  ['She would never have paid any attention to Wanda if Peggy hadn t invented the dresses game',
#   10],
#  ['But suppose Peggy and all the others started in on her next? She wasn t as poor as Wanda  perhaps  but she was poor',
#   10],
#  ['Of course she would have more sense than to say she had a hundred dresses',
#   10],
#  ['Still she would not like for them to begin on her', 10],
#  ['She wished Peggy would stop teasing Wanda Petronski', 10],
#  ['Today  even though they had been late to school  Maddie was glad she had not had to make fun of Wanda',
#   10],
#  ['She worked her arithmetic problems absentmindedly', 10],
#  ['Eight times eight   let s see   She wished she had the nerve to write Peggy a note  because she knew she never would have the courage to speak right out to Peggy  to say   Hey  Peg  let s stop asking Wanda how many dresses she has.  When she finished her arithmetic she did start a note to Peggy',
#   10],
#  ['Suddenly she paused and shuddered', 10],
#  ['She pictured herself in the school yard  a new target for Peggy and the girls',
#   10],
#  ['Peggy might ask her where she got the dress that she had on  and Maddie would have to say it was one of Peggy s old ones that Maddie s mother had tried to disguise with new trimmings so no one in Room Thirteen would recognise it',
#   10],
#  ['If only Peggy would decide of her own accord to stop having fun with Wanda',
#   10],
#  ['Oh  well! Maddie ran her hand through her short blonde hair as though to push the uncomfortable thoughts away',
#   10],
#  ['What difference did it make? Slowly Maddie tore into bits the note she had started',
#   10],
#  ['She was Peggy s best friend  and Peggy was the best liked girl in the whole room',
#   10],
#  ['Peggy could not possibly do anything that was really wrong  she thought',
#   10],
#  ['As for Wanda  she was just some girl who lived up on Boggins Heights and stood alone in the school yard',
#   10],
#  ['She scarcely ever said anything to anybody', 10],
#  ['The only time she talked was in the school yard about her hundred dresses',
#   10],
#  ['Maddie remembered her telling about one of her dresses  pale blue with coloured trimmings',
#   10],
#  ['And she remembered another that was brilliant jungle green with a red sash',
#   10],
#  ['You d look like a Christmas tree in that   the girls had said in pretended admiration',
#   10],
#  ['Thinking about Wanda and her hundred dresses all lined up in the closet  Maddie began to wonder who was going to win the drawing and colouring contest',
#   10],
#  ['For girls  this contest consisted of designing dresses and for boys  of designing motorboats',
#   10],
#  ['Probably Peggy would win the girls  medal', 10],
#  ['Peggy drew better than anyone else in the room', 10],
#  ['At least  that s what everybody thought', 10],
#  ['She could copy a picture in a magazine or some film star s head so that you could almost tell who it was',
#   10],
#  ['Oh  Maddie was sure Peggy would win', 10],
#  ['Well  tomorrow the teacher was going to announce the winners', 10],
#  ['Then they d know', 10],
#  ['The next day it was drizzling', 10],
#  ['Maddie and Peggy hurried to school under Peggy s umbrella', 10],
#  ['Naturally  on a day like this  they didn t wait for Wanda Petronski on the corner of Oliver Street  the street that far  far away  under the railroad tracks and up the hill  led to Boggins Heights',
#   10],
#  ['Anyway  they weren t taking chances on being late today  because today was important',
#   10],
#  ['Do you think Miss Mason will announce the winners today?  asked Peggy', 10],
#  ['Oh  I hope so  the minute we get in   said Maddie', 10],
#  ['Of course  you ll win  Peg', 10],
#  ['Hope so   said Peggy eagerly', 10],
#  ['The minute they entered the classroom  they stopped short and gasped', 10],
#  ['There were drawings all over the room  on every ledge and windowsill  dazzling colours and brilliant  lavish designs  all drawn on great sheets of wrapping paper',
#   10],
#  ['There must have been a hundred of them  all lined up', 10],
#  ['These must be the drawings for the contest', 10],
#  ['They were! Everybody stopped and whistled or murmured admiringly', 10],
#  ['As soon as the class had assembled  Miss Mason announced the winners', 10],
#  ['Jack Beggles had won for the boys  she said  and his design for an outboard motor was on exhibition in Room Twelve  along with the sketches by all the other boys',
#   10],
#  ['As for the girls   she said   although just one or two sketches were submitted by most  one girl   and Room Thirteen should be proud of her   this one girl actually drew one hundred designs   all different and all beautiful',
#   10],
#  ['In the opinion of the judges  any one of the drawings is worthy of winning the prize',
#   10],
#  ['I am very happy to say that Wanda Petronski is the winner of the girls  medal',
#   10],
#  ['Unfortunately  Wanda has been absent from school for some days and is not here to receive the applause that is due to her',
#   10],
#  ['Let us hope she will be back tomorrow', 10],
#  ['Now class  you may file around the room quietly and look at her exquisite drawings.  The children burst into applause  and even the boys were glad to have a chance to stamp on the floor  put their fingers in their mouths and whistle  though they were not interested in dresses',
#   10],
#  ['Look  Peg   whispered Maddie', 10],
#  ['There s that blue one she told us about', 10],
#  ['Isn t it beautiful?   Yes   said Peggy   And here s that green one', 10],
#  ['Boy  and I thought I could draw', 10],
#  ['WHILE the class was circling the room  the monitor from the principal s office brought Miss Mason a note',
#   10],
#  ['Miss Mason read it several times and studied it thoughtfully for a while',
#   10],
#  ['Then she clapped her hands', 10],
#  ['Everyone back to their seat.  When the shuffling of feet had stopped and the room was still and quiet  Miss Mason said   I have a letter from Wanda s father that I want to read to you',
#   10],
#  ['Miss Mason stood there a moment and the silence in the room grew tense and expectant',
#   10],
#  ['The teacher adjusted her glasses slowly and deliberately', 10],
#  ['Her manner indicated that what was coming   this letter from Wanda s father   was a matter of great importance',
#   10],
#  ['Everybody listened closely as Miss Mason read the brief note', 10],
#  ['Dear Teacher  My Wanda will not come to your school any more', 10],
#  ['Now we move away to big city', 10],
#  ['No more holler  Pollack', 10],
#  ['No more ask why funny name', 10],
#  ['Plenty of funny names in the big city', 10],
#  ['Yours truly  Jan Petronski', 10],
#  ['A deep silence met the reading of this letter', 10],
#  ['Miss Mason took off her glasses  blew on them and wiped them on her soft white handkerchief',
#   10],
#  ['Then she put them on again and looked at the class', 10],
#  ['When she spoke her voice was very low', 10],
#  ['I am sure that none of the boys and girls in Room Thirteen would purposely and deliberately hurt anyone s feelings because his or her name happened to be a long  unfamiliar one',
#   10],
#  ['I prefer to think that what was said was said in thoughtlessness', 10],
#  ['I know that all of you feel the way I do  that this is a very unfortunate thing to have happened   unfortunate and sad  both',
#   10],
#  ['And I want you all to think about it', 10],
#  ['The first period was a study period', 10],
#  ['Maddie tried to prepare her lessons  but she could not put her mind on her work',
#   10],
#  ['She had a very sick feeling in the bottom of her stomach', 10],
#  ['True  she had not enjoyed listening to Peggy ask Wanda how many dresses she had in her closet  but she had said nothing',
#   10],
#  ['She had stood by silently  and that was just as bad as what Peggy had done',
#   10],
#  ['She was a coward', 10],
#  ['At least Peggy hadn t considered they were being mean but she  Maddie  had thought they were doing wrong',
#   10],
#  ['She could put herself in Wanda s shoes', 10],
#  ['Goodness! Wasn t there anything she could do? If only she could tell Wanda she hadn t meant to hurt her feelings',
#   10],
#  ['She turned around and stole a glance at Peggy  but Peggy did not look up',
#   10],
#  ['She seemed to be studying hard', 10],
#  ['Well  whether Peggy felt badly or not  she  Maddie  had to do something',
#   10],
#  ['She had to find Wanda Petronski', 10],
#  ['Maybe she had not yet moved away', 10],
#  ['Maybe Peggy would climb the Heights with her  and they would tell Wanda she had won the contest  that they thought she was smart and the hundred dresses were beautiful',
#   10],
#  ['When school was dismissed in the afternoon  Peggy said  with pretended casualness   Hey  let s go and see if that kid has left town or not',
#   10],
#  ['So Peggy had had the same idea! Maddie glowed', 10],
#  ['Peg was really all right', 10],
#  ['The two girls hurried out of the building  up the street toward Boggins Heights  the part of town that wore such a forbidding air on this kind of a November afternoon  drizzly  damp and dismal',
#   10],
#  ['Well  at least   said Peggy gruffly   I never did call her a foreigner or make fun of her name',
#   10],
#  ['I never thought she had the sense to know we were making fun of her anyway',
#   10],
#  ['I thought she was too dumb', 10],
#  ['And gee  look how she can draw!  Maddie could say nothing', 10],
#  ['All she hoped was that they would find Wanda', 10],
#  ['She wanted to tell her that they were sorry they had picked on her  and how wonderful the whole school thought she was  and please  not to move away and everybody would be nice',
#   10],
#  ['She and Peggy would fight anybody who was not nice', 10],
#  ['The two girls hurried on', 10],
#  ['They hoped to get to the top of the hill before dark', 10],
#  ['I think that s where the Petronskis live   said Maddie  pointing to a little white house',
#   10],
#  ['Wisps of old grass stuck up here and there along the pathway like thin kittens',
#   10],
#  ['The house and its sparse little yard looked shabby but clean', 10],
#  ['It reminded Maddie of Wanda s one dress  her faded blue cotton dress  shabby but clean',
#   10],
#  ['There was not a sign of life about the house', 10],
#  ['Peggy knocked firmly on the door  but there was no answer', 10],
#  ['She and Maddie went around to the back yard and knocked there', 10],
#  ['Still there was no answer', 10],
#  ['There was no doubt about it', 10],
#  ['The Petronskis were gone', 10],
#  ['How could they ever make amends? They turned slowly and made their way back down the hill',
#   10],
#  ['Well  anyway   said Peggy   she s gone now  so what can we do? Besides  when I was asking her about all her dresses  she probably was getting good ideas for her drawings',
#   10],
#  ['She might not even have won the contest  otherwise.  Maddie turned this idea carefully over in her head  for if there were anything in it she would not have to feel so badly',
#   10],
#  ['But that night she could not get to sleep', 10],
#  ['She thought about Wanda and her faded blue dress and the little house she had lived in',
#   10],
#  ['And she thought of the glowing picture those hundred dresses made   all lined up in the classroom',
#   10],
#  ['At last Maddie sat up in bed and pressed her forehead tight in her hands and really thought',
#   10],
#  ['This was the hardest thinking she had ever done', 10],
#  ['After a long  long time  she reached an important conclusion', 10],
#  ['She was never going to stand by and say nothing again', 10],
#  ['If she ever heard anybody picking on someone because they were funny looking or because they had strange names  she d speak up',
#   10],
#  ['Even if it meant losing Peggy s friendship', 10],
#  ['She had no way of making things right with Wanda  but from now on she would never make anybody else that unhappy again',
#   10],
#  ['On Saturday Maddie spent the afternoon with Peggy', 10],
#  ['They were writing a letter to Wanda Petronski', 10],
#  ['It was just a friendly letter telling about the contest and telling Wanda she had won',
#   10],
#  ['They told her how pretty her drawings were', 10],
#  ['And they asked her if she liked where she was living and if she liked her new teacher',
#   10],
#  ['They had meant to say they were sorry  but it ended up with their just writing a friendly letter  the kind they would have written to any good friend  and they signed it with lots of X s for love',
#   10],
#  ['They mailed the letter to Boggins Heights  writing  Please Forward  on the envelope',
#   10],
#  ['Days passed and there was no answer  but the letter did not come back  so maybe Wanda had received it',
#   10],
#  ['Perhaps she was so hurt and angry she was not going to answer', 10],
#  ['You could not blame her', 10],
#  ['Weeks went by and still Wanda did not answer', 10],
#  ['Peggy had begun to forget the whole business  and Maddie put herself to sleep at night making speeches about Wanda  defending her from great crowds of girls who were trying to tease her with   How many dresses have you got?  And before Wanda could press her lips together in a tight line  the way she did before answering  Maddie would cry out   Stop!  Then everybody would feel ashamed the way she used to feel',
#   10],
#  ['Now it was Christmas time and there was snow on the ground', 10],
#  ['Christmas bells and a small tree decorated the classroom', 10],
#  ['On the last day of school before the holidays  the teacher showed the class a letter she had received that morning',
#   10],
#  ['You remember Wanda Petronski  the gifted little artist who won the drawing contest? Well  she has written me  and I am glad to know where she lives  because now I can send her medal',
#   10],
#  ['I want to read her letter to you', 10],
#  ['The class sat up with a sudden interest and listened intently', 10],
#  ['Dear Miss Mason  How are you and Room Thirteen? Please tell the girls they can keep those hundred dresses  because in my new house I have a hundred new ones  all lined up in my closet',
#   10],
#  ['I d like that girl Peggy to have the drawing of the green dress with the red trimming  and her friend Maddie to have the blue one',
#   10],
#  ['For Christmas  I miss that school and my new teacher does not equalise with you',
#   10],
#  ['Merry Christmas to you and everybody', 10],
#  ['Yours truly  Wanda Petronski', 10],
#  ['On the way home from school Maddie and Peggy held their drawings very carefully',
#   10],
#  ['All the houses had wreaths and holly in the windows', 10],
#  ['Outside the grocery store  hundreds of Christmas trees were stacked  and in the window  candy peppermint sticks and cornucopias of shiny transparent paper were strung',
#   10],
#  ['The air smelled like Christmas and light shining everywhere reflected different colours on the snow',
#   10],
#  ['Boy!  said Peggy   this shows she really likes us', 10],
#  ['It shows she got our letter and this is her way of saying that everything s all right',
#   10],
#  ['And that s that.   I hope so   said Maddie sadly', 10],
#  ['She felt sad because she knew she would never see the little tight lipped Polish girl again and couldn t ever really make things right between them',
#   10],
#  ['She went home and she pinned her drawing over a torn place in the pink flowered wallpaper in the bedroom',
#   10],
#  ['The shabby room came alive from the brilliancy of the colours', 10],
#  ['Maddie sat down on her bed and looked at the drawing', 10],
#  ['She had stood by and said nothing  but Wanda had been nice to her  anyway',
#   10],
#  ['Tears blurred her eyes and she gazed for a long time at the picture', 10],
#  ['Then hastily she rubbed her eyes and studied it intently', 10],
#  ['The colours in the dress were so vivid that she had scarcely noticed the face and head of the drawing',
#   10],
#  ['But it looked like her  Maddie!', 10],
#  ['It really looked like her own mouth', 10],
#  ['Why it really looked like her own self! Wanda had really drawn this for her',
#   10],
#  ['Excitedly  she ran over to Peggy s', 10],
#  ['Peg!  she said   let me see your picture', 10],
#  ['What s the matter?  asked Peggy  as they clattered up to her room where Wanda s drawing was lying face down on the bed',
#   10],
#  ['Maddie carefully raised it', 10],
#  ['Look! She drew you', 10],
#  ['That s you!  she exclaimed', 10],
#  ['And the head and face of this picture did look like Peggy', 10],
#  ['What did I say!  said Peggy   She must have really liked us  anyway', 10],
#  ['Yes  she must have   agreed Maddie  and she blinked away the tears that came every time she thought of Wanda standing alone in that sunny spot in the school yard  looking stolidly over at the group of laughing girls after she had walked off  after she had said   Sure  a hundred of them  all lined up. ',
#   10],
#  ['Help your students conduct a survey in their class to find out about the different talents that their classmates possess   anything from cooking to painting to singing to gardening',
#   10],
#  ['Divide the class into two equal sections  A and B', 10],
#  ['Each student from Section A talks with one student from Section B  and they interview each other for five or ten minutes  so that at the end of that time all the students have been interviewed',
#   10],
#  ['Then about five students from each section  more if there is time  talk about the talents of the person they interviewed',
#   10],
#  ['Make sure that some of the more  marginalised  students from your class  each class has some of them  have their moment of  fame',
#   10],
#  ['The poet tells us that he feels more at home with animals than humans  whom he finds complicated and false',
#   10],
#  ['Walt Whitman       is a major figure in early American poetry', 10],
#  ['In an age when all poetry was rhymed and metrical  Whitman made a break with tradition and wrote a revolutionary new kind of poetry in free verse',
#   10],
#  ['He was a nonconformist in all respects  including his social life', 10],
#  ['What are the  tokens  that the poet says he may have dropped long ago  and which the animals have kept for him? Discuss this in class',
#   10],
#  ['Hint  Whitman belongs to the Romantic tradition that includes Rousseau and Wordsworth  which holds that civilisation has made humans false to their own true nature',
#   10],
#  ['What could be the basic aspects of our nature as living beings that humans choose to ignore or deny? ',
#   10],
#  ['OUR elders are often heard reminiscing nostalgically about those good old Portuguese days  the Portuguese and their famous loaves of bread',
#   10],
#  ['Those eaters of loaves might have vanished but the makers are still there',
#   10],
#  ['We still have amongst us the mixers  the moulders and those who bake the loaves',
#   10],
#  ['Those age old  timetested furnaces still exist', 10],
#  ['The fire in the furnaces has not yet been extinguished', 10],
#  ['The thud and jingle of the traditional baker s bamboo  heralding his arrival in the morning  can still be heard in some places',
#   10],
#  ['Maybe the father is not alive but the son still carries on the family profession',
#   10],
#  ['These bakers are  even today  known as pader in Goa', 10],
#  ['During our childhood in Goa  the baker used to be our friend  companion and guide',
#   10],
#  ['He used to come at least twice a day', 10],
#  ['Once  when he set out in the morning on his selling round  and then again  when he returned after emptying his huge basket',
#   10],
#  ['The jingling thud of his bamboo woke us up from sleep and we ran to meet and greet him',
#   10],
#  ['Why was it so? Was it for the love of the loaf? Not at all', 10],
#  ['The loaves were bought by some Paskine or Bastine  the maid servant of the house! What we longed for were those bread bangles which we chose carefully',
#   10],
#  ['Sometimes it was sweet bread of special make', 10],
#  ['The baker made his musical entry on the scene with the  jhang  jhang  sound of his specially made bamboo staff',
#   10],
#  ['One hand supported the basket on his head and the other banged the bamboo on the ground',
#   10],
#  ['He would greet the lady of the house with  Good morning  and then place his basket on the vertical bamboo',
#   10],
#  ['We kids would be pushed aside with a mild rebuke and the loaves would be delivered to the servant',
#   10],
#  ['But we would not give up', 10],
#  ['We would climb a bench or the parapet and peep into the basket  somehow',
#   10],
#  ['I can still recall the typical fragrance of those loaves', 10],
#  ['Loaves for the elders and the bangles for the children', 10],
#  ['Then we did not even care to brush our teeth or wash our mouths properly',
#   10],
#  ['And why should we? Who would take the trouble of plucking the mango leaf for the toothbrush? And why was it necessary at all? The tiger never brushed his teeth',
#   10],
#  ['Hot tea could wash and clean up everything so nicely  after all!', 10],
#  ['Marriage gifts are meaningless without the sweet bread known as the bol  just as a party or a feast loses its charm without bread',
#   10],
#  ['Not enough can be said to show how important a baker can be for a village',
#   10],
#  ['The lady of the house must prepare sandwiches on the occasion of her daughter s engagement',
#   10],
#  ['Cakes and bolinhas are a must for Christmas as well as other festivals',
#   10],
#  ['Thus  the presence of the baker s furnace in the village is absolutely essential',
#   10],
#  ['The baker or bread seller of those days had a peculiar dress known as the kabai',
#   10],
#  ['It was a singlepiece long frock reaching down to the knees', 10],
#  ['In our childhood we saw bakers wearing a shirt and trousers which were shorter than full length ones and longer than half pants',
#   10],
#  ['Even today  anyone who wears a half pant which reaches just below the knees invites the comment that he is dressed like a pader!',
#   10],
#  ['The baker usually collected his bills at the end of the month', 10],
#  ['Monthly accounts used to be recorded on some wall in pencil', 10],
#  ['Baking was indeed a profitable profession in the old days', 10],
#  ['The baker and his family never starved', 10],
#  ['He  his family and his servants always looked happy and prosperous', 10],
#  ['Their plump physique was an open testimony to this', 10],
#  ['Even today any person with a jackfruit like physical appearance is easily compared to a baker',
#   10],
#  ['MIDWAY between Mysore and the coastal town of Mangalore sits a piece of heaven that must have drifted from the kingdom of god',
#   10],
#  ['This land of rolling hills is inhabited by a proud race of martial men  beautiful women and wild creatures',
#   10],
#  ['Coorg  or Kodagu  the smallest district of Karnataka  is home to evergreen rainforests  spices and coffee plantations',
#   10],
#  ['Evergreen rainforests cover thirty per cent of this district', 10],
#  ['During the monsoons  it pours enough to keep many visitors away', 10],
#  ['The season of joy commences from September and continues till March', 10],
#  ['The weather is perfect  with some showers thrown in for good measure', 10],
#  ['The air breathes of invigorating coffee', 10],
#  ['Coffee estates and colonial bungalows stand tucked under tree canopies in prime corners',
#   10],
#  ['The fiercely independent people of Coorg are possibly of Greek or Arabic descent',
#   10],
#  ['As one story goes  a part of Alexander s army moved south along the coast and settled here when return became impractical',
#   10],
#  ['These people married amongst the locals and their culture is apparent in the martial traditions  marriage and religious rites  which are distinct from the Hindu mainstream',
#   10],
#  ['The theory of Arab origin draws support from the long  black coat with an embroidered waist belt worn by the Kodavus',
#   10],
#  ['Known as kuppia  it resembles the kuffia worn by the Arabs and the Kurds',
#   10],
#  ['Coorgi homes have a tradition of hospitality  and they are more than willing to recount numerous tales of valour related to their sons and fathers',
#   10],
#  ['The Coorg Regiment is one of the most decorated in the Indian Army  and the first Chief of the Indian Army  General Cariappa  was a Coorgi',
#   10],
#  ['Even now  Kodavus are the only people in India permitted to carry firearms without a licence',
#   10],
#  ['The river  Kaveri  obtains its water from the hills and forests of Coorg',
#   10],
#  ['Mahaseer   a large freshwater fish   abound in these waters', 10],
#  ['Kingfishers dive for their catch  while squirrels and langurs drop partially eaten fruit for the mischief of enjoying the splash and the ripple effect in the clear water',
#   10],
#  ['Elephants enjoy being bathed and scrubbed in the river by their mahouts',
#   10],
#  ['The most laidback individuals become converts to the life of high energy adventure with river rafting  canoeing  rappelling  rock climbing and mountain biking',
#   10],
#  ['Numerous walking trails in this region are a favourite with trekkers', 10],
#  ['Birds  bees and butterflies are there to give you company', 10],
#  ['Macaques  Malabar squirrels  langurs and slender loris keep a watchful eye from the tree canopy',
#   10],
#  ['I do  however  prefer to step aside for wild elephants', 10],
#  ['The climb to the Brahmagiri hills brings you into a panoramic view of the entire misty landscape of Coorg',
#   10],
#  ['A walk across the rope bridge leads to the sixty four acre island of Nisargadhama',
#   10],
#  ['Running into Buddhist monks from India s largest Tibetan settlement  at nearby Bylakuppe  is a bonus',
#   10],
#  ['The monks  in red  ochre and yellow robes  are amongst the many surprises that wait to be discovered by visitors searching for the heart and soul of India  right here in Coorg',
#   10],
#  ['Pranjol  a youngster from Assam  is Rajvir s classmate at school in Delhi',
#   10],
#  ['Pranjol s father is the manager of a tea garden in Upper Assam and Pranjol has invited Rajvir to visit his home during the summer vacation',
#   10],
#  ['Give us two cups   Pranjol said', 10],
#  ['They sipped the steaming hot liquid', 10],
#  ['Almost everyone in their compartment was drinking tea too', 10],
#  ['Do you know that over eighty crore cups of tea are drunk every day throughout the world?  Rajvir said',
#   10],
#  ['Whew!  exclaimed Pranjol', 10],
#  ['Tea really is very popular.  The train pulled out of the station', 10],
#  ['Pranjol buried his nose in his detective book again', 10],
#  ['Rajvir too was an ardent fan of detective stories  but at the moment he was keener on looking at the beautiful scenery',
#   10],
#  ['It was green  green everywhere', 10],
#  ['Rajvir had never seen so much greenery before', 10],
#  ['Then the soft green paddy fields gave way to tea bushes', 10],
#  ['It was a magnificent view', 10],
#  ['Against the backdrop of densely wooded hills a sea of tea bushes stretched as far as the eye could see',
#   10],
#  ['Dwarfing the tiny tea plants were tall sturdy shade trees and amidst the orderly rows of bushes busily moved doll like figures',
#   10],
#  ['In the distance was an ugly building with smoke billowing out of tall chimneys',
#   10],
#  ['Hey  a tea garden!  Rajvir cried excitedly', 10],
#  ['Pranjol  who had been born and brought up on a plantation  didn t share Rajvir s excitement',
#   10],
#  ['Oh  this is tea country now   he said', 10],
#  ['Assam has the largest concentration of plantations in the world', 10],
#  ['You will see enough gardens to last you a lifetime!   I have been reading as much as I could about tea   Rajvir said',
#   10],
#  ['No one really knows who discovered tea but there are many legends.   What legends?   Well  there s the one about the Chinese emperor who always boiled water before drinking it',
#   10],
#  ['One day a few leaves of the twigs burning under the pot fell into the water giving it a delicious flavour',
#   10],
#  ['It is said they were tea leaves', 10],
#  ['Tell me another!  scoffed Pranjol', 10],
#  ['We have an Indian legend too', 10],
#  ['Bodhidharma  an ancient Buddhist ascetic  cut off his eyelids because he felt sleepy during meditations',
#   10],
#  ['Ten tea plants grew out of the eyelids', 10],
#  ['The leaves of these plants when put in hot water and drunk banished sleep',
#   10],
#  ['Tea was first drunk in China   Rajvir added  as far back as  B.C.! In fact words such as tea   chai  and  chini  are from Chinese',
#   10],
#  ['Tea came to Europe only in the sixteenth century and was drunk more as medicine than as beverage.  The train clattered into Mariani junction',
#   10],
#  ['The boys collected their luggage and pushed their way to the crowded platform',
#   10],
#  ['Pranjol s parents were waiting for them', 10],
#  ['Soon they were driving towards Dhekiabari  the tea garden managed by Pranjol s father',
#   10],
#  ['An hour later the car veered sharply off the main road', 10],
#  ['They crossed a cattle bridge and entered Dhekiabari Tea Estate', 10],
#  ['On both sides of the gravel road were acre upon acre of tea bushes  all neatly pruned to the same height',
#   10],
#  ['Groups of tea pluckers  with bamboo baskets on their backs  wearing plastic aprons  were plucking the newly sprouted leaves',
#   10],
#  ['Pranjol s father slowed down to allow a tractor  pulling a trailer load of tea leaves  to pass',
#   10],
#  ['This is the second flush or sprouting period  isn t it  Mr Barua?  Rajvir asked',
#   10],
#  ['It lasts from May to July and yields the best tea.   You seem to have done your homework before coming   Pranjol s father said in surprise',
#   10],
#  ['Yes  Mr Barua   Rajvir admitted', 10],
#  ['But I hope to learn much more while I m here.  India and tea are so intertwined together that life without the brew is unimaginable',
#   10],
#  ['Tea entered our life only in the mid nineteenth century when the British started plantations in Assam and Darjeeling! In the beginning though  Indians shunned the drink as they thought it was a poison that led to umpteen diseases',
#   10],
#  ['Ironically  tea colonised Britain where it became a part of their social diary and also led to the establishment of numerous tea houses',
#   10],
#  ['Adrienne Rich was born in Baltimore  Maryland  U.S.A', 10],
#  ['She is the author of nearly twenty volumes of poetry  and has been called a feminist and a radical poet',
#   10],
#  ['Gavin Maxwell lives in a cottage in Camusfearna  in the West Highlands in Scotland',
#   10],
#  ['When his dog Jonnie died  Maxwell was too sad to think of keeping a dog again',
#   10],
#  ['But life without a pet was lonely', 10],
#  ['Read what happened then  in Maxwell s own words', 10],
#  ['Owning a pet is a lifetime of commitment  up to ten years or more if you own a dog or a cat  involving considerable responsibility',
#   10],
#  ['The decision to acquire one  therefore  should be made by the whole family',
#   10],
#  ['Without full agreement by everyone  the pet could end up unwanted', 10],
#  ['Puppies and kittens are so adorable  it is easy to understand why adults and children alike would be attracted to them',
#   10],
#  ['Unfortunately their cute looks are often a disadvantage  because people purchase them without consideration and the knowledge on how to take proper care of them',
#   10],
#  ['Otters are found in large numbers in the marshes  i.e', 10],
#  ['wet areas near lakes  rivers or seas  near Basra  a town in Iraq', 10],
#  ['Imagine you wanted to bring an otter from Iraq to London  as a pet', 10],
#  ['What special arrangements would you need to make for your pet otter? You would need to find a place with lots of water  for example',
#   10],
#  ['What other points should you think about? EARLY in the New Year of  I travelled to Southern Iraq',
#   10],
#  ['By then it had crossed my mind that I should like to keep an otter instead of a dog  and that Camusfearna  ringed by water a stone s throw from its door  would be an eminently suitable spot for this experiment',
#   10],
#  ['When I casually mentioned this to a friend  he as casually replied that I had better get one in the Tigris marshes  for there they were as common as mosquitoes  and were often tamed by the Arabs',
#   10],
#  ['We were going to Basra to the Consulate General to collect and answer our mail from Europe',
#   10],
#  ['At the Consulate General we found that my friend s mail had arrived but that mine had not',
#   10],
#  ['I cabled to England  and when  three days later  nothing had happened  I tried to telephone',
#   10],
#  ['The call had to be booked twenty four hours in advance', 10],
#  ['On the first day the line was out of order  on the second the exchange was closed for a religious holiday',
#   10],
#  ['On the third day there was another breakdown', 10],
#  ['My friend left  and I arranged to meet him in a week s time', 10],
#  ['Five days later  my mail arrived', 10],
#  ['I carried it to my bedroom to read  and there squatting on the floor  were two Arabs  beside them lay a sack that squirmed from time to time',
#   10],
#  ['They handed me a note from my friend   Here is your otter...  With the opening of that sack began a phase of my life that has not yet ended  and may  for all I know  not end before I do',
#   10],
#  ['It is  in effect  a thraldom to otters  an otter fixation  that I have since found to be shared by most other people  who have ever owned one',
#   10],
#  ['The creature that emerged from this sack on to the spacious tiled floor of the Consulate bedroom resembled most of all a very small  medievally conceived  dragon',
#   10],
#  ['From the head to the tip of the tail he was coated with symmetrical pointed scales of mud armour  between whose tips was visible a soft velvet fur like that of a chocolate brown mole',
#   10],
#  ['He shook himself  and I half expected a cloud of dust  but in fact it was not for another month that I managed to remove the last of the mud and see the otter  as it were  in his true colours',
#   10],
#  ['Mijbil  as I called the otter  was  in fact  of a race previously unknown to science  and was at length christened by zoologists Lutrogale perspicillata maxwelli  or Maxwell s otter',
#   10],
#  ['For the first twentyfour hours Mijbil was neither hostile nor friendly  he was simply aloof and indifferent  choosing to sleep on the floor as far from my bed as possible',
#   10],
#  ['The second night Mijbil came on to my bed in the small hours and remained asleep in the crook of my knees until the servant brought tea in the morning  and during the day he began to lose his apathy and take a keen  much too keen  interest in his surroundings',
#   10],
#  ['I made a body belt for him and took him on a lead to the bathroom  where for half an hour he went wild with joy in the water  plunging and rolling in it  shooting up and down the length of the bathtub underwater  and making enough slosh and splash for a hippo',
#   10],
#  ['This  I was to learn  is a characteristic of otters  every drop of water must be  so to speak  extended and spread about the place  a bowl must at once be overturned  or  if it will not be overturned  be sat in and sploshed in until it overflows',
#   10],
#  ['Water must be kept on the move and made to do things  when static it is wasted and provoking',
#   10],
#  ['Two days later  Mijbil escaped from my bedroom as I entered it  and I turned to see his tail disappearing round the bend of the corridor that led to the bathroom',
#   10],
#  ['By the time I got there he was up on the end of the bathtub and fumbling at the chromium taps with his paws',
#   10],
#  ['I watched  amazed  in less than a minute he had turned the tap far enough to produce a trickle of water  and after a moment or two achieved the full flow',
#   10],
#  ['He had been lucky to turn the tap the right way  on later occasions he would sometimes screw it up still tighter  chittering with irritation and disappointment at the tap s failure to cooperate',
#   10],
#  ['Very soon Mij would follow me without a lead and come to me when I called his name',
#   10],
#  ['He spent most of his time in play', 10],
#  ['He spent hours shuffling a rubber ball round the room like a four footed soccer player using all four feet to dribble the ball  and he could also throw it  with a powerful flick of the neck  to a surprising height and distance',
#   10],
#  ['But the real play of an otter is when he lies on his back and juggles with small objects between his paws',
#   10],
#  ['Marbles were Mij s favourite toys for this pastime  he would lie on his back rolling two or more of them up and down his wide  flat belly without ever dropping one to the floor',
#   10],
#  ['The days passed peacefully at Basra  but I dreaded the prospect of transporting Mij to England  and to Camusfearna',
#   10],
#  ['The British airline to London would not fly animals  so I booked a flight to Paris on another airline  and from there to London',
#   10],
#  ['The airline insisted that Mij should be packed into a box not more than eighteen inches square  to be carried on the floor at my feet',
#   10],
#  ['I had a box made  and an hour before we started  I put Mij into the box so that he would become accustomed to it  and left for a hurried meal',
#   10],
#  ['When I returned  there was an appalling spectacle', 10],
#  ['There was complete silence from the box  but from its airholes and chinks around the lid  blood had trickled and dried',
#   10],
#  ['I whipped off the lock and tore open the lid  and Mij  exhausted and bloodspattered  whimpered and caught at my leg',
#   10],
#  ['He had torn the lining of the box to shreds  when I removed the last of it so that there were no cutting edges left  it was just ten minutes until the time of the flight  and the airport was five miles distant',
#   10],
#  ['I put the miserable Mij back into the box  holding down the lid with my hand',
#   10],
#  ['I sat in the back of the car with the box beside me as the driver tore through the streets of Basra like a ricochetting bullet',
#   10],
#  ['The aircraft was waiting to take off  I was rushed through to it by infuriated officials',
#   10],
#  ['Luckily  the seat booked for me was at the extreme front', 10],
#  ['I covered the floor around my feet with newspapers  rang for the air hostess  and gave her a parcel of fish  for Mij  to keep in a cool place',
#   10],
#  ['I took her into my confidence about the events of the last half hour', 10],
#  ['I have retained the most profound admiration for that air hostess  she was the very queen of her kind',
#   10],
#  ['She suggested that I might prefer to have my pet on my knee  and I could have kissed her hand in the depth of my gratitude',
#   10],
#  ['But  not knowing otters  I was quite unprepared for what followed', 10],
#  ['Mij was out of the box in a flash', 10],
#  ['He disappeared at high speed down the aircraft', 10],
#  ['There were squawks and shrieks  and a woman stood up on her seat screaming out   A rat! A rat!  I caught sight of Mij s tail disappearing beneath the legs of a portly whiteturbaned Indian',
#   10],
#  ['Diving for it  I missed  but found my face covered in curry', 10],
#  ['Perhaps   said the air hostess with the most charming smile   it would be better if you resumed your seat  and I will find the animal and bring it to you.  I returned to my seat',
#   10],
#  ['I was craning my neck trying to follow the hunt when suddenly I heard from my feet a distressed chitter of recognition and welcome  and Mij bounded on to my knee and began to nuzzle my face and my neck',
#   10],
#  ['Mij and I remained in London for nearly a month', 10],
#  ['He would play for hours with a selection of toys  ping pong balls  marbles  rubber fruit  and a terrapin shell that I had brought back from his native marshes',
#   10],
#  ['With the ping pong ball he invented a game of his own which could keep him engrossed for up to half an hour at a time',
#   10],
#  ['A suitcase that I had taken to Iraq had become damaged on the journey home  so that the lid  when closed  remained at a slope from one end to the other',
#   10],
#  ['Mij discovered that if he placed the ball on the high end it would run down the length of the suitcase',
#   10],
#  ['He would dash around to the other end to ambush its arrival  hide from it  crouching  to spring up and take it by surprise  grab it and trot off with it to the high end once more',
#   10],
#  ['Outside the house I exercised him on a lead  precisely as if he had been a dog',
#   10],
#  ['Mij quickly developed certain compulsive habits on these walks in the London streets  like the rituals of children who on their way to and from school must place their feet squarely on the centre of each paving block  musttouch every seventh upright of the iron railings  or pass to the outside of every second lamp post',
#   10],
#  ['Opposite to my flat was a single storied primary school  alongwhose frontage ran a low wall some two feet high',
#   10],
#  ['On his way home  but never on his way out  Mij would tug me to this wall  jump on to it  and gallop the full length of its thirty yards  to the hopeless distraction both of pupils and of staff within',
#   10],
#  ['It is not  I suppose  in any way strange that the average Londoner should not recognise an otter  but the variety of guesses as to what kind of animal this might be came as a surprise to me',
#   10],
#  ['Otters belong to a comparatively small group of animals called Mustellines  shared by the badger  mongoose  weasel  stoat  mink and others',
#   10],
#  ['I faced a continuous barrage of conjectural questions that sprayed all the Mustellines but the otter  more random guesses hit on  a baby seal  and  a squirrel.   Is that a walrus  mister?  reduced me to giggles  and outside a dog show I heard  a hippo',
#   10],
#  ['A beaver  a bear cub  a leopard   one  apparently  that had changed its spots   and a  brontosaur   Mij was anything but an otter',
#   10],
#  ['But the question for which I awarded the highest score came from a labourer digging a hole in the street',
#   10],
#  ['I was still far from him when he laid down his tool  put his hands on his hips  and began to stare',
#   10],
#  ['As I drew nearer I saw his expression of surprise and affront  as though he would have me know that he was not one upon whom to play jokes',
#   10],
#  ['I came abreast of him  he spat  glared  and then growled out   Here  Mister   what is that supposed to be?  You have seen how Maxwell describes Mij the otter s feelings and thoughts by watching him',
#   10],
#  ['Play the game of dumb charades', 10],
#  ['Take turns to express a feeling or thought silently  through gestures', 10],
#  ['Let the class speak out their guesses about the feelings or thoughts you are trying to express',
#   10],
#  ['THERE was a girl named Valliammai who was called Valli for short', 10],
#  ['She was eight years old and very curious about things', 10],
#  ['Her favourite pastime was standing in the front doorway of her house  watching what was happening in the street outside',
#   10],
#  ['There were no playmates of her own age on her street  and this was about all she had to do',
#   10],
#  ['But for Valli  standing at the front door was every bit as enjoyable as any of the elaborate games other children played',
#   10],
#  ['Watching the street gave her many new unusual experiences', 10],
#  ['The most fascinating thing of all was the bus that travelled between her village and the nearest town',
#   10],
#  ['It passed through her street each hour  once going to the town and once coming back',
#   10],
#  ['The sight of the bus  filled each time with a new set of passengers  was a source of unending joy for Valli',
#   10],
#  ['Day after day she watched the bus  and gradually a tiny wish crept into her head and grew there  she wanted to ride on that bus  even if just once',
#   10],
#  ['This wish became stronger and stronger  until it was an overwhelming desire',
#   10],
#  ['Valli would stare wistfully at the people who got on or off the bus when it stopped at the street corner',
#   10],
#  ['Their faces would kindle in her longings  dreams  and hopes', 10],
#  ['If one of her friends happened to ride the bus and tried to describe the sights of the town to her  Valli would be too jealous to listen and would shout  in English   Proud! proud!  Neither she nor her friends really understood the meaning of the word  but they used it often as a slang expression of disapproval',
#   10],
#  ['Over many days and months Valli listened carefully to conversations between her neighbours and people who regularly used the bus  and she also asked a few discreet questions here and there',
#   10],
#  ['This way she picked up various small details about the bus journey', 10],
#  ['The town was six miles from her village', 10],
#  ['The fare was thirty paise one way    which is almost nothing at all   she heard one well dressed man say  but to Valli  who scarcely saw that much money from one month to the next  it seemed a fortune',
#   10],
#  ['The trip to the town took forty five minutes', 10],
#  ['On reaching town  if she stayed in her seat and paid another thirty paise  she could return home on the same bus',
#   10],
#  ['This meant that she could take the one o clock afternoon bus  reach the town at one forty five  and be back home by about two forty five',
#   10],
# ...
#   10],
#  ['But she managed this without too much difficulty', 10],
#  ['Every day after lunch her mother would nap from about one to four or so',
#   10],
#  ['Valli always used these hours for her  excursions  as she stood looking from the doorway of her house or sometimes even ventured out into the village  today  these same hours could be used for her first excursion outside the village',
#   10],
#  ['The bus rolled on now cutting across a bare landscape  now rushing through a tiny hamlet or past an odd wayside shop',
#   10],
#  ['Sometimes the bus seemed on the point of gobbling up another vehicle that was coming towards them or a pedestrian crossing the road',
#   10],
#  ['But lo! somehow it passed on smoothly  leaving all obstacles safely behind',
#   10],
#  ['Trees came running towards them but then stopped as the bus reached them and simply stood there helpless for a moment by the side of the road before rushing away in the other direction',
#   10],
#  ['Suddenly Valli clapped her hands with glee', 10],
#  ['A young cow  tail high in the air  was running very fast  right in the middle of the road  right in front of the bus',
#   10],
#  ['The bus slowed to a crawl  and the driver sounded his horn loudly again and again',
#   10],
#  ['But the more he honked  the more frightened the animal became and the faster it galloped   always right in front of the bus',
#   10],
#  ['Somehow this was very funny to Valli', 10],
#  ['She laughed and laughed until there were tears in her eyes', 10],
#  ['Hey  lady  haven t you laughed enough?  called  the conductor', 10],
#  ['Better save some for tomorrow.  At last the cow moved off the road', 10],
#  ['And soon the bus came to a railroad crossing', 10],
#  ['A speck of a train could be seen in the distance  growing bigger and bigger as it drew near',
#   10],
#  ['Then it rushed past the crossing gate with a tremendous roar and rattle  shaking the bus',
#   10],
#  ['Then the bus went on and passed the train station', 10],
#  ['From there it traversed a busy  well laid out shopping street and  turning  entered a wider thoroughfare',
#   10],
#  ['Such big  bright looking shops! What glittering displays of clothes and other merchandise! Such big crowds! Struck dumb with wonder  Valli gaped at everything',
#   10],
#  ['Then the bus stopped and everyone got off except Valli', 10],
#  ['Hey  lady   said the conductor   aren t you ready to get off? This is as far as your thirty paise takes you.   No   Valli said   I m going back on this same bus.  She took another thirty paise from her pocket and handed the coins to the conductor. Why  is something the matter?',
#   10],
#  ['No  nothing s the matter', 10],
#  ['I just felt like having a bus ride  that s all.   Don t you want to have a look at the sights  now that you re here?',
#   10],
#  ['All by myself? Oh  I d be much too afraid.  Greatly amused by the girl s way of speaking  the conductor said   But you weren t afraid to come in the bus.   Nothing to be afraid of about that   she answered',
#   10],
#  ['Well  then  why not go to that stall over there and have something to drink? Nothing to be afraid of about that either',
#   10],
#  ['Oh  no  I couldn t do that.   Well  then  let me bring you a cold drink.   No  I don t have enough money',
#   10],
#  ['Just give me my ticket  that s all.   It ll be my treat and not cost you anything',
#   10],
#  ['No  no   she said firmly   please  no.  The conductor shrugged  and they waited until it was time for the bus to begin the return journey',
#   10],
#  ['Again there weren t many passengers', 10],
#  ['Won t your mother be looking for you?  the conductor asked when he gave the girl her ticket',
#   10],
#  ['No  no one will be looking for me   she said', 10],
#  ['The bus started  and again there were the same wonderful sights', 10],
#  ['Valli wasn t bored in the slightest and greeted everything with the same excitement she d felt the first time',
#   10],
#  ['But suddenly she saw a young cow lying dead by the roadside  just where it had been struck by some fast moving vehicle',
#   10],
#  ['Isn t that the same cow that ran in front of the bus on our trip to town?  she asked the conductor',
#   10],
#  ['The conductor nodded  and she was overcome with sadness', 10],
#  ['What had been a lovable  beautiful creature just a little while ago had now suddenly lost its charm and its life and looked so horrible  so frightening as it lay there  legs spreadeagled  a fixed stare in its lifeless eyes  blood all over',
#   10],
#  ['The bus moved on', 10],
#  ['The memory of the dead cow haunted her  dampening her enthusiasm', 10],
#  ['She no longer wanted to look out the window', 10],
#  ['She sat thus  glued to her seat  until the bus reached her village at three forty',
#   10],
#  ['She stood up and stretched herself', 10],
#  ['Then she turned to the conductor and said   Well  sir   hope to see you again.   Okay  madam   he answered her  smiling',
#   10],
#  ['Whenever you feel like a bus ride  come and join us', 10],
#  ['And don t forget to bring your fare.  She laughed and jumped down from the bus',
#   10],
#  ['Then away she went  running straight for home', 10],
#  ['When she entered her house she found her mother awake and talking to one of Valli s aunts  the one from South Street',
#   10],
#  ['This aunt was a real chatterbox  never closing her mouth once she started talking',
#   10],
#  ['And where have you been?  said her aunt when Valli came in', 10],
#  ['She spoke very casually  not expecting a reply', 10],
#  ['So Valli just smiled  and her mother and aunt went on with their conversation. Yes  you re right   her mother said',
#   10],
#  ['So many things in our midst and in the world outside', 10],
#  ['How can we possibly know about everything? And even when we do know about something  we often can t understand it completely  can we?   Oh  yes!  breathed Valli',
#   10],
#  ['What?  asked her mother', 10],
#  ['What s that you say?   Oh   said Valli   I was just agreeing with what you said about things happening without our knowledge.   Just a chit of a girl  she is   said her aunt   and yet look how she pokes her nose into our conversation  just as though she were a grown lady.  Valli smiled to herself',
#   10],
#  ['She didn t want them to understand her smile', 10],
#  ['But  then  there wasn t much chance of that  was there? GAUTAMA Buddha   B.C',
#   10],
#  ['B.C.  began life as a prince named Siddhartha Gautama  in northern India',
#   10],
#  ['At twelve  he was sent away for schooling in the Hindu sacred scriptures and four years later he returned home to marry a princess',
#   10],
#  ['They had a son and lived for ten years as befitted royalty', 10],
#  ['At about the age of twenty five  the Prince  heretofore shielded from the sufferings of the world  while out hunting chanced upon a sick man  then an aged man  then a funeral procession  and finally a monk begging for alms',
#   10],
#  ['These sights so moved him that he at once became a beggar and went out into the world to seek enlightenment concerning the sorrows he had witnessed',
#   10],
#  ['He wandered for seven years and finally sat down under a fig tree  where he vowed to stay until enlightenment came',
#   10],
#  ['Enlightened after seven days  he renamed the tree the Bo Tree  Tree of Wisdom  and began to teach and to share his new understandings',
#   10],
#  ['At that point he became known as the Buddha  the Awakened or the Enlightened',
#   10],
#  ['The Buddha preached his first sermon at the city of Benares  most holy of the dipping places on the River Ganges  that sermon has been preserved and is given here',
#   10],
#  ['It reflects the Buddha s wisdom about one inscrutable kind of suffering',
#   10],
#  ['Kisa Gotami had an only son  and he died', 10],
#  ['In her grief she carried the dead child to all her neighbours  asking them for medicine  and the people said   She has lost her senses',
#   10],
#  ['The boy is dead.  At length  Kisa Gotami met a man who replied to her request   I cannot give thee medicine for thy child  but I know a physician who can.  And the girl said   Pray tell me  sir  who is it?  And the man replied   Go to Salyamuni  the Buddha.  Kisa Gotami repaired to the Buddha and cried   Lord and Master  give me the medicine that will cure my boy.  The Buddha answered   I want a handful of mustardseed.  And when the girl in her joy promised to procure it  the Buddha added   The mustard seed must be taken from a house where no one has lost a child  husband  parent or friend.  Poor Kisa Gotami now went from house to house  and the people pitied her and said   Here is mustardseed  take it!  But when she asked   Did a son or daughter  a father or mother  die in your family?  they answered her   Alas! the living are few  but the dead are many',
#   10],
#  ['Do not remind us of our deepest grief.  And there was no house but some beloved one had died in it',
#   10],
#  ['Kisa Gotami became weary and hopeless  and sat down at the wayside watching the lights of the city  as they flickered up and were extinguished again',
#   10],
#  ['At last the darkness of the night reigned everywhere', 10],
#  ['And she considered the fate of men  that their lives flicker up and are extinguished again',
#   10],
#  ['And she thought to herself   How selfish am I in my grief! Death is common to all  yet in this valley of desolation there is a path that leads him to immortality who has surrendered all selfishness.  The Buddha said    The life of mortals in this world is troubled and brief and combined with pain',
#   10],
#  ['For there is not any means by which those that have been born can avoid dying  after reaching old age there is death  of such a nature are living beings',
#   10],
#  ['As ripe fruits are early in danger of falling  so mortals when born are always in danger of death',
#   10],
#  ['As all earthen vessels made by the potter end in being broken  so is the life of mortals',
#   10],
#  ['Both young and adult  both those who are fools and those who are wise  all fall into the power of death  all are subject to death',
#   10],
#  ['Of those who  overcome by death  depart from life  a father cannot save his son  nor kinsmen their relations',
#   10],
#  ['Mark! while relatives are looking on and lamenting deeply  one by one mortals are carried off  like an ox that is led to the slaughter',
#   10],
#  ['So the world is afflicted with death and decay  therefore the wise do not grieve  knowing the terms of the world',
#   10],
#  ['Not from weeping nor from grieving will anyone obtain peace of mind  on the contrary  his pain will be the greater and his body will suffer',
#   10],
#  ['He will make himself sick and pale  yet the dead are not saved by his lamentation',
#   10],
#  ['He who seeks peace should draw out the arrow of lamentation  and complaint  and grief',
#   10],
#  ['He who has drawn out the arrow and has become composed will obtain peace of mind  he who has overcome all sorrow will become free from sorrow  and be blessed.  Soon after my wife died   her car slid off an icy road in    a school psychologist warned me that my children and I were not mourning in the right way',
#   10],
#  ['We felt angry  the proper first stage  he said  is denial', 10],
#  ['In late August this year  my  year old son  Michael  died suddenly in his sleep  leaving behind a  year old son and a wife expecting their next child',
#   10],
#  ['There is no set form for grief  and no  right  way to express it', 10],
#  ['There seems to be an expectation that  after a great loss  we will progress systematically through the well known stages of grief',
#   10],
#  ['It is wrong  we are told  to jump to anger   or to wallow too long in this stage before moving towards acceptance',
#   10],
#  ['But I was  and am  angry', 10],
#  ['To make parents bury their children is wrong  to have both my wife and son taken from me  for forever and a day  is cruel beyond words',
#   10],
#  ['A relative from Jerusalem  who is a psychiatrist  brought some solace by citing the maxim   We are not to ask why  but what',
#   10],
#  ['The  what  is that which survivors in grief are bound to do for one another',
#   10],
#  ['Following that advice  my family  close friends and I keep busy  calling each other and giving long answers to simple questions like   How did your day go today?',
#   10],
#  ['We try to avoid thinking about either the immediate past or the bereft future',
#   10],
#  ['We take turns playing with Max  Michael s two year old son', 10],
#  ['Friends spend nights with the young widow  and will be among those holding her hand when the baby is born',
#   10],
#  ['Focusing on what we do for one another is the only consolation we can find',
#   10],
#  ['Do you know anything about a Russian marriage ceremony? Read this article about a Russian wedding',
#   10],
#  ['Preparations for a Russian Wedding  A Russian wedding is very simple', 10],
#  ['The planning only includes arranging for rings  brides  dress  cars  and a reception',
#   10],
#  ['Earlier  the bride s family paid for the reception  but now a days brides  and grooms  families usually share expenses',
#   10],
#  ['A Russian wedding lasts for two days  some weddings last as long as a week  and the occasion becomes something to remember for years',
#   10],
#  ['The necessary part of the wedding ceremony is a wedding procession of several cars',
#   10],
#  ['The best friends of the groom bride meet before the wedding a few times  make posters  write speeches and organise contests',
#   10],
#  ['When the groom arrives to fetch the bride for the registration  he has to fight to get her!',
#   10],
#  ['Russians usually live in apartments in tall buildings  and the groom has to climb several stairs to reach his bride',
#   10],
#  ['But at each landing he must answer a question to be allowed to go up', 10],
#  ['The bride s friends ask difficult questions  sometimes about the bride  sometimes just difficult riddles   and the groom must answer with the help of his friends',
#   10],
#  ['For example  he may be shown a few photos of baby girls and he must say which one his bride is',
#   10],
#  ['If he guesses wrong  he must pay cash to move ahead', 10],
#  ['After the marriage registration  the newly married couple leaves the guests for a tour of the city sights',
#   10],
#  ['After two or three hours of the city tour the couple arrives at the reception',
#   10],
#  ['The couple sits at a specially arranged table with their family  friends and invited guests',
#   10],
#  ['The reception starts with toasts to the couple', 10],
#  ['A wedding toast is a custom where a close friend or relative of the groom or the bride says a few words to wish the couple  then everyone raises their glass of wine  and drink it up at the same moment',
#   10],
#  ['The groom is then asked to kiss the bride', 10],
#  ['After a few toasts  people start eating and drinking  and generally have fun',
#   10],
#  ['After some time  the bride gets  stolen ! She disappears  and when the groom starts looking for her  he is asked to pay a fee',
#   10],
#  ['Usually it is his friends who  steal  the bride', 10],
#  ['Then there are the bride s friends   they steal the bride s shoe', 10],
#  ['The groom must pay money for the shoe too', 10],
#  ['The guests enjoy watching these tussles  and continue partying', 10],
#  ['The Proposal   originally titled  A Marriage Proposal   is a one act play  a farce  by the Russian short story writer and dramatist Anton Chekhov',
#   10],
#  ['It was written in', 10],
#  ['The play is about the tendency of wealthy families to seek ties with other wealthy families  to increase their estates by encouraging marriages that make good economic sense',
#   10],
#  ['Ivan Lomov  a long time wealthy neighbour of Stepan Chubukov  also wealthy  comes to seek the hand of Chubukov s twenty five year old daughter  Natalya',
#   10],
#  ['All three are quarrelsome people  and they quarrel over petty issues', 10],
#  ['The proposal is in danger of being forgotten amidst all this quarrelling',
#   10],
#  ['But economic good sense ensures that the proposal is made  after all   although the quarrelling perhaps continues!',
#   10]]

# %% [markdown]
# ### Checking for Data Imbalance:

# %%
len(new_examples1)
# Out:
# 263

# %%
len(new_examples2)
# Out:
# 658

# %%
len(new_examples1)+len(new_examples2)
# Out:
# 921

# %% [markdown]
# ### Checking the Readability Scores using the Textstat Library:

# %%
fs = open('../data/gradeoneindia.txt', 'r') 
bookone = fs.read()

# %%
# https://pypi.org/project/textstat/
bookonescore = round(textstat.flesch_kincaid_grade(bookone))
bookonescore
# Out:
# 7

# %%
fs = open('../data/gradetenindia.txt', 'r') 
booktwo = fs.read()

# %%
# https://pypi.org/project/textstat/
booktwoscore = round(textstat.flesch_kincaid_grade(booktwo))
booktwoscore
# Out:
# 16

# %% [markdown]
# ### Organising the Labelled Data together using a Pandas Dataframe:

# %%
dataset = pd.DataFrame(columns = ["text", "label"])  
dataset = dataset.append(pd.DataFrame(new_examples2+new_examples1, columns = ["text", "label"]))

# %% [markdown]
# ### Downloading Pre-trained Vectors trained on part of Google News dataset:

# %%
# https://code.google.com/archive/p/word2vec/
# !pip install wget
import wget
import os
if not os.path.isfile("GoogleNews-vectors-negative300.bin.gz"):
    print("downloading")
    wget.download("https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz")
else:
    print("you already have it!")

# %%
embeddings_file = "../data/GoogleNews-vectors-negative300.bin.gz"
wv = KeyedVectors.load_word2vec_format(embeddings_file, binary=True, limit=200000)

# %% [markdown]
# ### Classification:

# %%
#Code Adapted from the NLP in Action book ch7 https://github.com/totalgood/nlpia
word_vectors = KeyedVectors.load_word2vec_format(embeddings_file, binary=True, limit=200000)
def tokenize_and_vectorize(dataset):
    vectorized_data = []
    for sample in dataset:
        tokens = casual_tokenize(sample)
        sample_vecs = []
        for token in tokens:
            try:
                sample_vecs.append(word_vectors[token])
            except KeyError:
                pass  # No matching token in the Google w2v vocab
        vectorized_data.append(sample_vecs)

    return vectorized_data

def pad_trunc(data, maxlen):
    """ For a given dataset pad with zero vectors or truncate to maxlen """
    new_data = []

    # Creating a vector of 0's the length of the word vectors
    zero_vector = []
    for _ in range(len(data[0][0])):
        zero_vector.append(0.0)

    for sample in data:
 
        if len(sample) > maxlen:
            temp = sample[:maxlen]
        elif len(sample) < maxlen:
            temp = sample
            additional_elems = maxlen - len(sample)
            for _ in range(additional_elems):
                temp.append(zero_vector)
        else:
            temp = sample
        new_data.append(temp)
    return new_data

# %%
features = tokenize_and_vectorize(dataset["text"].values)
x_train, x_test, y_train, y_test = train_test_split(features, dataset["label"], test_size=0.2, random_state=0)

# %%
type(x_train)
# Out:
# list

# %%
maxlen = 50
embedding_dims = 300    # Length of the token vectors for passing into the Convnet

# %%
np.array(x_train).shape,np.array(x_test).shape
# Out:
# <ipython-input-52-6dd20099d2f7>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   np.array(x_train).shape,np.array(x_test).shape
# ((736,), (185,))

# %%
x_train = pad_trunc(x_train, maxlen)
x_test = pad_trunc(x_test, maxlen)

# %%
type(x_train)
# Out:
# list

# %%
np.array(x_train).shape
# Out:
# (736, 50, 300)

# %%
x_train = np.reshape(x_train, (len(x_train), maxlen, embedding_dims))
y_train = np.array(y_train)
x_train = np.reshape(x_train, (len(x_train), maxlen, embedding_dims))
y_train = np.array(y_train)
x_test = np.reshape(x_test, (len(x_test), maxlen, embedding_dims))
y_test = np.array(y_test)

# %%
np.array(x_train).shape,np.array(x_test).shape
# Out:
# ((736, 50, 300), (185, 50, 300))

# %%
batch_size = 32      
filters = 1        
kernel_size = 10   
hidden_dims = 10       
epochs = 7

# %% [markdown]
# ### Building the Model:

# %%
#Code Adapted from the NLP in Action book ch7 https://github.com/totalgood/nlpia
print('Build model...')
model = Sequential()

# Adding a Convolution1D, which will learn filters
# word group filters of size filter_length:
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1,
                 input_shape=(maxlen, embedding_dims)))
# Using max pooling:
model.add(GlobalMaxPooling1D())
# Adding a vanilla hidden layer:
model.add(Dense(hidden_dims))
model.add(Dropout(0.4))
model.add(Activation('relu'))
# Projecting onto a single unit output layer, and squashing it with a sigmoid:
model.add(Dense(1))
model.add(Activation('sigmoid'))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
print(model.summary())
# Out:
# Build model...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 41, 1)             3001
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 1)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                20
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10)                0
# _________________________________________________________________
# activation_2 (Activation)    (None, 10)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# _________________________________________________________________
# activation_3 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 3,032
# Trainable params: 3,032
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# https://stackoverflow.com/questions/58636087/tensorflow-valueerror-failed-to-convert-a-numpy-array-to-a-tensor-unsupporte

x_train = np.asarray(x_train).astype(np.float32)
y_train = np.asarray(y_train).astype(np.float32)
x_test = np.asarray(x_test).astype(np.float32)
y_test = np.asarray(y_test).astype(np.float32)

# %% [markdown]
# ### Train Model:

# %%
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, y_test))
model_structure = model.to_json()
with open("cnn_model.json", "w") as json_file:
    json_file.write(model_structure)

model.save_weights("cnn_weights.h5")
print('Model saved.')
# Out:
# Epoch 1/7
# 23/23 [==============================] - 2s 40ms/step - loss: -1.6168 - accuracy: 0.2133 - val_loss: -3.9735 - val_accuracy: 0.3243
# Epoch 2/7
# 23/23 [==============================] - 0s 18ms/step - loss: -8.0957 - accuracy: 0.2500 - val_loss: -11.8701 - val_accuracy: 0.3243
# Epoch 3/7
# 23/23 [==============================] - 0s 22ms/step - loss: -18.5324 - accuracy: 0.2351 - val_loss: -23.9339 - val_accuracy: 0.3243
# Epoch 4/7
# 23/23 [==============================] - 0s 20ms/step - loss: -35.4818 - accuracy: 0.2595 - val_loss: -41.4181 - val_accuracy: 0.3243
# Epoch 5/7
# 23/23 [==============================] - 0s 20ms/step - loss: -58.4520 - accuracy: 0.2704 - val_loss: -65.2012 - val_accuracy: 0.3243
# Epoch 6/7
# 23/23 [==============================] - 0s 20ms/step - loss: -87.6141 - accuracy: 0.2690 - val_loss: -95.9135 - val_accuracy: 0.3243
# Epoch 7/7
# 23/23 [==============================] - 0s 18ms/step - loss: -129.2660 - accuracy: 0.2731 - val_loss: -136.1580 - val_accuracy: 0.3243
# Model saved.

# %% [markdown]
# #### `(All observations and findings shall be included in the critical essay).`

# %% [markdown]
# ### Citation List:
#
#
# #### Websites:
#
# 1) Code.google.com. 2022. Google Code Archive - Word2Vec. [online] Available at: <https://code.google.com/archive/p/word2vec/> [Accessed 5 December 2021].
#
# 2) Davis, A., 2021. The fundamentals of programming - Python Video Tutorial | LinkedIn Learning, formerly Lynda.com. [online] LinkedIn. Available at: <https://www.linkedin.com/learning/programming-foundations-fundamentals-3/the-fundamentals-of-programming?autoAdvance=true&autoSkip=false&autoplay=true&resume=true&u=57077561> [Accessed 24 October 2021].
#
# 3) Dib, F., 2021. regex101: build, test, and debug regex. [online] regex101. Available at: <https://regex101.com/> [Accessed 4 December 2021].
#
# 4) GitHub. 2021. GitHub - totalgood/nlpia: Examples and libraries for "Natural Language Processing in Action" book. [online] Available at: <https://github.com/totalgood/nlpia> [Accessed 5 December 2021].
#
# 5) Libgen.is. 2021. Library Genesis. [online] Available at: <https://www.libgen.is/> [Accessed 4 November 2021].
#
# 6) McCallum, L., 2021. NLP Week 4.1 - Classification Task Notebook. [online] GitHub. Available at: <https://git.arts.ac.uk/lmccallum/nlp-21-22/blob/master/NLP%20Week%204.1%20-%20Classification%20Task.ipynb> [Accessed 16 November 2021].
#
# 7) McCallum, L., 2021. NLP Week 5.1 CNNs Notebook. [online] GitHub. Available at: <https://git.arts.ac.uk/lmccallum/nlp-21-22/blob/master/NLP%20Week%205.1%20CNNs.ipynb> [Accessed 2 December 2021].
#
# 8) Nisbet, J., 2021. Python for students - Python Video Tutorial | LinkedIn Learning, formerly Lynda.com. [online] LinkedIn. Available at: <https://www.linkedin.com/learning/python-for-students/python-for-students?autoAdvance=true&autoSkip=false&autoplay=true&resume=false&u=57077561> [Accessed 18 October 2021].
#
# 9) Portilla, J., 2021. Natural Language Processing with Python. [online] Udemy. Available at: <https://www.udemy.com/course/nlp-natural-language-processing-with-python/?ranMID=39197&ranEAID=JVFxdTr9V80&ranSiteID=JVFxdTr9V80-gIa4CDf8o_3HXX8ZIg_F1g&LSNPUBID=JVFxdTr9V80&utm_source=aff-campaign&utm_medium=udemyads> [Accessed 27 October 2021].
#
# 10) Rose, D., 2021. Artificial Intelligence Foundations: Neural Networks Video Tutorial | LinkedIn Learning, formerly Lynda.com. [online] LinkedIn. Available at: <https://www.linkedin.com/learning/artificial-intelligence-foundations-neural-networks/welcome?autoAdvance=true&autoSkip=false&autoplay=true&resume=true&u=57077561> [Accessed 6 December 2021].
#
# 11) PyPI. 2021. clean-text. [online] Available at: <https://pypi.org/project/clean-text/> [Accessed 14 November 2021].
#
# 12) PyPI. 2021. textstat. [online] Available at: <https://pypi.org/project/textstat/> [Accessed 15 November 2021].
#
# 13) Stack Abuse. 2021. Using Regex for Text Manipulation in Python. [online] Available at: <https://stackabuse.com/using-regex-for-text-manipulation-in-python/> [Accessed 16 November 2021].
#
# 14) T., Carvalho, V. and Fedor, Z., 2021. Tensorflow - ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type float). [online] Stack Overflow. Available at: <https://stackoverflow.com/questions/58636087/tensorflow-valueerror-failed-to-convert-a-numpy-array-to-a-tensor-unsupporte> [Accessed 5 December 2021].
#
# 15) Zamzar.com. 2021. Zamzar - video converter, audio converter, image converter, eBook converter. [online] Available at: <https://www.zamzar.com/> [Accessed 7 November 2021].
