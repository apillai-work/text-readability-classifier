# %% [markdown]
# # Using a Convolutional Neural Network for Text Readability Classification
#
# Code cells have been individually cited via comments wherever third-party code has been referred to or implemented, and a citation list has been added at the bottom of this notebook in Harvard style referencing.

# %% [markdown]
# ### Project Overview:
#
# The purpose of this project is to create a text readability classifier (inspired by the flesch kincaid readability tests) that determines whether a piece of text is easy or hard to read. I shall be making use of english textbooks from South-East Asian / Middle Eastern areas as datasets. Since most readability classifiers use data from the United Kingdom / United States in their model, I thought it would be interesting to approach this problem using data from non-western regions to see if they could predict readability scores accurately for english phrases across the world. After building the classifier, I shall test it on speech / interview transcripts of various politicians as a use case to get a bit more insight into their speaking styles.

# %% [markdown]
# ### Project Aim:
#
# 1) To construct a model that allows writers to have more control over their writing, so that they could structure their work according to their intended audience.

# %% [markdown]
# ### Installing and Importing the Required Libraries:

# %%
import numpy as np  
from keras.preprocessing import sequence   
from keras.models import Sequential         
from keras.layers import Dense, Dropout, Activation   
from keras.layers import Conv1D, GlobalMaxPooling1D
from gensim.models.keyedvectors import KeyedVectors
from nltk.tokenize.casual import casual_tokenize
from gensim.models import KeyedVectors
from sklearn.model_selection import train_test_split
import pandas as pd
from random import shuffle
import regex as re
from cleantext import clean
from nltk import word_tokenize
import textstat
# Out:
# Since the GPL-licensed package `unidecode` is not installed, using Python's `unicodedata` package which yields worse results.

# %% [markdown]
# ### Selection of Data:
#
# For this project, I'm using English textbooks of varying grades from different countries. I found all of them on [Library Genesis](https://www.libgen.is/) and since they were PDF files, I then converted them to text files using [Zamzar File Converter](https://www.zamzar.com/). I initially tried using python modules for this task like PDF Miner and PyPDF, but kept running into errors as most of the code I found on StackOverflow was not suitable with the latest version of Python.
#
# For this notebook, I have used **fourth and twelfth grade english textbooks from Afghanistan by the country's Ministry of Education (2011 Edition)**, which can be found [here](https://libgen.is/search.php?req=afghanistan+english&lg_topic=libgen&open=0&view=simple&res=25&phrase=1&column=def).

# %% [markdown]
# ### Preprocessing the Data:
#
# I've used Regex and the Clean-Text Library to prepare the data before the classification task. I defined a 'read_and_clean' function to read any given text file and clean the data in it, whilst replacing the line-breaks according to every condition (as described in the comments) as the text files for this task aren't following a particular pattern with grammar since it was converted from an image-heavy PDF. After that, I'm splitting the sentence after every full stop ('.') and avoiding any sentences with less than two words as it won't be of much use.

# %%
def remove(text):
    text = re.sub(r"#\S+", " ", text) #remove hashtags
    text = re.sub(r'\w*\d+\w*', '', text) #remove numbers 
    text = re.sub(r'[^a-zA-Z0-9\n\?!\.]', ' ', text) #remove special characters
    text = text.strip(" ")
    text = text.strip(".")
    return text

# %%
# read the file and clean it.
def read_and_clean(file_name):
# read the file
    fs = open(file_name, 'r') 
    book1 = fs.read()
# convert it to . if 2 or more line breaks are together
    book1 = re.sub(r"\n{2,}",". ", book1)
# convert it to . if 2 or more spaces are together
    book1 = re.sub(r"\s{2,}",". ", book1)
# convert a single line break to space if it is followed by a small letter
    book1 = re.sub(r"\n{1}(?=\s[a-z])"," ", book1)
# convert a single line break to space if it is followed by a space and small letter
    book1 = re.sub(r"\n{1}(?=[a-z])"," ", book1)
# convert all remaining line breaks to .
    book1 = re.sub(r"\n",". ", book1)
    total = []
    
    clean(book1,
        no_urls=True) # https://pypi.org/project/clean-text/
    
# split the sentence based on .
    for i in book1.split(". "):
# clean it using above function
        clean_text = remove(i)
# convert the sentence to a list of words and check the length. if it is greater then 2, then consider it a sentence
        if len(word_tokenize(clean_text)) >2:
            total.append(clean_text)
# return the final list
    return total

# %% [markdown]
# ### Labelling the Data and Calling the Functions:

# %%
# read the grade one file
grade_one_sentence = read_and_clean("../data/gradefourafghan.txt")

# %%
label = 0
new_examples1 = []
for i in grade_one_sentence:  
    if len(word_tokenize(i)) >2:
        new_examples1 = new_examples1 + [[i, label]]

# %%
new_examples1 = new_examples1[16:] # slicing the few sentences in the beginning to remove the contents page.

# %%
new_examples1
# Out:
# [['The goal of this chapter is for students to practice writing the letters A to M in English',
#   0],
#  ['Learning to Write N Z', 0],
#  ['The goal of this chapter is for students to practice writing the letters N to Z in English',
#   0],
#  ['The goal of this chapter is for students to practice writing words in English',
#   0],
#  ['Write the following words three times in your notebooks', 0],
#  ['My First Words in English', 0],
#  ['fish  apple  book  cat  dog  egg', 0],
#  ['Teacher  Good morning', 0],
#  ['Student  Good morning', 0],
#  ['Name the pictures after your teacher', 0],
#  ['Look at the above pictures and name them', 0],
#  ['In pairs  Student A points to a picture and student', 0],
#  ['B names it', 0],
#  ['Follow the example', 0],
#  ['Student A  points to', 0],
#  ['Student B  says apple', 0],
#  ['Teacher  Good bye', 0],
#  ['Students  Good bye', 0],
#  ['egg    dog  apple  book  cat  fish', 0],
#  ['Look at the pictures and name them', 0],
#  ['Each student finds a partner', 0],
#  ['Student A points to a picture and student B names it', 0],
#  ['Follow the example', 0],
#  ['What is this? Points to', 0],
#  ['It is a book', 0],
#  ['Note  All Students take turns', 0],
#  ['C.Look at the pictures and read the words after your teacher', 0],
#  ['         !         fish    dog  egg  apple  book  cat', 0],
#  ['Look at each picture and circle the correct word', 0],
#  ['cat apple egg', 0],
#  ['dog book apple', 0],
#  ['dog book cat', 0],
#  ['egg cat fish', 0],
#  ['egg cat fish', 0],
#  ['book fish apple', 0],
#  ['Look at the above pictures and read the words below', 0],
#  ['Write the letters in your notebooks', 0],
#  ['Follow the example', 0],
#  ['         !                        AB               b', 0],
#  ['Match each letter with the picture that its name begins with that letter',
#   0],
#  ['Write the first letter of each picture s name in your', 0],
#  ['Match the pictures with the correct words', 0],
#  ['book cat dog', 0],
#  ['Write the words of exercise C in your notebooks', 0],
#  ['          goat  hen  iron  jug  kite  lamp', 0],
#  ['Name the pictures after your teacher', 0],
#  ['Look at the pictures and name them', 0],
#  ['In pairs  Student A points to a picture', 0],
#  ['Student B names it', 0],
#  ['Follow the example', 0],
#  ['F           lamp   goat  hen  iron  jug  kite                     .!', 0],
#  ['Look at the pictures and name them', 0],
#  ['In pairs  Student a points to a picture  student B names it', 0],
#  ['Follow the example', 0],
#  ['What is it? Points to', 0],
#  ['It is a goat', 0],
#  ['C.  Look at the pictures and read the words after your teacher', 0],
#  ['D  In pairs  Student A points to a picture  student', 0],
#  ['B reads the word', 0],
#  ['Student A   points to', 0],
#  ['Student B   reads  goat', 0],
#  ['N      !         lamp  goat', 0],
#  ['hen  iron  jug  kite', 0],
#  ['Look at each picture and circle the correct word below', 0],
#  ['iron goat lamp', 0],
#  ['hen lamp jug', 0],
#  ['hen jug kite', 0],
#  ['lamp jug hen', 0],
#  ['lamp jug goat', 0],
#  ['goat iron kite', 0],
#  ['Look at the above pictures and read the words below', 0],
#  ['Write the letters in your notebooks', 0],
#  ['Follow the example', 0],
#  ['h i g', 0],
#  ['Match each letter with the picture that its name begins with that letter',
#   0],
#  ['i j k l', 0],
#  ['Write the first letter of each picture s name in your notebooks', 0],
#  ['Match the pictures with the correct word', 0],
#  ['goat hen iron jug kite lamp', 0],
#  ['Write the words of exercise C in your notebooks', 0],
#  ['!G     FD', 0],
#  ['!         sun   queen  radio  map  net  orange  pen', 0],
#  ['Name the pictures after your teacher', 0],
#  ['U nic ef Afghanistan', 0],
#  ['Pu lik humr i', 0],
#  ['Qalay i  now', 0],
#  ['PARW AN KAP S', 0],
#  ['Unicef Country Office', 0],
#  ['Look at the pictures and name them', 0],
#  ['Unicef Af ghanistan', 0],
#  ['TAKHARFa zi ab ad', 0],
#  ['Pulik humr i', 0],
#  ['Qalay  i now', 0],
#  ['Unicef Cou ntry Offi ce', 0],
#  ['In pairs  Student A points to a picture', 0],
#  ['Student B names it', 0],
#  ['Follow the example', 0],
#  ['Student A  What is it? Points to', 0],
#  ['Student B  It is a pen', 0],
#  ['sun   map  net  orange  pen  queen  radio                   H', 0],
#  ['Look at the pictures and name them', 0],
#  ['Qalay i now', 0],
#  ['Unicef Country Office', 0],
#  ['In pairs  Student A points to a picture  student B names it', 0],
#  ['Follow the example', 0],
#  ['I               B                                       A', 0],
#  ['What is this? Points to', 0],
#  ['It is a pen', 0],
#  ['Look at the pictures and read the words after your teacher', 0],
#  ['Qalay i now', 0],
#  ['!         sun  map  net  orange  pen  queen  radio', 0],
#  ['Look at each picture and circle the correct word below', 0],
#  ['Unicef Af ghanistan', 0],
#  ['TAKHARFa zi ab ad', 0],
#  ['Pulik humr i', 0],
#  ['Qalay  i now', 0],
#  ['Unicef Cou ntry Offi ce', 0],
#  ['queen map orange g', 0],
#  ['map orange queen', 0],
#  ['orange pen net', 0],
#  ['net pen radio', 0],
#  ['map radio pen', 0],
#  ['sun map net', 0],
#  ['radio rad dio queen net', 0],
#  ['Look at the above pictures and read the words below', 0],
#  ['Write the letters in your notebooks', 0],
#  ['Follow the example', 0],
#  ['         !           .        AB', 0],
#  ['Write each letter m  n  o  p  q  r and s five times in your notebooks', 0],
#  ['m m m m', 0],
#  ['K  !LM N!                      OP              Q', 0],
#  ['Match each letter with the picture s name that begins with that letter', 0],
#  ['     D                A R       B      C        R', 0],
#  ['n o p q r s', 0],
#  ['Qalay i now', 0],
#  ['Unicef Country Office', 0],
#  ['Write the first letter of each picture s name in your notebooks', 0],
#  ['Un c i ef Afgh a nistan', 0],
#  ['Qala y i now', 0],
#  ['SAMANG AN   BAGHLAN', 0],
#  ['PAK TYAKHO ST', 0],
#  ['Nort heaster n', 0],
#  ['Un icef Co untr y Office', 0],
#  ['Un icef ZO', 0],
#  ['Match the pictures with the correct words', 0],
#  ['Unic ef Afg ha nis tan', 0],
#  ['map net orange pen queen radio', 0],
#  ['SAMANG AN BAG HLAN', 0],
#  ['Qalay i now', 0],
#  ['KABU L W', 0],
#  ['Unicef Count ry Off ice', 0],
#  ['Write the words of exercise C in your notebooks', 0],
#  ['         AB                   B   C', 0],
#  ['I know the Alphabet in English', 0],
#  ['zoo  table  umbrella  van  wall  x  ray  yak     P', 0],
#  ['Hello  how are you?', 0],
#  ['Hello  how are you?', 0],
#  ['I am fine  thank you', 0],
#  ['Fine  thank you', 0],
#  ['Look at the pictures and repeat their names after your teacher', 0],
#  ['Look at the above pictures and name them', 0],
#  ['In pairs  Student A points to a picture  student B names it', 0],
#  ['Follow the example', 0],
#  ['B   B                                   A', 0],
#  ['What is this? Points to', 0],
#  ['It is an umbrella', 0],
#  ['!         zoo   table  umbrella  van  wall  x ray  yak      !', 0],
#  ['Look at the pictures and name them', 0],
#  ['In pairs  Student A points to a picture  student B names the picture', 0],
#  ['Follow the example', 0],
#  ['I           B      K                             A', 0],
#  ['What is this? points to', 0],
#  ['It is an umbrella', 0],
#  ['Look at the pictures and read the words after your', 0],
#  ['Look at the above pictures and read their names', 0],
#  ['  N      !       table  umbrella  van  wall  x ray  yak  zoo', 0],
#  ['                   Q             z        t', 0],
#  ['Look at the picture and circle the correct word below', 0],
#  ['umbrella table van', 0],
#  ['zoo wall yak', 0],
#  ['table yak umbrella', 0],
#  ['x ray zoo van', 0],
#  ['van wall x ray', 0],
#  ['umbrella yak table', 0],
#  ['wall x ray zoo', 0],
#  ['Look at the above pictures and read the words below', 0],
#  ['Write the letters in your notebooks', 0],
#  ['Follow the example', 0],
#  ['         !           .        AB', 0],
#  ['Write each letter t  u  v  w  x  y and z fives times in your notebooks', 0],
#  ['Match each letter with the picture s name that begins with that letter', 0],
#  ['     D                A          B      C', 0],
#  ['u v w x', 0],
#  ['Write the first letter of each picture s name in your notebooks', 0],
#  ['Match the pictures with the correct word', 0],
#  ['  H                               table umbrella', 0],
#  ['van wall x ray', 0],
#  ['Write each letter t  u  v  w  x  y and z five times in your notebooks', 0],
#  ['Review of Unit', 0],
#  ['Good morning students', 0],
#  ['Good morning teacher', 0],
#  ['How are you?', 0],
#  ['Fine  thank you', 0],
#  ['The teacher points to a picture and the students read the word under the picture',
#   0],
#  ['Match the picture with the correct word', 0],
#  ['  H                                             apple book cat  dog egg fish',
#   0],
#  ['goat hen iron jug kite lamp', 0],
#  ['Read the above words', 0],
#  ['Write the words in part C in your notebooks and draw five of your favorite pictures  and color them',
#   0],
#  ['F                 AB                   B   C', 0],
#  ['See you students', 0],
#  ['See you teacher', 0],
#  ['Review of Units', 0],
#  ['Hello boys girls', 0],
#  ['How are you?', 0],
#  ['Fine  thank you', 0],
#  ['The teacher points to a picture and the students name it', 0],
#  ['What is this? Points to', 0],
#  ['Says  It is a pen', 0],
#  ['Un icef Af gh anistan', 0],
#  ['Ma yma na', 0],
#  ['Qal ay i', 0],
#  ['SAMANG AN   BAGHLAN', 0],
#  ['Unicef Country O ffice', 0],
#  ['Out Po sts', 0],
#  ['Paved r o.shp', 0],
#  ['The teacher points to a picture  and the students read the word under the picture',
#   0],
#  ['Un icef Af gh anistan', 0],
#  ['Ma yma na', 0],
#  ['Qal ay i', 0],
#  ['SAMANG AN   BAGHLAN', 0],
#  ['Unicef Country O ffice', 0],
#  ['Out Po sts', 0],
#  ['Paved r o.shp', 0],
#  ['Match the picture with the correct word', 0],
#  ['map net orange', 0],
#  ['Unicef Af ghanistan', 0],
#  ['Qalay  i now', 0],
#  ['P ARWAN KAP ISA', 0],
#  ['S AMANG AN', 0],
#  ['Pulik humr i', 0],
#  ['TAKHARFa zi ab ad', 0],
#  ['Unicef C ou ntry Offi ce', 0],
#  ['radio sun table', 0],
#  ['umbrella van wall', 0],
#  ['x ray yak zoo', 0],
#  ['Read the above words', 0],
#  ['Write the words of part C in your notebooks and draw five of your favorite pictures and color them',
#   0],
#  ['    L      R                                        AB              B   C',
#   0],
#  ['More English Words', 0],
#  ['             fox   ant  ball  car  desk  eagle', 0],
#  ['                   SI             F                A   Q', 0],
#  ['Aziz  please stand up', 0],
#  ['Now read this', 0],
#  ['Please sit down', 0],
#  ['Look at the pictures and repeat their names after your teacher', 0],
#  ['Look at the above pictures and name them', 0],
#  ['Look at the pictures', 0],
#  ['Listen to your teacher s pronounciation and read the words after him her',
#   0],
#  ['                              K    U I    T          !     F', 0],
#  ['Look at the above pictures and read the words below', 0],
#  ['In pairs  Student A says the name of a picture  student B points to it', 0],
#  ['Follow the example', 0],
#  ['Student A   says  an ant', 0],
#  ['Student B   points to', 0],
#  ['Draw one of the part D pictures and color it', 0],
#  ['    L                             L      D', 0],
#  ['Teacher  Good bye', 0],
#  ['Students  Good bye', 0],
#  ['                          Fox    Ant  Ball  Car  Desk  Eagle', 0],
#  ['Look at the pictures', 0],
#  ['Listen to your teacher s pronunciation and read the words after him her',
#   0],
#  ['                            K    U I    T          !', 0],
#  ['Read the words under the above pictures', 0],
#  ['Look at the pictures and read the sentences after your teacher', 0],
#  ['It is an ant', 0],
#  ['It is a ball', 0],
#  ['It is a desk', 0],
#  ['It is a car', 0],
#  ['It is an eagle', 0],
#  ['It is a fox', 0],
#  ['D.In pairs  Student A points to a picture in part C and student B reads the sentence',
#   0],
#  ['M      V             B                                   A', 0],
#  ['Example  Student A  points to', 0],
#  ['Student B  Reads', 0],
#  ['It is an ant', 0],
#  ['Write the words of part A in your notebooks', 0],
#  ['  N      !         Fox    Ant  Ball  Car  Desk  Eagle', 0],
#  ['!        SI   Q             F        A', 0],
#  ['Look at the pictures and circle the correct word below', 0],
#  ['Look at the pictures and read the words below', 0],
#  ['Write the capital letters A  B  C  D  E  F in your notebooks', 0],
#  ['Follow the example', 0],
#  ['AB                F        A', 0],
#  ['Write each letter A  B  C  D  E and F five times in', 0],
#  ['          AB                       your notebooks', 0],
#  ['Match each letter with the picture sname which begins with that letter', 0],
#  ['     D               A          B      C        R', 0],
#  ['Write the first letter of picture s name in your notebooks', 0],
#  ['          A            E    ET', 0],
#  ['Match the pictures with the correct words', 0],
#  ['Write for each letter A  B  C  D  E and F five times in your notebooks', 0],
#  ['Listening to the Teacher', 0],
#  ['             Lock   Jar  Key Glass  Hand  Ice cream', 0],
#  ['            SI   Q             L        G', 0],
#  ['Please stand up boys girls', 0],
#  ['How are you?', 0],
#  ['standing  Fine  Thank you', 0],
#  ['Sit down please', 0],
#  ['sitting  Thank you', 0],
#  ['Look at this picture', 0],
#  ['What is it?', 0],
#  ['It is a       ', 0],
#  ['Look at the pictures  repeat their names after your teacher', 0],
#  ['Look at the above pictures and name them', 0],
#  ['In pairs  Student A points to a picture and student B names it', 0],
#  ['Student A  points to', 0],
#  ['Student B   says  Glass', 0],
#  ['Look at the pictures', 0],
#  ['Listen to your teacher s pronunciation and read the words after him her',
#   0],
#  ['                          K    U I    T          !', 0],
#  ['Student A says the name of a picture', 0],
#  ['Student B points to it', 0],
#  ['Follow the example', 0],
#  ['Student A   says  ice cream', 0],
#  ['Student B  points to', 0],
#  ['Draw one of the part D pictures and color it', 0],
#  ['    L      R                        L      D', 0],
#  ['Glass  Hand  Ice Cream  Jar  Key  Lock      !', 0],
#  ['Look at the pictures', 0],
#  ['Listen to your teacher and read the words after him her', 0],
#  ['                           K    U I          !', 0],
#  ['Read the words under each picture', 0],
#  ['Look at the pictures and read the sentences after', 0],
#  ['This is a glass', 0],
#  ['This is a hand', 0],
#  ['This is a jar', 0],
#  ['This is an ice cream', 0],
#  ['This is a key', 0],
#  ['This is a lock', 0],
#  ['In pairs  Student A points to a picture  student B reads the sentence', 0],
#  ['V             B                                     A', 0],
#  ['In pairs  Student A asks his partner  student B answers', 0],
#  ['Follow the example', 0],
#  ['         !           .      X                            !              A',
#   0],
#  ['Student A  What is this that?', 0],
#  ['Student B  It is a jar', 0],
#  ['Write the words of part A in your notebooks', 0],
#  ['   VW    !         Lock   Glass  Hand  Ice cream  Jar  Key', 0],
#  ['           SI   Q            L        G', 0],
#  ['Look at each picture and circle the correct word', 0],
#  ['Look at the above pictures and read the words below', 0],
#  ['G G G', 0],
#  ['    DE                          VW                     F', 0],
#  ['Match each letter with the picture s name that begins with that letter', 0],
#  ['Write the first letter of each picture s name in your notebooks', 0],
#  ['          AB           X    X', 0],
#  ['Match the pictures with the correct words', 0],
#  ['a Glass a Hand', 0],
#  ['an Ice cream a Jar a Key a Lock', 0],
#  ['Write each letter G  H  I  J  K and L five times in your notebooks', 0],
#  ['Some More English Words', 0],
#  ['             Star    Pencil  Quail  Rose  Moon  Nest  Onion', 0],
#  ['  N           SI   Q             S        M', 0],
#  ['Hello students  how are you?', 0],
#  ['Fine thank you', 0],
#  ['Repeat after me', 0],
#  ['Read the word  please', 0],
#  ['Now write the word please', 0],
#  ['Look at the pictures and repeat their names after your teacher', 0],
#  ['Look at the above pictures and name them', 0],
#  ['In pairs  Student A points to a picture and student B names it', 0],
#  ['Student A  points to', 0],
#  ['Student B   says  Nest', 0],
#  ['Look at the pictures', 0],
#  ['Listen to your teacher s pronunciation and read the words after him her',
#   0],
#  ['                          K    U I    T          !    ', 0],
#  ['Look at the above pictures and read the words', 0],
#  ['In pairs  Student A says the name of a picture', 0],
#  ['Student B points to it', 0],
#  ['Student B names a picture and student A points to it', 0],
#  ['points to a picture', 0],
#  ['Says its name', 0],
#  ['Draw a picture from part B and color it', 0],
#  ['    L      R               B   B', 0],
#  ['Star    Moon  Nest  Onion  Pencil  Quail  Rose', 0],
#  ['Look at the pictures  listen to your teacher s pronunciation and read the words after him  her',
#   0],
#  ['                           K    U I    T', 0],
#  ['Read the words under the above pictures', 0],
#  ['Look at the pictures and read the sentences after your teacher', 0],
#  ['That is a moon', 0],
#  ['That is a nest', 0],
#  ['That is a pencil', 0],
#  ['That is an onion', 0],
#  ['That is a quail', 0],
#  ['That is a rose', 0],
#  ['That is a star', 0],
#  ['Look at the above pictures and read the sentences', 0],
#  ['In pairs  Student A points to one of the above pictures and student B reads its name',
#   0],
#  ['Follow the example', 0],
#  ['         !           .M                   B', 0],
#  ['Student A  What is this?', 0],
#  ['Student B  Moon', 0],
#  ['In pairs  Student A points to a pictures in part C  student B reads the sentence',
#   0],
#  ['M      W             B                               A', 0],
#  ['Student A  points to', 0],
#  ['Student B  reads That is a nest', 0],
#  ['Write the sentences in part C in your notebooks', 0],
#  ['          AB              V    B  D', 0],
#  ['!         Star  Moon  Nest  Onion  Pencil  Quail  Rose', 0],
#  ['SI   Q            S        M', 0],
#  ['Look at each picture and circle the correct words below', 0],
#  ['Look at the above pictures and read the words below them', 0],
#  ['Write the letters M  N  O  P  Q  R  and S in your notebooks', 0],
#  ['Follow the example', 0],
#  ['         !                     Y !     F     R', 0],
#  ['Write each letter M  N  O  P  Q  R  and S five times in your notebooks', 0],
#  ['         Y !     F     R     E', 0],
#  ['K  !LM', 0],
#  ['!                    O                       Q', 0],
#  ['Match each letter with the pictures  which begins their names', 0],
#  ['     D               A          B      C        R', 0],
#  ['Write the first letter of the name of each picture in your notebooks', 0],
#  ['Match the pictures with correct words', 0],
#  ['Write each letters M  N  O  P  Q  R and S five times in your notebook', 0],
#  ['          Y !     F     R', 0],
#  ['I can write the Alphabet', 0],
#  ['             Zebra    Tree  Uniform  Vase  Wolf  X ray  Yoke', 0],
#  ['    N     E D        SI   Q', 0],
#  ['Please open your books', 0],
#  ['Read this word', 0],
#  ['Thank you  teacher', 0],
#  ['Look at the pictures and repeat their names after your teacher', 0],
#  ['Look at the above pictures and name them', 0],
#  ['Look at the pictures  listen to your teacher s pronuciation and read the words after him   her',
#   0],
#  ['                           K    U I    T', 0],
#  ['In pairs  Student A points to a picture and Student B name s the picture',
#   0],
#  ['Follow the example', 0],
#  ['Student A  points to', 0],
#  ['Student B   says  tree', 0],
#  ['Draw one of the above pictures and color it', 0],
#  ['Teacher  Good bye students', 0],
#  ['Students  Good bye teacher', 0],
#  ['Tree  Uniform  Vase  Wolf  X  ray  Yoke  Zebra     !', 0],
#  ['Look at the pictures  listen to your teacher s pronunciation and read the words after him her',
#   0],
#  ['                      F K    U I    T          !', 0],
#  ['Read the words under the above pictures', 0],
#  ['Student A points to a picture and student B reads the word', 0],
#  ['Follow the example', 0],
#  ['FM                      B                                    A', 0],
#  ['What is this?', 0],
#  ['x ray x  ray', 0],
#  ['Look at the pictures', 0],
#  ['Listen and read the sentences after your teacher..         V              !      F',
#   0],
#  ['I have a tree', 0],
#  ['He has a uniform', 0],
#  ['This is my tree', 0],
#  ['It is his unifom', 0],
#  ['She has a vase', 0],
#  ['This is her vase', 0],
#  ['You have an x ray', 0],
#  ['This is your x ray', 0],
#  ['He has a wolf', 0],
#  ['This is his wolf', 0],
#  ['They have a yoke', 0],
#  ['This is their yoke', 0],
#  ['She has a zebra', 0],
#  ['This is her zebra', 0],
#  ['Look at the above pictures and read the sentences', 0],
#  ['Write the sentences of part D in your notebooks', 0],
#  ['          AB              V    B    D', 0],
#  ['Zebra    Tree  Uniform  Vase  Wolf  X  ray  Yoke', 0],
#  ['            Q             Z        T', 0],
#  ['Look at the pictures  circle the correct word below', 0],
#  ['a Zebra aWolf', 0],
#  ['Look at the above pictures and read the words below them', 0],
#  ['Write the capital letters T  U  V  W  X  Y and Z in your notebooks', 0],
#  ['Follow the example', 0],
#  ['Write each letter T  U  V  W  X  Y and Z five times in your notebooks', 0],
#  ['    DE                         N                             F', 0],
#  ['Match each letter which begins the names of the picture', 0],
#  ['D               A          B      C        R', 0],
#  ['Write the first letter of the name of each picture s name in your notebooks',
#   0],
#  ['Match the pictures with the correct words', 0],
#  ['Write each letter T  U  V  W  X  Y and Z five times in your notebooks', 0],
#  ['Review of Units', 0],
#  ['!       !    N                         B', 0],
#  ['Good morning students', 0],
#  ['Good morning teacher', 0],
#  ['Please look at this picture', 0],
#  ['It is a cat  an ant', 0],
#  ['The teacher points to a picture and students name it', 0],
#  ['Look at the pictures and read their names with correct pronunciation', 0],
#  ['Match the pictures with the correct word', 0],
#  ['Read the above words with correct pronunciation', 0],
#  ['      T    R          C', 0],
#  ['Write the words of part C in your notebooks', 0],
#  ['          AB                   B   C', 0],
#  ['Draw your favorite picture and color it', 0],
#  ['Review of Units', 0],
#  ['!       !    N                         B', 0],
#  ['Please stand up Fatah', 0],
#  ['Name this picture', 0],
#  ['That is a moon', 0],
#  ['Thank you  Fatah', 0],
#  ['Please name this picture', 0],
#  ['That is a nest', 0],
#  ['Please sit down', 0],
#  ['Look at the pictures and name them', 0],
#  ['C.Look at the pictures and read their names with correct pronunciation', 0],
#  ['Match the pictures with the correct words', 0],
#  ['Write the words of part C in your notebook', 0],
#  ['AB                   B   C', 0],
#  ['            a                       carrot  turnip  radish  potato  tomato  cabbage      F!              b',
#   0],
#  ['How are you?', 0],
#  ['I am fine thank you', 0],
#  ['Do you like vegetables?', 0],
#  ['Yes  I do', 0],
#  ['What kind of vegetables do you like?', 0],
#  ['I like carrots and turnips', 0],
#  ['Look at the pictures of vegetables and repeat their names after your teacher',
#   0],
#  ['Look at the above pictures and name them', 0],
#  ['In pairs  One student shows a real vegetable or its picture and asks a question',
#   0],
#  ['Other students answer the question', 0],
#  ['What is this?', 0],
#  ['It is a potato', 0],
#  ['What is this?', 0],
#  ['It is a tomato', 0],
#  ['Draw a picture of a vegetable of part B and color it', 0],
#  ['           R          B           B   B', 0],
#  ['Teacher  Good bye students', 0],
#  ['Students  Good bye teacher', 0],
#  ['!         cabbage    carrot  turnip  radish  potato  tomato', 0],
#  ['Look at the pictures of vegetables and read the words after your teacher',
#   0],
#  ['Read the words below the above pictures', 0],
#  ['Look at these pictures and read the sentences after your teacher', 0],
#  ['                   !          B  d', 0],
#  ['This is a radish', 0],
#  ['Is this a radish?', 0],
#  ['Yes  it is', 0],
#  ['This is a carrot', 0],
#  ['Is this a carrot?', 0],
#  ['Yes  it is', 0],
#  ['This is a potato', 0],
#  ['Is this a ptato?', 0],
#  ['Yes  it is', 0],
#  ['This is a turnip', 0],
#  ['Is this a turnip?', 0],
#  ['Yes  it is', 0],
#  ['This is a tomato', 0],
#  ['This is a cabbage', 0],
#  ['Is this a tomato? Is this a cabbage?', 0],
#  ['Yes  it is', 0],
#  ['Yes  it is', 0],
#  ['Look at the above pictures and read the sentences below them', 0],
#  ['Read these sentences and Point to the correct pictures in part A of the lesson',
#   0],
#  ['                   Q            A           W', 0],
#  ['This is a carrot', 0],
#  ['This is a turnip', 0],
#  ['This is a radish', 0],
#  ['This is a potato', 0],
#  ['This is a cabbage', 0],
#  ['This is a tomato', 0],
#  ['Read these words and write them in your notebook', 0],
#  ['Carrot  turnip  radish  potato  tomato and cabbage', 0],
#  ['             B  d        B    V      B', 0],
#  ['Look at the pictures  circle the correct words below', 0],
#  ['radish carrot turnip', 0],
#  ['turnip radish carrot', 0],
#  ['carrot cabbage turnip potato radish tomato', 0],
#  ['tomato potato cabbage', 0],
#  ['potato cabbage tomato', 0],
#  ['Look at the above pictures and read the words', 0],
#  ['            !                                 below them', 0],
#  ['Write the name of each picture in your notebooks', 0],
#  ['Match the words with the pictures', 0],
#  ['turnip radish potato tomato cabbage', 0],
#  ['Change the following sentences to questions and answer them', 0],
#  ['     c  d                    V', 0],
#  ['This is a potato', 0],
#  ['Is this a potato?', 0],
#  ['Yes  it is', 0],
#  ['This is a carrot', 0],
#  ['This is a turnip', 0],
#  ['This is a radish', 0],
#  ['This is a cabbage', 0],
#  ['This is a tomato', 0],
#  ['Change the above sentences to questions and write them in your notebooks',
#   0],
#  ['           Y !     F     Q             W', 0],
#  ['!  V                   cherry  watermelon  pear          V', 0],
#  ['   !        peach    banana  melon  apricot', 0],
#  ['Do you like fruit?', 0],
#  ['Yes  we do', 0],
#  ['What fruits do you like?', 0],
#  ['We like cherries and apples', 0],
#  ['Look at the pictures of fruits and repeat their names after your teacher',
#   0],
#  ['Look at the above pictures and name them', 0],
#  ['Look at the pictures', 0],
#  ['Listen to your teacher and repeat the sentences after him her', 0],
#  ['                           K    U I          !   F', 0],
#  ['This is an apricot', 0],
#  ['This is a banana', 0],
#  ['This is a peach', 0],
#  ['This is a watermelon', 0],
#  ['This is a cherry', 0],
#  ['This is a melon', 0],
#  ['That is a pear', 0],
#  ['That is a peach', 0],
#  ['In pairs  Student A points to a picture and asks a question  and student B answers',
#   0],
#  ['Student A  What is this? Points to', 0],
#  ['Student B  That is a banana', 0],
#  ['Draw a picture of fruit from part B and color it', 0],
#  ['cherry  melon  apricot  peach  pear', 0],
#  ['!            V       T          banana    watermelon', 0],
#  ['Look at the pictures of fruit  and read their names after your teacher', 0],
#  ['Look at the above pictures and read their names', 0],
#  ['Look at these pictures', 0],
#  ['Listen and read the sentences after your teacher', 0],
#  ['Is that a banana?', 0],
#  ['No  it is not a banana', 0],
#  ['It is a watermelon', 0],
#  ['Is that a pear?', 0],
#  ['No  it is not a pear', 0],
#  ['It is a cherry', 0],
#  ['Is that a melon?', 0],
#  ['No  it is not a melon', 0],
#  ['It is a pear', 0],
#  ['Is that a peach?', 0],
#  ['No  it is not a peach', 0],
#  ['It is a melon', 0],
#  ['Is that a watermelon?', 0],
#  ['No  it is not a watermelon', 0],
#  ['It is a banana', 0],
#  ['Is that an apricot?', 0],
#  ['No  it is not a apricot', 0],
#  ['It is a peach', 0],
#  ['Look at the pictures from part B again and read the following sentences after your teacher',
#   0],
#  ['That is a pear', 0],
#  ['That is an apricot', 0],
#  ['That is a peach', 0],
#  ['That is a melon', 0],
#  ['That is a watermelon', 0],
#  ['That is a banana', 0],
#  ['That is a cherry', 0],
#  ['Read these words and write them in your notebooks', 0],
#  ['Pear  apricot  melon  cherry  grape  peach and banana', 0],
#  ['Look at the pictures', 0],
#  ['Circle and read the correct word below', 0],
#  ['a peach an apricot', 0],
#  ['an apricot a peach a pear', 0],
#  ['an apricot a pear a peach', 0],
#  ['a cherry a banana', 0],
#  ['a banana a melon', 0],
#  ['a melon awatermelon', 0],
#  ['a peach a watermelon', 0],
#  ['Look at the above pictures and read the words below them', 0],
#  ['Write the name of each picture in your notebooks', 0],
#  ['Match the words with the pictures', 0],
#  ['  H                       an apricot a pear a peach', 0],
#  ['a cherry a banana a melon', 0],
#  ['Answer the questions in short and long from', 0],
#  ['Follow the example', 0],
#  ['         !           .        B  d', 0],
#  ['Is that a pear?', 0],
#  ['No  it is not', 0],
#  ['It is a watermelon', 0],
#  ['Is that a banana?', 0],
#  ['Is that a peach?', 0],
#  ['Is that a watermelon?', 0],
#  ['Is that cherry?', 0],
#  ['Is that a melon?', 0],
#  ['Is that a pear?', 0],
#  ['Is that an apricot?', 0],
#  ['Use the words of part E in sentences and write them in your notebooks', 0],
#  ['This  That is a  an', 0],
#  ['What is your name?', 0],
#  ['My name is          ', 0],
#  ['What are you?', 0],
#  ['I am a student', 0],
#  ['Look at the family pictures and repeat the words after your teacher', 0],
#  ['Look at the family pictures and repeat the sentences after your teacher',
#   0],
#  ['This is Habib', 0],
#  ['Halima is his wife', 0],
#  ['This is Halima', 0],
#  ['Habib is her husband', 0],
#  ['This boy is Ali', 0],
#  ['His father is Habib', 0],
#  ['This girl is Hafiza', 0],
#  ['Her mother is Halima', 0],
#  ['Ali has a sister', 0],
#  ['Her name is Hafiza', 0],
#  ['Hafiza has a brother', 0],
#  ['His name is Ali', 0],
#  ['Habib and Halima have a son', 0],
#  ['His name is Ali', 0],
#  ['Halima and Habib have a daughter', 0],
#  ['Her name is Hafiza', 0],
#  ['Look at these pictures and repeat the sentences after your teacher', 0],
#  ['He is a boy She is a girl', 0],
#  ['He is a man She is a woman', 0],
#  ['Repeat these sentences after your teacher', 0],
#  ['This is a man', 0],
#  ['He is my father', 0],
#  ['This is a woman', 0],
#  ['She is my mother', 0],
#  ['This is a boy', 0],
#  ['He is my brother', 0],
#  ['This is a girl', 0],
#  ['She is my sister', 0],
#  ['This is a boy', 0],
#  ['He is my son', 0],
#  ['This is a girl', 0],
#  ['She is my daughter', 0],
#  ['This is a man', 0],
#  ['He is my husband', 0],
#  ['Read the sentences of part E and write them in your notebooks', 0],
#  ['Teacher  Good bye boys girls', 0],
#  ['Student  Good bye teacher', 0],
#  ['Repeat these words after your teacher the words are singular and plural',
#   0],
#  ['A  boy girl family', 0],
#  ['B  boys girls families', 0],
#  ['A  man woman child', 0],
#  ['men women children', 0],
#  ['Repeat these sentences after your teacher', 0],
#  ['This is a boy', 0],
#  ['These are boys', 0],
#  ['This is a girl', 0],
#  ['These are girls', 0],
#  ['This is a man', 0],
#  ['These are men', 0],
#  ['This is a woman', 0],
#  ['These are women', 0],
#  ['In pairs  Student A reads one of the above singular sentences  student B reads its plural form',
#   0],
#  ['Student A  reads  This is a boy', 0],
#  ['Student B  reads  These are boys', 0],
#  ['Note  All students take turns', 0],
#  ['Write the words of part A in your notebooks', 0],
#  ['  N          woman    boy  girl man', 0],
#  ['Please answer this question', 0],
#  ['What is the plural for boy?', 0],
#  ['The plural for boy is boys', 0],
#  ['What is the plural for girl?', 0],
#  ['The plural for girl is girls', 0],
#  ['Match singular sentences with plural', 0],
#  ['Follow the example', 0],
#  ['This boy is a student', 0],
#  ['They are men', 0],
#  ['That boy is a child', 0],
#  ['They are women', 0],
#  ['This girl is a student', 0],
#  ['They are my brothers', 0],
#  ['That girl is a child', 0],
#  ['These boys are students', 0],
#  ['He is a man', 0],
#  ['These boys are children', 0],
#  ['She is a woman', 0],
#  ['These girls are students', 0],
#  ['He is my brother', 0],
#  ['Those girls are children', 0],
#  ['This woman is a teacher', 0],
#  ['These women are teachers', 0],
#  ['Match the words with the pictures', 0],
#  ['D.Change these words to plural  read and write them', 0],
#  ['E.Change these sentences to their singular form', 0],
#  ['These women are teachers', 0],
#  ['This woman is a teacher', 0],
#  ['They are my brothers', 0],
#  ['Those girls are students', 0],
#  ['Those girls are children', 0],
#  ['Those boys are students', 0],
#  ['They are men', 0],
#  ['They are women', 0],
#  ['In pairs  Student A says a singular word or a sentence  student B changes it to plural',
#   0],
#  ['C         B           V                               A', 0],
#  ['R Q i V', 0],
#  ['Student A   says  woman', 0],
#  ['Student B   says  women', 0],
#  ['Student A  He is a boy', 0],
#  ['Student B  They are boys', 0],
#  ['Write the plural form of nouns in part  C  in your notebooks.Follow the example',
#   0],
#  ['Example  Teacher   Teachers', 0],
#  ['face   head  mouth  lips  ear  eye  nose  neck', 0],
#  ['How are you?', 0],
#  ['We are fine  thank you', 0],
#  ['How are you?', 0],
#  ['I am fine  thank you', 0],
#  ['Look at these pictures and repeat their names after your teacher', 0],
#  ['Look at the above pictures and name each of them', 0],
#  ['In pairs  Student A points to a part of his her body and asks a question Student B answers',
#   0],
#  ['Student A  What is this?', 0],
#  ['Student B  That is your  ', 0],
#  ['Look at the picture of the boy  listen and repeat the sentences after your teacher',
#   0],
#  ['This is a boy', 0],
#  ['This is his head', 0],
#  ['This is his mouth', 0],
#  ['These are his lips', 0],
#  ['These are his teeth', 0],
#  ['This is his neck', 0],
#  ['This is his nose', 0],
#  ['These are his ears', 0],
#  ['These are his eyes', 0],
#  ['This is his face', 0],
#  ['face nose mouth', 0],
#  ['Point to the parts of your body and make sentences', 0],
#  ['I am Saber', 0],
#  ['This is my head', 0],
#  ['These are my eyes', 0],
#  ['Note  All students take turns', 0],
#  ['In pairs  Student A points to a part of his her body and asks a question',
#   0],
#  ['Student B answers the question', 0],
#  ['Follow the example', 0],
#  ['points to his head', 0],
#  ['What is this?', 0],
#  ['That is your head', 0],
#  ['points to his eyes', 0],
#  ['What are these?', 0],
#  ['Those are your eyes', 0],
#  ['Write the names of parts of your body in your notebook', 0],
#  ['I will see you tomorrow students', 0],
#  ['We will see you tomorrow teacher', 0],
#  ['Look at the picture and read the words after your', 0],
#  ['Look at the above pictures and read the words below them', 0],
#  ['Look at the picture and read these sentences', 0],
#  ['That is a girl', 0],
#  ['That is her head', 0],
#  ['That is her face', 0],
#  ['That is her nose', 0],
#  ['That is her mouth', 0],
#  ['That is her neck', 0],
#  ['Those are her ears', 0],
#  ['These are her eyes', 0],
#  ['These are her lips', 0],
#  ['These are her theeth', 0],
#  ['The sex are her teeth', 0],
#  ['This is her arm', 0],
#  ['Point to the parts of your body and read these sentences', 0],
#  ['This is my ear', 0],
#  ['These are my ears', 0],
#  ['This is my tooth', 0],
#  ['These are my teeth', 0],
#  ['This is my lip', 0],
#  ['These are my lips', 0],
#  ['This is my eye', 0],
#  ['These are my eyes', 0],
#  ['In pairs  Student A points to a part of his her body and asks a question  student B answers the question',
#   0],
#  ['Student A   asks  What is this?', 0],
#  ['Student B   answers  That is your face', 0],
#  ['Note  All students take turns', 0],
#  ['Change these words in English in your notebook', 0],
#  ['Match the words with the pictures', 0],
#  ['Match the singular words with their plurals', 0],
#  ['eye ear tooth lip finger', 0],
#  ['lips eyes ears teeth feet', 0],
#  ['Circle the correct word for each picture and read the word', 0],
#  ['eye foot lip', 0],
#  ['teeth neck nose', 0],
#  ['mouth nose neck', 0],
#  ['mouth face ear', 0],
#  ['nose teeth ear', 0],
#  ['eye nose head', 0],
#  ['lips neck head', 0],
#  ['nose face lips', 0],
#  ['mouth neck teeth', 0],
#  ['Write the plural forms of the following words in your notebooks', 0],
#  ['Example  lip lips face eye', 0],
#  ['Review of Units', 0],
#  ['How are you this morning afternoon?', 0],
#  ['We are fine  thank you', 0],
#  ['How are you teacher?', 0],
#  ['I am fine  thank you', 0],
#  ['Look at these pictures and name them', 0],
#  ['Look at these pictures and read their names', 0],
#  ['Read these Senterces and match them with their pictures', 0],
#  ['That is a pear', 0],
#  ['That is a peach', 0],
#  ['That is a banana', 0],
#  ['That is a melon', 0],
#  ['That is a watermelon', 0],
#  ['That is a carrot', 0],
#  ['That is a turnip', 0],
#  ['That is a tomato', 0],
#  ['That is a potato', 0],
#  ['That is a radish', 0],
#  ['Look at the pictures  answer the questions like the given example', 0],
#  ['Is that a banana?', 0],
#  ['No  it is not a banana', 0],
#  ['It is a water melon', 0],
#  ['Is that a pear?', 0],
#  ['Is that a melon?', 0],
#  ['Is that a peach?', 0],
#  ['Is that a watermelon?', 0],
#  ['Write the words of part C in your notebook and draw    of your favorite pictures',
#   0],
#  ['Color the pictures', 0],
#  ['Review of Units', 0],
#  ['A woman has a child', 0],
#  ['Her child is a girl', 0],
#  ['What do we call the woman s child?', 0],
#  ['The woman s child is her daughter', 0],
#  ['Yes  Now this woman has another child', 0],
#  ['He is a boy', 0],
#  ['What do we call this child', 0],
#  ['This child is the woman s son', 0],
#  ['Look at the family diagram and read the words related to each picture', 0],
#  ['Read these words and sentences with correct pronunciation', 0],
#  ['She  He  They  I  You  We', 0],
#  ['She is his wife', 0],
#  ['He is her husband', 0],
#  ['They have a daughter and a son', 0],
#  ['I have a brother', 0],
#  ['You are my sister', 0],
#  ['We are a family', 0],
#  ['It is our house', 0],
#  ['It is your house', 0],
#  ['Look at these pictures and name them', 0],
#  ['E.Look at the pictures and read their names with the correct pronunciation',
#   0],
#  ['F.Read the words and match them with their pictures', 0],
#  ['  H                                   face eye', 0],
#  ['head  lips boy', 0],
#  ['man teeth nose woman', 0],
#  ['girl ear mouth neck', 0],
#  ['Look at the pictures  read the sentences and check', 0],
#  ['the correct sentence', 0],
#  ['This is my hand', 0],
#  ['This is my eye', 0],
#  ['This is my nose', 0],
#  ['This is your nose', 0],
#  ['This is your ear', 0],
#  ['This is your lip', 0],
#  ['That is his head', 0],
#  ['That is his neck', 0],
#  ['That is his nose', 0],
#  ['It is her ear', 0],
#  ['It is her nose', 0],
#  ['It is her arm', 0],
#  ['Those are her ears', 0],
#  ['Those are her eyes', 0],
#  ['Those are her lips', 0],
#  ['Write the words of part E in your notebook', 0],
#  ['of your favorite pictures and color them', 0],
#  ['Father r   Finger', 0],
#  ['I have to eat the cherry', 0],
#  ['Fish k B Foot  feet', 0],
#  ['S  P His', 0],
#  ['Onion e  K w  Orange', 0],
#  ['Pear k      Pen', 0],
#  ['Not  is not', 0],
#  ['N  Shopkeeper b a  Sister', 0],
#  ['C U    Son', 0],
#  ['G        I Sun', 0],
#  ['V Tailor b    Teacher', 0],
#  ['These v   They', 0],
#  ['Good morning students', 0],
#  ['Students  Good morning teacher', 0],
#  ['Teacher  Please look at this picture', 0],
#  ['Students  It is a cat  an ant', 0],
#  ['Teacher  Thank you', 0]]

# %%
# read the grade ten file
grade_ten_sentence = read_and_clean("../data/gradetwelveafghan.txt")

# %%
label = 1
new_examples2 = []
for i in grade_ten_sentence:  
    if len(word_tokenize(i))>2:
        new_examples2 = new_examples2 + [[i, label]]

# %%
new_examples2 = new_examples2[2000:] # slicing to avoid overfitting due to data imbalance

# %%
new_examples2
# Out:
# [['There are  professors who are working very hard to graduate as many scholars as they can',
#   1],
#  ['Kabul Medical University  formerly as Kabul', 1],
#  ['Medical Faculty  is located in Kabul', 1],
#  ['Afghanistan on the campus of Kabul University', 1],
#  ['The medical institution was initially maintained by collaboration with the Turkish and French sponsors',
#   1],
#  ['KMU developed into a single selfautonomic University in', 1],
#  ['It is currently graduates professionals in fields of Curative', 1],
#  ['Medicine  Pediatric  Stomatology and Nursing', 1],
#  ['All subjects are taught in national languages but most medical terms are either in Arabic  Greek',
#   1],
#  ['English or French', 1],
#  ['Currently  more than  medical institutions are known to exist in Afghanistan but the KMU and',
#   1],
#  ['Nangarhar Medical institutions are the leading medical institutions for the country',
#   1],
#  ['Read the following statements about the passages', 1],
#  ['Put T  True  or F  False  and the line number', 1],
#  ['Write out the correct statement if you put F', 1],
#  ['PUK and Kabul Medical University both teach medicine', 1],
#  ['Kabul University accepts male and female students', 1],
#  ['Kabul University has around  both male and female students', 1],
#  ['Kabul Medical University is currently graduates professionals in fields of curative medicine  pediatric and engineering',
#   1],
#  ['Kabul University offers less than  degrees', 1],
#  ['Polytechnic University has four faculties with  sub departments  including  professional and  general subject departments',
#   1],
#  ['Kabul Education University is the oldest university in Afghanistan', 1],
#  ['First  it was established as Kabul Institute teacher training and then in  it became Kabul Medical University',
#   1],
#  ['The Polytechnic University of Kabul  PUK  was established on an area of  hectares in December ',
#   1],
#  ['Kabul University was established in   then one year later  its door was opened to students  across the country',
#   1],
#  ['intellectual  adj  connected with or using a person s ability to think in a logical way and understand things',
#   1],
#  ['She s very intellectual', 1],
#  ['law  n  the whole system of rules that everyone in a country or society must obey',
#   1],
#  ['In Sweden it is against the law to hit a child', 1],
#  ['political science  n  the study of government and politics', 1],
#  ['management n  the act of running and controlling a business or similar organization',
#   1],
#  ['architecture  n  the art and study of designing buildings', 1],
#  ['civil  adj  connected with the people who live in a country', 1],
#  ['mechanical  adj  operated by power from an engine  a mechanical device toy  clock',
#   1],
#  ['The breakdown was due to mechanical failure', 1],
#  ['estimated  v  something to form an idea of the cost  size  value etc  of something  but without calculating it exactly',
#   1],
#  ['A police estimate the crowd at', 1],
#  ['computer science  n  the study of computers and how they can be used  a degree in computer science',
#   1],
#  ['pharmacology  n  the scientific study of medicines and their effects', 1],
#  ['He is studying pharmacology', 1],
#  ['The pharmacology department at the hospital can tell you what that medicine contains',
#   1],
#  ['Where can you study pharmacology in Afghanistan? pharmaceutical  adj  connected with making and selling drugs and medicines',
#   1],
#  ['implemented  vn  to make something that has been officially decided start to happen or be used',
#   1],
#  ['agronomy  n  the study of relationship between crops and the environment forestry  n  the science or practice of planting and taking care of trees and forests',
#   1],
#  ['horticulture  n  the study or practice of growing flowers  fruit  vegetables  a college of agriculture and horticulture',
#   1],
#  ['food Hygiene  n  the practice of keeping yourself and your living and working areas clean in order to prevent illness and disease',
#   1],
#  ['veterinary science  n  the study of animal medicine  the study of how to treat sick animals',
#   1],
#  ['You must study veterinary sciences to become a veterinary surgeon', 1],
#  ['clinic  n  a period of time during which doctors give special medical treatment or advice',
#   1],
#  ['cadre  n  a small group of people who are specially chosen and trained for a particular purpose',
#   1],
#  ['animal husbandry  n  farming that involves keeping animals to produce food',
#   1],
#  ['campus  n  the land which a school  college or university is located on',
#   1],
#  ['The library is located in the centre of the campus', 1],
#  ['That university has got several campuses', 1],
#  ['How many campuses has KMU got?', 1],
#  ['How many campuses has PUK got?', 1],
#  ['Write the correct words in the blank spaces', 1],
#  ['She got a good                 in the schoolleaving exam so she is going to university',
#   1],
#  ['When he leaves university  he wants to work in', 1],
#  ['building roads and bridges', 1],
#  ['Polytechnic University was                 in', 1],
#  ['He will probably become a good', 1],
#  ['because he likes animals', 1],
#  ['She got a Bachelor of Arts                  from', 1],
#  ['Kabul Education University and then did some teacher training before she became a teacher',
#   1],
#  ['When we saw the children without any food  we felt a lot of                   for them',
#   1],
#  ['Their school                  covers several square hectares', 1],
#  ['I did not have time to go to the main office  so I went to a local              ',
#   1],
#  ['The                include the study of literature and history', 1],
#  ['Part of the study of management is the study of', 1],
#  ['established veterinary surgeon grade degree engineering', 1],
#  ['Perhaps we can do it in the future  but it is not possible             ',
#   1],
#  ['He is a very               man', 1],
#  ['He always finds the answers to our problems', 1],
#  ['What a pity you failed the test', 1],
#  ['Can you ask me your question tomorrow? I am', 1],
#  ['Ask your brother what happened', 1],
#  ['He is very', 1],
#  ['branch pity humanities economics campus', 1],
#  ['intelligent about to keep on keen on at present', 1],
#  ['Pay close attention to the clauses with who  which or that', 1],
#  ['Pupils who come to class late are not allowed in the classroom', 1],
#  ['Without the who clause  the sentence has an unusual meaning', 1],
#  ['The part of the year which is cold is called winter', 1],
#  ['Without the which clause  we do not know which part of the year is meant',
#   1],
#  ['Try taking out the who and which clauses and see what happens', 1],
#  ['There are no commas before or after who  which or that clauses like this',
#   1],
#  ['Now look at the following sentences with who  which or that clauses', 1],
#  ['Husnia  who comes from India  is an English teacher', 1],
#  ['We can take out the who clause and still understand the sentence', 1],
#  ['Polytechnic University  which was founded in   is one of the largest universities in Afghanistan',
#   1],
#  ['We can take out the which clause and still understand the sentence', 1],
#  ['Try taking out the who and which clauses and see what happens', 1],
#  ['There are commas before or after who  which or that clauses like this', 1],
#  ['Remember that we can shorten a passive clause after  who  which or that',
#   1],
#  ['which was founded in   is one of the largest universities', 1],
#  ['Which was established in   has over    students', 1],
#  ['Remember this kind of clause with who  which or that', 1],
#  ['about to is followed by verb  no ending', 1],
#  ['These are followed by verbbe keen on consider keep on think about', 1],
#  ['Playing games going to England watching TV having a party', 1],
#  ['about to is', 1],
#  ['makea lot of noise', 1],
#  ['Shorten the clauses with who  which or that', 1],
#  ['KU  Kabul University   which was founded in   is the largest university in',
#   1],
#  ['Those students  who were sent to India  learned to speak excellent English',
#   1],
#  ['The number of students that are accepted by the universities is increased',
#   1],
#  ['KPU  Kabul Polytechnic University   which was opened in   is very beautiful',
#   1],
#  ['KMU  Kabul Medical University   which is considered the leading center for',
#   1],
#  ['Curative Medicine  Pediatric  Stomatology and Nursing  offers degrees in most medical sciences',
#   1],
#  ['Complete these sentences using a phrase from the box on the right', 1],
#  ['Add ing to the verb if necessary', 1],
#  ['Suhail is about to              ', 1],
#  ['The pilot is thinking about', 1],
#  ['The plane is about to           ', 1],
#  ['try to land drive to work crash buy a new dress', 1],
#  ['At the end of this unit students will be able to  talk discuss about the biography of King Ghazi',
#   1],
#  ['review the simple past tense and while  the past continuous tense', 1],
#  ['read a topic about the biography and political life of', 1],
#  ['King Ghazi Amanullah Khan know the new words and use them in sentences', 1],
#  ['Discuss with your teacher about biography of King Ghazi Amanullah Khan', 1],
#  ['Try to answer the following question as you discussed before', 1],
#  ['Why did the people of Afghanistan entitle King Amanullah Khan as Ghazi ?',
#   1],
#  ['What do you know about several trips of King Ghazi Amanullah Khan to abroad?',
#   1],
#  ['Look at these new words and at the words in the box', 1],
#  ['Choose the words from the box which you think best explain the new words',
#   1],
#  ['Be fond of', 1],
#  ['The children of your children b', 1],
#  ['A group of people talking g', 1],
#  ['Ready to give freely', 1],
#  ['Finally  discuss this general question about King Ghazi Amanullah Khan with your teacher and your classmates',
#   1],
#  ['What do you know about king Ghazi', 1],
#  ['Amanullah Khan s political life and achievements?', 1],
#  ['Practice the conversation in column A below', 1],
#  ['Has anybody seen the tomb of', 1],
#  ['King Ghazi Amanullah Khan in', 1],
#  ['Yes  I have', 1],
#  ['Good  what did you like the best about it?', 1],
#  ['The Amir Shaheed Garden  I think', 1],
#  ['The story of', 1],
#  ['Aha! Do you know anything about', 1],
#  ['The story of', 1],
#  ['the King s character?', 1],
#  ['Cotton began to', 1],
#  ['Well  he loved a lot to develop', 1],
#  ['established on an', 1],
#  ['education and he was very fond of', 1],
#  ['area of  hectares', 1],
#  ['Can you tell the class about him?', 1],
#  ['his brave nation', 1],
#  ['Make more conversations  but this time use the words in the B and C columns',
#   1],
#  ['Look at the following verbs they are in simple past tense form', 1],
#  ['Did ..like .?', 1],
#  ['Was fond of', 1],
#  ['Did learn ..?', 1],
#  ['Did .find out .?', 1],
#  ['You have seen the past continuous tense before', 1],
#  ['Kabul University was graduating thousands of students before ', 1],
#  ['By   Afghanistan was serving several domestic destinations', 1],
#  ['Now look at this sentence', 1],
#  ['While I was visiting a friend in Jalalabad  I went to Amir Shaheed Garden',
#   1],
#  ['The verb was visiting is in the past continuous tense', 1],
#  ['It is used here in a while clause note the verb in the other clause', 1],
#  ['While I was visiting a friend in Jalalabad  I went to Amir Shaheed Garden',
#   1],
#  ['While   Past continuous   ', 1],
#  ['We use this to show that', 1],
#  ['the pupil went to the Garden in the past and  the visiting began before the garden and continued after it',
#   1],
#  ['I was visiting my friend', 1],
#  ['I went to the Garden', 1],
#  ['Here is another example', 1],
#  ['While the king was starting his speech  he recited a verse from the holy Qur an',
#   1],
#  ['Write the correct form of the verb in brackets', 1],
#  ['The first one is an example', 1],
#  ['While he was playing  he lost his keys', 1],
#  ['While they              along the street  they saw an accident', 1],
#  ['While you                a man called at the door', 1],
#  ['While it                my clothes became wet', 1],
#  ['While we               television  our father came home', 1],
#  ['While I                my homework last night  I broke my pen', 1],
#  ['While she                her soup  an insect fell into it', 1],
#  ['While he                 he became ill', 1],
#  ['While they                  a policeman drove up in a car', 1],
#  ['While we                  we saw Tamim', 1],
#  ['Answer the following questions about the following situations', 1],
#  ['Begin with while', 1],
#  ['The first one is an example', 1],
#  ['Hamdard arrived at the airport early', 1],
#  ['He sat in the lounge for a long time', 1],
#  ['Then they called out his flight', 1],
#  ['What did they do while he was sitting in the lounge?', 1],
#  ['While he was sitting in the lounge  they called out his flight', 1],
#  ['Omer had a shower last night', 1],
#  ['In the middle of his shower  the phone rang', 1],
#  ['He went downstairs and answered it', 1],
#  ['What happened while he was having a shower?', 1],
#  ['We sat in the garden yesterday', 1],
#  ['A very loud plane flew over', 1],
#  ['We had to go inside', 1],
#  ['What happened while we were sitting in the garden?', 1],
#  ['There was a good program on television last night  but I watched only part of it because my TV broke down',
#   1],
#  ['What happened while I was watching television?', 1],
#  ['King Ghazi Amanullah Khan was one of the very famous rulers of Afghanistan',
#   1],
#  ['He was the founder of the new modern and independent', 1],
#  ['Amanullah Khan was crowned the', 1],
#  ['Amir of Afghanistan after the death of his father', 1],
#  ['Amir Habibullah was assassinated in February', 1],
#  ['Amanullah Khan wanted Afghanistan to be free and independent in its policies  so he was fiercely against British political control over the country',
#   1],
#  ['He wanted to revoke the agreement which', 1],
#  ['Afghanistan s foreign policy', 1],
#  ['The British resisted this move  and so began the Third Anglo Afghan', 1],
#  ['After the heroic struggle of the people of Afghanistan  the British were defeated',
#   1],
#  ['Eventually  they surrendered and lost their', 1],
#  ['King Amanullah Khan s plans of modernization', 1],
#  ['launched among the people  were not', 1],
#  ['control over Afghanistan s foreign policy', 1],
#  ['greeted so warmly by the public in', 1],
#  ['Afterwards  Amanullah Khan became a national', 1],
#  ['hero  because of his courageous leadership', 1],
#  ['tribes revolted against him', 1],
#  ['against British colonialism  he was given the', 1],
#  ['end  the greater uprising of people', 1],
#  ['Putting his country in the line of', 1],
#  ['sovereign and independent countries of the', 1],
#  ['dethroned from the kingdom', 1],
#  ['world  he wanted the country to be progress and', 1],
#  ['Afghanistan and lived in exile in', 1],
#  ['prosperous  so he turned his attention towards', 1],
#  ['Italy and Switzerland', 1],
#  ['He died in', 1],
#  ['the modernization of Afghanistan', 1],
#  ['and was buried in Jalalabad', 1],
#  ['his title from Amir to Padshah  King  in ', 1],
#  ['near his father s tomb', 1],
#  ['Read the following statements about the passage', 1],
#  ['Put T  True  or F  False  and the line number', 1],
#  ['Write out a correct statement if you put F', 1],
#  ['King Ghazi Amanullah Khan was one of the very famous rulers of', 1],
#  ['He became the King of Afghanistan in ', 1],
#  ['Amanullah Khan wanted Afghanistan to be free and independent in its policies',
#   1],
#  ['Amir Habibullah Khan was the founder of the new modern and independent Afghanistan',
#   1],
#  ['He became an international hero  and was given the title of Emperor', 1],
#  ['Amanullah Khan changed his title from Amir to Padshah  King  in', 1],
#  ['Ghazi Amanullah Khan died in   and was buried in Kunar  near his uncle s tomb',
#   1],
#  ['Amanullah Khan left Afghanistan and lived in exile in Italy and', 1],
#  ['Amanullah Khan s plans of modernization were not accepted by the people',
#   1],
#  ['The third Anglo Afghan war began in ', 1],
#  ['greet  v  to react to t somebody  something in a', 1],
#  ['crowned  v  to put a crown on the head of a new king or queen as a sign of royal power',
#   1],
#  ['King Amanullah Khan was crowned the Amir of Afghanistan in ', 1],
#  ['The team s win was greeted as a major triumph', 1],
#  ['assassinate  v  to murder an important or famous person  especially for political reasons',
#   1],
#  ['The prime minister was assassinated by extremists', 1],
#  ['tribe  n  a group of people of the same', 1],
#  ['fierce  adj  angry and aggressive in a way that is frightening', 1],
#  ['He suddenly looked fierce', 1],
#  ['revolt  v  to take violent action against the', 1],
#  ['race and with the same customs  language  religion  etc  writing in a particular area and often led by a chief',
#   1],
#  ['people in power', 1],
#  ['Finally the people revolted against the fiercely  adv  very strong in a way that military dictatorship',
#   1],
#  ['could cause damage', 1],
#  ['The air craft was burning fiercely', 1],
#  ['uprising  n  a situation in which a group revoke  v  to officially cancel of people join together in order to fight something so that it is no longer valid',
#   1],
#  ['against the people who are in power', 1],
#  ['resist  v  to refuse  to accept and try to throne  n  a special chair used by a king stop it from happening',
#   1],
#  ['heroic  adj  showing extreme courage or queen to sit on at ceremonies', 1],
#  ['and admired by many people', 1],
#  ['dethrone  vt  to remove a king or queen', 1],
#  ['We watched our team s heroic struggle from power  to remove some body from a to win back the cup',
#   1],
#  ['position of authority or power', 1],
#  ['defeat  v  to win against somebody in a war  competition  sports game etc',
#   1],
#  ['exile  v  to force somebody to leave their', 1],
#  ['He defeated the champion in three sets', 1],
#  ['country  especially for political reasons or surrender  v  to admit that you have a punishment',
#   1],
#  ['been defeated and want to stop tomb  n  a large grave  especially one fighting  to allow yourself to be caught',
#   1],
#  ['built of stone above or below the ground', 1],
#  ['Write the correct words in the blank spaces', 1],
#  ['Amanullah Khan was            the Amir of', 1],
#  ['Afghanistan after the death of his father', 1],
#  ['Amir Habibullah was             in February', 1],
#  ['King Amanullah Khan was           against', 1],
#  ['British political control over the country', 1],
#  ['agreement which gave the British control over', 1],
#  ['this move  and so began the Third', 1],
#  ['Anglo Afghan War in ', 1],
#  ['After the             struggle of the people of', 1],
#  ['Afghanistan  the British were defeated', 1],
#  ['Afterwards  Amanullah Khan became a         hero', 1],
#  ['because of his           leadership  against', 1],
#  ['British              he was given the title  Ghazi ', 1],
#  ['Amanullah Khan turned his attention towards the', 1],
#  ['Amanullah Khan changed his          from Amir to', 1],
#  ['Padshah  King  in ', 1],
#  ['King Ghazi Amanullah Khan was one of the very famous', 1],
#  ['Write the correct words from the box in the spaces below', 1],
#  ['Then copy the sentences in your notebooks', 1],
#  ['King Amanullah Khan was one of the national          in Afghanistan', 1],
#  ['Amanullah Khan was the           of the new modern and', 1],
#  ['Rahim           at the airport early', 1],
#  ['Kabul University was             thousands of students before ', 1],
#  ['By   Afghanistan was                 several domestic destinations', 1],
#  ['The third Anglo Afghan         began in ', 1],
#  ['While I was            a friend in Jalalabad  I went to Amir Shahid', 1],
#  ['The prime minister was             by extremists', 1],
#  ['He           the champion in two rounds', 1],
#  ['King Amanullah Khan           in   and was           in Jalalabad  near his father s tomb',
#   1],
#  ['Remember how we use while with the past continuous tense', 1],
#  ['I was visiting my friend', 1],
#  ['I went to the Garden', 1],
#  ['Here are some more examples', 1],
#  ['While he was leading the government of Afghanistan  his desire to make his nation s education level increased',
#   1],
#  ['While he was traveling to Badakhshan for sightseeing  his car had a puncture',
#   1],
#  ['While he was waiting for repairs  a man on a horse came near', 1],
#  ['Remember  there is a comma after the while clause when it begins a sentence and the word While has a capital letter',
#   1],
#  ['We can also change the order of the sentences', 1],
#  ['His desire to make his nation s education level increased  while he was leading the government of Afghanistan',
#   1],
#  ['His car had a puncture', 1],
#  ['while he was traveling to Badakhshan for sightseeing', 1],
#  ['A man on a horse rode and came near', 1],
#  ['while he was waiting for repairs', 1],
#  ['Remember  there is no comma after the while clause when it begins a sentence and the word While has a capital letter',
#   1],
#  ['Pay attention to the following sentence', 1],
#  ['Not recognizing Baryalai the director  he asked if the director had passed by already',
#   1],
#  ['The beginning of this sentence is a phrase verb   ing', 1],
#  ['It explains why he asked the question', 1],
#  ['When a sentence begins with verb   ing  it can show', 1],
#  ['something was done', 1],
#  ['something was done', 1],
#  ['something was done', 1],
#  ['Look at these examples', 1],
#  ['Why  Not recognizing Baryalai the director  he asked if the director had passed by',
#   1],
#  ['Living in Jalalabad  we often visit the garden', 1],
#  ['When  Crossing the road  he was hit by a car', 1],
#  ['How  Using a knife  he opened the letter', 1],
#  ['Remember  there is a comma after those phrases that introduce a sentence',
#   1],
#  ['Note  sentences like these are common in written English  but they are not usually heard in spoken English',
#   1],
#  ['Change the order of these sentences', 1],
#  ['If they begin with While  change them so that they do not', 1],
#  ['If they do not begin with while  change them so that they do', 1],
#  ['Remember  if the sentence begins with While  you will need a comma', 1],
#  ['While she was playing  she lost her watch', 1],
#  ['I broke my pencil while I was writing the answers', 1],
#  ['While I was watching TV  the phone rang', 1],
#  ['Fahima broke a tooth while she was eating meals', 1],
#  ['We saw Ramish while we were standing at the bus stop', 1],
#  ['While it was raining  the explorer collected water in a tin', 1],
#  ['Change these sentences', 1],
#  ['If they are with           ing  change them to begin with the word in brackets at the end',
#   1],
#  ['If they do not begin with           ing  make them do so', 1],
#  ['Finding the door locked  the policemen broke it down', 1],
#  ['Working in a library  he found a very good book', 1],
#  ['Walking on the eggs  he broke them', 1],
#  ['By using a tin opener  he opened the tin', 1],
#  ['While I was doing my homework', 1],
#  ['I broke my pen', 1],
#  ['Because he has a car  he often drives into the streets', 1],
#  ['At the end of this unit students will be able to  talk discuss about explorers in the Antarctic',
#   1],
#  ['learn the use of some and any in sentences', 1],
#  ['read paragraphs about scientists explorers in the', 1],
#  ['know the new words and use them in sentences', 1],
#  ['learn grammatical issues such as  if   past perfect tense  would have', 1],
#  ['Answer the following questions', 1],
#  ['What do scientists research in Antarctic?', 1],
#  ['What are their aims purpose?', 1],
#  ['What is Antarctic look like?', 1],
#  ['Is it possible to live in', 1],
#  ['What kind of animals can you find there?', 1],
#  ['What will happen if the ice and snows in Antarctic mills down?', 1],
#  ['Discuss about any other continents in the world with your teacher and your classmates',
#   1],
#  ['Practice the following conversation with your partner', 1],
#  ['Practice the conversation in column A below', 1],
#  ['Scientists went to the', 1],
#  ['Antarctic  didn t they?', 1],
#  ['Afghan   were part of a multinational group  weren t they?', 1],
#  ['Yes  they did', 1],
#  ['C are keen on such journeys  aren t you', 1],
#  ['Their aim was to sail They came from around Antarctica and several different research about its countries  didn t atmosphere',
#   1],
#  ['You had to adapt to new conditions  didn t you?', 1],
#  ['Yes  it was', 1],
#  ['Their plan for the They hadn t expedition had five worked together before  had they? stages  hadn t they?',
#   1],
#  ['Yes  they had', 1],
#  ['they hadn t', 1],
#  ['You hadn t been there before  had you?', 1],
#  ['I hadn t', 1],
#  ['Make more conversations but this time use the words in the B and C columns',
#   1],
#  ['Look at this question', 1],
#  ['Can you tell us something about your adventure?', 1],
#  ['You already know the word some  but this example is a little different', 1],
#  ['Can you see why this example is different from examples you have seen before? Look at the information below and on the next page',
#   1],
#  ['First  you will see some other words like something', 1],
#  ['Finally  you will see why this example is different', 1],
#  ['Look at these two lists  some any every no', 1],
#  ['body one thing where', 1],
#  ['Each of the words on the left can go in front of all the words on the right',
#   1],
#  ['somebody anybody everybody nobody', 1],
#  ['someone anyone everyone no one', 1],
#  ['Note that no one is different  It is two words', 1],
#  ['something anything everything nothing', 1],
#  ['somewhere anywhere everywhere nowhere', 1],
#  ['The words begin with some and any are normally used like some and any', 1],
#  ['We had some books', 1],
#  ['Do you have any books?', 1],
#  ['We do not have any books', 1],
#  ['Somebody was here', 1],
#  ['Is anybody at home?', 1],
#  ['I did not see anybody', 1],
#  ['He is somewhere', 1],
#  ['Is he anywhere?', 1],
#  ['He is not anywhere', 1],
#  ['In questions  the word any is normally used  but look at this question again',
#   1],
#  ['Can you tell us something about your adventure?', 1],
#  ['In this question  the word something is used instead of anything', 1],
#  ['The word some  something  someone  somebody and somewhere are often used in questions when we expect the answer Yes',
#   1],
#  ['Look at these examples', 1],
#  ['Can I borrow some money until tomorrow  please?', 1],
#  ['You look ill', 1],
#  ['Is there something wrong with you?', 1],
#  ['Will someone open the window  please?', 1],
#  ['Can somebody lend me a pencil  please?', 1],
#  ['Let s go to a restaurant', 1],
#  ['Do you know somewhere nice?', 1],
#  ['Answer these questions with negative sentences', 1],
#  ['Did you see anybody?', 1],
#  ['Did you go anywhere at the weekend?', 1],
#  ['Can they tell us anything about the accident?', 1],
#  ['Could he reach anyone on the phone?', 1],
#  ['Did they leave anything from dinner?', 1],
#  ['Here are some answers  ask questions for them', 1],
#  ['No  I did not visit anyone', 1],
#  ['No  we could not find him anywhere', 1],
#  ['No  she does not know anyone here', 1],
#  ['No  she was not able to say anything', 1],
#  ['No  we did not go anywhere in Thursday', 1],
#  ['Here are some answers  ask questions for them', 1],
#  ['Yes  I met my friend', 1],
#  ['Yes  I will open the window', 1],
#  ['Yes  he was able to say his name', 1],
#  ['Yes  she knows the girl in the corner', 1],
#  ['Yes  they went to the market on Monday', 1],
#  ['In   scientists from all around Fifth  they should share their the world were in an international information for the benefit of everybody and for a greater understanding of the expedition to the Antarctic',
#   1],
#  ['The aim was to sail around Antarctica and research the amount of ultraviolet After their preparation in Chile  the team light  ozone and pollution in different was ready to fly to Antarctica  a land covered with ice and snow',
#   1],
#  ['They stayed locations there', 1],
#  ['there for six weeks', 1],
#  ['During that period  some scientists spent some time at the', 1],
#  ['South Pole before beginning their sea', 1],
#  ['The plan for the expedition had five voyage round the continent', 1],
#  ['First  all equipment and materials would be made ready', 1],
#  ['The Supplies and', 1],
#  ['Second  everyone would become physically fit  be able to ski well and', 1],
#  ['Equipment learn to survive in the icy conditions', 1],
#  ['Third  they would have practice in They had to take all their food with them camping and in Antarctic travel',
#   1],
#  ['because nothing grows there', 1],
#  ['Fourth  they would do research round water was only a problem on the boat  where it was rationed',
#   1],
#  ['Their equipment the coasts of Antarctica', 1],
#  ['was designed for survival', 1],
#  ['It had to keep them warm and dry', 1],
#  ['For example  they wore several layers of special clothes which let moisture out but not in',
#   1],
#  ['On land  they slept in double sleeping', 1],
#  ['The multinational team was successful', 1],
#  ['bags in tents', 1],
#  ['They sheltered there', 1],
#  ['Antarctic is greater now than before', 1],
#  ['One night at sea  there were', 1],
#  ['Individually  each member has his own', 1],
#  ['strong and icy winds', 1],
#  ['In five meter', 1],
#  ['memories of the experience', 1],
#  ['waves  the boat crashed into an iceberg', 1],
#  ['Part of it was knocked off and disappeared to the bottom of the sea', 1],
#  ['Fortunately  the boat did not sink', 1],
#  ['If it had sunk  they would have died in the freezing water', 1],
#  ['Find the answers to the following questions from the reading on pages  and',
#   1],
#  ['Then write the line number where you found the answer in one box and the letter of the correct answer in the other box',
#   1],
#  ['The  expedition had', 1],
#  ['Only two people b', 1],
#  ['Only Americans c', 1],
#  ['Scientists from different countries d', 1],
#  ['More than two Americans', 1],
#  ['Which part of the plan would come to an end', 1],
#  ['of the expedition? a', 1],
#  ['Make the equipment ready b', 1],
#  ['Become physically fit c', 1],
#  ['Practice Antarctic travel d', 1],
#  ['Do research around the coasts e', 1],
#  ['Share the information', 1],
#  ['One aim was to research the amount of', 1],
#  ['in the Antarctic', 1],
#  ['The route was in the following order  a', 1],
#  ['Chile  South Pole  Sea Voyage', 1],
#  ['Chile  Sea Voyage  South Pole', 1],
#  ['South Pole  Chile  Antarctica', 1],
#  ['Antarctica  Chile  home', 1],
#  ['On the boat  they could not have as much as on land', 1],
#  ['When they were on the boat  a', 1],
#  ['they slept in tents b', 1],
#  ['their clothes let moisture in', 1],
#  ['They slept in double sleeping bags because', 1],
#  ['There was little food', 1],
#  ['It was very cold', 1],
#  ['Their equipment was for survival', 1],
#  ['The boat crashed into an iceberg', 1],
#  ['It crashed into an iceberg', 1],
#  ['a  dapt  a dapt  vt i reg', 1],
#  ['vt  change something to match another purpose or environment', 1],
#  ['He adapted a car engine to use in his boat', 1],
#  ['vi  change oneself to match another purpose or environment', 1],
#  ['She adapts very easily to new situations', 1],
#  ['ben e fit  ben efit   vt reg.  be an advantage or a good thing', 1],
#  ['A good education is a benefit to everyone', 1],
#  ['Chal lenge  chal lenge.   vt reg', 1],
#  ['Call someone to compete against you', 1],
#  ['test someone s ability', 1],
#  ['Climbing the mountain challenged his skills', 1],
#  ['me   m or ize  me morize   vt  reg.  learn', 1],
#  ['mois ture  mois', 1],
#  ['i ture  t    n', 1],
#  ['water in small quantities  often in the air or seen on surfaces', 1],
#  ['There is moisture in the air on humid days', 1],
#  ['You can often see tiny drops of moisture on the bathroom mirror after someone has had a bath or shower',
#   1],
#  ['ration  ra tion   vt   reg.  limit and control co op e ra tion  coope ra tion   n  the amount that someone gets',
#   1],
#  ['working together  help', 1],
#  ['In the desert  water for soldiers was rationed', 1],
#  ['The Antarctic expedition needed the to four litres a day', 1],
#  ['cooperation of several countries', 1],
#  ['ra tion  n  the amount which a person gets', 1],
#  ['co op e rate  co op erate  vi reg  work During the war  butter was rationed',
#   1],
#  ['The together  help eachother', 1],
#  ['ration was  grams per person per day', 1],
#  ['ex plor er  n  a person who travels to', 1],
#  ['If there are eight people who want a piece of remote places to find out about them',
#   1],
#  ['the cake below  how much is each person s', 1],
#  ['Early explorers discovered America', 1],
#  ['hu man be ing  hu man be ing  n  a person  a man  woman or child', 1],
#  ['Human beings cannot live under water', 1],
#  ['in di vid u al ly  indi vid ually   adv  affecting only one person  separately',
#   1],
#  ['Sometimes teachers speak to each student individually', 1],
#  ['Note that we add   ly to the adjective individual to make the adverb', 1],
#  ['This makes the adverb end in  lly', 1],
#  ['Make adverbs from the following adjectives  geological  medical  personal  professional  seasonal',
#   1],
#  ['mem o ry  me mory   n', 1],
#  ['an ability to remember things', 1],
#  ['She has a good memory', 1],
#  ['She never forgets anythings', 1],
#  ['an example of remembering', 1],
#  ['I have good memories of my holiday in', 1],
#  ['ul tra vi o let  ul tra vi olet   adj   about light  consisting of rays that cannot be seen by human eyes',
#   1],
#  ['Ultraviolet light can cure some skin diseases', 1],
#  ['Too much ultraviolet light from the sun can cause skin cancer', 1],
#  ['Use words form the box to complete the following definitions', 1],
#  ['Write the whole definition out on the line', 1],
#  ['You will not need to use all the words', 1],
#  ['The first one is an example', 1],
#  ['A      .is a long journey or trip  usually by sea', 1],
#  ['A voyage is a long journey or trip  usually by sea', 1],
#  ['To      .means to change something to match another purpose or environment',
#   1],
#  ['An     .is a journey or voyage with a scientific purpose', 1],
#  ['Something which is      tests a person s ability', 1],
#  ['temperatures are temperatures below  Centigrade', 1],
#  ['A      is an advantage or a good thing', 1],
#  ['means working together or helping each other', 1],
#  ['To     ..something is to control the amount which someone receives', 1],
#  ['is water in small amounts in the air', 1],
#  ['is the ability to remember something', 1],
#  ['Do you remember this from page ?', 1],
#  ['Fortunately  the boat did not sink', 1],
#  ['If the boat had sunk  they would have died', 1],
#  ['We use this when think about the past and imagine that the opposite happened',
#   1],
#  ['What were the facts?', 1],
#  ['Did the boat sink?', 1],
#  ['No  it didn t', 1],
#  ['Did they die?', 1],
#  ['No  they didn t', 1],
#  ['The facts were  The boat did not sink and they did not die', 1],
#  ['But we can imagine the opposite', 1],
#  ['If the boat had sunk  they would have died', 1],
#  ['Study the clause', 1],
#  ['Read these sentences', 1],
#  ['Say if each one is fact or imagined', 1],
#  ['Did they really happen or not?', 1],
#  ['Scientists went to the Antarctic', 1],
#  ['They did some research', 1],
#  ['If they had not gone there  they would not have learned to ski', 1],
#  ['If they had not had a boat  they would not have sailed around Antarctic',
#   1],
#  ['The boat crashed into an iceberg and part of it was knocked off', 1],
#  ['If the boat had not crashed  part of it would not have been knocked off',
#   1],
#  ['Not  If the fact sentence is negative  the imagined sentence is positive  not negative ',
#   1],
#  ['The boat did not sink and they did not die', 1],
#  ['If the boat had sunk  they would have died', 1],
#  ['Note  If the fact sentence is positive  the imagined sentence is negative',
#   1],
#  ['The boat crashed into an iceberg and part of it was knocked off', 1],
#  ['If the boat had not crashed  part of it would not have been knocked off',
#   1],
#  ['Make a sentence for each situation shown below', 1],
#  ['Each sentence should contain if   the past perfect and would have', 1],
#  ['The first one is done for you', 1],
#  ['You did not watch that TV program', 1],
#  ['The next day your friend told you that you would have enjoyed it', 1],
#  ['If I had watched that TV program  I would have enjoyed it', 1],
#  ['It was raining very hard', 1],
#  ['You wanted to go out', 1],
#  ['Your father told you to wait  but went out and got wet', 1],
#  ['Five minutes later  the rain stopped', 1],
#  ['If I had waited five minutes  the rain', 1],
#  ['Kabir did not study very hard', 1],
#  ['He failed the test', 1],
#  ['Passed the test', 1],
#  ['Maryam tried to explain why she was late  but her teacher would not let her',
#   1],
#  ['If Maryam s teacher', 1],
#  ['Omer liked his job  but the money was bad', 1],
#  ['So he left', 1],
#  ['Tawfiq had a car accident', 1],
#  ['He lost a lot of blood', 1],
#  ['He nearly died  but a doctor stopped the bleeding', 1],
#  ['If the doctor had not', 1],
#  ['Barialay wanted to buy a car', 1],
#  ['The one he wanted cost', 1],
#  ['He only had   ', 1],
#  ['So he did not buy it', 1],
#  ['Friba did not go to school this morning', 1],
#  ['She had a headache', 1],
#  ['But she wanted to go', 1],
#  ['If she had not', 1],
#  ['I went to bed very late', 1],
#  ['I was tired the next morning', 1],
#  ['If you had not', 1],
#  ['At the end of this unit students will be able to  talk discuss about calligraphy',
#   1],
#  ['review some grammatical points such as  comparing people and things', 1],
#  ['read a topic about calligraphy know the new words and use them in sentences',
#   1],
#  ['Discuss the following questions with your teacher and your classmates', 1],
#  ['What does a calligrapher do?', 1],
#  ['Can we see calligraphy only in Dari Pashto?', 1],
#  ['Finally discuss these general questions about calligraphy in English with your teacher',
#   1],
#  ['Can you name any other scripts in Dari Pashto?', 1],
#  ['Is calligraphy important? Why or why not?', 1],
#  ['Where can you see calligraphy in everyday life?', 1],
#  ['Practice the conversation in column A below', 1],
#  ['Your handwriting is terrible', 1],
#  ['You should try to improve it', 1],
#  ['B spoken English', 1],
#  ['But I m doing my best', 1],
#  ['No  you re not', 1],
#  ['Look at your brother s handwriting', 1],
#  ['It s much better than yours', 1],
#  ['It s clearer and easier to read', 1],
#  ['spoken English  more fluent and easier to understand', 1],
#  ['Look at  arithmetic  faster and more correct', 1],
#  ['But he s taken a special course', 1],
#  ['It was called', 1],
#  ['Yes  I can tell', 1],
#  ['Make more conversations but this time use the words in B and C columns', 1],
#  ['Comparing two People or Things', 1],
#  ['Look at the following sentences', 1],
#  ['Your brother s handwriting is better than yours', 1],
#  ['It s clearer than yours', 1],
#  ['It is easier to understand than yours', 1],
#  ['It is faster than yours', 1],
#  ['Remember that we add  er  to many adjectives when we want to compare two things and add than if we name both',
#   1],
#  ['clearer  than that', 1],
#  ['Fast          faster  than that', 1],
#  ['But remember these spelling rules', 1],
#  ['If an adjective ends with an e  add r only', 1],
#  ['safer  than that', 1],
#  ['Simple        ..simpler  than that', 1],
#  ['If the adjective ends with a y  change the y to ier', 1],
#  ['Easier  than that', 1],
#  ['And remember that some adjectives are irregular', 1],
#  ['Good        .better  than that', 1],
#  ['Worst  than that', 1],
#  ['Look at this summary', 1],
#  ['er slower than', 1],
#  ['All the adjectives in above table are short', 1],
#  ['All of them  except easy  have only one syllable', 1],
#  ['Longer adjective  with more than one syllable  do not usually take    er',
#   1],
#  ['Instead  the word more or the most are put in front of them', 1],
#  ['Have you used these conversations in your daily life?', 1],
#  ['It s more fluent and easier to understand', 1],
#  ['It s faster and more correct', 1],
#  ['Look at this summary', 1],
#  ['The most   adjective', 1],
#  ['more correct than', 1],
#  ['the most correct', 1],
#  ['more fluent than', 1],
#  ['the most fluent', 1],
#  ['more beautiful than', 1],
#  ['the most beautiful', 1],
#  ['Use the words in brackets to complete the sentences', 1],
#  ['Decide if you should use   er or   est', 1],
#  ['The first two are examples', 1],
#  ['student in the class', 1],
#  ['That car is', 1],
#  ['the other one', 1],
#  ['This exercise is', 1],
#  ['the last one', 1],
#  ['foot ball team in Afghanistan?  good', 1],
#  ['One English script is', 1],
#  ['A propeller plane is normally', 1],
#  ['winter weather for ten years', 1],
#  ['Many people say that Dari and Pashto are', 1],
#  ['than English to learn', 1],
#  ['This summer is', 1],
#  ['hot   be careful with the spelling', 1],
#  ['That shop sells', 1],
#  ['soft drinks in this area', 1],
#  ['Use the words in brackets to complete the sentences', 1],
#  ['Decide if you should use   er or est  The first two are examples', 1],
#  ['Kabul University is', 1],
#  ['Which English script is the most beautiful', 1],
#  ['of all?', 1],
#  ['Kabul University is', 1],
#  ['My father s English is', 1],
#  ['Pip s sister', 1],
#  ['person you know?  kind', 1],
#  ['That restaurant makes', 1],
#  ['food in town', 1],
#  ['People say that English is', 1],
#  ['Dari and Pashto to learn', 1],
#  ['In the world in general  tea is', 1],
#  ['Is learning grammar', 1],
#  ['popular  learning new words?', 1],
#  ['As there are different scripts in', 1],
#  ['Arabic  Dari and Pashto calligraphy which you recognize them as Nastaliq  Naskh  and',
#   1],
#  ['Kufi  have English language also many different scripts', 1],
#  ['Perhaps they are not so important in', 1],
#  ['English nowadays as different scripts are in Arabic  Dari and', 1],
#  ['Calligraphy is probably the most important form of art for Muslims', 1],
#  ['It is seen not only in the holy Qur an and in books  but also in many other places',
#   1],
#  ['It is used  for the decoration of buildings', 1],
#  ['There are wallhangings  framed samples and inscriptions inside and outside public and private buildings',
#   1],
#  ['In the western world  the art of calligraphy declined with the introduction of printing and typewriters',
#   1],
#  ['However  it is now becoming more popular again and calligraphers are in demand to illustrate books  posters  cards  letterheads and many other things',
#   1],
#  ['Some of the different', 1],
#  ['English scripts are so common that you will almost certainly see them in your reading',
#   1],
#  ['Three of the most common scripts used are Roman  based on letters developed by the Romans about',
#   1],
#  ['which developed in northern', 1],
#  ['Europe between  and  centuries AD and Italic  from  and  century Italy', 1],
#  ['There are some examples of alphabets in these three scripts in the top of the next page',
#   1],
#  ['How common are these scripts and where will you see them? Roman script is probably the most common',
#   1],
#  ['This is because it is the clearest and easiest to read', 1],
#  ['Almost all the newspapers  magazines and books which you will ever see in English use some form of the Roman script',
#   1],
#  ['Gothic script is quite difficult to read  even for native speakers', 1],
#  ['It is usually seen on letter heads  in the names of newspapers  and outside buildings',
#   1],
#  ['Italic scripts as you see it on the next page is always written by hand',
#   1],
#  ['However  a slanted version of Roman script is often used in printing to stress or emphasize things  and this is also called Italic',
#   1],
#  ['Look at the examples on the next page', 1],
#  ['Decide which of the English scripts is used in each example and why it is used',
#   1],
#  ['Some Alphabets in Different English Scripts abcdefghijklmnopqrstuvwxyz', 1],
#  ['Times New Roman Script', 1],
#  ['Lucida Handwriting Script', 1],
#  ['Lucida Calligraphy Script', 1],
#  ['Examples of Different Scripts in Use', 1],
#  ['Read the following statements about the passage', 1],
#  ['Put T  True  or F  False  and the line number', 1],
#  ['Write out the correct statement if you put F', 1],
#  ['The Dari Pashto calligrapher can use three different scripts', 1],
#  ['There are many different scripts in English', 1],
#  ['Calligraphy is probably the most important form of art in the West', 1],
#  ['Calligraphy is more popular now than it was some time ago', 1],
#  ['Gothic script was developed in Italy', 1],
#  ['Italic script is used to emphasize things in printing', 1],
#  ['com  mon  com mon   adj', 1],
#  ['Belonging to several people  not to one person', 1],
#  ['Britain  the U.S.A', 1],
#  ['and Australia share a common language', 1],
#  ['found in many places', 1],
#  ['That bird  the pigeon  is common all over', 1],
#  ['It is common for a woman to leave her parents house when she gets married',
#   1],
#  ['We did not like him because he was a very common person', 1],
#  ['Which of the meanings above is correct for the passage about calligraphy? de   cline  de cline   vt i  reg',
#   1],
#  ['vt  say  No  to something which has been offered', 1],
#  ['He declined my offer of help', 1],
#  ['vi  become weaker or less', 1],
#  ['That used to be a beautiful part of town but it has declined in the last few years',
#   1],
#  ['Which of the meanings above is correct for the passage about calligraphy? dec  o rate  dec orate  vt  reg  make something more beautiful by adding things to it',
#   1],
#  ['They decorated the street with flags', 1],
#  ['She decorated the room with flowers', 1],
#  ['dec o ra tion  deco ra tion   n  something used to decorate', 1],
#  ['Some people put decorations outside their houses to celebrate the Eid', 1],
#  ['em  pha   size  em phasize   vt   reg.   make people notice something  make something noticeable  stress',
#   1],
#  ['The speaker emphasized the word  one  when he spoke', 1],
#  ['The edge of metal or wood around a picture or the glass of a window', 1],
#  ['The picture had a beautiful wooden frame', 1],
#  ['the structure which supports a house  a plane or a ship', 1],
#  ['That building has a street frame', 1],
#  ['framed  adj  with a frame around', 1],
#  ['The picture was beautifully framed in wood', 1],
#  ['il lus trate  il lustrate   vt reg.  use pictures  photographs or diagrams in a book or a lesson  explain by using pictures  photographs or diagrams',
#   1],
#  ['He illustrated his lecture about France with photographs of Paris', 1],
#  ['in de mand  in de mand   adj phr  wanted  popular', 1],
#  ['That writer s books are always in demand', 1],
#  ['Can you think of things which are always in demand on very hot days? ink  n  a black or colored substance used for writing or printing',
#   1],
#  ['Black and blue are the most popular colors for ink', 1],
#  ['na tive speak er  na tive speak er   n  someone who has spoken a language since he or she was born',
#   1],
#  ['Are you a native speaker? of which language?', 1],
#  ['pop u lar  pop ular  adj  liked by many people', 1],
#  ['He is popular with his classmates', 1],
#  ['Can you name the most popular soft drink in', 1],
#  ['Afghanistan? print ing  print ing  n  the business copying letters  words and books by machine',
#   1],
#  ['Many people say that the Chinese invented printing', 1],
#  ['slant ed  slant ed   adj  not vertical but at an angle from vertical', 1],
#  ['His handwriting was slanted from left to right', 1],
#  ['Handwriting Slanted from Left to Right', 1],
#  ['ver sion  ver sion  n  a form of something which has been changed a little from the original',
#   1],
#  ['There are two different versions of this car  one with four doors and one with two',
#   1],
#  ['Write the correct words', 1],
#  ['I am going to send my brother              to wish him a happy Eid', 1],
#  ['Before we can give you a job  we must see', 1],
#  ['of your work', 1],
#  ['I like that picture', 1],
#  ['Now I must find              for it before I hang it on', 1],
#  ['a native speaker a card a sample a frame', 1],
#  ['If you want to know how to pronounce a word correctly  ask                ',
#   1],
#  ['The number of accidents has               since the government introduced the new speed limited',
#   1],
#  ['The new book is             with photographs and drawings', 1],
#  ['The speaker               the important words in', 1],
#  ['emphasized decorated illustrated declined', 1],
#  ['every sentence which he spoke', 1],
#  ['They                  their bedroom with new carpets and furniture', 1],
#  ['Elephants are                    in Africa', 1],
#  ['You see them in many places there', 1],
#  ['Many people like tea', 1],
#  ['In fact  it is one of the most', 1],
#  ['drinks in the world', 1],
#  ['On the wall  there was a page from the Holy Qur an', 1],
#  ['Italic printing is               to the left', 1],
#  ['slanted framed popular common', 1],
#  ['Remember how we compare when using short adjectives', 1],
#  ['Now remember how we compare when using longer adjectives', 1],
#  ['more useful than', 1],
#  ['the least safe', 1],
#  ['more popular than', 1],
#  ['the least useful', 1],
#  ['more beautiful than', 1],
#  ['the least important', 1],
#  ['Do you remember the opposite of more and most?', 1],
#  ['We use less than and the least with long and short adjectives', 1],
#  ['Less safe than', 1],
#  ['The least safe', 1],
#  ['Less useful than', 1],
#  ['The least useful', 1],
#  ['Less important than', 1],
#  ['The least important', 1],
#  ['Syllable in safe there are', 1],
#  ['Syllables in useful and', 1],
#  ['Syllables in important', 1],
#  ['Now look at these sentences from the reading passage', 1],
#  ['Perhaps they are not as important in English as different scripts are in  Arabic  Dari Pashto',
#   1],
#  ['Remember  we use this when things are not similar', 1],
#  ['Here are some more examples', 1],
#  ['I am not as clever as you', 1],
#  ['Jamshid is as happy as Rabbani', 1],
#  ['Now remember how we show things that are similar', 1],
#  ['I am as clever as you', 1],
#  ['Jamshid is as happy as Rabbani', 1],
#  ['Finally  remember centuries in English', 1],
#  ['The seventh century', 1],
#  ['which means the years', 1],
#  ['The tenth century', 1],
#  ['The fifteenth century', 1],
#  ['The sixteenth century', 1],
#  ['The seventeenth century', 1],
#  ['The eighteenth century', 1],
#  ['The nineteenth century', 1],
#  ['but we write', 1],
#  ['The twentieth century', 1],
#  ['The twenty   first century', 1],
#  ['The twenty   second century', 1],
#  ['The twenty   third century', 1],
#  ['Use the words in brackets to complete the sentences', 1],
#  ['Decide if you should use eror est  more than or the most', 1],
#  ['The first one is an example', 1],
#  ['Roman script is more common than Gothic Script', 1],
#  ['Roman script is of the three English scripts to read', 1],
#  ['Which is soft drink in Afghanistan?  popular', 1],
#  ['Use the words in brackets to complete these sentences', 1],
#  ['Decide if you should use more than  less than  the most or the least', 1],
#  ['Hamidi is his brother', 1],
#  ['He gives lots of money to the poor but his brother gives less', 1],
#  ['He is man in the world', 1],
#  ['Use the words in brackets to complete the following sentences', 1],
#  ['He is meter', 1],
#  ['big  his elder brother', 1],
#  ['They are both', 1],
#  ['At the end of this unit students will be able to  talk discuss about the expansion of the holy mosque at',
#   1],
#  ['Makkah Al Mokarramah', 1],
#  ['learn some grammatical points such as  adjectives made from more than one word  countable and uncountable nouns',
#   1],
#  ['read a paragraphs about the expansion of the holy mosque at Makkah Al Mokarramah',
#   1],
#  ['know the new words and use them in sentences', 1],
#  ['Try to answer the following questions', 1],
#  ['What is the total area of the holly Mosque at', 1],
#  ['Makkah now?', 1],
#  ['What was the area of the Holly Mosque at', 1],
#  ['Makkah before the first Saudi extension?', 1],
#  ['Look at the words on the left and those in the box', 1],
#  ['Choose the words from the box which you think best explain the words on the left',
#   1],
#  ['A person praying', 1],
#  ['You are welcome', 1],
#  ['Not at all', 1],
#  ['Finally  what do you know about the extension of the Holly mosque in', 1],
#  ['Discuss this in English with your teacher and classmates', 1],
#  ['Practice the conversation in column A below with your partner in the class',
#   1],
#  ['Can you give us some', 1],
#  ['information about the Holy', 1],
#  ['University in Kabul', 1],
#  ['Mosque at Makkah?', 1],
#  ['For a start  it', 1],
#  ['has room for', 1],
#  ['passengers a day', 1],
#  ['What about the design?', 1],
#  ['It matches the rest of the', 1],
#  ['is very modern and', 1],
#  ['building and has two new', 1],
#  ['covers a  square', 1],
#  ['Terminal has newly', 1],
#  ['meter high minarets', 1],
#  ['built in modern shape', 1],
#  ['Thank you for telling us those interesting facts', 1],
#  ['Not at all', 1],
#  ['Make more conversations  but this time use the words in B and C columns',
#   1],
#  ['Look at these adjectives and learn them carefully', 1],
#  ['It has two new  meter high minarets', 1],
#  ['It covers a  square kilometer area', 1],
#  ['It has many  meter high pillars', 1],
#  ['Note the hyphens', 1],
#  ['Note there is no S to show the plural', 1],
#  ['Here are some more examples', 1],
#  ['A ten Afghani note', 1],
#  ['He is a  year old boy', 1],
#  ['The Kabah is a', 1],
#  ['meter high building', 1],
#  ['Look at this sentence from the conversation in lesson', 1],
#  ['The Holy Mosque in Makkah now has room for   worshippers', 1],
#  ['The words room and worshippers are both nouns', 1],
#  ['However  they are very different', 1],
#  ['They have different meanings  of course  but there is another important difference',
#   1],
#  ['You can count worshippers but you cannot count room', 1],
#  ['This word room means space', 1],
#  ['It is not the same as a room in a house', 1],
#  ['You can count the rooms in a house', 1],
#  ['We call worshippers a countable noun', 1],
#  ['We call room an uncountable noun', 1],
#  ['It is important to know if a noun is countable or uncountable because you cannot do certain things with uncountable nouns',
#   1],
#  ['You cannot use numbers with uncountable nouns', 1],
#  ['You cannot use a or an with uncountable nouns', 1],
#  ['You cannot make uncountable nouns plural', 1],
#  ['You cannot ask questions with How many  ?', 1],
#  ['You must use How much  ?', 1],
#  ['You cannot use fewer   the fewest  You must use less   the least', 1],
#  ['Answer the following questions', 1],
#  ['What kind of  ..is it? With adjectives like these  a', 1],
#  ['This note has a value of ten Afghani', 1],
#  ['What kind of note is it?', 1],
#  ['It is a', 1],
#  ['That boy is  years old', 1],
#  ['What kind of building is it?', 1],
#  ['That building has eight floors', 1],
#  ['What kind of building is it?', 1],
#  ['That apartment has two rooms', 1],
#  ['What kind of apartment is it?', 1],
#  ['That bridge is ten meters wide', 1],
#  ['What kind of bridge is it?', 1],
#  ['This lesson lasts  minutes', 1],
#  ['What kind of lesson is it?', 1],
#  ['His family has three cars', 1],
#  ['What kind of family is it?', 1],
#  ['Our Holiday lasts two weeks', 1],
#  ['What kind of holiday is it?', 1],
#  ['Our watch counts  hours every day', 1],
#  ['What kind of watch is it?', 1],
#  ['That tent can hold three persons', 1],
#  ['What kind of tent is it?', 1],
#  ['You can find out if a noun is countable or uncountable by looking in a dictionary',
#   1],
#  ['In many dictionaries  countable nouns have  ne  after them and uncountable nouns have  nu  after them',
#   1],
#  ['Here are two examples', 1],
#  ['ad ven ture  ad venture   nc  an', 1],
#  ['phar   ma   col   o   gy', 1],
#  ['exciting or dangerous event or', 1],
#  ['pharmacology   nu  the scientific', 1],
#  ['study of medicines and their', 1],
#  ['He wrote a book about his', 1],
#  ['adverntures in the jungle', 1],
#  ['He is studying pharmacology', 1],
#  ['The explorer told us about his', 1],
#  ['department at the hospital can tell', 1],
#  ['adventure in the Antarctic', 1],
#  ['you what that medicine contains', 1],
#  ['Look at the word study of this unit', 1],
#  ['Look at all the nouns', 1],
#  ['Make a list of all the countable nouns on the left on the next page', 1],
#  ['Make a list of all the uncountable nouns on the right on the next page', 1],
#  ['The Holy Mosque at the Time of the Prophet Muhammad', 1],
#  ['Peace Be Upon Him', 1],
#  ['Expansion between the Year  AH and  AH', 1],
#  ['On Tuesday   Safar  AH   September  AD   the', 1],
#  ['Custodian of the Two Holly Mosques  King Fahd  laid the foundation stone for a new addition to the Holly Mosques at Makkah AlMukarramah',
#   1],
#  ['This is not the first time that the Mosque has been expanded', 1],
#  ['If you look at the plans in the previews page  you will see that it was enlarged eight times between the days of the prophet',
#   1],
#  ['Muhammad  Peace be upon him  and the Saudi period', 1],
#  ['Expansion under the Al Saud Family', 1],
#  ['The first expansion', 1],
#  ['The first Saudi expansion took place between  and  AH   and  AD ', 1],
#  ['You can see how large this was on the right', 1],
#  ['The First Saudi Expansion', 1],
#  ...]

# %% [markdown]
# ### Checking for Data Imbalance:

# %%
len(new_examples1)
# Out:
# 956

# %%
len(new_examples2)
# Out:
# 1102

# %%
len(new_examples1)+len(new_examples2)
# Out:
# 2058

# %% [markdown]
# ### Checking the Readability Scores using the Textstat Library:

# %%
fs = open('../data/gradefourafghan.txt', 'r') 
bookone = fs.read()

# %%
# https://pypi.org/project/textstat/
bookonescore = round(textstat.flesch_kincaid_grade(bookone))
bookonescore
# Out:
# 4

# %%
fs = open('../data/gradetwelveafghan.txt', 'r') 
booktwo = fs.read()

# %%
# https://pypi.org/project/textstat/
booktwoscore = round(textstat.flesch_kincaid_grade(booktwo))
booktwoscore
# Out:
# 6

# %% [markdown]
# ### Organising the Labelled Data together using a Pandas Dataframe:

# %%
dataset = pd.DataFrame(columns = ["text", "label"])  
dataset = dataset.append(pd.DataFrame(new_examples2+new_examples1, columns = ["text", "label"]))

# %% [markdown]
# ### Downloading Pre-trained Vectors trained on part of Google News dataset:

# %%
# https://code.google.com/archive/p/word2vec/
# !pip install wget
import wget
import os
if not os.path.isfile("GoogleNews-vectors-negative300.bin.gz"):
    print("downloading")
    wget.download("https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz")
else:
    print("you already have it!")

# %%
embeddings_file = "../data/GoogleNews-vectors-negative300.bin.gz"
wv = KeyedVectors.load_word2vec_format(embeddings_file, binary=True, limit=200000)

# %% [markdown]
# ### Classification:

# %%
#Code Adapted from the NLP in Action book ch7 https://github.com/totalgood/nlpia
word_vectors = KeyedVectors.load_word2vec_format(embeddings_file, binary=True, limit=200000)
def tokenize_and_vectorize(dataset):
    vectorized_data = []
    for sample in dataset:
        tokens = casual_tokenize(sample)
        sample_vecs = []
        for token in tokens:
            try:
                sample_vecs.append(word_vectors[token])
            except KeyError:
                pass  # No matching token in the Google w2v vocab
        vectorized_data.append(sample_vecs)

    return vectorized_data

def pad_trunc(data, maxlen):
    """ For a given dataset pad with zero vectors or truncate to maxlen """
    new_data = []

    # Creating a vector of 0's the length of the word vectors
    zero_vector = []
    for _ in range(len(data[0][0])):
        zero_vector.append(0.0)

    for sample in data:
 
        if len(sample) > maxlen:
            temp = sample[:maxlen]
        elif len(sample) < maxlen:
            temp = sample
            additional_elems = maxlen - len(sample)
            for _ in range(additional_elems):
                temp.append(zero_vector)
        else:
            temp = sample
        new_data.append(temp)
    return new_data

# %%
features = tokenize_and_vectorize(dataset["text"].values)
x_train, x_test, y_train, y_test = train_test_split(features, dataset["label"], test_size=0.2, random_state=0)

# %%
type(x_train)
# Out:
# list

# %%
maxlen = 50
embedding_dims = 300    # Length of the token vectors for passing into the Convnet

# %%
np.array(x_train).shape,np.array(x_test).shape
# Out:
# <ipython-input-26-6dd20099d2f7>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   np.array(x_train).shape,np.array(x_test).shape
# ((1646,), (412,))

# %%
x_train = pad_trunc(x_train, maxlen)
x_test = pad_trunc(x_test, maxlen)

# %%
type(x_train)
# Out:
# list

# %%
np.array(x_train).shape
# Out:
# (1646, 50, 300)

# %%
x_train = np.reshape(x_train, (len(x_train), maxlen, embedding_dims))
y_train = np.array(y_train)
x_train = np.reshape(x_train, (len(x_train), maxlen, embedding_dims))
y_train = np.array(y_train)
x_test = np.reshape(x_test, (len(x_test), maxlen, embedding_dims))
y_test = np.array(y_test)

# %%
np.array(x_train).shape,np.array(x_test).shape
# Out:
# ((1646, 50, 300), (412, 50, 300))

# %%
batch_size = 32        
filters = 1           
kernel_size = 5         
hidden_dims = 10       
epochs = 8

# %% [markdown]
# ### Building the Model:

# %%
#Code Adapted from the NLP in Action book ch7 https://github.com/totalgood/nlpia

print('Build model...')
model = Sequential()

# Adding a Convolution1D, which will learn filters
# word group filters of size filter_length:
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1,
                 input_shape=(maxlen, embedding_dims)))
# Using max pooling:
model.add(GlobalMaxPooling1D())
# Adding a vanilla hidden layer:
model.add(Dense(hidden_dims))
model.add(Dropout(0.3))
model.add(Activation('relu'))
# Projecting onto a single unit output layer, and squash it with a sigmoid:
model.add(Dense(1))
model.add(Activation('sigmoid'))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
print(model.summary())
# Out:
# Build model...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 46, 1)             1501
# _________________________________________________________________
# global_max_pooling1d (Global (None, 1)                 0
# _________________________________________________________________
# dense (Dense)                (None, 10)                20
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 1,532
# Trainable params: 1,532
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# https://stackoverflow.com/questions/58636087/tensorflow-valueerror-failed-to-convert-a-numpy-array-to-a-tensor-unsupporte

x_train = np.asarray(x_train).astype(np.float32)
y_train = np.asarray(y_train).astype(np.float32)
x_test = np.asarray(x_test).astype(np.float32)
y_test = np.asarray(y_test).astype(np.float32)

# %% [markdown]
# ### Train Model:

# %%
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, y_test))
model_structure = model.to_json()
with open("cnn_model.json", "w") as json_file:
    json_file.write(model_structure)

model.save_weights("cnn_weights.h5")
print('Model saved.')
# Out:
# Epoch 1/8
# 52/52 [==============================] - 2s 23ms/step - loss: 0.6768 - accuracy: 0.4812 - val_loss: 0.6498 - val_accuracy: 0.5485
# Epoch 2/8
# 52/52 [==============================] - 1s 17ms/step - loss: 0.6177 - accuracy: 0.5851 - val_loss: 0.5801 - val_accuracy: 0.7087
# Epoch 3/8
# 52/52 [==============================] - 1s 14ms/step - loss: 0.5555 - accuracy: 0.7473 - val_loss: 0.5212 - val_accuracy: 0.8180
# Epoch 4/8
# 52/52 [==============================] - 1s 16ms/step - loss: 0.5033 - accuracy: 0.8366 - val_loss: 0.4745 - val_accuracy: 0.8471
# Epoch 5/8
# 52/52 [==============================] - 1s 14ms/step - loss: 0.4682 - accuracy: 0.8827 - val_loss: 0.4392 - val_accuracy: 0.8908
# Epoch 6/8
# 52/52 [==============================] - 1s 15ms/step - loss: 0.4226 - accuracy: 0.9125 - val_loss: 0.4116 - val_accuracy: 0.8908
# Epoch 7/8
# 52/52 [==============================] - 1s 13ms/step - loss: 0.3965 - accuracy: 0.9204 - val_loss: 0.3907 - val_accuracy: 0.9029
# Epoch 8/8
# 52/52 [==============================] - 1s 13ms/step - loss: 0.3687 - accuracy: 0.9399 - val_loss: 0.3707 - val_accuracy: 0.9223
# Model saved.

# %% [markdown]
# #### `(All observations and findings shall be included in the critical essay).`

# %% [markdown]
# ### Citation List:
#
#
# #### Websites:
#
# 1) Code.google.com. 2022. Google Code Archive - Word2Vec. [online] Available at: <https://code.google.com/archive/p/word2vec/> [Accessed 5 December 2021].
#
# 2) Davis, A., 2021. The fundamentals of programming - Python Video Tutorial | LinkedIn Learning, formerly Lynda.com. [online] LinkedIn. Available at: <https://www.linkedin.com/learning/programming-foundations-fundamentals-3/the-fundamentals-of-programming?autoAdvance=true&autoSkip=false&autoplay=true&resume=true&u=57077561> [Accessed 24 October 2021].
#
# 3) Dib, F., 2021. regex101: build, test, and debug regex. [online] regex101. Available at: <https://regex101.com/> [Accessed 4 December 2021].
#
# 4) GitHub. 2021. GitHub - totalgood/nlpia: Examples and libraries for "Natural Language Processing in Action" book. [online] Available at: <https://github.com/totalgood/nlpia> [Accessed 5 December 2021].
#
# 5) Libgen.is. 2021. Library Genesis. [online] Available at: <https://www.libgen.is/> [Accessed 4 November 2021].
#
# 6) McCallum, L., 2021. NLP Week 4.1 - Classification Task Notebook. [online] GitHub. Available at: <https://git.arts.ac.uk/lmccallum/nlp-21-22/blob/master/NLP%20Week%204.1%20-%20Classification%20Task.ipynb> [Accessed 16 November 2021].
#
# 7) McCallum, L., 2021. NLP Week 5.1 CNNs Notebook. [online] GitHub. Available at: <https://git.arts.ac.uk/lmccallum/nlp-21-22/blob/master/NLP%20Week%205.1%20CNNs.ipynb> [Accessed 2 December 2021].
#
# 8) Nisbet, J., 2021. Python for students - Python Video Tutorial | LinkedIn Learning, formerly Lynda.com. [online] LinkedIn. Available at: <https://www.linkedin.com/learning/python-for-students/python-for-students?autoAdvance=true&autoSkip=false&autoplay=true&resume=false&u=57077561> [Accessed 18 October 2021].
#
# 9) Portilla, J., 2021. Natural Language Processing with Python. [online] Udemy. Available at: <https://www.udemy.com/course/nlp-natural-language-processing-with-python/?ranMID=39197&ranEAID=JVFxdTr9V80&ranSiteID=JVFxdTr9V80-gIa4CDf8o_3HXX8ZIg_F1g&LSNPUBID=JVFxdTr9V80&utm_source=aff-campaign&utm_medium=udemyads> [Accessed 27 October 2021].
#
# 10) Rose, D., 2021. Artificial Intelligence Foundations: Neural Networks Video Tutorial | LinkedIn Learning, formerly Lynda.com. [online] LinkedIn. Available at: <https://www.linkedin.com/learning/artificial-intelligence-foundations-neural-networks/welcome?autoAdvance=true&autoSkip=false&autoplay=true&resume=true&u=57077561> [Accessed 6 December 2021].
#
# 11) PyPI. 2021. clean-text. [online] Available at: <https://pypi.org/project/clean-text/> [Accessed 14 November 2021].
#
# 12) PyPI. 2021. textstat. [online] Available at: <https://pypi.org/project/textstat/> [Accessed 15 November 2021].
#
# 13) Stack Abuse. 2021. Using Regex for Text Manipulation in Python. [online] Available at: <https://stackabuse.com/using-regex-for-text-manipulation-in-python/> [Accessed 16 November 2021].
#
# 14) T., Carvalho, V. and Fedor, Z., 2021. Tensorflow - ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type float). [online] Stack Overflow. Available at: <https://stackoverflow.com/questions/58636087/tensorflow-valueerror-failed-to-convert-a-numpy-array-to-a-tensor-unsupporte> [Accessed 5 December 2021].
#
# 15) Zamzar.com. 2021. Zamzar - video converter, audio converter, image converter, eBook converter. [online] Available at: <https://www.zamzar.com/> [Accessed 7 November 2021].
