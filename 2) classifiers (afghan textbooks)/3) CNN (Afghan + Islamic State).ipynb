# %% [markdown]
# # Using a Convolutional Neural Network for Text Readability Classification
#
# Code cells have been individually cited via comments wherever third-party code has been referred to or implemented, and a citation list has been added at the bottom of this notebook in Harvard style referencing.

# %% [markdown]
# ### Project Overview:
#
# The purpose of this project is to create a text readability classifier (inspired by the flesch kincaid readability tests) that determines whether a piece of text is easy or hard to read. I shall be making use of english textbooks from South-East Asian / Middle Eastern areas as datasets. Since most readability classifiers use data from the United Kingdom / United States in their model, I thought it would be interesting to approach this problem using data from non-western regions to see if they could predict readability scores accurately for english phrases across the world. After building the classifier, I shall test it on speech / interview transcripts of various politicians as a use case to get a bit more insight into their speaking styles.

# %% [markdown]
# ### Project Aim:
#
# 1) To construct a model that allows writers to have more control over their writing, so that they could structure their work according to their intended audience.

# %% [markdown]
# ### Installing and Importing the Required Libraries:

# %%
import numpy as np  
from keras.preprocessing import sequence   
from keras.models import Sequential         
from keras.layers import Dense, Dropout, Activation   
from keras.layers import Conv1D, GlobalMaxPooling1D
from gensim.models.keyedvectors import KeyedVectors
from nltk.tokenize.casual import casual_tokenize
from gensim.models import KeyedVectors
from sklearn.model_selection import train_test_split
import pandas as pd
from random import shuffle
import regex as re
from cleantext import clean
from nltk import word_tokenize
import textstat
# Out:
# Since the GPL-licensed package `unidecode` is not installed, using Python's `unicodedata` package which yields worse results.

# %% [markdown]
# ### Selection of Data:
#
# For this project, I'm using English textbooks of varying grades from different countries. I found all of them on [Library Genesis](https://www.libgen.is/) and since they were PDF files, I then converted them to text files using [Zamzar File Converter](https://www.zamzar.com/). I initially tried using python modules for this task like PDF Miner and PyPDF, but kept running into errors as most of the code I found on StackOverflow was not suitable with the latest version of Python.
#
# For this notebook, I have used a **fourth grade english textbook from Afghanistan by the country's Ministry of Education (2011 Edition)**, which can be found [here](https://libgen.is/search.php?req=afghanistan+english&lg_topic=libgen&open=0&view=simple&res=25&phrase=1&column=def), and a **sixth grade textbook from the Islamic State** which can be found [here](https://libgen.is/search.php?req=islamic+state+english&open=0&res=25&view=simple&phrase=1&column=def). The reason for doing so is to verify if the CNN classifier is performing better when given textbooks from two different regions (which turns out to be false in this case).

# %% [markdown]
# ### Preprocessing the Data:
#
# I've used Regex and the Clean-Text Library to prepare the data before the classification task. I defined a 'read_and_clean' function to read any given text file and clean the data in it, whilst replacing the line-breaks according to every condition (as described in the comments) as the text files for this task aren't following a particular pattern with grammar since it was converted from an image-heavy PDF. After that, I'm splitting the sentence after every full stop ('.') and avoiding any sentences with less than two words as it won't be of much use.

# %%
def remove(text):
    text = re.sub(r"#\S+", " ", text) #remove hashtags
    text = re.sub(r'\w*\d+\w*', '', text) #remove numbers 
    text = re.sub(r'[^a-zA-Z0-9\n\?!\.]', ' ', text) #remove special characters
    text = text.strip(" ")
    text = text.strip(".")
    return text

# %%
# read the file and clean it.
def read_and_clean(file_name):
# read the file
    fs = open(file_name, 'r') 
    book1 = fs.read()
# convert it to . if 2 or more line breaks are together
    book1 = re.sub(r"\n{2,}",". ", book1)
# convert it to . if 2 or more spaces are together
    book1 = re.sub(r"\s{2,}",". ", book1)
# convert a single line break to space if it is followed by a small letter
    book1 = re.sub(r"\n{1}(?=\s[a-z])"," ", book1)
# convert a single line break to space if it is followed by a space and small letter
    book1 = re.sub(r"\n{1}(?=[a-z])"," ", book1)
# convert all remaining line breaks to .
    book1 = re.sub(r"\n",". ", book1)
    total = []
    
    clean(book1,
        no_urls=True) # https://pypi.org/project/clean-text/
    
# split the sentence based on .
    for i in book1.split(". "):
# clean it using above function
        clean_text = remove(i)
# convert the sentence to a list of words and check the length. if it is greater then 2, then consider it a sentence
        if len(word_tokenize(clean_text)) >2:
            total.append(clean_text)
# return the final list
    return total

# %% [markdown]
# ### Labelling the Data and Calling the Functions:

# %%
# read the grade one file
grade_one_sentence = read_and_clean("../data/gradefourafghan.txt")

# %%
label = 0
new_examples1 = []
for i in grade_one_sentence:  
    if len(word_tokenize(i)) >2:
        new_examples1 = new_examples1 + [[i, label]]

# %%
new_examples1 = new_examples1[16:] # slicing the few sentences in the beginning to remove the contents page.

# %%
new_examples1
# Out:
# [['The goal of this chapter is for students to practice writing the letters A to M in English',
#   1],
#  ['Learning to Write N Z', 1],
#  ['The goal of this chapter is for students to practice writing the letters N to Z in English',
#   1],
#  ['The goal of this chapter is for students to practice writing words in English',
#   1],
#  ['Write the following words three times in your notebooks', 1],
#  ['My First Words in English', 1],
#  ['fish  apple  book  cat  dog  egg', 1],
#  ['Teacher  Good morning', 1],
#  ['Student  Good morning', 1],
#  ['Name the pictures after your teacher', 1],
#  ['Look at the above pictures and name them', 1],
#  ['In pairs  Student A points to a picture and student', 1],
#  ['B names it', 1],
#  ['Follow the example', 1],
#  ['Student A  points to', 1],
#  ['Student B  says apple', 1],
#  ['Teacher  Good bye', 1],
#  ['Students  Good bye', 1],
#  ['egg    dog  apple  book  cat  fish', 1],
#  ['Look at the pictures and name them', 1],
#  ['Each student finds a partner', 1],
#  ['Student A points to a picture and student B names it', 1],
#  ['Follow the example', 1],
#  ['What is this? Points to', 1],
#  ['It is a book', 1],
#  ['Note  All Students take turns', 1],
#  ['C.Look at the pictures and read the words after your teacher', 1],
#  ['         !         fish    dog  egg  apple  book  cat', 1],
#  ['Look at each picture and circle the correct word', 1],
#  ['cat apple egg', 1],
#  ['dog book apple', 1],
#  ['dog book cat', 1],
#  ['egg cat fish', 1],
#  ['egg cat fish', 1],
#  ['book fish apple', 1],
#  ['Look at the above pictures and read the words below', 1],
#  ['Write the letters in your notebooks', 1],
#  ['Follow the example', 1],
#  ['         !                        AB               b', 1],
#  ['Match each letter with the picture that its name begins with that letter',
#   1],
#  ['Write the first letter of each picture s name in your', 1],
#  ['Match the pictures with the correct words', 1],
#  ['book cat dog', 1],
#  ['Write the words of exercise C in your notebooks', 1],
#  ['          goat  hen  iron  jug  kite  lamp', 1],
#  ['Name the pictures after your teacher', 1],
#  ['Look at the pictures and name them', 1],
#  ['In pairs  Student A points to a picture', 1],
#  ['Student B names it', 1],
#  ['Follow the example', 1],
#  ['F           lamp   goat  hen  iron  jug  kite                     .!', 1],
#  ['Look at the pictures and name them', 1],
#  ['In pairs  Student a points to a picture  student B names it', 1],
#  ['Follow the example', 1],
#  ['What is it? Points to', 1],
#  ['It is a goat', 1],
#  ['C.  Look at the pictures and read the words after your teacher', 1],
#  ['D  In pairs  Student A points to a picture  student', 1],
#  ['B reads the word', 1],
#  ['Student A   points to', 1],
#  ['Student B   reads  goat', 1],
#  ['N      !         lamp  goat', 1],
#  ['hen  iron  jug  kite', 1],
#  ['Look at each picture and circle the correct word below', 1],
#  ['iron goat lamp', 1],
#  ['hen lamp jug', 1],
#  ['hen jug kite', 1],
#  ['lamp jug hen', 1],
#  ['lamp jug goat', 1],
#  ['goat iron kite', 1],
#  ['Look at the above pictures and read the words below', 1],
#  ['Write the letters in your notebooks', 1],
#  ['Follow the example', 1],
#  ['h i g', 1],
#  ['Match each letter with the picture that its name begins with that letter',
#   1],
#  ['i j k l', 1],
#  ['Write the first letter of each picture s name in your notebooks', 1],
#  ['Match the pictures with the correct word', 1],
#  ['goat hen iron jug kite lamp', 1],
#  ['Write the words of exercise C in your notebooks', 1],
#  ['!G     FD', 1],
#  ['!         sun   queen  radio  map  net  orange  pen', 1],
#  ['Name the pictures after your teacher', 1],
#  ['U nic ef Afghanistan', 1],
#  ['Pu lik humr i', 1],
#  ['Qalay i  now', 1],
#  ['PARW AN KAP S', 1],
#  ['Unicef Country Office', 1],
#  ['Look at the pictures and name them', 1],
#  ['Unicef Af ghanistan', 1],
#  ['TAKHARFa zi ab ad', 1],
#  ['Pulik humr i', 1],
#  ['Qalay  i now', 1],
#  ['Unicef Cou ntry Offi ce', 1],
#  ['In pairs  Student A points to a picture', 1],
#  ['Student B names it', 1],
#  ['Follow the example', 1],
#  ['Student A  What is it? Points to', 1],
#  ['Student B  It is a pen', 1],
#  ['sun   map  net  orange  pen  queen  radio                   H', 1],
#  ['Look at the pictures and name them', 1],
#  ['Qalay i now', 1],
#  ['Unicef Country Office', 1],
#  ['In pairs  Student A points to a picture  student B names it', 1],
#  ['Follow the example', 1],
#  ['I               B                                       A', 1],
#  ['What is this? Points to', 1],
#  ['It is a pen', 1],
#  ['Look at the pictures and read the words after your teacher', 1],
#  ['Qalay i now', 1],
#  ['!         sun  map  net  orange  pen  queen  radio', 1],
#  ['Look at each picture and circle the correct word below', 1],
#  ['Unicef Af ghanistan', 1],
#  ['TAKHARFa zi ab ad', 1],
#  ['Pulik humr i', 1],
#  ['Qalay  i now', 1],
#  ['Unicef Cou ntry Offi ce', 1],
#  ['queen map orange g', 1],
#  ['map orange queen', 1],
#  ['orange pen net', 1],
#  ['net pen radio', 1],
#  ['map radio pen', 1],
#  ['sun map net', 1],
#  ['radio rad dio queen net', 1],
#  ['Look at the above pictures and read the words below', 1],
#  ['Write the letters in your notebooks', 1],
#  ['Follow the example', 1],
#  ['         !           .        AB', 1],
#  ['Write each letter m  n  o  p  q  r and s five times in your notebooks', 1],
#  ['m m m m', 1],
#  ['K  !LM N!                      OP              Q', 1],
#  ['Match each letter with the picture s name that begins with that letter', 1],
#  ['     D                A R       B      C        R', 1],
#  ['n o p q r s', 1],
#  ['Qalay i now', 1],
#  ['Unicef Country Office', 1],
#  ['Write the first letter of each picture s name in your notebooks', 1],
#  ['Un c i ef Afgh a nistan', 1],
#  ['Qala y i now', 1],
#  ['SAMANG AN   BAGHLAN', 1],
#  ['PAK TYAKHO ST', 1],
#  ['Nort heaster n', 1],
#  ['Un icef Co untr y Office', 1],
#  ['Un icef ZO', 1],
#  ['Match the pictures with the correct words', 1],
#  ['Unic ef Afg ha nis tan', 1],
#  ['map net orange pen queen radio', 1],
#  ['SAMANG AN BAG HLAN', 1],
#  ['Qalay i now', 1],
#  ['KABU L W', 1],
#  ['Unicef Count ry Off ice', 1],
#  ['Write the words of exercise C in your notebooks', 1],
#  ['         AB                   B   C', 1],
#  ['I know the Alphabet in English', 1],
#  ['zoo  table  umbrella  van  wall  x  ray  yak     P', 1],
#  ['Hello  how are you?', 1],
#  ['Hello  how are you?', 1],
#  ['I am fine  thank you', 1],
#  ['Fine  thank you', 1],
#  ['Look at the pictures and repeat their names after your teacher', 1],
#  ['Look at the above pictures and name them', 1],
#  ['In pairs  Student A points to a picture  student B names it', 1],
#  ['Follow the example', 1],
#  ['B   B                                   A', 1],
#  ['What is this? Points to', 1],
#  ['It is an umbrella', 1],
#  ['!         zoo   table  umbrella  van  wall  x ray  yak      !', 1],
#  ['Look at the pictures and name them', 1],
#  ['In pairs  Student A points to a picture  student B names the picture', 1],
#  ['Follow the example', 1],
#  ['I           B      K                             A', 1],
#  ['What is this? points to', 1],
#  ['It is an umbrella', 1],
#  ['Look at the pictures and read the words after your', 1],
#  ['Look at the above pictures and read their names', 1],
#  ['  N      !       table  umbrella  van  wall  x ray  yak  zoo', 1],
#  ['                   Q             z        t', 1],
#  ['Look at the picture and circle the correct word below', 1],
#  ['umbrella table van', 1],
#  ['zoo wall yak', 1],
#  ['table yak umbrella', 1],
#  ['x ray zoo van', 1],
#  ['van wall x ray', 1],
#  ['umbrella yak table', 1],
#  ['wall x ray zoo', 1],
#  ['Look at the above pictures and read the words below', 1],
#  ['Write the letters in your notebooks', 1],
#  ['Follow the example', 1],
#  ['         !           .        AB', 1],
#  ['Write each letter t  u  v  w  x  y and z fives times in your notebooks', 1],
#  ['Match each letter with the picture s name that begins with that letter', 1],
#  ['     D                A          B      C', 1],
#  ['u v w x', 1],
#  ['Write the first letter of each picture s name in your notebooks', 1],
#  ['Match the pictures with the correct word', 1],
#  ['  H                               table umbrella', 1],
#  ['van wall x ray', 1],
#  ['Write each letter t  u  v  w  x  y and z five times in your notebooks', 1],
#  ['Review of Unit', 1],
#  ['Good morning students', 1],
#  ['Good morning teacher', 1],
#  ['How are you?', 1],
#  ['Fine  thank you', 1],
#  ['The teacher points to a picture and the students read the word under the picture',
#   1],
#  ['Match the picture with the correct word', 1],
#  ['  H                                             apple book cat  dog egg fish',
#   1],
#  ['goat hen iron jug kite lamp', 1],
#  ['Read the above words', 1],
#  ['Write the words in part C in your notebooks and draw five of your favorite pictures  and color them',
#   1],
#  ['F                 AB                   B   C', 1],
#  ['See you students', 1],
#  ['See you teacher', 1],
#  ['Review of Units', 1],
#  ['Hello boys girls', 1],
#  ['How are you?', 1],
#  ['Fine  thank you', 1],
#  ['The teacher points to a picture and the students name it', 1],
#  ['What is this? Points to', 1],
#  ['Says  It is a pen', 1],
#  ['Un icef Af gh anistan', 1],
#  ['Ma yma na', 1],
#  ['Qal ay i', 1],
#  ['SAMANG AN   BAGHLAN', 1],
#  ['Unicef Country O ffice', 1],
#  ['Out Po sts', 1],
#  ['Paved r o.shp', 1],
#  ['The teacher points to a picture  and the students read the word under the picture',
#   1],
#  ['Un icef Af gh anistan', 1],
#  ['Ma yma na', 1],
#  ['Qal ay i', 1],
#  ['SAMANG AN   BAGHLAN', 1],
#  ['Unicef Country O ffice', 1],
#  ['Out Po sts', 1],
#  ['Paved r o.shp', 1],
#  ['Match the picture with the correct word', 1],
#  ['map net orange', 1],
#  ['Unicef Af ghanistan', 1],
#  ['Qalay  i now', 1],
#  ['P ARWAN KAP ISA', 1],
#  ['S AMANG AN', 1],
#  ['Pulik humr i', 1],
#  ['TAKHARFa zi ab ad', 1],
#  ['Unicef C ou ntry Offi ce', 1],
#  ['radio sun table', 1],
#  ['umbrella van wall', 1],
#  ['x ray yak zoo', 1],
#  ['Read the above words', 1],
#  ['Write the words of part C in your notebooks and draw five of your favorite pictures and color them',
#   1],
#  ['    L      R                                        AB              B   C',
#   1],
#  ['More English Words', 1],
#  ['             fox   ant  ball  car  desk  eagle', 1],
#  ['                   SI             F                A   Q', 1],
#  ['Aziz  please stand up', 1],
#  ['Now read this', 1],
#  ['Please sit down', 1],
#  ['Look at the pictures and repeat their names after your teacher', 1],
#  ['Look at the above pictures and name them', 1],
#  ['Look at the pictures', 1],
#  ['Listen to your teacher s pronounciation and read the words after him her',
#   1],
#  ['                              K    U I    T          !     F', 1],
#  ['Look at the above pictures and read the words below', 1],
#  ['In pairs  Student A says the name of a picture  student B points to it', 1],
#  ['Follow the example', 1],
#  ['Student A   says  an ant', 1],
#  ['Student B   points to', 1],
#  ['Draw one of the part D pictures and color it', 1],
#  ['    L                             L      D', 1],
#  ['Teacher  Good bye', 1],
#  ['Students  Good bye', 1],
#  ['                          Fox    Ant  Ball  Car  Desk  Eagle', 1],
#  ['Look at the pictures', 1],
#  ['Listen to your teacher s pronunciation and read the words after him her',
#   1],
#  ['                            K    U I    T          !', 1],
#  ['Read the words under the above pictures', 1],
#  ['Look at the pictures and read the sentences after your teacher', 1],
#  ['It is an ant', 1],
#  ['It is a ball', 1],
#  ['It is a desk', 1],
#  ['It is a car', 1],
#  ['It is an eagle', 1],
#  ['It is a fox', 1],
#  ['D.In pairs  Student A points to a picture in part C and student B reads the sentence',
#   1],
#  ['M      V             B                                   A', 1],
#  ['Example  Student A  points to', 1],
#  ['Student B  Reads', 1],
#  ['It is an ant', 1],
#  ['Write the words of part A in your notebooks', 1],
#  ['  N      !         Fox    Ant  Ball  Car  Desk  Eagle', 1],
#  ['!        SI   Q             F        A', 1],
#  ['Look at the pictures and circle the correct word below', 1],
#  ['Look at the pictures and read the words below', 1],
#  ['Write the capital letters A  B  C  D  E  F in your notebooks', 1],
#  ['Follow the example', 1],
#  ['AB                F        A', 1],
#  ['Write each letter A  B  C  D  E and F five times in', 1],
#  ['          AB                       your notebooks', 1],
#  ['Match each letter with the picture sname which begins with that letter', 1],
#  ['     D               A          B      C        R', 1],
#  ['Write the first letter of picture s name in your notebooks', 1],
#  ['          A            E    ET', 1],
#  ['Match the pictures with the correct words', 1],
#  ['Write for each letter A  B  C  D  E and F five times in your notebooks', 1],
#  ['Listening to the Teacher', 1],
#  ['             Lock   Jar  Key Glass  Hand  Ice cream', 1],
#  ['            SI   Q             L        G', 1],
#  ['Please stand up boys girls', 1],
#  ['How are you?', 1],
#  ['standing  Fine  Thank you', 1],
#  ['Sit down please', 1],
#  ['sitting  Thank you', 1],
#  ['Look at this picture', 1],
#  ['What is it?', 1],
#  ['It is a       ', 1],
#  ['Look at the pictures  repeat their names after your teacher', 1],
#  ['Look at the above pictures and name them', 1],
#  ['In pairs  Student A points to a picture and student B names it', 1],
#  ['Student A  points to', 1],
#  ['Student B   says  Glass', 1],
#  ['Look at the pictures', 1],
#  ['Listen to your teacher s pronunciation and read the words after him her',
#   1],
#  ['                          K    U I    T          !', 1],
#  ['Student A says the name of a picture', 1],
#  ['Student B points to it', 1],
#  ['Follow the example', 1],
#  ['Student A   says  ice cream', 1],
#  ['Student B  points to', 1],
#  ['Draw one of the part D pictures and color it', 1],
#  ['    L      R                        L      D', 1],
#  ['Glass  Hand  Ice Cream  Jar  Key  Lock      !', 1],
#  ['Look at the pictures', 1],
#  ['Listen to your teacher and read the words after him her', 1],
#  ['                           K    U I          !', 1],
#  ['Read the words under each picture', 1],
#  ['Look at the pictures and read the sentences after', 1],
#  ['This is a glass', 1],
#  ['This is a hand', 1],
#  ['This is a jar', 1],
#  ['This is an ice cream', 1],
#  ['This is a key', 1],
#  ['This is a lock', 1],
#  ['In pairs  Student A points to a picture  student B reads the sentence', 1],
#  ['V             B                                     A', 1],
#  ['In pairs  Student A asks his partner  student B answers', 1],
#  ['Follow the example', 1],
#  ['         !           .      X                            !              A',
#   1],
#  ['Student A  What is this that?', 1],
#  ['Student B  It is a jar', 1],
#  ['Write the words of part A in your notebooks', 1],
#  ['   VW    !         Lock   Glass  Hand  Ice cream  Jar  Key', 1],
#  ['           SI   Q            L        G', 1],
#  ['Look at each picture and circle the correct word', 1],
#  ['Look at the above pictures and read the words below', 1],
#  ['G G G', 1],
#  ['    DE                          VW                     F', 1],
#  ['Match each letter with the picture s name that begins with that letter', 1],
#  ['Write the first letter of each picture s name in your notebooks', 1],
#  ['          AB           X    X', 1],
#  ['Match the pictures with the correct words', 1],
#  ['a Glass a Hand', 1],
#  ['an Ice cream a Jar a Key a Lock', 1],
#  ['Write each letter G  H  I  J  K and L five times in your notebooks', 1],
#  ['Some More English Words', 1],
#  ['             Star    Pencil  Quail  Rose  Moon  Nest  Onion', 1],
#  ['  N           SI   Q             S        M', 1],
#  ['Hello students  how are you?', 1],
#  ['Fine thank you', 1],
#  ['Repeat after me', 1],
#  ['Read the word  please', 1],
#  ['Now write the word please', 1],
#  ['Look at the pictures and repeat their names after your teacher', 1],
#  ['Look at the above pictures and name them', 1],
#  ['In pairs  Student A points to a picture and student B names it', 1],
#  ['Student A  points to', 1],
#  ['Student B   says  Nest', 1],
#  ['Look at the pictures', 1],
#  ['Listen to your teacher s pronunciation and read the words after him her',
#   1],
#  ['                          K    U I    T          !    ', 1],
#  ['Look at the above pictures and read the words', 1],
#  ['In pairs  Student A says the name of a picture', 1],
#  ['Student B points to it', 1],
#  ['Student B names a picture and student A points to it', 1],
#  ['points to a picture', 1],
#  ['Says its name', 1],
#  ['Draw a picture from part B and color it', 1],
#  ['    L      R               B   B', 1],
#  ['Star    Moon  Nest  Onion  Pencil  Quail  Rose', 1],
#  ['Look at the pictures  listen to your teacher s pronunciation and read the words after him  her',
#   1],
#  ['                           K    U I    T', 1],
#  ['Read the words under the above pictures', 1],
#  ['Look at the pictures and read the sentences after your teacher', 1],
#  ['That is a moon', 1],
#  ['That is a nest', 1],
#  ['That is a pencil', 1],
#  ['That is an onion', 1],
#  ['That is a quail', 1],
#  ['That is a rose', 1],
#  ['That is a star', 1],
#  ['Look at the above pictures and read the sentences', 1],
#  ['In pairs  Student A points to one of the above pictures and student B reads its name',
#   1],
#  ['Follow the example', 1],
#  ['         !           .M                   B', 1],
#  ['Student A  What is this?', 1],
#  ['Student B  Moon', 1],
#  ['In pairs  Student A points to a pictures in part C  student B reads the sentence',
#   1],
#  ['M      W             B                               A', 1],
#  ['Student A  points to', 1],
#  ['Student B  reads That is a nest', 1],
#  ['Write the sentences in part C in your notebooks', 1],
#  ['          AB              V    B  D', 1],
#  ['!         Star  Moon  Nest  Onion  Pencil  Quail  Rose', 1],
#  ['SI   Q            S        M', 1],
#  ['Look at each picture and circle the correct words below', 1],
#  ['Look at the above pictures and read the words below them', 1],
#  ['Write the letters M  N  O  P  Q  R  and S in your notebooks', 1],
#  ['Follow the example', 1],
#  ['         !                     Y !     F     R', 1],
#  ['Write each letter M  N  O  P  Q  R  and S five times in your notebooks', 1],
#  ['         Y !     F     R     E', 1],
#  ['K  !LM', 1],
#  ['!                    O                       Q', 1],
#  ['Match each letter with the pictures  which begins their names', 1],
#  ['     D               A          B      C        R', 1],
#  ['Write the first letter of the name of each picture in your notebooks', 1],
#  ['Match the pictures with correct words', 1],
#  ['Write each letters M  N  O  P  Q  R and S five times in your notebook', 1],
#  ['          Y !     F     R', 1],
#  ['I can write the Alphabet', 1],
#  ['             Zebra    Tree  Uniform  Vase  Wolf  X ray  Yoke', 1],
#  ['    N     E D        SI   Q', 1],
#  ['Please open your books', 1],
#  ['Read this word', 1],
#  ['Thank you  teacher', 1],
#  ['Look at the pictures and repeat their names after your teacher', 1],
#  ['Look at the above pictures and name them', 1],
#  ['Look at the pictures  listen to your teacher s pronuciation and read the words after him   her',
#   1],
#  ['                           K    U I    T', 1],
#  ['In pairs  Student A points to a picture and Student B name s the picture',
#   1],
#  ['Follow the example', 1],
#  ['Student A  points to', 1],
#  ['Student B   says  tree', 1],
#  ['Draw one of the above pictures and color it', 1],
#  ['Teacher  Good bye students', 1],
#  ['Students  Good bye teacher', 1],
#  ['Tree  Uniform  Vase  Wolf  X  ray  Yoke  Zebra     !', 1],
#  ['Look at the pictures  listen to your teacher s pronunciation and read the words after him her',
#   1],
#  ['                      F K    U I    T          !', 1],
#  ['Read the words under the above pictures', 1],
#  ['Student A points to a picture and student B reads the word', 1],
#  ['Follow the example', 1],
#  ['FM                      B                                    A', 1],
#  ['What is this?', 1],
#  ['x ray x  ray', 1],
#  ['Look at the pictures', 1],
#  ['Listen and read the sentences after your teacher..         V              !      F',
#   1],
#  ['I have a tree', 1],
#  ['He has a uniform', 1],
#  ['This is my tree', 1],
#  ['It is his unifom', 1],
#  ['She has a vase', 1],
#  ['This is her vase', 1],
#  ['You have an x ray', 1],
#  ['This is your x ray', 1],
#  ['He has a wolf', 1],
#  ['This is his wolf', 1],
#  ['They have a yoke', 1],
#  ['This is their yoke', 1],
#  ['She has a zebra', 1],
#  ['This is her zebra', 1],
#  ['Look at the above pictures and read the sentences', 1],
#  ['Write the sentences of part D in your notebooks', 1],
#  ['          AB              V    B    D', 1],
#  ['Zebra    Tree  Uniform  Vase  Wolf  X  ray  Yoke', 1],
#  ['            Q             Z        T', 1],
#  ['Look at the pictures  circle the correct word below', 1],
#  ['a Zebra aWolf', 1],
#  ['Look at the above pictures and read the words below them', 1],
#  ['Write the capital letters T  U  V  W  X  Y and Z in your notebooks', 1],
#  ['Follow the example', 1],
#  ['Write each letter T  U  V  W  X  Y and Z five times in your notebooks', 1],
#  ['    DE                         N                             F', 1],
#  ['Match each letter which begins the names of the picture', 1],
#  ['D               A          B      C        R', 1],
#  ['Write the first letter of the name of each picture s name in your notebooks',
#   1],
#  ['Match the pictures with the correct words', 1],
#  ['Write each letter T  U  V  W  X  Y and Z five times in your notebooks', 1],
#  ['Review of Units', 1],
#  ['!       !    N                         B', 1],
#  ['Good morning students', 1],
#  ['Good morning teacher', 1],
#  ['Please look at this picture', 1],
#  ['It is a cat  an ant', 1],
#  ['The teacher points to a picture and students name it', 1],
#  ['Look at the pictures and read their names with correct pronunciation', 1],
#  ['Match the pictures with the correct word', 1],
#  ['Read the above words with correct pronunciation', 1],
#  ['      T    R          C', 1],
#  ['Write the words of part C in your notebooks', 1],
#  ['          AB                   B   C', 1],
#  ['Draw your favorite picture and color it', 1],
#  ['Review of Units', 1],
#  ['!       !    N                         B', 1],
#  ['Please stand up Fatah', 1],
#  ['Name this picture', 1],
#  ['That is a moon', 1],
#  ['Thank you  Fatah', 1],
#  ['Please name this picture', 1],
#  ['That is a nest', 1],
#  ['Please sit down', 1],
#  ['Look at the pictures and name them', 1],
#  ['C.Look at the pictures and read their names with correct pronunciation', 1],
#  ['Match the pictures with the correct words', 1],
#  ['Write the words of part C in your notebook', 1],
#  ['AB                   B   C', 1],
#  ['            a                       carrot  turnip  radish  potato  tomato  cabbage      F!              b',
#   1],
#  ['How are you?', 1],
#  ['I am fine thank you', 1],
#  ['Do you like vegetables?', 1],
#  ['Yes  I do', 1],
#  ['What kind of vegetables do you like?', 1],
#  ['I like carrots and turnips', 1],
#  ['Look at the pictures of vegetables and repeat their names after your teacher',
#   1],
#  ['Look at the above pictures and name them', 1],
#  ['In pairs  One student shows a real vegetable or its picture and asks a question',
#   1],
#  ['Other students answer the question', 1],
#  ['What is this?', 1],
#  ['It is a potato', 1],
#  ['What is this?', 1],
#  ['It is a tomato', 1],
#  ['Draw a picture of a vegetable of part B and color it', 1],
#  ['           R          B           B   B', 1],
#  ['Teacher  Good bye students', 1],
#  ['Students  Good bye teacher', 1],
#  ['!         cabbage    carrot  turnip  radish  potato  tomato', 1],
#  ['Look at the pictures of vegetables and read the words after your teacher',
#   1],
#  ['Read the words below the above pictures', 1],
#  ['Look at these pictures and read the sentences after your teacher', 1],
#  ['                   !          B  d', 1],
#  ['This is a radish', 1],
#  ['Is this a radish?', 1],
#  ['Yes  it is', 1],
#  ['This is a carrot', 1],
#  ['Is this a carrot?', 1],
#  ['Yes  it is', 1],
#  ['This is a potato', 1],
#  ['Is this a ptato?', 1],
#  ['Yes  it is', 1],
#  ['This is a turnip', 1],
#  ['Is this a turnip?', 1],
#  ['Yes  it is', 1],
#  ['This is a tomato', 1],
#  ['This is a cabbage', 1],
#  ['Is this a tomato? Is this a cabbage?', 1],
#  ['Yes  it is', 1],
#  ['Yes  it is', 1],
#  ['Look at the above pictures and read the sentences below them', 1],
#  ['Read these sentences and Point to the correct pictures in part A of the lesson',
#   1],
#  ['                   Q            A           W', 1],
#  ['This is a carrot', 1],
#  ['This is a turnip', 1],
#  ['This is a radish', 1],
#  ['This is a potato', 1],
#  ['This is a cabbage', 1],
#  ['This is a tomato', 1],
#  ['Read these words and write them in your notebook', 1],
#  ['Carrot  turnip  radish  potato  tomato and cabbage', 1],
#  ['             B  d        B    V      B', 1],
#  ['Look at the pictures  circle the correct words below', 1],
#  ['radish carrot turnip', 1],
#  ['turnip radish carrot', 1],
#  ['carrot cabbage turnip potato radish tomato', 1],
#  ['tomato potato cabbage', 1],
#  ['potato cabbage tomato', 1],
#  ['Look at the above pictures and read the words', 1],
#  ['            !                                 below them', 1],
#  ['Write the name of each picture in your notebooks', 1],
#  ['Match the words with the pictures', 1],
#  ['turnip radish potato tomato cabbage', 1],
#  ['Change the following sentences to questions and answer them', 1],
#  ['     c  d                    V', 1],
#  ['This is a potato', 1],
#  ['Is this a potato?', 1],
#  ['Yes  it is', 1],
#  ['This is a carrot', 1],
#  ['This is a turnip', 1],
#  ['This is a radish', 1],
#  ['This is a cabbage', 1],
#  ['This is a tomato', 1],
#  ['Change the above sentences to questions and write them in your notebooks',
#   1],
#  ['           Y !     F     Q             W', 1],
#  ['!  V                   cherry  watermelon  pear          V', 1],
#  ['   !        peach    banana  melon  apricot', 1],
#  ['Do you like fruit?', 1],
#  ['Yes  we do', 1],
#  ['What fruits do you like?', 1],
#  ['We like cherries and apples', 1],
#  ['Look at the pictures of fruits and repeat their names after your teacher',
#   1],
#  ['Look at the above pictures and name them', 1],
#  ['Look at the pictures', 1],
#  ['Listen to your teacher and repeat the sentences after him her', 1],
#  ['                           K    U I          !   F', 1],
#  ['This is an apricot', 1],
#  ['This is a banana', 1],
#  ['This is a peach', 1],
#  ['This is a watermelon', 1],
#  ['This is a cherry', 1],
#  ['This is a melon', 1],
#  ['That is a pear', 1],
#  ['That is a peach', 1],
#  ['In pairs  Student A points to a picture and asks a question  and student B answers',
#   1],
#  ['Student A  What is this? Points to', 1],
#  ['Student B  That is a banana', 1],
#  ['Draw a picture of fruit from part B and color it', 1],
#  ['cherry  melon  apricot  peach  pear', 1],
#  ['!            V       T          banana    watermelon', 1],
#  ['Look at the pictures of fruit  and read their names after your teacher', 1],
#  ['Look at the above pictures and read their names', 1],
#  ['Look at these pictures', 1],
#  ['Listen and read the sentences after your teacher', 1],
#  ['Is that a banana?', 1],
#  ['No  it is not a banana', 1],
#  ['It is a watermelon', 1],
#  ['Is that a pear?', 1],
#  ['No  it is not a pear', 1],
#  ['It is a cherry', 1],
#  ['Is that a melon?', 1],
#  ['No  it is not a melon', 1],
#  ['It is a pear', 1],
#  ['Is that a peach?', 1],
#  ['No  it is not a peach', 1],
#  ['It is a melon', 1],
#  ['Is that a watermelon?', 1],
#  ['No  it is not a watermelon', 1],
#  ['It is a banana', 1],
#  ['Is that an apricot?', 1],
#  ['No  it is not a apricot', 1],
#  ['It is a peach', 1],
#  ['Look at the pictures from part B again and read the following sentences after your teacher',
#   1],
#  ['That is a pear', 1],
#  ['That is an apricot', 1],
#  ['That is a peach', 1],
#  ['That is a melon', 1],
#  ['That is a watermelon', 1],
#  ['That is a banana', 1],
#  ['That is a cherry', 1],
#  ['Read these words and write them in your notebooks', 1],
#  ['Pear  apricot  melon  cherry  grape  peach and banana', 1],
#  ['Look at the pictures', 1],
#  ['Circle and read the correct word below', 1],
#  ['a peach an apricot', 1],
#  ['an apricot a peach a pear', 1],
#  ['an apricot a pear a peach', 1],
#  ['a cherry a banana', 1],
#  ['a banana a melon', 1],
#  ['a melon awatermelon', 1],
#  ['a peach a watermelon', 1],
#  ['Look at the above pictures and read the words below them', 1],
#  ['Write the name of each picture in your notebooks', 1],
#  ['Match the words with the pictures', 1],
#  ['  H                       an apricot a pear a peach', 1],
#  ['a cherry a banana a melon', 1],
#  ['Answer the questions in short and long from', 1],
#  ['Follow the example', 1],
#  ['         !           .        B  d', 1],
#  ['Is that a pear?', 1],
#  ['No  it is not', 1],
#  ['It is a watermelon', 1],
#  ['Is that a banana?', 1],
#  ['Is that a peach?', 1],
#  ['Is that a watermelon?', 1],
#  ['Is that cherry?', 1],
#  ['Is that a melon?', 1],
#  ['Is that a pear?', 1],
#  ['Is that an apricot?', 1],
#  ['Use the words of part E in sentences and write them in your notebooks', 1],
#  ['This  That is a  an', 1],
#  ['What is your name?', 1],
#  ['My name is          ', 1],
#  ['What are you?', 1],
#  ['I am a student', 1],
#  ['Look at the family pictures and repeat the words after your teacher', 1],
#  ['Look at the family pictures and repeat the sentences after your teacher',
#   1],
#  ['This is Habib', 1],
#  ['Halima is his wife', 1],
#  ['This is Halima', 1],
#  ['Habib is her husband', 1],
#  ['This boy is Ali', 1],
#  ['His father is Habib', 1],
#  ['This girl is Hafiza', 1],
#  ['Her mother is Halima', 1],
#  ['Ali has a sister', 1],
#  ['Her name is Hafiza', 1],
#  ['Hafiza has a brother', 1],
#  ['His name is Ali', 1],
#  ['Habib and Halima have a son', 1],
#  ['His name is Ali', 1],
#  ['Halima and Habib have a daughter', 1],
#  ['Her name is Hafiza', 1],
#  ['Look at these pictures and repeat the sentences after your teacher', 1],
#  ['He is a boy She is a girl', 1],
#  ['He is a man She is a woman', 1],
#  ['Repeat these sentences after your teacher', 1],
#  ['This is a man', 1],
#  ['He is my father', 1],
#  ['This is a woman', 1],
#  ['She is my mother', 1],
#  ['This is a boy', 1],
#  ['He is my brother', 1],
#  ['This is a girl', 1],
#  ['She is my sister', 1],
#  ['This is a boy', 1],
#  ['He is my son', 1],
#  ['This is a girl', 1],
#  ['She is my daughter', 1],
#  ['This is a man', 1],
#  ['He is my husband', 1],
#  ['Read the sentences of part E and write them in your notebooks', 1],
#  ['Teacher  Good bye boys girls', 1],
#  ['Student  Good bye teacher', 1],
#  ['Repeat these words after your teacher the words are singular and plural',
#   1],
#  ['A  boy girl family', 1],
#  ['B  boys girls families', 1],
#  ['A  man woman child', 1],
#  ['men women children', 1],
#  ['Repeat these sentences after your teacher', 1],
#  ['This is a boy', 1],
#  ['These are boys', 1],
#  ['This is a girl', 1],
#  ['These are girls', 1],
#  ['This is a man', 1],
#  ['These are men', 1],
#  ['This is a woman', 1],
#  ['These are women', 1],
#  ['In pairs  Student A reads one of the above singular sentences  student B reads its plural form',
#   1],
#  ['Student A  reads  This is a boy', 1],
#  ['Student B  reads  These are boys', 1],
#  ['Note  All students take turns', 1],
#  ['Write the words of part A in your notebooks', 1],
#  ['  N          woman    boy  girl man', 1],
#  ['Please answer this question', 1],
#  ['What is the plural for boy?', 1],
#  ['The plural for boy is boys', 1],
#  ['What is the plural for girl?', 1],
#  ['The plural for girl is girls', 1],
#  ['Match singular sentences with plural', 1],
#  ['Follow the example', 1],
#  ['This boy is a student', 1],
#  ['They are men', 1],
#  ['That boy is a child', 1],
#  ['They are women', 1],
#  ['This girl is a student', 1],
#  ['They are my brothers', 1],
#  ['That girl is a child', 1],
#  ['These boys are students', 1],
#  ['He is a man', 1],
#  ['These boys are children', 1],
#  ['She is a woman', 1],
#  ['These girls are students', 1],
#  ['He is my brother', 1],
#  ['Those girls are children', 1],
#  ['This woman is a teacher', 1],
#  ['These women are teachers', 1],
#  ['Match the words with the pictures', 1],
#  ['D.Change these words to plural  read and write them', 1],
#  ['E.Change these sentences to their singular form', 1],
#  ['These women are teachers', 1],
#  ['This woman is a teacher', 1],
#  ['They are my brothers', 1],
#  ['Those girls are students', 1],
#  ['Those girls are children', 1],
#  ['Those boys are students', 1],
#  ['They are men', 1],
#  ['They are women', 1],
#  ['In pairs  Student A says a singular word or a sentence  student B changes it to plural',
#   1],
#  ['C         B           V                               A', 1],
#  ['R Q i V', 1],
#  ['Student A   says  woman', 1],
#  ['Student B   says  women', 1],
#  ['Student A  He is a boy', 1],
#  ['Student B  They are boys', 1],
#  ['Write the plural form of nouns in part  C  in your notebooks.Follow the example',
#   1],
#  ['Example  Teacher   Teachers', 1],
#  ['face   head  mouth  lips  ear  eye  nose  neck', 1],
#  ['How are you?', 1],
#  ['We are fine  thank you', 1],
#  ['How are you?', 1],
#  ['I am fine  thank you', 1],
#  ['Look at these pictures and repeat their names after your teacher', 1],
#  ['Look at the above pictures and name each of them', 1],
#  ['In pairs  Student A points to a part of his her body and asks a question Student B answers',
#   1],
#  ['Student A  What is this?', 1],
#  ['Student B  That is your  ', 1],
#  ['Look at the picture of the boy  listen and repeat the sentences after your teacher',
#   1],
#  ['This is a boy', 1],
#  ['This is his head', 1],
#  ['This is his mouth', 1],
#  ['These are his lips', 1],
#  ['These are his teeth', 1],
#  ['This is his neck', 1],
#  ['This is his nose', 1],
#  ['These are his ears', 1],
#  ['These are his eyes', 1],
#  ['This is his face', 1],
#  ['face nose mouth', 1],
#  ['Point to the parts of your body and make sentences', 1],
#  ['I am Saber', 1],
#  ['This is my head', 1],
#  ['These are my eyes', 1],
#  ['Note  All students take turns', 1],
#  ['In pairs  Student A points to a part of his her body and asks a question',
#   1],
#  ['Student B answers the question', 1],
#  ['Follow the example', 1],
#  ['points to his head', 1],
#  ['What is this?', 1],
#  ['That is your head', 1],
#  ['points to his eyes', 1],
#  ['What are these?', 1],
#  ['Those are your eyes', 1],
#  ['Write the names of parts of your body in your notebook', 1],
#  ['I will see you tomorrow students', 1],
#  ['We will see you tomorrow teacher', 1],
#  ['Look at the picture and read the words after your', 1],
#  ['Look at the above pictures and read the words below them', 1],
#  ['Look at the picture and read these sentences', 1],
#  ['That is a girl', 1],
#  ['That is her head', 1],
#  ['That is her face', 1],
#  ['That is her nose', 1],
#  ['That is her mouth', 1],
#  ['That is her neck', 1],
#  ['Those are her ears', 1],
#  ['These are her eyes', 1],
#  ['These are her lips', 1],
#  ['These are her theeth', 1],
#  ['The sex are her teeth', 1],
#  ['This is her arm', 1],
#  ['Point to the parts of your body and read these sentences', 1],
#  ['This is my ear', 1],
#  ['These are my ears', 1],
#  ['This is my tooth', 1],
#  ['These are my teeth', 1],
#  ['This is my lip', 1],
#  ['These are my lips', 1],
#  ['This is my eye', 1],
#  ['These are my eyes', 1],
#  ['In pairs  Student A points to a part of his her body and asks a question  student B answers the question',
#   1],
#  ['Student A   asks  What is this?', 1],
#  ['Student B   answers  That is your face', 1],
#  ['Note  All students take turns', 1],
#  ['Change these words in English in your notebook', 1],
#  ['Match the words with the pictures', 1],
#  ['Match the singular words with their plurals', 1],
#  ['eye ear tooth lip finger', 1],
#  ['lips eyes ears teeth feet', 1],
#  ['Circle the correct word for each picture and read the word', 1],
#  ['eye foot lip', 1],
#  ['teeth neck nose', 1],
#  ['mouth nose neck', 1],
#  ['mouth face ear', 1],
#  ['nose teeth ear', 1],
#  ['eye nose head', 1],
#  ['lips neck head', 1],
#  ['nose face lips', 1],
#  ['mouth neck teeth', 1],
#  ['Write the plural forms of the following words in your notebooks', 1],
#  ['Example  lip lips face eye', 1],
#  ['Review of Units', 1],
#  ['How are you this morning afternoon?', 1],
#  ['We are fine  thank you', 1],
#  ['How are you teacher?', 1],
#  ['I am fine  thank you', 1],
#  ['Look at these pictures and name them', 1],
#  ['Look at these pictures and read their names', 1],
#  ['Read these Senterces and match them with their pictures', 1],
#  ['That is a pear', 1],
#  ['That is a peach', 1],
#  ['That is a banana', 1],
#  ['That is a melon', 1],
#  ['That is a watermelon', 1],
#  ['That is a carrot', 1],
#  ['That is a turnip', 1],
#  ['That is a tomato', 1],
#  ['That is a potato', 1],
#  ['That is a radish', 1],
#  ['Look at the pictures  answer the questions like the given example', 1],
#  ['Is that a banana?', 1],
#  ['No  it is not a banana', 1],
#  ['It is a water melon', 1],
#  ['Is that a pear?', 1],
#  ['Is that a melon?', 1],
#  ['Is that a peach?', 1],
#  ['Is that a watermelon?', 1],
#  ['Write the words of part C in your notebook and draw    of your favorite pictures',
#   1],
#  ['Color the pictures', 1],
#  ['Review of Units', 1],
#  ['A woman has a child', 1],
#  ['Her child is a girl', 1],
#  ['What do we call the woman s child?', 1],
#  ['The woman s child is her daughter', 1],
#  ['Yes  Now this woman has another child', 1],
#  ['He is a boy', 1],
#  ['What do we call this child', 1],
#  ['This child is the woman s son', 1],
#  ['Look at the family diagram and read the words related to each picture', 1],
#  ['Read these words and sentences with correct pronunciation', 1],
#  ['She  He  They  I  You  We', 1],
#  ['She is his wife', 1],
#  ['He is her husband', 1],
#  ['They have a daughter and a son', 1],
#  ['I have a brother', 1],
#  ['You are my sister', 1],
#  ['We are a family', 1],
#  ['It is our house', 1],
#  ['It is your house', 1],
#  ['Look at these pictures and name them', 1],
#  ['E.Look at the pictures and read their names with the correct pronunciation',
#   1],
#  ['F.Read the words and match them with their pictures', 1],
#  ['  H                                   face eye', 1],
#  ['head  lips boy', 1],
#  ['man teeth nose woman', 1],
#  ['girl ear mouth neck', 1],
#  ['Look at the pictures  read the sentences and check', 1],
#  ['the correct sentence', 1],
#  ['This is my hand', 1],
#  ['This is my eye', 1],
#  ['This is my nose', 1],
#  ['This is your nose', 1],
#  ['This is your ear', 1],
#  ['This is your lip', 1],
#  ['That is his head', 1],
#  ['That is his neck', 1],
#  ['That is his nose', 1],
#  ['It is her ear', 1],
#  ['It is her nose', 1],
#  ['It is her arm', 1],
#  ['Those are her ears', 1],
#  ['Those are her eyes', 1],
#  ['Those are her lips', 1],
#  ['Write the words of part E in your notebook', 1],
#  ['of your favorite pictures and color them', 1],
#  ['Father r   Finger', 1],
#  ['I have to eat the cherry', 1],
#  ['Fish k B Foot  feet', 1],
#  ['S  P His', 1],
#  ['Onion e  K w  Orange', 1],
#  ['Pear k      Pen', 1],
#  ['Not  is not', 1],
#  ['N  Shopkeeper b a  Sister', 1],
#  ['C U    Son', 1],
#  ['G        I Sun', 1],
#  ['V Tailor b    Teacher', 1],
#  ['These v   They', 1],
#  ['Good morning students', 1],
#  ['Students  Good morning teacher', 1],
#  ['Teacher  Please look at this picture', 1],
#  ['Students  It is a cat  an ant', 1],
#  ['Teacher  Thank you', 1]]

# %%
# read the grade ten file
grade_ten_sentence = read_and_clean("../data/gradesixis.txt")

# %%
label = 1
new_examples2 = []
for i in grade_ten_sentence:  
    if len(word_tokenize(i))>2:
        new_examples2 = new_examples2 + [[i, label]]

# %%
# new_examples2 = new_examples2[2:] # slicing to avoid overfitting due to data imbalance

# %%
new_examples2
# Out:
# [['English for the Islamic State', 10],
#  ['Book Six   First Course', 10],
#  ['Tariq bin Ziyad', 10],
#  ['How can you remember', 10],
#  ['Smoking is prohibited', 10],
#  ['Listening   Reading   Speaking', 10],
#  ['Listening   Reading   Speaking', 10],
#  ['Future simple   be', 10],
#  ['Listening   Speaking   Reading going to   Present', 10],
#  ['Writing continuous for future', 10],
#  ['Listening   Reading   Writing', 10],
#  ['Adjective  ing   ed', 10],
#  ['The Glorious Quran', 10],
#  ['The Open University', 10],
#  ['Fluency    Before you start', 10],
#  ['When someone asks you   Can you help me?  What do usually say if you agree?',
#   10],
#  ['Asking people to do things', 10],
#  ['Look at the dialogues below', 10],
#  ['Do you find any differences between As and Bs speakers?', 10],
#  ['A boy is carrying heavy bags', 10],
#  ['A  Can you help me  brother please?', 10],
#  ['A man needs someone to close the car s door', 10],
#  ['A  I wonder if you could close the door', 10],
#  ['Now look at the box below and check your answers', 10],
#  ['The first speakers   As   express situations to ask someone to do something  whereas the second speakers   Bs   express the agreement to do something',
#   10],
#  ['Study the rules below of asking someone to do something and their response',
#   10],
#  ['Can you   please?  the agreement for it is   certainly', 10],
#  ['I wonder if you could   ', 10],
#  ['the agreement is    Sure', 10],
#  ['Would you mind   v  ing?   the agreement is    Not at all', 10],
#  ['Could you   infinitive  ', 10],
#  ['please?  the agreement is   Of course', 10],
#  ['Work in pairs', 10],
#  ['Ask someone to do something and say the response', 10],
#  ['A  Can you open that window  please?', 10],
#  ['A  I wonder if you could open that window  please', 10],
#  ['B  No  of course not', 10],
#  ['A  Would you mind opening that window  please?', 10],
#  ['B  Not at all', 10],
#  ['A  Could you open that window  please?', 10],
#  ['B  Yes  of course', 10],
#  ['Now make similar situations', 10],
#  ['Ask someone to repair your broken car b', 10],
#  ['Ask someone to explain the meaning of a verse in the Quran', 10],
#  ['Ask someone to carry a sofa', 10],
#  ['Ask someone to clean my gun', 10],
#  ['Write similar dialogue as in  ask about the following situations  a', 10],
#  ['Ask someone to give you a lift b', 10],
#  ['Ask someone to explain the meaning of one of Mohammad s hadeeth', 10],
#  ['Ask someone to deliver the box to his neighbour', 10],
#  ['Before you start', 10],
#  ['What do you do when you have a flu?', 10],
#  ['Do you prefer herbal to chemical medicine?', 10],
#  ['Look at the pictures and match them with the health problems below  e.g',
#   10],
#  ['I have a headache', 10],
#  ['I burnt my hand on the heater', 10],
#  ['I need to sit down', 10],
#  ['My arms hurt', 10],
#  ['I lifted heavy boxes', 10],
#  ['I have muscles ache', 10],
#  ['I have a stomach ache', 10],
#  ['I have a sore throat', 10],
#  ['I have eaten too much  I feel sick', 10],
#  ['I feel dizzy', 10],
#  ['I can t stop sneezing  I think I ve caught a cold', 10],
#  ['I have a temperature  diarrhea and fever', 10],
#  ['Which health problems don t you find in the pictures?', 10],
#  ['What do you say to those people who are suffering from health problems?',
#   10],
#  ['A  I have a headache', 10],
#  ['B  You should take a painkiller', 10],
#  ['Now look at the problems in  and do similar dialogues', 10],
#  ['Look at the chart below and suggest the treatment for each diseases  make use of the treatment list below',
#   10],
#  ['Diseases the flu  influenza  a cold food poisoning', 10],
#  ['Symptoms cold  sneeze  headache etc', 10],
#  ['cough  fever  pain in muscles etc', 10],
#  ['vomit  headache  temperature etc', 10],
#  ['rest in bed', 10],
#  ['take a decongestant', 10],
#  ['drink herbal tea', 10],
#  ['eat very little food', 10],
#  ['eat fruit and vegetables', 10],
#  ['Add other diseases to the chart ', 10],
#  ['Have you ever had a medical problem? In no more than  words write a short story about that',
#   10],
#  ['Before you start', 10],
#  ['Have you ever had a food poisoning? What did you do?', 10],
#  ['Read this paragraph and fill in the blanks with the diseases from the box',
#   10],
#  ['If you have a stomach ache  nausea  and diarrhea  you may have', 10],
#  ['Rest in bed  drink herbal tea  and don t eat very much', 10],
#  ['If the symptoms continue  see your doctor', 10],
#  ['You need some antibiotics', 10],
#  ['The symptoms of                are often nausea  fever  and abdominal pain  especially on the right side',
#   10],
#  ['See a doctor immediately  because you may need surgery!              is a virus  so antibiotics won t help',
#   10],
#  ['The symptoms are aching muscles  headache  fever  and sometimes sneezing',
#   10],
#  ['Rest in bed  drink fluids  and take aspirin.             is similar to influenza  but usually less severe',
#   10],
#  ['The symptoms are usually sneezing  coughing  headache  and sometimes fever',
#   10],
#  ['If necessary  take a decongestant', 10],
#  ['is a type of headache  but there are usually less severe', 10],
#  ['The symptoms are usually other symptoms', 10],
#  ['You may have nausea and vision problems  and you may be extremely sensitive to light and noise',
#   10],
#  ['If the problem is very severe or frequent  you may need to see a doctor to get some medicine',
#   10],
#  ['Grammar builder   must  may  might  can t  for deductions', 10],
#  ['Note  For deduction  can t and must are opposites  e.g', 10],
#  ['It can t be appendicitis  so it must be food poisoning', 10],
#  ['Say the short dialogue and then answer the questions', 10],
#  ['A  I have a stomach ache', 10],
#  ['I might have appendicitis', 10],
#  ['B  You can t have appendicitis because you don t have a fever.it may be something you ate',
#   10],
#  ['A  If I m not better tomorrow  then it must be appendicitis', 10],
#  ['Which of the verbs  might  can t  may and must in the dialogue above expresses a possibility?',
#   10],
#  ['Which one expresses a strong positive probability?', 10],
#  ['Which one expresses a strong negative probability?', 10],
#  ['Complete these two conversations using may  might  must  or can t', 10],
#  ['A  Who is she? She talks like a doctor', 10],
#  ['But she            be a doctorshe s too young', 10],
#  ['B  She           be a medical student obviously', 10],
#  ['A  Not necessarily', 10],
#  ['She          be a nurse  or the daughter of a doctor', 10],
#  ['A  I can t sleep at night', 10],
#  ['It          be the coffee I m drinking  or possibly', 10],
#  ['I m worrying about work', 10],
#  ['B  It          be the worry  no question about it', 10],
#  ['How much coffee do you drink?', 10],
#  ['A  Two or three cups a day', 10],
#  ['That s nothing', 10],
#  ['It          be that', 10],
#  ['The Open University', 10],
#  ['Before you start', 10],
#  ['Is it possible to get Islamic Khlafa again?', 10],
#  ['How do Muslims feel towards Khil fah?', 10],
#  ['Read the text carefully and check your answers in', 10],
#  ['he revival of Khil fahh  which was announced by the spokesman for Islamic State  Sheikh Abu Mohammed Al Adnani on the first of',
#   10],
#  ['Ramadan  H  surprised the true Muslims and shocked the nonMuslims all over the world',
#   10],
#  ['eal announcement of Khil fah surprised the true Muslims positively and made the people inside the Waliyats of Islamic State feel pleased and proud whereas the Muslims outside the Islamic',
#   10],
#  ['State have become eager to immigrate to it', 10],
#  ['Because they have been under the rule of tawaghits since the collapse of Othmani Khil fah in',
#   10],
#  ['Now it is time for Real Islam  Sharia and Sunni  to take the ruling of',
#   10],
#  ['Islamic State over', 10],
#  ['The revival of Khil fah means we are walking towards the right path of satisfying Allah who orders us to leave all sorts of governing people except applying Sharia and Sunni',
#   10],
#  ['That is the true way to get happiness in both lives  here in the world and in the Day of',
#   10],
#  ['n the other side  the announcement of Khil fah shocked the nonMuslims  such as jews  Christians  rafiddah  other sorts of kufar and tawaghits negatively',
#   10],
#  ['All together announced their coalition publicly to fight the Islamic State',
#   10],
#  ['The big question is  WHY?', 10],
#  ['Because all of them deeply know that the path of applying Khil fah means the end of them altogether sooner or later',
#   10],
#  ['inally  it can be said that the revival of Khil fah amazed true', 10],
#  ['Muslims who were inside or outside the Islamic State whereas it upset and troubled the non Muslims all over the world',
#   10],
#  ['Read the text again and answer the questions below', 10],
#  ['Who announced the revival of Khil fah? b', 10],
#  ['How was the reaction of the announcement of Khil fah on both', 10],
#  ['Muslims and non Muslims? c', 10],
#  ['What does the revival of Khil fah mean? d', 10],
#  ['Do you think that applying Khil fah is the right way in life? e', 10],
#  ['Why are all the non Muslims and tawgheed afraid of the announcement of Khil fah?',
#   10],
#  ['Match the words with their meaning', 10],
#  ['an unexpected event  or the feeling caused by something unexpected happening',
#   10],
#  ['to fall down suddenly because of pressure or having no strength or support',
#   10],
#  ['when something becomes more active or popular again', 10],
#  ['wanting very much to do or have something  especially something interesting or enjoyable',
#   10],
#  ['a sudden  unexpected and usually unpleasant event or experience', 10],
#  ['Summarize the text of  The Announcement of Khil fah  in no more than', 10],
#  ['Fill in the blanks with words taken from the box  independent disabled a',
#   10],
#  ['of the students come from the country side', 10],
#  ['He was          in the accident', 10],
#  ['It is just a short                  from here to the university', 10],
#  ['A lot of               workers work in their factory', 10],
#  ['All lecturers are                  ', 10],
#  ['He left school with two              ', 10],
#  ['We wanted to create an           learner', 10],
#  ['Make a conversation asking someone to do something and show the agreement in these situations',
#   10],
#  ['ask someone to repair your bike b', 10],
#  ['ask someone to explain the meaning of one of the Messenger s hadeith  peace be upon him  c',
#   10],
#  ['ask someone to carry a heavy box d', 10],
#  ['ask someone to show you where to rent a car', 10],
#  ['Guess the illness! Make use of the words in the box below', 10],
#  ['food poisoning cold appendicitis', 10],
#  ['A  I have a temperature  diarrhea and fever', 10],
#  ['B  I think you ve got a              ', 10],
#  ['A  My stomach is aching too much', 10],
#  ['B  I think you ve got a             ', 10],
#  ['A  I can t stop sneezing  and I have a sore throat', 10],
#  ['B  I think you ve got a              ', 10],
#  ['Complete these two conversations using may  may not  might  might not must  or can t',
#   10],
#  ['You re expecting Ahmed to ring', 10],
#  ['The phone rings', 10],
#  ['There is a knock at the door', 10],
#  ['Your mother says it might be Ali  but you know Ali is on holiday', 10],
#  ['It             be Ali', 10],
#  ['Your brother is looking for his bag', 10],
#  ['You think it s possible that it s in the living room', 10],
#  ['It               be in the living room', 10],
#  ['They re speaking Arabic', 10],
#  ['They              be foreigners', 10],
#  ['Their bed room lights are off', 10],
#  ['They             be asleep', 10],
#  ['It s very cold here', 10],
#  ['The heating                be on', 10],
#  ['She s passed her driving test', 10],
#  ['She              be happy', 10],
#  ['fluency  n.  stomach ache  n.  sneeze  n.  painkiller  n.  symptoms  n.  poisoning  n.  appendicitis  n.  migraine  n.  decongestant  n.  nausea  n.  abdominal  adj.  qualifications  n.  impaired  adj.  respiratory  n.  circulation  n.  digestive  n.  nervous  adj.  sensory  adj.  detect  v.  sore throat  n.  foreigner  n',
#   10],
#  ['Reciting the Quran', 10],
#  ['Reciting the Quran', 10],
#  ['Importance of Second  Foreign', 10],
#  ['Fluency    Before you start', 10],
#  ['Don t mention it', 10],
#  ['When do you say a sentence like that?', 10],
#  ['The dialogue below is in wrong order', 10],
#  ['First  number it in the right order and then work in pairs', 10],
#  ['Big thank for you Mum a', 10],
#  ['Shopper  Thanks a lot', 10],
#  ['Shop assistant  How about Sahih Al Bukhari? c', 10],
#  ['Shop assistant  Can I help you  brother? Are you looking for something in particular?  d',
#   10],
#  ['Shopper  That s great idea', 10],
#  ['Thanks  can you wrap it for me?', 10],
#  ['Shop assistant  Don t mention it', 10],
#  ['Shopper  Yes  I am looking for a gift for my mother', 10],
#  ['I wonder if you could give me some ideas', 10],
#  ['Shop assistant  Well  what kind of things does she like? h', 10],
#  ['Shopper  She likes reading Islamic books', 10],
#  ['Shop assistant  I sure can', 10],
#  ['Check your answers in the box below', 10],
#  ['Turn it upside down', 10],
#  ['C  f  g  h  b  d  I  a  e', 10],
#  ['Check your answer in ', 10],
#  ['Answer the questions below', 10],
#  ['Is the previous dialogue formal or informal?', 10],
#  ['When do you say thank you? Tick the situation s  below', 10],
#  ['When you buy something in a store', 10],
#  ['When you get change in a shop', 10],
#  ['When you borrow your friend s pen', 10],
#  ['When your friend gives you back your book', 10],
#  ['When a waiter brings your food', 10],
#  ['When a waiter clears the table', 10],
#  ['When you get off the bus', 10],
#  ['When someone holds a door open for you', 10],
#  ['What does our Messenger say about thanking people?', 10],
#  ['If you don t say thank you  is there anything else you say? Does it vary according to the speaker s status or age?',
#   10],
#  ['There are many means of expressing  thanking  such as  a', 10],
#  ['Jazaka Allahu Khayrn', 10],
#  ['Islamic expression  b', 10],
#  ['Barak Allahu Feekum', 10],
#  ['Islamic Expression  c', 10],
#  ['Thanks a lot', 10],
#  ['That s very good of you', 10],
#  ['I appreciate it', 10],
#  ['Responding to thank', 10],
#  ['To respond to  thanking  we usually say  a', 10],
#  ['Jazakum Allah Aljanah', 10],
#  ['Islamic expression  b', 10],
#  ['Wafeekum Baraka Allah', 10],
#  ['Islamic expression  c', 10],
#  ['Don t mention it', 10],
#  ['All my pleasure', 10],
#  ['Assignment  Show how to thank someone in the situations below and the responses',
#   10],
#  ['A  Thank you very much for your help', 10],
#  ['B  Not at all', 10],
#  ['Now make use of the forms of thanking and response you learn in this lesson',
#   10],
#  ['Answer the question below', 10],
#  ['What do you say when  a', 10],
#  ['a shop assistant gives you your things you buy? b', 10],
#  ['you borrow a pen from your friend', 10],
#  ['your friend gets your book back? d', 10],
#  ['a waiter brings your food e', 10],
#  ['someone holds a door open for you?', 10],
#  ['Before you start', 10],
#  ['Do you want to go further on with your studies?', 10],
#  ['What are you going to study at university  if you go there?', 10],
#  ['Match the noun or the noun phrase to each of the following verbs  a', 10],
#  ['apply to attend enrol at obtain take study', 10],
#  ['There are five stages in the process of writing a paragraph', 10],
#  ['What does each stage mean? Study the details of each of five stages of writing a paragraph',
#   10],
#  ['Who is it for?', 10],
#  ['What is it about?', 10],
#  ['Where can I find more information?', 10],
#  ['What is the writing plan?', 10],
#  ['How many paragraphs do I need?', 10],
#  ['What information should be in each paragraph?', 10],
#  ['The first draft   writing for the writer himself', 10],
#  ['Does the first draft make sense?', 10],
#  ['Have I made any mistakes in spelling  grammar or word order?', 10],
#  ['Correct any mistakes', 10],
#  ['The final version of the paragraph   writing for the reader', 10],
#  ['Respond to the five stages of writing above and write a paragraph about joining a college you would like to',
#   10],
#  ['Write two forms of a paragraph  draft writing  write  and final writing',
#   10],
#  ['rewrite  about a topic you choose', 10],
#  ['Make use of stages of writing', 10],
#  ['Reciting the Quran', 10],
#  ['Before you start', 10],
#  ['Answer the questions below', 10],
#  ['What is the opposite of interesting? b', 10],
#  ['Is there a difference between', 10],
#  ['boring  and  bored ?', 10],
#  ['Read the text and write the adjectives which end with  ing  or', 10],
#  ['ed  in the chart below', 10],
#  ['Add similar adjectives from your own?', 10],
#  ['Every Muslim is interested in reciting the Quran', 10],
#  ['However  it is frustrating to find some people who are still away from reciting the',
#   10],
#  ['Therefore  we advise such people not to be frustrated because if they start reciting it  they ll find it very interesting',
#   10],
#  ['They ll never get bored with it', 10],
#  ['The best way of not being bored is to deeply recite the Quran now and then  because it makes you feel satisfied  convinced and relaxed',
#   10],
#  ['Read the text again and check your answers in ', 10],
#  ['Adjective ending   ing  or   ed', 10],
#  ['Adjectives ending  ing describe something that we are reacting to  outside us',
#   10],
#  ['In other word  they are used to describe the things or people that cause the feelings  e.g',
#   10],
#  ['My work was tiring', 10],
#  ['Adjectives ending   ed  describe our feelings and reactions', 10],
#  ['In other words  they talk about how we feel  e.g', 10],
#  ['It made me tired', 10],
#  ['Underline the correct word', 10],
#  ['She is not very  interested   interesting  in fashion', 10],
#  ['She prefers books', 10],
#  ['I saw a very  excited   exciting  IS DVD last night', 10],
#  ['This book is very  bored   boring', 10],
#  ['I fall asleep whenever I try to read it', 10],
#  ['We were very  frightened   frightening  when our car broke down in the desert',
#   10],
#  ['He is a very  interested   interesting  person', 10],
#  ['He has lots of great stories to tell', 10],
#  ['Choose the right adjective', 10],
#  ['That little boy always wants more to eat', 10],
#  ['He s never             ', 10],
#  ['satisfying   satisfied  b', 10],
#  ['The assistant manager lost his job because everybody was', 10],
#  ['by his lies', 10],
#  ['disgusting   disgusted  c', 10],
#  ['When we got back to town  we saw the            damage done by the crusade plane bombing',
#   10],
#  ['worrying   worried  d', 10],
#  ['The last IS DVDs were              exciting   excited  Everyone was really',
#   10],
#  ['exciting   excited  Everyone was', 10],
#  ['at the speed of those fighters in the battle', 10],
#  ['Importance of Second   Foreign Language', 10],
#  ['Before you start', 10],
#  ['How many languages do you know?', 10],
#  ['What is the mental benefit of learning a foreign language?', 10],
#  ['Read the article and answer the questions on the next page', 10],
#  ['A recent study says that speaking two languages can help old people to keep mentally active',
#   10],
#  ['Young people learning a second or a foreign language can keep them mentally active when they get older',
#   10],
#  ['A group of researchers at one university carried out some experiments', 10],
#  ['Then they asked  people between the ages of  and  to do them', 10],
#  ['From the tests  the researchers found out that people who can speak two languages are good at thinking fast',
#   10],
#  ['The group carried out different experiments and concluded that being bilingual can help old people to think quickly',
#   10],
#  ['The group thinks that speaking different languages is very good for you and your brain',
#   10],
#  ['Half of the people who did the tests came from', 10],
#  ['Indonesia and only spoke their mother tongue', 10],
#  ['The other half came from', 10],
#  ['India and could speak English and a language called Tamil', 10],
#  ['The group tested the two halves in vocabulary skills and mathematics ability',
#   10],
#  ['They checked how fast the people did the activity', 10],
#  ['The ones who spoke two languages did the exercises quickly and well', 10],
#  ['The people who spoke only one language weren t as good', 10],
#  ['Learning a second or foreign language when we are young can help us when we are old',
#   10],
#  ['Leaning in general can certainly help the brain to stay active', 10],
#  ['What did the study show? b', 10],
#  ['Who did the test? c', 10],
#  ['Are people who can speak two languages good and fast in different activities? d',
#   10],
#  ['Where are the two halves from? e', 10],
#  ['What did the researchers conclude from doing different experiments? f', 10],
#  ['What is the effect of learning on the brain?', 10],
#  ['Match the words in list A with their meaning in list B', 10],
#  ['List A discover bilingual mental investigate active', 10],
#  ['always ready to do things', 10],
#  ['relating to the mind', 10],
#  ['find out something', 10],
#  ['able to speak two languages', 10],
#  ['Fill in the blanks with words from the box  make the necessary changes',
#   10],
#  ['active carry out', 10],
#  ['Keep reciting and memorizing the Quran help your', 10],
#  ['to be active', 10],
#  ['Scientists have             many experiments on two types of animals', 10],
#  ['Her physical and           health had got better', 10],
#  ['Don t shake hands with a            woman', 10],
#  ['Muslims always take a more          role in life', 10],
#  ['In no more than  words summarize the article  Importance of Foreign', 10],
#  ['Language    mention the most important points', 10],
#  ['Fill in the blanks with words or phrases taken from the box below', 10],
#  ['bilingual experiments active', 10],
#  ['My grandfather is very                for his age', 10],
#  ['I have come to the                that he is very brilliant', 10],
#  ['They did               on rats to test the drug', 10],
#  ['I have got a                dictionary', 10],
#  ['Safety procedures at the airport are currently under             ', 10],
#  ['They demanded that Ali should bring a                 photo', 10],
#  ['Fill in the blanks with adjectives which end with   ed  or', 10],
#  ['It was a very            day', 10],
#  ['This programme is very', 10],
#  ['I saw a very             sight last year', 10],
#  ['Yasser was             when he was asked to address a word', 10],
#  ['There are many ways to express thanks', 10],
#  ['Respond to the following situations as Muslims and English people', 10],
#  ['Thank you very much for your great help', 10],
#  ['Thanks a lot for your cooperation', 10],
#  ['Jazaka Allahu Khayrn', 10],
#  ['Barak Allah Feekum', 10],
#  ['That s very good of you', 10],
#  ['I appreciate it', 10],
#  ['Write in no more than  words about the importance of foreign   second language',
#   10],
#  ['Follow the steps of writing  Think  Organize', 10],
#  ['Write  Edit Rewrite', 10],
#  ['Make use of the Writing Stages in lesson  to write a paragraph', 10],
#  ['Vocabulary attend  v', 10],
#  ['Tariq bin Ziyad', 10],
#  ['Latitudes and Longitudes', 10],
#  ['From Al Rraqqa to Nigeria', 10],
#  ['Tariq bin Ziyad', 10],
#  ['Fluency     Make Yourself at Home', 10],
#  ['Before you start', 10],
#  ['What do you do if you receive a card like this?', 10],
#  ['Would you like sending a card like this?', 10],
#  ['Abo Omar invites you for dinner at AlSalam Rest', 10],
#  ['At   next Friday', 10],
#  ['Making  accepting  and refusing invitations', 10],
#  ['Look at this dialogue and decide where the sentences in the box go', 10],
#  ['Then we could go on to your parents', 10],
#  ['At about eight o clock', 10],
#  ['That s a great idea!', 10],
#  ['Would you like to go?', 10],
#  ['We re already going out that evening', 10],
#  ['Amar  I just got this invitation from Ali and Ahmed', 10],
#  ['They re having a barbecue next weekend with some friends', 10],
#  ['Salman  Oh  I m sorry  but we can t', 10],
#  ['We re going to my parents for dinner', 10],
#  ['Amar  Oh  of course! What time do your parents expect us to be there?', 10],
#  ['Amar  Why don t we go and see Ali and Salman on our way just for an hour?                             ',
#   10],
#  ['Work in pairs and act out the dialogue', 10],
#  ['Discuss your answers to the following questions', 10],
#  ['In your Wilaya  are people hospitable to brothers in Islam at their homes? b',
#   10],
#  ['How does the host make the invitation  by letter  by phone  or in person? c',
#   10],
#  ['How do you reply to the invitation? Do you have to reply immediately? d',
#   10],
#  ['If not  how long can you wait before replying? e', 10],
#  ['Can you take your friend or your partner? f', 10],
#  ['What time is usually a dinner invitation? g', 10],
#  ['What time should you arrive?', 10],
#  ['Look at this formal invitation and answer the questions', 10],
#  ['Professor Omar invites', 10],
#  ['Khalid Azzam and guests to dinner at home on Friday  at    p.m', 10],
#  ['Who is the invitation for?', 10],
#  ['What is it for?', 10],
#  ['What time should the guests arrive?', 10],
#  ['What should they do when they know if they can go?', 10],
#  ['Study the function s table', 10],
#  ['Would you like to have dinner with us?', 10],
#  ['How about having a cup of tea with me?', 10],
#  ['Let s go out for a meal', 10],
#  ['Are you free for lunch on Friday?', 10],
#  ['Why don t you go for a picnic on Sunday?', 10],
#  ['I d love to', 10],
#  ['Thank you that would be great!', 10],
#  ['That s a great idea', 10],
#  ['I am very pleased to accept your kind invitation', 10],
#  ['I m sorry  but I m going out that evening', 10],
#  ['No  I can t make it', 10],
#  ['I regret that I am unable to accept as I ve got another engagement', 10],
#  ['Make two invitations and then accept the first one and refuse the second one',
#   10],
#  ['Latitudes and Longitudes', 10],
#  ['Before you start', 10],
#  ['What is this figure about?', 10],
#  ['Read the text below and label the figure with words from the text', 10],
#  ['Where is Raqqa city? Where is Mosul city? Where is Sirte city? We can locate any city on Earth by using latitudes and longitudes lines',
#   10],
#  ['Using these lines can give us the position of any place on the Earth', 10],
#  ['Where do the lines of latitude run around? They run around the Earth', 10],
#  ['What are latitude and longitude lines? Latitude lines are the position north or south of the equator measured from  to   whereas longitude lines are the distances of places east or west of an imaginary lines from the top to the bottom of the Earth  measured in degrees',
#   10],
#  ['The most important line of longitude is the Greenwich Meridian     which runs through London',
#   10],
#  ['GMT  Greenwich Mean Time  an international time  is taken from this line',
#   10],
#  ['So where is Raqqa city? It is on latitude  north and longitude  west', 10],
#  ['Mosul is also on  north  but on  east  whereas Sirte is on latitude  and longitude  east',
#   10],
#  ['Look at the table and answer the questions', 10],
#  ['New Delhi  India', 10],
#  ['Washington  D.C.  USA', 10],
#  ['Wellington  New Zealand', 10],
#  ['How many columns are there in the table above?', 10],
#  ['What does this table show?', 10],
#  ['What is the measurement unit of the second and the third columns?', 10],
#  ['Which city is the nearest to the equator?', 10],
#  ['Where does such information come from?', 10],
#  ['Discuss the questions below', 10],
#  ['Do you find the table difficult to understand?', 10],
#  ['Is this table easy to understand?', 10],
#  ['How do you improve such tables?', 10],
#  ['Fill in the blanks with words from the box', 10],
#  ['equator latitude longitude located position imaginary a', 10],
#  ['The distance between east and west is called', 10],
#  ['The USA victory against IS is set in an             story', 10],
#  ['Sudan and Singapore lie on the', 10],
#  ['Our camp is                among heavy trees', 10],
#  ['At these                the sun does not rise at all on winter days', 10],
#  ['If you want to see your           check that on Google Earth', 10],
#  ['Look at the table in the lesson  and write about the cities mentioned in it showing the latitude and longitude lines for each city',
#   10],
#  ['Write no more than  words', 10],
#  ['Start like this', 10],
#  ['Tokyo city  which is in Japan  locates on latitude  N  and longitude', 10],
#  ['From Raqqa to Nigeria', 10],
#  ['Before you start', 10],
#  ['Look at the two answers of the question  which one is correct?', 10],
#  ['What are you doing tomorrow?', 10],
#  ['I will travel to Asham', 10],
#  ['I am travelling to Asham', 10],
#  ['Read the text below and then answer the questions', 10],
#  ['Are there any differences between the italic verbs?', 10],
#  ['Mustafa is travelling from Raqqa to Nigeria to see his uncle', 10],
#  ['Mohammad  who joins Buko Haram there  tomorrow', 10],
#  ['He is staying with him for two weeks', 10],
#  ['The mobile phone is ringing now', 10],
#  ['Ali  Assalam Alaykum', 10],
#  ['How are you?', 10],
#  ['Mustafa  Waalaykum Assalam Ali', 10],
#  ['How are you  too', 10],
#  ['Ali  Would you like to come with me to watch the applying stone limit on a couple of adultery in the city centre this afternoon?',
#   10],
#  ['Mustafa   Oh! That s good idea', 10],
#  ['I ll meet you now and I will bring my wallet', 10],
#  ['I am going to exchange some money I need them in my way to', 10],
#  ['I ll see you then', 10],
#  ['Look at the example below  write similar ones', 10],
#  ['Make use of the prompts below', 10],
#  ['a decision taken at the moment b', 10],
#  ['a promise c', 10],
#  ['am going to exchange', 10],
#  ['a plan carried out by the help of others d', 10],
#  ['a plan in the mind of the speaker', 10],
#  ['Example  The form  is travelling  is a plan can be carried out by the help of others',
#   10],
#  ['Now check your answers in ', 10],
#  ['Complete the sentences with the forms  be   doing  will   infinitive or be   going to   infinitive',
#   10],
#  ['What are you            do  tomorrow?', 10],
#  ['I              visit  my grandfather', 10],
#  ['Look at those heavy clouds', 10],
#  ['What would you like to do in the future? I             work  as an engineer',
#   10],
#  ['I think they          carry out  the mission for us next week', 10],
#  ['I ve got a headache', 10],
#  ['I            bring  you an aspirin', 10],
#  ['Put each verb in brackets into a form of will  going to or present continuous',
#   10],
#  ['More than one answer may be possible', 10],
#  ['Have you heard the news? Salman            join  Al Usrah army', 10],
#  ['Sorry to keep you waiting', 10],
#  ['I  not be               long', 10],
#  ['According to weather news  it  snow                    tomorrow', 10],
#  ['I m sorry I can t meet you tonight', 10],
#  ['I  go out                with my parents to visit my grandfather', 10],
#  ['Our teacher  give              us a test next week', 10],
#  ['Tariq bin Ziyad', 10],
#  ['Before you start', 10],
#  ['Where did the word  Gibraltar  come from?', 10],
#  ['What was the original name of Spain?', 10],
#  ['Islamic armies reached what is called nowadays Morocco in the year  AD',
#   10],
#  ['They were not able to go further west because of the Atlantic', 10],
#  ['They decided to go to the north towards Andalusia  which is called Spain nowadays',
#   10],
#  ['The Muslim leader  Tariq Bin Ziyad  led the', 10],
#  ['Islamic armies across the strait of Gibraltar', 10],
#  ['They conquered Toledo which was the capital of Andalusia at that time', 10],
#  ['Muslims ruled it for several hundred years', 10],
#  ['Cordoba was as beautiful city as Baghdad and Damascus when it was ruled by Abdul Rahman Al Nasir  who left his noticeable figure prints on various fields',
#   10],
#  ['His greatest achievement was in building a great masjid which its ruins still exist today',
#   10],
#  ['Muslims made beautiful gardens and planted various farms', 10],
#  ['They paved roads which were clear and lit at night', 10],
#  ['They set up the first paper factories in Europe', 10],
#  ['The University of Cordoba was a good example of higher learning process',
#   10],
#  ['Muslims placed the cornerstone of the scientific developments which guided the world to progress and build civilization',
#   10],
#  ['Muslims showed an excellent ruling of', 10],
#  ['Andalusia for several centuries', 10],
#  ['Answer the following questions  a', 10],
#  ['Where did the Islamic armies reach in ?', 10],
#  ['Who is Tariq bin Ziyad?', 10],
#  ['Why didn t they go further west?', 10],
#  ['How long did Muslims rule Andalusia?', 10],
#  ['What did Muslims do in Spain?', 10],
#  ['Fill in the blanks', 10],
#  ['The Muslim armies reached         in the year          ', 10],
#  ['They were not able to go further west because of          ', 10],
#  ['The Muslims captured           which was the capital of Spain', 10],
#  ['The Muslim ruled Spain for            ', 10],
#  ['Cordoba was as beautiful as             and             ', 10],
#  ['Muslims paved roads which were          and          at night', 10],
#  ['Write T if the statement is true and F in not  a', 10],
#  ['The Muslims could not reach Morocco because of the ocean', 10],
#  ['The Muslims were led by Tariq bin Ziyad', 10],
#  ['The Muslims ruled Spain for several days', 10],
#  ['The Muslim guided the world to progress and civilization', 10],
#  ['Match the words with their meaning', 10],
#  ['to take control of foreign land b', 10],
#  ['arrange or organize c', 10],
#  ['something of great importance d', 10],
#  ['the pattern of curved lines on figure or thumb e', 10],
#  ['something is spoilt or destroyed f', 10],
#  ['to succeed in finishing something', 10],
#  ['In no more than  words summarize the article about  Tariq bin', 10],
#  ['Fill in the blanks with words from the box', 10],
#  ['People who commit              in Islamic State are stoned', 10],
#  ['There are three             in this article  all talk about jihad', 10],
#  ['We are really happy to accept your', 10],
#  ['Our               was to isolate the enemies  supporting lines over the bridge',
#   10],
#  ['Many soldiers were killed during the           of fire', 10],
#  ['Match the words with their meaning', 10],
#  ['the lowest part of something', 10],
#  ['an imaginary line drawn around the middle of the Earth', 10],
#  ['the amount of space between two places', 10],
#  ['something which created by and exist in mind', 10],
#  ['Look at the invitation card on the right and then answer the questions',
#   10],
#  ['Mohammad Amar invites a', 10],
#  ['Who invites his guests? b', 10],
#  ['What is the invitation for? c', 10],
#  ['Where is the invitation?', 10],
#  ['you our dearest guests for his son dinner s wedding at home on', 10],
#  ['Now you receive this invitation card  what would you say if you accept it? But your brother apologizes for the invitation  what does he say?',
#   10],
#  ['Correct the verbs in the sentences below', 10],
#  ['Do you think Omar is going to get the job? b', 10],
#  ['Look! It s', 10],
#  ['We will be late', 10],
#  ['What will you do tomorrow? d', 10],
#  ['They are probably arriving at  o clock', 10],
#  ['She is opening the newspaper', 10],
#  ['She will read the article', 10],
#  ['I go swimming next Friday', 10],
#  ['Would you like to come? g', 10],
#  ['The weather news says it is rainy tomorrow', 10],
#  ['In no more than  words write a paragraph about an Islamic character', 10],
#  ['Vocabulary latitude  n', 10],
#  ['How can you remember?', 10],
#  ['A good night sleep', 10],
#  ['How can you remember?', 10],
#  ['Asking for directions', 10],
#  ['Before you start', 10],
#  ['Look at those two children in the photo', 10],
#  ['What are they talking about?', 10],
#  ['Do you usually ask people for things?', 10],
#  ['Work the dialogue in pairs', 10],
#  ['Then answer the question', 10],
#  ['Official  Assalam Alaykum', 10],
#  ['Can I see your ticket  please?', 10],
#  ['Passenger  Waalykum Alsalam', 10],
#  ['Here you are', 10],
#  ['Official  Is that your luggage?', 10],
#  ['Official  Window or aisle?', 10],
#  ['Passenger  I ll have an aisle seat  please', 10],
#  ['Official  There you go  brother .Here s your pass', 10],
#  ['Boarding begins at seven o clock', 10],
#  ['Passenger  And what gate does it leave from?', 10],
#  ['Official  Sixteen  brother', 10],
#  ['Passenger  And how do I get to gate sixteen?', 10],
#  ['Official  Go along here and follow the signs for   Departure  ', 10],
#  ['You ll see the gate number when you go through into the lounge', 10],
#  ['Official  Have a nice day  brother', 10],
#  ['Where do you think the dialogue is taking place?', 10],
#  ['Tick the right answer  a  b or c  a', 10],
#  ['at police station', 10],
#  ['at an airport', 10],
#  ['Study the function s table', 10],
#  ['Asking for directions', 10],
#  ['How do I get to the hospital?', 10],
#  ['I m looking for the train station', 10],
#  ['Excuse me  Could you tell me where the bus station is?', 10],
#  ['Giving directions and describing position', 10],
#  ['Go up   Go down   Go along this street', 10],
#  ['Go straight ahead', 10],
#  ['Go to the end of the street', 10],
#  ['Turn left   Turn right', 10],
#  ['It s at the intersection', 10],
#  ['Take the first  second turn on the left   on the right', 10],
#  ['It s four blocks up   down on your left', 10],
#  ['Asking for travel information', 10],
#  ['Where do I get a car to Asham?', 10],
#  ['What platform does the train to Raqqa leave from?', 10],
#  ['What gate does the plane to Al  Madinah leave from?', 10],
#  ['How long does the flight to Pakistan take?', 10],
#  ['How much is a trip to Tripoli?', 10],
#  ['What does it cost to get to the peninsula of Arabs by taxi?', 10],
#  ['Where do I get the connection to Halab?', 10],
#  ['What s the quickest way to get across town?', 10],
#  ['How far is it to Dramadi from here?', 10],
#  ['Look at the map', 10],
#  ['Make use of the map and write a conversation asking about police station  hospital  bus stop  petrol station  school   suq   library',
#   10],
#  ['A  Excuse me', 10],
#  ['How can I get the library?', 10],
#  ['B  Go along this street', 10],
#  ['Go to the end of the street', 10],
#  ['The library will be on your left  next to the bank', 10],
#  ['A  Thank you very much', 10],
#  ['B  You re welcome', 10],
#  ['Now make similar conversations', 10],
#  ['Look at the map in  and write two different conversations asking about places such as zoo  metro  grocery store etc',
#   10],
#  ['Before you start', 10],
#  ['Which transportation method do you prefer? Why?', 10],
#  ['What do we call the vehicle which can move over land or sea?', 10],
#  ['There are many means of transportations  such as bus  car  motorbike  train  boat  ferry  plane  ambulance  bike  helicopter  coach  tram  ship  yacht  spaceship  lorry  hovercraft  moped  taxi etc',
#   10],
#  ['Match the photos you find with some of the words above', 10],
#  ['Can you add other means of transportation?', 10],
#  ['Everyone can use any of those means of transportations except one which is used by very specialized people',
#   10],
#  ['What is it  guess?', 10],
#  ['Classify the means of transportation into three groups  land  sea and air',
#   10],
#  ['Work in pairs', 10],
#  ['Follow the example', 10],
#  ['A  What is the vehicle which is used to carry goods by road?', 10],
#  ['B  Is it small or large?', 10],
#  ['A  It is large', 10],
#  ['B  I think it is a truck', 10],
#  ['What about the small one?', 10],
#  ['B  I think it is a pick up truck', 10],
#  ['Now make similar dialogue', 10],
#  ['Make use of the following information', 10],
#  ['a vehicle spends a lot of time on motorways carrying people from one place to another',
#   10],
#  ['it has no roof and often goes faster than a car', 10],
#  ['it takes people to hospital', 10],
#  ['it take people around or work or student to school', 10],
#  ['it carries a few people in the air', 10],
#  ['it travels on top of the water', 10],
#  ['it travels about  kilometer per hour  kph', 10],
#  ['it travels on rails', 10],
#  ['a lot of families own it', 10],
#  ['it travel quite slowly and it takes people across water', 10],
#  ['it goes long journeys across water  it carries people and goods', 10],
#  ['it has two wheels  carries only one person and has a very small engine',
#   10],
#  ['it runs on rails and it has several carriages', 10],
#  ['Write ten sentences using the adverbs of frequency  always  usually  sometimes  often  never  ever  rarely etc.  describing various means of transportations',
#   10],
#  ['Example  I never travel by sea', 10],
#  ['A good night sleep', 10],
#  ['Before you start', 10],
#  ['Look at these two statements', 10],
#  ['What is the difference between them?', 10],
#  ['He said    I don t think so', 10],
#  ['He said  that  He didn t think so', 10],
#  ['Look at the sentences numbered below in the interview', 10],
#  ['What do we call each one?', 10],
#  ['Abdullah     Do you think sleep is a waste of time for teenagers? Dr', 10],
#  ['Abdullah said      I don t think so.   Teenagers should take enough sleep to grow healthy and stay strong',
#   10],
#  ['Interviewer   What do you advise the teenagers who stay up late?', 10],
#  ['Abdullah said     Go to bed at the same time every night.   Don t do anything exciting before bed  instead recite some verses from the',
#   10],
#  ['Quran.  Now you know what to do before sleeping  you will feel much better in the morning',
#   10],
#  ['Finally  we can say that sleep is not a waste of time', 10],
#  ['Note   I don t think so.  Is called direct speech', 10],
#  ['When we often tell people what other people have said  it is called reported or indirect speech  e.g',
#   10],
#  ['Abdullah said that he didn t think so', 10],
#  ['in the interview above is called  Question   No.   is', 10],
#  ['Statement  and No', 10],
#  ['is called  Request', 10],
#  ['Now check your answers in', 10],
#  ['Find other examples in the interview', 10],
#  ['I   is changed into   he      do   is changed into  did  Note', 10],
#  ['Brackets     mean that you can use  that  or not  both are correct', 10],
#  ['See more in pages', 10],
#  ['Report the statements below', 10],
#  ['He said  We sleep few hours at night.  b', 10],
#  ['He told us   I do not stay late up late', 10],
#  ['Change into indirect', 10],
#  ['He said  that  he took part in many battles against his enemy', 10],
#  ['They told us  that  they had captured several war prisoners', 10],
#  ['Look at the examples below and then change the question into reported speech',
#   10],
#  ['We asked him   What are they?', 10],
#  ['We asked him what they were', 10],
#  ['He asked him   Is it ready to use?  He asked him if it was ready to use',
#   10],
#  ['Are you still at college?  Saad asked me', 10],
#  ['I asked him   What are you reading this week?', 10],
#  ['Change the statements into reported speech', 10],
#  ['They won the match.  They said', 10],
#  ['He said   I am working outside this city.  c', 10],
#  ['We arrived home late yesterday.  They told us', 10],
#  ['She said   I will help you.  e', 10],
#  ['Salman asked Ali   Where have you been?  f', 10],
#  ['Did you remember Bakr?  he asked him', 10],
#  ['How can you remember?', 10],
#  ['Before you start', 10],
#  ['Is it important to revise the information you learn from time to time?',
#   10],
#  ['How long does it take to forget the information we learn?', 10],
#  ['Look at the first graph which shows the percentage of learning remembered   vertical  and the time since initial learning  horizontal',
#   10],
#  ['Three colours are used  green one which shows regular review  blue one review after ten minutes and the brown one which shows no review',
#   10],
#  ['Now read and check your answers in ', 10],
#  ['Within  hours of learning  we almost forget   of the new information and after a month only about   remains',
#   10],
#  ['The big question is how we can stop or reduce the loss of information', 10],
#  ['Simply  the answer', 10],
#  ['is reviewing regularly', 10],
#  ['Does it need to revise every day? Not necessarily  but the first revision is very important which must be after  minutes',
#   10],
#  ['If you look at the blue line how it raises memory to    but if we do not look at the information again  we will forget nearly everything over time',
#   10],
#  ['Thus  it is very important to revise regularly', 10],
#  ['If we revise after one day as shown in the graph  one month and then six months as shown in the green line  we will remember the information for ever  because the information will be now in long term memory',
#   10],
#  ['What happens while revising? Which revising hour is the best for us  first  second etc.? Which information can we remember better  the first one or the last one? When we revise for a test  for example we need nearly  hours  the information in the first and second hours will probably be remembered better than the things you revise in the last two hours',
#   10],
#  ['The reason is that we revise the information without taking break after each hour',
#   10],
#  ['We should take at least  minutes break after an hour of revising', 10],
#  ['Look at the second graph and check how much information you can remember',
#   10],
#  ['Answer the questions below', 10],
#  ['How long does it take to retain    of the new information?', 10],
#  ['What is the best way to keep the information?', 10],
#  ['Which information will be the best in a test  first hour of revising or the last hour?',
#   10],
#  ['What do advise students while revising for long hours?', 10],
#  ['Do you agree with these ideas in this topic? Why? Why not?', 10],
#  ['Write T if the statement is true  and F if it is false', 10],
#  ['We nearly forget    of the new information and after two weeks only about    remains',
#   10],
#  ['The second revision is very important which must be after  minutes', 10],
#  ['It is important to revise regularly', 10],
#  ['The best revising hour is the last one', 10],
#  ['We forget the information while revising because we do not take break', 10],
#  ['In no more than  words summarize the topic  How can we remember?', 10],
#  ['Fill in the blanks with a proper word', 10],
#  ['is a vehicle which flies over land or water', 10],
#  ['is an underground electric railway system in some cities', 10],
#  ['is a boat or ship for taking passengers and vehicles cross an area of water',
#   10],
#  ['is a large cylindrical object which moves very fast', 10],
#  ['is a long vehicle which takes groups of people on journeys', 10],
#  ['Match the words with their meanings', 10],
#  ['a particular way of doing something', 10],
#  ['to make something smaller in size  amount  degree etc', 10],
#  ['to stay in the same place', 10],
#  ['happening or doing something often', 10],
#  ['the ability to remember information  experience  people', 10],
#  ['Change into reported speech', 10],
#  ['My little brother needs to memorize Surat Baqarh  Ahmed told me', 10],
#  ['I ll be in Sham next July Insha Allah  Saad said', 10],
#  ['I have washed the car  Yusuf said', 10],
#  ['What do elephant eat?  He asked me', 10],
#  ['Where are you going?  I asked him', 10],
#  ['Is this your car?  She asked me', 10],
#  ['Did you have it with you?  I asked her', 10],
#  ['Could you help me  please?  A stranger asked me', 10],
#  ['Don t sit in the middle of the road.  My father told me', 10],
#  ['Slow down  check point ahead.  My mother warned me', 10],
#  ['Look at the map and ask and answer in pairs about   mall  masjid  petrol station',
#   10],
#  ['Look at Lesson   ex', 10],
#  ['Vocabulary transportation  n', 10],
#  ['pick up  n', 10],
#  ['Smoking is prohibited in Islam', 10],
#  ['Things I own', 10],
#  ['Speak up!', 10],
#  ['Smoking is prohibited in', 10],
#  ['Once you decide', 10],
#  ['Things I own', 10],
#  ['Before you start', 10],
#  ['What parts of speech are these words  cheap  antique  crazy  ugly?', 10],
#  ['Can you add words more from your own?', 10],
#  ['Look at the photographs', 10],
#  ['Match what these people say and write them in the small box', 10],
#  ['I was walking down town when I saw this in a shop window  and I decided to buy it that day',
#   10],
#  ['I don t have any other any antique  but it looks good in my big room', 10],
#  ['I have had it for two years now', 10],
#  ['It was expensive  but in my opinion it was not worth it because it s the most useful thing in the kitchen',
#   10],
#  ['I think this is great because I like unusual furniture', 10],
#  ['Some people say it s not very comfortable in hot weather but I don t mind',
#   10],
#  ['It s crazy  isn t it? Everyone laughs when they see it  but it works OK  and it makes me happy',
#   10],
#  ['I don t really like it all because it s old fashioned  and I prefer modern furniture',
#   10],
#  ['But I can t offered to change it and its quite useful', 10],
#  ['I can keep lots of things in it', 10],
#  ['What we call the italic words in the five texts above?', 10],
#  ['Which order of adjectives is correct  a  or b  ? a  I ve bought a lovely long black leather belt',
#   10],
#  ['b  I ve bought a lovely black long leather belt', 10],
#  ['Look at the order of adjectives in the table below and check your answer in',
#   10],
#  ['size   age   shape short   old', 10],
#  ['Add more adjectives to the table', 10],
#  ['When we use adjectives together  we put words which express opinion before words which describe the characteristics or type of what we are talking about  e.g',
#   10],
#  ['a beautiful Arabic fashion  beautiful   opinion   Arabic   nationality',
#   10],
#  ['The sentences below are incorrect  write them correctly', 10],
#  ['She bought a round  beautiful  Pakistani cloth', 10],
#  ['He saw an ugly  blue  wooden  little wardrobe', 10],
#  ['That is a red  new  terrible scarf', 10],
#  ['I ve got an expensive square old box', 10],
#  ['Speak up!', 10],
#  ['Before you start', 10],
#  ['What do we call the italic verbs in the dialogue below?', 10],
#  ['Is there a difference in meaning between  look for  and  search ?', 10],
#  ['Work in pairs', 10],
#  ['An interview between a boy and a presenter', 10],
#  ['Presenter  We are here today with Abdullah who had a strange experience last week',
#   10],
#  ['Abdullah  Well  I was moving up the stairs to our flat in the fifth floor',
#   10],
#  ['I saw a flame coming up to the second floor', 10],
#  ['Presenter  What were you doing at that moment?', 10],
#  ['Abdullah  I was looking down for my little brother who was at the third floor',
#   10],
#  ['Presenter  You mean that your brother was in great danger?', 10],
#  ['Abdullah  Yes  indeed', 10],
#  ['The flames speed up very quickly', 10],
#  ['No time was left out', 10],
#  ['Thanks for Allah  someone had called the fire engine and put out the fire completely',
#   10],
#  ['The verbs in italic in the interview are called multi word verbs which combine with one   or two particles',
#   10],
#  ['If the addition of the particles changes the meaning of the verb  it is usually called a phrasal verb because it has the meaning of a phrase  e.g',
#   10],
#  ['The fire engine put out the fire', 10],
#  ['Phrasal verbs are in three types', 10],
#  ['With object  Doctors look after sick people', 10],
#  ['Without object  There is a check point ahead  slow down', 10],
#  ['Within object  He gave up smoking  he gave it up forever', 10],
#  ['Now check your answers in ', 10],
#  ['Match the phrasal verbs with their meaning', 10],
#  ['Phrasal verbs a', 10],
#  ['The paper ran out  we need more', 10],
#  ['We usually look after our poor neighbours', 10],
#  ['Could you speak up? I can t hear you', 10],
#  ['The man put the device on', 10],
#  ['We have the permission to go ahead with the task', 10],
#  ['She has to give up fatty food  it s dangerous', 10],
#  ['We need to work out the total cost of the project', 10],
#  ['Everyone is looking forward to accomplishing success', 10],
#  ['To stop trying', 10],
#  ['To take care of', 10],
#  ['To start to do something', 10],
#  ['To speak in a louder voice', 10],
#  ['To feel pleased or excited', 10],
#  ['Look at the verbs in italic in the examples below and match them with the combined two or three particles',
#   10],
#  ['I m looking for my keys', 10],
#  ['Have you seen them? b', 10],
#  ['Look out! There s a motorcycle coming', 10],
#  ['The one who looks down on other people is called a snob', 10],
#  ['verb   adverb   preposition', 10],
#  ['a preposition and   or an adverb', 10],
#  ['Fill in the blanks with a proper phrasal verbs from the box', 10],
#  ['look forward to', 10],
#  ['look out onto', 10],
#  ['drop in on', 10],
#  ['I               participating one of the battles  fronts every summer', 10],
#  ['One must            his   her shoes before entering misjad', 10],
#  ['Yasir was ill with flu  but he is               it now', 10],
#  ['Let s             Omar while we are in Dirna', 10],
#  ['Al Waritheen hotel              Tigress River', 10],
#  ['Smoking is prohibited in Islam', 10],
#  ['Before you start', 10],
#  ['Where can you find such warnings?  Don t smoke!   Stop smoking!', 10],
#  ['Do you agree with those warnings? Why? Why not?', 10],
#  ['Look at the italic sentences', 10],
#  ['Don t smoke  and  Stop smoking  are sentences you may hear or read everywhere',
#   10],
#  ['Another phrase you may hear is  Stop smoking before it s too late', 10],
#  ['Firstly  smoking is prohibited in Islam based on the Messenger of Allah s hadith   peace be upon him   Hurt neither yourself nor others',
#   10],
#  ['Moreover  those warnings tell us that smoking is very dangerous', 10],
#  ['It damages your health', 10],
#  ['Warning statements are everywhere you find it on cigarette packets  it says   Leave smoking',
#   10],
#  ['It is one of the main reasons for cancer.  Such phrases are not written on food  or drink packets  yet a number of people still smoke',
#   10],
#  ['Look at the examples below and do as required', 10],
#  ['He ordered us   Stop smoking', 10],
#  ['He ordered us to stop smoking', 10],
#  ['Reported speech  b', 10],
#  ['They asked me   Would you carry these bags for me  please?', 10],
#  ['They asked me to carry those bags for him', 10],
#  ['Look at the examples  a  and  b  abovex and guess which one is formal and which one is informal',
#   10],
#  ['We use the infinitive  to do   to stay   to take etc.  in reported speech  especially with tell and ask  for orders and requests ',
#   10],
#  ['There are two methods of expressing requests  informal and formal', 10],
#  ['Example for informal', 10],
#  ['Stay in bed for a few days.  The doctor said to me', 10],
#  ['The doctor told me to stay in bed for a few days', 10],
#  ['Don t speed up  I asked the taxi driver', 10],
#  ['I asked the taxi driver not to speed up', 10],
#  ['Example for formal', 10],
#  ['Would you mind opening that door  please?  a stranger asked me', 10],
#  ['A stranger asked me to open the door', 10],
#  ['Check your answer in ', 10],
#  ['Now do the following', 10],
#  ['Could you open the door  please?  a stranger asked me', 10],
#  ['The man asked me  Don t park your car here.  c', 10],
#  ['Stop here  a man warned me', 10],
#  ['Turn the TV off  my father asked me', 10],
#  ['Change the sentences below into direct speech', 10],
#  ['You define if it is formal or informal', 10],
#  ['He asked his older brother not backbite others', 10],
#  ['She told her little sister to say the truth', 10],
#  ['A stranger asked me to open the umbrella for him', 10],
#  ['Her father told her to turn the TV off', 10],
#  ['A friend of mine warned me not to speed up', 10],
#  ['An old man asked me to carry his bags for him', 10],
#  ['Once you decide', 10],
#  ['Before you start', 10],
#  ['How do you make a decision?', 10],
#  ['Have you ever regretted a decision?', 10],
#  ['Read the text', 10],
#  ['You may need to take a decision every day  every week  every month etc',
#   10],
#  ['But is your decision good or not? What are the steps of good decision making? A lot of people make decisions without really thinking about them',
#   10],
#  ['They probably use their instinct and they believe that they just hope they have done the right thing',
#   10],
#  ['However  such a decision making is no good in business  or in big things in every day s life',
#   10],
#  ['Making decisions is not a moment in time  but it is process', 10],
#  ['It can be said that making decision is embodied in six process steps', 10],
#  ['Define the problem', 10],
#  ['Imagine a successful solution', 10],
#  ['Generate alternative possibilities', 10],
#  ['Evaluate the possibilities', 10],
#  ['Select the best possibility', 10],
#  ['Tell people your decision', 10],
#  ['Let s have a look at the example of the process of action', 10],
#  ['Let s define the problem first', 10],
#  ['You may come late to school', 10],
#  ['Secondly  let s imagine that the successful solution for this problem is to arrive  minutes before the first lesson',
#   10],
#  ['Now you need to generate a list of alternative possibilities  for example  take a taxi  go with your father s car  take the bus  ride your bike etc',
#   10],
#  ['You can go through those alternatives with your father or even with your friend and think of the difficulties of each alternative',
#   10],
#  ['Then it is time to select the best possibility', 10],
#  ['people around you your final decision  but remember not all your decisions are perfect even if you follow the process of taking good decisions because you forget one important thing',
#   10],
#  ['It is to follow the advice of our prophet Mohammad  peace be upon him  before taking decision  you should pray to Allah to choose for you the best alternative to take the final decision',
#   10],
#  ['Thus  the good decision should be taken after istikhara  decisions  prayer  even if you discover later on it was not a good decision  but indeed it is good for you because no one knows which one is good or bad  but Almighty Allah',
#   10],
#  ['Check your answers in ', 10],
#  ['Answer the questions below', 10],
#  ['Is it good to use instinct to take a business decision? b', 10],
#  ['What is making decision? c', 10],
#  ['How many steps one should follow before telling people his or her decision? d',
#   10],
#  ['Do you think that the six process steps are active in a decision?', 10],
#  ['Why? Why not?', 10],
#  ['Write T if the statement is true and F if it is not', 10],
#  ['Very few people make decisions without really thinking about them', 10],
#  ['It is very good to use our instinct to take a decision in big things in every day s life',
#   10],
#  ['There is no need to define the problem in taking decisions', 10],
#  ['After studying the possibilities  one should select one of them', 10],
#  ['Imagine you do not live in the Islamic State and you want to immigrate to it',
#   10],
#  ['Read the six process steps of make your decision ', 10],
#  ['Define the problem', 10],
#  ['Imagine a successful solution', 10],
#  ['Generate alternative possibilities', 10],
#  ['Evaluate the possibilities', 10],
#  ['Select the best possibility', 10],
#  ['Tell closest people your decision', 10],
#  ['Use the words in the box to complete the following sentences', 10],
#  ['It s important that young people understand the            and', 10],
#  ['effects of smoking', 10],
#  ['With the help of your dictionary  checkup the meaning of the', 10],
#  ['Wherever you go in the Islamic state  you find              people who are always willing to help',
#   10],
#  ['One should look after his            ', 10],
#  ['Write adjectives in the table below from your own', 10],
#  ['opinion a  an', 10],
#  ['size   age   shape large', 10],
#  ['Match the words with their meaning', 10],
#  ...]

# %% [markdown]
# ### Checking for Data Imbalance:

# %%
len(new_examples1)
# Out:
# 956

# %%
len(new_examples2)
# Out:
# 1377

# %%
len(new_examples1)+len(new_examples2)
# Out:
# 2333

# %% [markdown]
# ### Checking the Readability Scores using the Textstat Library:

# %%
fs = open('../data/gradefourafghan.txt', 'r') 
bookone = fs.read()

# %%
# https://pypi.org/project/textstat/
bookonescore = round(textstat.flesch_kincaid_grade(bookone))
bookonescore
# Out:
# 4

# %%
fs = open('../data/gradesixis.txt', 'r') 
booktwo = fs.read()

# %%
# https://pypi.org/project/textstat/
booktwoscore = round(textstat.flesch_kincaid_grade(booktwo))
booktwoscore
# Out:
# 6

# %% [markdown]
# ### Organising the Labelled Data together using a Pandas Dataframe:

# %%
dataset = pd.DataFrame(columns = ["text", "label"])  
dataset = dataset.append(pd.DataFrame(new_examples2+new_examples1, columns = ["text", "label"]))

# %% [markdown]
# ### Downloading Pre-trained Vectors trained on part of Google News dataset:

# %%
# https://code.google.com/archive/p/word2vec/
# !pip install wget
import wget
import os
if not os.path.isfile("GoogleNews-vectors-negative300.bin.gz"):
    print("downloading")
    wget.download("https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz")
else:
    print("you already have it!")

# %%
embeddings_file = "../data/GoogleNews-vectors-negative300.bin.gz"
wv = KeyedVectors.load_word2vec_format(embeddings_file, binary=True, limit=200000)

# %% [markdown]
# ### Classification:

# %%
#Code Adapted from the NLP in Action book ch7 https://github.com/totalgood/nlpia
word_vectors = KeyedVectors.load_word2vec_format(embeddings_file, binary=True, limit=200000)
def tokenize_and_vectorize(dataset):
    vectorized_data = []
    for sample in dataset:
        tokens = casual_tokenize(sample)
        sample_vecs = []
        for token in tokens:
            try:
                sample_vecs.append(word_vectors[token])
            except KeyError:
                pass  # No matching token in the Google w2v vocab
        vectorized_data.append(sample_vecs)

    return vectorized_data

def pad_trunc(data, maxlen):
    """ For a given dataset pad with zero vectors or truncate to maxlen """
    new_data = []

    # Creating a vector of 0's the length of the word vectors
    zero_vector = []
    for _ in range(len(data[0][0])):
        zero_vector.append(0.0)

    for sample in data:
 
        if len(sample) > maxlen:
            temp = sample[:maxlen]
        elif len(sample) < maxlen:
            temp = sample
            additional_elems = maxlen - len(sample)
            for _ in range(additional_elems):
                temp.append(zero_vector)
        else:
            temp = sample
        new_data.append(temp)
    return new_data

# %%
features = tokenize_and_vectorize(dataset["text"].values)
x_train, x_test, y_train, y_test = train_test_split(features, dataset["label"], test_size=0.2, random_state=0)

# %%
type(x_train)
# Out:
# list

# %%
maxlen = 50
embedding_dims = 300    # Length of the token vectors for passing into the Convnet

# %%
np.array(x_train).shape,np.array(x_test).shape
# Out:
# <ipython-input-26-6dd20099d2f7>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   np.array(x_train).shape,np.array(x_test).shape
# ((1866,), (467,))

# %%
x_train = pad_trunc(x_train, maxlen)
x_test = pad_trunc(x_test, maxlen)

# %%
type(x_train)
# Out:
# list

# %%
np.array(x_train).shape
# Out:
# (1866, 50, 300)

# %%
x_train = np.reshape(x_train, (len(x_train), maxlen, embedding_dims))
y_train = np.array(y_train)
x_train = np.reshape(x_train, (len(x_train), maxlen, embedding_dims))
y_train = np.array(y_train)
x_test = np.reshape(x_test, (len(x_test), maxlen, embedding_dims))
y_test = np.array(y_test)

# %%
np.array(x_train).shape,np.array(x_test).shape
# Out:
# ((1866, 50, 300), (467, 50, 300))

# %%
batch_size = 32        
filters = 1           
kernel_size = 5         
hidden_dims = 10      
epochs = 8

# %% [markdown]
# ### Building the Model:

# %%
#Code Adapted from the NLP in Action book ch7 https://github.com/totalgood/nlpia

print('Build model...')
model = Sequential()

# Adding a Convolution1D, which will learn filters
# word group filters of size filter_length:
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1,
                 input_shape=(maxlen, embedding_dims)))
# Using max pooling:
model.add(GlobalMaxPooling1D())
# Adding a vanilla hidden layer:
model.add(Dense(hidden_dims))
model.add(Dropout(0.3))
model.add(Activation('relu'))
# Projecting onto a single unit output layer, and squashing it with a sigmoid:
model.add(Dense(1))
model.add(Activation('sigmoid'))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
print(model.summary())
# Out:
# Build model...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 46, 1)             1501
# _________________________________________________________________
# global_max_pooling1d (Global (None, 1)                 0
# _________________________________________________________________
# dense (Dense)                (None, 10)                20
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 1,532
# Trainable params: 1,532
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# https://stackoverflow.com/questions/58636087/tensorflow-valueerror-failed-to-convert-a-numpy-array-to-a-tensor-unsupporte

x_train = np.asarray(x_train).astype(np.float32)
y_train = np.asarray(y_train).astype(np.float32)
x_test = np.asarray(x_test).astype(np.float32)
y_test = np.asarray(y_test).astype(np.float32)

# %% [markdown]
# ### Train Model:

# %%
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, y_test))
model_structure = model.to_json()
with open("cnn_model.json", "w") as json_file:
    json_file.write(model_structure)

model.save_weights("cnn_weights.h5")
print('Model saved.')
# Out:
# Epoch 1/8
# 59/59 [==============================] - 3s 23ms/step - loss: 0.3643 - accuracy: 0.3896 - val_loss: -0.0557 - val_accuracy: 0.4069
# Epoch 2/8
# 59/59 [==============================] - 1s 14ms/step - loss: -0.8962 - accuracy: 0.4084 - val_loss: -3.5084 - val_accuracy: 0.4069
# Epoch 3/8
# 59/59 [==============================] - 1s 18ms/step - loss: -15.4803 - accuracy: 0.4062 - val_loss: -34.9173 - val_accuracy: 0.4069
# Epoch 4/8
# 59/59 [==============================] - 1s 15ms/step - loss: -66.3648 - accuracy: 0.4105 - val_loss: -106.3422 - val_accuracy: 0.4069
# Epoch 5/8
# 59/59 [==============================] - 1s 14ms/step - loss: -161.2436 - accuracy: 0.4105 - val_loss: -229.5026 - val_accuracy: 0.4069
# Epoch 6/8
# 59/59 [==============================] - 1s 16ms/step - loss: -321.6557 - accuracy: 0.4105 - val_loss: -420.8122 - val_accuracy: 0.4069
# Epoch 7/8
# 59/59 [==============================] - 1s 18ms/step - loss: -559.9609 - accuracy: 0.4105 - val_loss: -693.0710 - val_accuracy: 0.4069
# Epoch 8/8
# 59/59 [==============================] - 1s 19ms/step - loss: -851.3088 - accuracy: 0.4105 - val_loss: -1048.2428 - val_accuracy: 0.4069
# Model saved.

# %% [markdown]
# #### `(All observations and findings shall be included in the critical essay).`

# %% [markdown]
# ### Citation List:
#
#
# #### Websites:
#
# 1) Code.google.com. 2022. Google Code Archive - Word2Vec. [online] Available at: <https://code.google.com/archive/p/word2vec/> [Accessed 5 December 2021].
#
# 2) Davis, A., 2021. The fundamentals of programming - Python Video Tutorial | LinkedIn Learning, formerly Lynda.com. [online] LinkedIn. Available at: <https://www.linkedin.com/learning/programming-foundations-fundamentals-3/the-fundamentals-of-programming?autoAdvance=true&autoSkip=false&autoplay=true&resume=true&u=57077561> [Accessed 24 October 2021].
#
# 3) Dib, F., 2021. regex101: build, test, and debug regex. [online] regex101. Available at: <https://regex101.com/> [Accessed 4 December 2021].
#
# 4) GitHub. 2021. GitHub - totalgood/nlpia: Examples and libraries for "Natural Language Processing in Action" book. [online] Available at: <https://github.com/totalgood/nlpia> [Accessed 5 December 2021].
#
# 5) Libgen.is. 2021. Library Genesis. [online] Available at: <https://www.libgen.is/> [Accessed 4 November 2021].
#
# 6) McCallum, L., 2021. NLP Week 4.1 - Classification Task Notebook. [online] GitHub. Available at: <https://git.arts.ac.uk/lmccallum/nlp-21-22/blob/master/NLP%20Week%204.1%20-%20Classification%20Task.ipynb> [Accessed 16 November 2021].
#
# 7) McCallum, L., 2021. NLP Week 5.1 CNNs Notebook. [online] GitHub. Available at: <https://git.arts.ac.uk/lmccallum/nlp-21-22/blob/master/NLP%20Week%205.1%20CNNs.ipynb> [Accessed 2 December 2021].
#
# 8) Nisbet, J., 2021. Python for students - Python Video Tutorial | LinkedIn Learning, formerly Lynda.com. [online] LinkedIn. Available at: <https://www.linkedin.com/learning/python-for-students/python-for-students?autoAdvance=true&autoSkip=false&autoplay=true&resume=false&u=57077561> [Accessed 18 October 2021].
#
# 9) Portilla, J., 2021. Natural Language Processing with Python. [online] Udemy. Available at: <https://www.udemy.com/course/nlp-natural-language-processing-with-python/?ranMID=39197&ranEAID=JVFxdTr9V80&ranSiteID=JVFxdTr9V80-gIa4CDf8o_3HXX8ZIg_F1g&LSNPUBID=JVFxdTr9V80&utm_source=aff-campaign&utm_medium=udemyads> [Accessed 27 October 2021].
#
# 10) Rose, D., 2021. Artificial Intelligence Foundations: Neural Networks Video Tutorial | LinkedIn Learning, formerly Lynda.com. [online] LinkedIn. Available at: <https://www.linkedin.com/learning/artificial-intelligence-foundations-neural-networks/welcome?autoAdvance=true&autoSkip=false&autoplay=true&resume=true&u=57077561> [Accessed 6 December 2021].
#
# 11) PyPI. 2021. clean-text. [online] Available at: <https://pypi.org/project/clean-text/> [Accessed 14 November 2021].
#
# 12) PyPI. 2021. textstat. [online] Available at: <https://pypi.org/project/textstat/> [Accessed 15 November 2021].
#
# 13) Stack Abuse. 2021. Using Regex for Text Manipulation in Python. [online] Available at: <https://stackabuse.com/using-regex-for-text-manipulation-in-python/> [Accessed 16 November 2021].
#
# 14) T., Carvalho, V. and Fedor, Z., 2021. Tensorflow - ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type float). [online] Stack Overflow. Available at: <https://stackoverflow.com/questions/58636087/tensorflow-valueerror-failed-to-convert-a-numpy-array-to-a-tensor-unsupporte> [Accessed 5 December 2021].
#
# 15) Zamzar.com. 2021. Zamzar - video converter, audio converter, image converter, eBook converter. [online] Available at: <https://www.zamzar.com/> [Accessed 7 November 2021].
