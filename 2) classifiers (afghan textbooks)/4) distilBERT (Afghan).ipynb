# %% [markdown]
# # Fine-tuning distilBERT for Text Readability Classification
#
# Code cells have been individually cited via comments wherever third-party code has been referred to or implemented, and a citation list has been added at the bottom of this notebook in Harvard style referencing.

# %% [markdown]
# ### Project Overview:
#
# The purpose of this project is to create a text readability classifier (inspired by the flesch kincaid readability tests) that determines whether a piece of text is easy or hard to read. I shall be making use of english textbooks from South-East Asian / Middle Eastern areas as datasets. Since most readability classifiers use data from the United Kingdom / United States in their model, I thought it would be interesting to approach this problem using data from non-western regions to see if they could predict readability scores accurately for english phrases across the world. After building the classifier, I shall test it on speech / interview transcripts of various politicians as a use case to get a bit more insight into their speaking styles.

# %% [markdown]
# ### Project Aim:
#
# 1) To construct a model that allows writers to have more control over their writing, so that they could structure their work according to their intended audience.

# %% [markdown]
# ### Installing and Importing the Required Libraries:

# %%
# !pip install transformers
# !pip install datasets
# Out:
# Requirement already satisfied: transformers in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (4.12.5)
# Requirement already satisfied: sacremoses in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from transformers) (0.0.46)
# Requirement already satisfied: pyyaml>=5.1 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from transformers) (5.4.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from transformers) (0.10.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from transformers) (0.1.2)
# Requirement already satisfied: requests in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from transformers) (2.25.1)
# Requirement already satisfied: numpy>=1.17 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from transformers) (1.19.5)
# Requirement already satisfied: regex!=2019.12.17 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from transformers) (2021.4.4)
# Requirement already satisfied: tqdm>=4.27 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from transformers) (4.62.3)
# Requirement already satisfied: packaging>=20.0 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from transformers) (20.9)
# Requirement already satisfied: filelock in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from transformers) (3.0.12)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: six in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: datasets in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (1.16.1)
# Requirement already satisfied: aiohttp in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from datasets) (3.8.1)
# Requirement already satisfied: numpy>=1.17 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from datasets) (1.19.5)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from datasets) (2021.11.1)
# Requirement already satisfied: dill in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from datasets) (0.3.4)
# Requirement already satisfied: packaging in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from datasets) (20.9)
# Requirement already satisfied: multiprocess in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: requests>=2.19.0 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from datasets) (2.25.1)
# Requirement already satisfied: pandas in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from datasets) (1.2.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from datasets) (0.1.2)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from datasets) (4.62.3)
# Requirement already satisfied: xxhash in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: filelock in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.0.12)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.7.4.3)
# Requirement already satisfied: pyyaml in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (5.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from packaging->datasets) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (1.26.4)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets) (2.0.8)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets) (20.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets) (5.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets) (4.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from pandas->datasets) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from pandas->datasets) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/ashwathi/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)

# %%
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from nltk.tokenize.casual import casual_tokenize
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
import re
from cleantext import clean
from nltk import word_tokenize
import textstat
from transformers import DistilBertTokenizerFast
import torch
from transformers import DistilBertForSequenceClassification, Trainer, TrainingArguments
from datasets import load_metric
# Out:
# Since the GPL-licensed package `unidecode` is not installed, using Python's `unicodedata` package which yields worse results.

# %% [markdown]
# ### Selection of Data:
#
# For this project, I'm using English textbooks of varying grades from different countries. I found all of them on [Library Genesis](https://www.libgen.is/) and since they were PDF files, I then converted them to text files using [Zamzar File Converter](https://www.zamzar.com/). I initially tried using python modules for this task like PDF Miner and PyPDF, but kept running into errors as most of the code I found on StackOverflow was not suitable with the latest version of Python.
#
# For this notebook, I have used **fourth and twelfth grade english textbooks from Afghanistan by the country's Ministry of Education (2011 Edition)**, which can be found [here](https://libgen.is/search.php?req=afghanistan+english&lg_topic=libgen&open=0&view=simple&res=25&phrase=1&column=def).

# %% [markdown]
# ### Preprocessing the Data:
#
# I've used Regex and the Clean-Text Library to prepare the data before the classification task. I defined a 'read_and_clean' function to read any given text file and clean the data in it, whilst replacing the line-breaks according to every condition (as described in the comments) as the text files for this task aren't following a particular pattern with grammar since it was converted from an image-heavy PDF. After that, I'm splitting the sentence after every full stop ('.') and avoiding any sentences with less than two words as it won't be of much use.

# %%
def remove(text):
    text = re.sub(r"#\S+", " ", text) #remove hashtags
    text = re.sub(r'\w*\d+\w*', '', text) #remove numbers
    text = re.sub(r'[^a-zA-Z0-9\n\?!\.]', ' ', text) #remove special characters
    text = text.strip(" ")
    text = text.strip(".")
    return text

# %%
# read the file and clean it.
def read_and_clean(file_name):
# read the file
    fs = open(file_name, 'r') 
    book1 = fs.read()
# convert it to . if 2 or more line breaks are together
    book1 = re.sub(r"\n{2,}",". ", book1)
# convert it to . if 2 or more spaces are together
    book1 = re.sub(r"\s{2,}",". ", book1)
# convert a single line break to space if it is followed by a small letter
    book1 = re.sub(r"\n{1}(?=\s[a-z])"," ", book1)
# convert a single line break to space if it is followed by a space and small letter
    book1 = re.sub(r"\n{1}(?=[a-z])"," ", book1)
# convert all remaining line breaks to .
    book1 = re.sub(r"\n",". ", book1)
    total = []
    
    clean(book1,
        no_urls=True) #https://pypi.org/project/clean-text/

# split the sentence after every '.'
    for i in book1.split(". "):
# clean it using the above function
        clean_text = remove(i)
# convert the sentence to a list of words and check the length. if it is greater then 2, then consider it a sentence
        if len(word_tokenize(clean_text)) >2:
            total.append(clean_text)
# return the final list
    return total

# %% [markdown]
# ### Labelling the Data and Calling the Functions

# %%
# reading the grade four file
grade_one_sentence = read_and_clean("../data/gradefourafghan.txt")

# %%
label = 0
new_examples1 = []
for i in grade_one_sentence:  
    if len(word_tokenize(i)) >2:
        new_examples1 = new_examples1 + [[i, label]]

# %%
new_examples1 = new_examples1[16:] # slicing the few sentences in the beginning to remove the contents page.
new_examples1
# Out:
# [['The goal of this chapter is for students to practice writing the letters A to M in English',
#   0],
#  ['Learning to Write N Z', 0],
#  ['The goal of this chapter is for students to practice writing the letters N to Z in English',
#   0],
#  ['The goal of this chapter is for students to practice writing words in English',
#   0],
#  ['Write the following words three times in your notebooks', 0],
#  ['My First Words in English', 0],
#  ['fish  apple  book  cat  dog  egg', 0],
#  ['Teacher  Good morning', 0],
#  ['Student  Good morning', 0],
#  ['Name the pictures after your teacher', 0],
#  ['Look at the above pictures and name them', 0],
#  ['In pairs  Student A points to a picture and student', 0],
#  ['B names it', 0],
#  ['Follow the example', 0],
#  ['Student A  points to', 0],
#  ['Student B  says apple', 0],
#  ['Teacher  Good bye', 0],
#  ['Students  Good bye', 0],
#  ['egg    dog  apple  book  cat  fish', 0],
#  ['Look at the pictures and name them', 0],
#  ['Each student finds a partner', 0],
#  ['Student A points to a picture and student B names it', 0],
#  ['Follow the example', 0],
#  ['What is this? Points to', 0],
#  ['It is a book', 0],
#  ['Note  All Students take turns', 0],
#  ['C.Look at the pictures and read the words after your teacher', 0],
#  ['fish    dog  egg  apple  book  cat', 0],
#  ['Look at each picture and circle the correct word', 0],
#  ['cat apple egg', 0],
#  ['dog book apple', 0],
#  ['dog book cat', 0],
#  ['egg cat fish', 0],
#  ['egg cat fish', 0],
#  ['book fish apple', 0],
#  ['Look at the above pictures and read the words below', 0],
#  ['Write the letters in your notebooks', 0],
#  ['Follow the example', 0],
#  ['!                        AB               b', 0],
#  ['Match each letter with the picture that its name begins with that letter',
#   0],
#  ['Write the first letter of each picture s name in your', 0],
#  ['Match the pictures with the correct words', 0],
#  ['book cat dog', 0],
#  ['Write the words of exercise C in your notebooks', 0],
#  ['          goat  hen  iron  jug  kite  lamp', 0],
#  ['Name the pictures after your teacher', 0],
#  ['Look at the pictures and name them', 0],
#  ['In pairs  Student A points to a picture', 0],
#  ['Student B names it', 0],
#  ['Follow the example', 0],
#  ['F           lamp   goat  hen  iron  jug  kite', 0],
#  ['Look at the pictures and name them', 0],
#  ['In pairs  Student a points to a picture  student B names it', 0],
#  ['Follow the example', 0],
#  ['What is it? Points to', 0],
#  ['It is a goat', 0],
#  ['C.  Look at the pictures and read the words after your teacher', 0],
#  ['D  In pairs  Student A points to a picture  student', 0],
#  ['B reads the word', 0],
#  ['Student A   points to', 0],
#  ['Student B   reads  goat', 0],
#  ['hen  iron  jug  kite', 0],
#  ['Look at each picture and circle the correct word below', 0],
#  ['iron goat lamp', 0],
#  ['hen lamp jug', 0],
#  ['hen jug kite', 0],
#  ['lamp jug hen', 0],
#  ['lamp jug goat', 0],
#  ['goat iron kite', 0],
#  ['Look at the above pictures and read the words below', 0],
#  ['Write the letters in your notebooks', 0],
#  ['Follow the example', 0],
#  ['h i g', 0],
#  ['Match each letter with the picture that its name begins with that letter',
#   0],
#  ['i j k l', 0],
#  ['Write the first letter of each picture s name in your notebooks', 0],
#  ['Match the pictures with the correct word', 0],
#  ['goat hen iron jug kite lamp', 0],
#  ['Write the words of exercise C in your notebooks', 0],
#  ['!G     FD', 0],
#  ['sun   queen  radio  map  net  orange  pen', 0],
#  ['Name the pictures after your teacher', 0],
#  ['U nic ef Afghanistan', 0],
#  ['Pu lik humr i', 0],
#  ['Qalay i  now', 0],
#  ['PARW AN KAP S', 0],
#  ['Unicef Country Office', 0],
#  ['Look at the pictures and name them', 0],
#  ['Unicef Af ghanistan', 0],
#  ['TAKHARFa zi ab ad', 0],
#  ['Pulik humr i', 0],
#  ['Qalay  i now', 0],
#  ['Unicef Cou ntry Offi ce', 0],
#  ['In pairs  Student A points to a picture', 0],
#  ['Student B names it', 0],
#  ['Follow the example', 0],
#  ['Student A  What is it? Points to', 0],
#  ['Student B  It is a pen', 0],
#  ['sun   map  net  orange  pen  queen  radio                   H', 0],
#  ['Look at the pictures and name them', 0],
#  ['Qalay i now', 0],
#  ['Unicef Country Office', 0],
#  ['In pairs  Student A points to a picture  student B names it', 0],
#  ['Follow the example', 0],
#  ['What is this? Points to', 0],
#  ['It is a pen', 0],
#  ['Look at the pictures and read the words after your teacher', 0],
#  ['Qalay i now', 0],
#  ['sun  map  net  orange  pen  queen  radio', 0],
#  ['Look at each picture and circle the correct word below', 0],
#  ['Unicef Af ghanistan', 0],
#  ['TAKHARFa zi ab ad', 0],
#  ['Pulik humr i', 0],
#  ['Qalay  i now', 0],
#  ['Unicef Cou ntry Offi ce', 0],
#  ['queen map orange g', 0],
#  ['map orange queen', 0],
#  ['orange pen net', 0],
#  ['net pen radio', 0],
#  ['map radio pen', 0],
#  ['sun map net', 0],
#  ['radio rad dio queen net', 0],
#  ['Look at the above pictures and read the words below', 0],
#  ['Write the letters in your notebooks', 0],
#  ['Follow the example', 0],
#  ['!           .        AB', 0],
#  ['Write each letter m  n  o  p  q  r and s five times in your notebooks', 0],
#  ['m m m m', 0],
#  ['K  !LM N!', 0],
#  ['Match each letter with the picture s name that begins with that letter', 0],
#  ['n o p q r s', 0],
#  ['Qalay i now', 0],
#  ['Unicef Country Office', 0],
#  ['Write the first letter of each picture s name in your notebooks', 0],
#  ['Un c i ef Afgh a nistan', 0],
#  ['Qala y i now', 0],
#  ['SAMANG AN   BAGHLAN', 0],
#  ['PAK TYAKHO ST', 0],
#  ['Nort heaster n', 0],
#  ['Un icef Co untr y Office', 0],
#  ['Un icef ZO', 0],
#  ['Match the pictures with the correct words', 0],
#  ['Unic ef Afg ha nis tan', 0],
#  ['map net orange pen queen radio', 0],
#  ['SAMANG AN BAG HLAN', 0],
#  ['Qalay i now', 0],
#  ['KABU L W', 0],
#  ['Unicef Count ry Off ice', 0],
#  ['Write the words of exercise C in your notebooks', 0],
#  ['         AB                   B   C', 0],
#  ['I know the Alphabet in English', 0],
#  ['zoo  table  umbrella  van  wall  x  ray  yak     P', 0],
#  ['Hello  how are you?', 0],
#  ['Hello  how are you?', 0],
#  ['I am fine  thank you', 0],
#  ['Fine  thank you', 0],
#  ['Look at the pictures and repeat their names after your teacher', 0],
#  ['Look at the above pictures and name them', 0],
#  ['In pairs  Student A points to a picture  student B names it', 0],
#  ['Follow the example', 0],
#  ['What is this? Points to', 0],
#  ['It is an umbrella', 0],
#  ['zoo   table  umbrella  van  wall  x ray  yak      !', 0],
#  ['Look at the pictures and name them', 0],
#  ['In pairs  Student A points to a picture  student B names the picture', 0],
#  ['Follow the example', 0],
#  ['What is this? points to', 0],
#  ['It is an umbrella', 0],
#  ['Look at the pictures and read the words after your', 0],
#  ['Look at the above pictures and read their names', 0],
#  ['table  umbrella  van  wall  x ray  yak  zoo', 0],
#  ['Look at the picture and circle the correct word below', 0],
#  ['umbrella table van', 0],
#  ['zoo wall yak', 0],
#  ['table yak umbrella', 0],
#  ['x ray zoo van', 0],
#  ['van wall x ray', 0],
#  ['umbrella yak table', 0],
#  ['wall x ray zoo', 0],
#  ['Look at the above pictures and read the words below', 0],
#  ['Write the letters in your notebooks', 0],
#  ['Follow the example', 0],
#  ['!           .        AB', 0],
#  ['Write each letter t  u  v  w  x  y and z fives times in your notebooks', 0],
#  ['Match each letter with the picture s name that begins with that letter', 0],
#  ['u v w x', 0],
#  ['Write the first letter of each picture s name in your notebooks', 0],
#  ['Match the pictures with the correct word', 0],
#  ['van wall x ray', 0],
#  ['Write each letter t  u  v  w  x  y and z five times in your notebooks', 0],
#  ['Review of Unit', 0],
#  ['Good morning students', 0],
#  ['Good morning teacher', 0],
#  ['How are you?', 0],
#  ['Fine  thank you', 0],
#  ['The teacher points to a picture and the students read the word under the picture',
#   0],
#  ['Match the picture with the correct word', 0],
#  ['apple book cat  dog egg fish', 0],
#  ['goat hen iron jug kite lamp', 0],
#  ['Read the above words', 0],
#  ['Write the words in part C in your notebooks and draw five of your favorite pictures  and color them',
#   0],
#  ['F                 AB                   B   C', 0],
#  ['See you students', 0],
#  ['See you teacher', 0],
#  ['Review of Units', 0],
#  ['Hello boys girls', 0],
#  ['How are you?', 0],
#  ['Fine  thank you', 0],
#  ['The teacher points to a picture and the students name it', 0],
#  ['What is this? Points to', 0],
#  ['Says  It is a pen', 0],
#  ['Un icef Af gh anistan', 0],
#  ['Ma yma na', 0],
#  ['Qal ay i', 0],
#  ['SAMANG AN   BAGHLAN', 0],
#  ['Unicef Country O ffice', 0],
#  ['Out Po sts', 0],
#  ['Paved r o.shp', 0],
#  ['The teacher points to a picture  and the students read the word under the picture',
#   0],
#  ['Un icef Af gh anistan', 0],
#  ['Ma yma na', 0],
#  ['Qal ay i', 0],
#  ['SAMANG AN   BAGHLAN', 0],
#  ['Unicef Country O ffice', 0],
#  ['Out Po sts', 0],
#  ['Paved r o.shp', 0],
#  ['Match the picture with the correct word', 0],
#  ['map net orange', 0],
#  ['Unicef Af ghanistan', 0],
#  ['Qalay  i now', 0],
#  ['P ARWAN KAP ISA', 0],
#  ['S AMANG AN', 0],
#  ['Pulik humr i', 0],
#  ['TAKHARFa zi ab ad', 0],
#  ['Unicef C ou ntry Offi ce', 0],
#  ['radio sun table', 0],
#  ['umbrella van wall', 0],
#  ['x ray yak zoo', 0],
#  ['Read the above words', 0],
#  ['Write the words of part C in your notebooks and draw five of your favorite pictures and color them',
#   0],
#  ['    L      R                                        AB              B   C',
#   0],
#  ['More English Words', 0],
#  ['             fox   ant  ball  car  desk  eagle', 0],
#  ['Aziz  please stand up', 0],
#  ['Now read this', 0],
#  ['Please sit down', 0],
#  ['Look at the pictures and repeat their names after your teacher', 0],
#  ['Look at the above pictures and name them', 0],
#  ['Look at the pictures', 0],
#  ['Listen to your teacher s pronounciation and read the words after him her',
#   0],
#  ['K    U I    T', 0],
#  ['Look at the above pictures and read the words below', 0],
#  ['In pairs  Student A says the name of a picture  student B points to it', 0],
#  ['Follow the example', 0],
#  ['Student A   says  an ant', 0],
#  ['Student B   points to', 0],
#  ['Draw one of the part D pictures and color it', 0],
#  ['Teacher  Good bye', 0],
#  ['Students  Good bye', 0],
#  ['Fox    Ant  Ball  Car  Desk  Eagle', 0],
#  ['Look at the pictures', 0],
#  ['Listen to your teacher s pronunciation and read the words after him her',
#   0],
#  ['K    U I    T', 0],
#  ['Read the words under the above pictures', 0],
#  ['Look at the pictures and read the sentences after your teacher', 0],
#  ['It is an ant', 0],
#  ['It is a ball', 0],
#  ['It is a desk', 0],
#  ['It is a car', 0],
#  ['It is an eagle', 0],
#  ['It is a fox', 0],
#  ['D.In pairs  Student A points to a picture in part C and student B reads the sentence',
#   0],
#  ['Example  Student A  points to', 0],
#  ['Student B  Reads', 0],
#  ['It is an ant', 0],
#  ['Write the words of part A in your notebooks', 0],
#  ['Fox    Ant  Ball  Car  Desk  Eagle', 0],
#  ['Look at the pictures and circle the correct word below', 0],
#  ['Look at the pictures and read the words below', 0],
#  ['Write the capital letters A  B  C  D  E  F in your notebooks', 0],
#  ['Follow the example', 0],
#  ['AB                F        A', 0],
#  ['Write each letter A  B  C  D  E and F five times in', 0],
#  ['          AB                       your notebooks', 0],
#  ['Match each letter with the picture sname which begins with that letter', 0],
#  ['Write the first letter of picture s name in your notebooks', 0],
#  ['          A            E    ET', 0],
#  ['Match the pictures with the correct words', 0],
#  ['Write for each letter A  B  C  D  E and F five times in your notebooks', 0],
#  ['Listening to the Teacher', 0],
#  ['             Lock   Jar  Key Glass  Hand  Ice cream', 0],
#  ['Please stand up boys girls', 0],
#  ['How are you?', 0],
#  ['standing  Fine  Thank you', 0],
#  ['Sit down please', 0],
#  ['sitting  Thank you', 0],
#  ['Look at this picture', 0],
#  ['What is it?', 0],
#  ['It is a       ', 0],
#  ['Look at the pictures  repeat their names after your teacher', 0],
#  ['Look at the above pictures and name them', 0],
#  ['In pairs  Student A points to a picture and student B names it', 0],
#  ['Student A  points to', 0],
#  ['Student B   says  Glass', 0],
#  ['Look at the pictures', 0],
#  ['Listen to your teacher s pronunciation and read the words after him her',
#   0],
#  ['K    U I    T', 0],
#  ['Student A says the name of a picture', 0],
#  ['Student B points to it', 0],
#  ['Follow the example', 0],
#  ['Student A   says  ice cream', 0],
#  ['Student B  points to', 0],
#  ['Draw one of the part D pictures and color it', 0],
#  ['Glass  Hand  Ice Cream  Jar  Key  Lock      !', 0],
#  ['Look at the pictures', 0],
#  ['Listen to your teacher and read the words after him her', 0],
#  ['K    U I', 0],
#  ['Read the words under each picture', 0],
#  ['Look at the pictures and read the sentences after', 0],
#  ['This is a glass', 0],
#  ['This is a hand', 0],
#  ['This is a jar', 0],
#  ['This is an ice cream', 0],
#  ['This is a key', 0],
#  ['This is a lock', 0],
#  ['In pairs  Student A points to a picture  student B reads the sentence', 0],
#  ['In pairs  Student A asks his partner  student B answers', 0],
#  ['Follow the example', 0],
#  ['!           .      X', 0],
#  ['Student A  What is this that?', 0],
#  ['Student B  It is a jar', 0],
#  ['Write the words of part A in your notebooks', 0],
#  ['Lock   Glass  Hand  Ice cream  Jar  Key', 0],
#  ['Look at each picture and circle the correct word', 0],
#  ['Look at the above pictures and read the words below', 0],
#  ['G G G', 0],
#  ['Match each letter with the picture s name that begins with that letter', 0],
#  ['Write the first letter of each picture s name in your notebooks', 0],
#  ['          AB           X    X', 0],
#  ['Match the pictures with the correct words', 0],
#  ['a Glass a Hand', 0],
#  ['an Ice cream a Jar a Key a Lock', 0],
#  ['Write each letter G  H  I  J  K and L five times in your notebooks', 0],
#  ['Some More English Words', 0],
#  ['             Star    Pencil  Quail  Rose  Moon  Nest  Onion', 0],
#  ['  N           SI   Q', 0],
#  ['Hello students  how are you?', 0],
#  ['Fine thank you', 0],
#  ['Repeat after me', 0],
#  ['Read the word  please', 0],
#  ['Now write the word please', 0],
#  ['Look at the pictures and repeat their names after your teacher', 0],
#  ['Look at the above pictures and name them', 0],
#  ['In pairs  Student A points to a picture and student B names it', 0],
#  ['Student A  points to', 0],
#  ['Student B   says  Nest', 0],
#  ['Look at the pictures', 0],
#  ['Listen to your teacher s pronunciation and read the words after him her',
#   0],
#  ['K    U I    T', 0],
#  ['Look at the above pictures and read the words', 0],
#  ['In pairs  Student A says the name of a picture', 0],
#  ['Student B points to it', 0],
#  ['Student B names a picture and student A points to it', 0],
#  ['points to a picture', 0],
#  ['Says its name', 0],
#  ['Draw a picture from part B and color it', 0],
#  ['    L      R               B   B', 0],
#  ['Star    Moon  Nest  Onion  Pencil  Quail  Rose', 0],
#  ['Look at the pictures  listen to your teacher s pronunciation and read the words after him  her',
#   0],
#  ['K    U I    T', 0],
#  ['Read the words under the above pictures', 0],
#  ['Look at the pictures and read the sentences after your teacher', 0],
#  ['That is a moon', 0],
#  ['That is a nest', 0],
#  ['That is a pencil', 0],
#  ['That is an onion', 0],
#  ['That is a quail', 0],
#  ['That is a rose', 0],
#  ['That is a star', 0],
#  ['Look at the above pictures and read the sentences', 0],
#  ['In pairs  Student A points to one of the above pictures and student B reads its name',
#   0],
#  ['Follow the example', 0],
#  ['Student A  What is this?', 0],
#  ['Student B  Moon', 0],
#  ['In pairs  Student A points to a pictures in part C  student B reads the sentence',
#   0],
#  ['Student A  points to', 0],
#  ['Student B  reads That is a nest', 0],
#  ['Write the sentences in part C in your notebooks', 0],
#  ['          AB              V    B  D', 0],
#  ['Star  Moon  Nest  Onion  Pencil  Quail  Rose', 0],
#  ['Look at each picture and circle the correct words below', 0],
#  ['Look at the above pictures and read the words below them', 0],
#  ['Write the letters M  N  O  P  Q  R  and S in your notebooks', 0],
#  ['Follow the example', 0],
#  ['Write each letter M  N  O  P  Q  R  and S five times in your notebooks', 0],
#  ['         Y !     F     R     E', 0],
#  ['K  !LM', 0],
#  ['Match each letter with the pictures  which begins their names', 0],
#  ['Write the first letter of the name of each picture in your notebooks', 0],
#  ['Match the pictures with correct words', 0],
#  ['Write each letters M  N  O  P  Q  R and S five times in your notebook', 0],
#  ['          Y !     F     R', 0],
#  ['I can write the Alphabet', 0],
#  ['             Zebra    Tree  Uniform  Vase  Wolf  X ray  Yoke', 0],
#  ['    N     E D        SI   Q', 0],
#  ['Please open your books', 0],
#  ['Read this word', 0],
#  ['Thank you  teacher', 0],
#  ['Look at the pictures and repeat their names after your teacher', 0],
#  ['Look at the above pictures and name them', 0],
#  ['Look at the pictures  listen to your teacher s pronuciation and read the words after him   her',
#   0],
#  ['                           K    U I    T', 0],
#  ['In pairs  Student A points to a picture and Student B name s the picture',
#   0],
#  ['Follow the example', 0],
#  ['Student A  points to', 0],
#  ['Student B   says  tree', 0],
#  ['Draw one of the above pictures and color it', 0],
#  ['Teacher  Good bye students', 0],
#  ['Students  Good bye teacher', 0],
#  ['Tree  Uniform  Vase  Wolf  X  ray  Yoke  Zebra     !', 0],
#  ['Look at the pictures  listen to your teacher s pronunciation and read the words after him her',
#   0],
#  ['F K    U I    T', 0],
#  ['Read the words under the above pictures', 0],
#  ['Student A points to a picture and student B reads the word', 0],
#  ['Follow the example', 0],
#  ['What is this?', 0],
#  ['x ray x  ray', 0],
#  ['Look at the pictures', 0],
#  ['Listen and read the sentences after your teacher..         V', 0],
#  ['I have a tree', 0],
#  ['He has a uniform', 0],
#  ['This is my tree', 0],
#  ['It is his unifom', 0],
#  ['She has a vase', 0],
#  ['This is her vase', 0],
#  ['You have an x ray', 0],
#  ['This is your x ray', 0],
#  ['He has a wolf', 0],
#  ['This is his wolf', 0],
#  ['They have a yoke', 0],
#  ['This is their yoke', 0],
#  ['She has a zebra', 0],
#  ['This is her zebra', 0],
#  ['Look at the above pictures and read the sentences', 0],
#  ['Write the sentences of part D in your notebooks', 0],
#  ['          AB              V    B    D', 0],
#  ['Zebra    Tree  Uniform  Vase  Wolf  X  ray  Yoke', 0],
#  ['Look at the pictures  circle the correct word below', 0],
#  ['a Zebra aWolf', 0],
#  ['Look at the above pictures and read the words below them', 0],
#  ['Write the capital letters T  U  V  W  X  Y and Z in your notebooks', 0],
#  ['Follow the example', 0],
#  ['Write each letter T  U  V  W  X  Y and Z five times in your notebooks', 0],
#  ['Match each letter which begins the names of the picture', 0],
#  ['Write the first letter of the name of each picture s name in your notebooks',
#   0],
#  ['Match the pictures with the correct words', 0],
#  ['Write each letter T  U  V  W  X  Y and Z five times in your notebooks', 0],
#  ['Review of Units', 0],
#  ['Good morning students', 0],
#  ['Good morning teacher', 0],
#  ['Please look at this picture', 0],
#  ['It is a cat  an ant', 0],
#  ['The teacher points to a picture and students name it', 0],
#  ['Look at the pictures and read their names with correct pronunciation', 0],
#  ['Match the pictures with the correct word', 0],
#  ['Read the above words with correct pronunciation', 0],
#  ['      T    R          C', 0],
#  ['Write the words of part C in your notebooks', 0],
#  ['          AB                   B   C', 0],
#  ['Draw your favorite picture and color it', 0],
#  ['Review of Units', 0],
#  ['Please stand up Fatah', 0],
#  ['Name this picture', 0],
#  ['That is a moon', 0],
#  ['Thank you  Fatah', 0],
#  ['Please name this picture', 0],
#  ['That is a nest', 0],
#  ['Please sit down', 0],
#  ['Look at the pictures and name them', 0],
#  ['C.Look at the pictures and read their names with correct pronunciation', 0],
#  ['Match the pictures with the correct words', 0],
#  ['Write the words of part C in your notebook', 0],
#  ['AB                   B   C', 0],
#  ['            a                       carrot  turnip  radish  potato  tomato  cabbage',
#   0],
#  ['How are you?', 0],
#  ['I am fine thank you', 0],
#  ['Do you like vegetables?', 0],
#  ['Yes  I do', 0],
#  ['What kind of vegetables do you like?', 0],
#  ['I like carrots and turnips', 0],
#  ['Look at the pictures of vegetables and repeat their names after your teacher',
#   0],
#  ['Look at the above pictures and name them', 0],
#  ['In pairs  One student shows a real vegetable or its picture and asks a question',
#   0],
#  ['Other students answer the question', 0],
#  ['What is this?', 0],
#  ['It is a potato', 0],
#  ['What is this?', 0],
#  ['It is a tomato', 0],
#  ['Draw a picture of a vegetable of part B and color it', 0],
#  ['           R          B           B   B', 0],
#  ['Teacher  Good bye students', 0],
#  ['Students  Good bye teacher', 0],
#  ['cabbage    carrot  turnip  radish  potato  tomato', 0],
#  ['Look at the pictures of vegetables and read the words after your teacher',
#   0],
#  ['Read the words below the above pictures', 0],
#  ['Look at these pictures and read the sentences after your teacher', 0],
#  ['This is a radish', 0],
#  ['Is this a radish?', 0],
#  ['Yes  it is', 0],
#  ['This is a carrot', 0],
#  ['Is this a carrot?', 0],
#  ['Yes  it is', 0],
#  ['This is a potato', 0],
#  ['Is this a ptato?', 0],
#  ['Yes  it is', 0],
#  ['This is a turnip', 0],
#  ['Is this a turnip?', 0],
#  ['Yes  it is', 0],
#  ['This is a tomato', 0],
#  ['This is a cabbage', 0],
#  ['Is this a tomato? Is this a cabbage?', 0],
#  ['Yes  it is', 0],
#  ['Yes  it is', 0],
#  ['Look at the above pictures and read the sentences below them', 0],
#  ['Read these sentences and Point to the correct pictures in part A of the lesson',
#   0],
#  ['Q            A           W', 0],
#  ['This is a carrot', 0],
#  ['This is a turnip', 0],
#  ['This is a radish', 0],
#  ['This is a potato', 0],
#  ['This is a cabbage', 0],
#  ['This is a tomato', 0],
#  ['Read these words and write them in your notebook', 0],
#  ['Carrot  turnip  radish  potato  tomato and cabbage', 0],
#  ['             B  d        B    V', 0],
#  ['Look at the pictures  circle the correct words below', 0],
#  ['radish carrot turnip', 0],
#  ['turnip radish carrot', 0],
#  ['carrot cabbage turnip potato radish tomato', 0],
#  ['tomato potato cabbage', 0],
#  ['potato cabbage tomato', 0],
#  ['Look at the above pictures and read the words', 0],
#  ['            !                                 below them', 0],
#  ['Write the name of each picture in your notebooks', 0],
#  ['Match the words with the pictures', 0],
#  ['turnip radish potato tomato cabbage', 0],
#  ['Change the following sentences to questions and answer them', 0],
#  ['     c  d                    V', 0],
#  ['This is a potato', 0],
#  ['Is this a potato?', 0],
#  ['Yes  it is', 0],
#  ['This is a carrot', 0],
#  ['This is a turnip', 0],
#  ['This is a radish', 0],
#  ['This is a cabbage', 0],
#  ['This is a tomato', 0],
#  ['Change the above sentences to questions and write them in your notebooks',
#   0],
#  ['           Y !     F     Q             W', 0],
#  ['!  V                   cherry  watermelon  pear          V', 0],
#  ['   !        peach    banana  melon  apricot', 0],
#  ['Do you like fruit?', 0],
#  ['Yes  we do', 0],
#  ['What fruits do you like?', 0],
#  ['We like cherries and apples', 0],
#  ['Look at the pictures of fruits and repeat their names after your teacher',
#   0],
#  ['Look at the above pictures and name them', 0],
#  ['Look at the pictures', 0],
#  ['Listen to your teacher and repeat the sentences after him her', 0],
#  ['K    U I', 0],
#  ['This is an apricot', 0],
#  ['This is a banana', 0],
#  ['This is a peach', 0],
#  ['This is a watermelon', 0],
#  ['This is a cherry', 0],
#  ['This is a melon', 0],
#  ['That is a pear', 0],
#  ['That is a peach', 0],
#  ['In pairs  Student A points to a picture and asks a question  and student B answers',
#   0],
#  ['Student A  What is this? Points to', 0],
#  ['Student B  That is a banana', 0],
#  ['Draw a picture of fruit from part B and color it', 0],
#  ['cherry  melon  apricot  peach  pear', 0],
#  ['V       T          banana    watermelon', 0],
#  ['Look at the pictures of fruit  and read their names after your teacher', 0],
#  ['Look at the above pictures and read their names', 0],
#  ['Look at these pictures', 0],
#  ['Listen and read the sentences after your teacher', 0],
#  ['Is that a banana?', 0],
#  ['No  it is not a banana', 0],
#  ['It is a watermelon', 0],
#  ['Is that a pear?', 0],
#  ['No  it is not a pear', 0],
#  ['It is a cherry', 0],
#  ['Is that a melon?', 0],
#  ['No  it is not a melon', 0],
#  ['It is a pear', 0],
#  ['Is that a peach?', 0],
#  ['No  it is not a peach', 0],
#  ['It is a melon', 0],
#  ['Is that a watermelon?', 0],
#  ['No  it is not a watermelon', 0],
#  ['It is a banana', 0],
#  ['Is that an apricot?', 0],
#  ['No  it is not a apricot', 0],
#  ['It is a peach', 0],
#  ['Look at the pictures from part B again and read the following sentences after your teacher',
#   0],
#  ['That is a pear', 0],
#  ['That is an apricot', 0],
#  ['That is a peach', 0],
#  ['That is a melon', 0],
#  ['That is a watermelon', 0],
#  ['That is a banana', 0],
#  ['That is a cherry', 0],
#  ['Read these words and write them in your notebooks', 0],
#  ['Pear  apricot  melon  cherry  grape  peach and banana', 0],
#  ['Look at the pictures', 0],
#  ['Circle and read the correct word below', 0],
#  ['a peach an apricot', 0],
#  ['an apricot a peach a pear', 0],
#  ['an apricot a pear a peach', 0],
#  ['a cherry a banana', 0],
#  ['a banana a melon', 0],
#  ['a melon awatermelon', 0],
#  ['a peach a watermelon', 0],
#  ['Look at the above pictures and read the words below them', 0],
#  ['Write the name of each picture in your notebooks', 0],
#  ['Match the words with the pictures', 0],
#  ['an apricot a pear a peach', 0],
#  ['a cherry a banana a melon', 0],
#  ['Answer the questions in short and long from', 0],
#  ['Follow the example', 0],
#  ['!           .        B  d', 0],
#  ['Is that a pear?', 0],
#  ['No  it is not', 0],
#  ['It is a watermelon', 0],
#  ['Is that a banana?', 0],
#  ['Is that a peach?', 0],
#  ['Is that a watermelon?', 0],
#  ['Is that cherry?', 0],
#  ['Is that a melon?', 0],
#  ['Is that a pear?', 0],
#  ['Is that an apricot?', 0],
#  ['Use the words of part E in sentences and write them in your notebooks', 0],
#  ['This  That is a  an', 0],
#  ['What is your name?', 0],
#  ['My name is          ', 0],
#  ['What are you?', 0],
#  ['I am a student', 0],
#  ['Look at the family pictures and repeat the words after your teacher', 0],
#  ['Look at the family pictures and repeat the sentences after your teacher',
#   0],
#  ['This is Habib', 0],
#  ['Halima is his wife', 0],
#  ['This is Halima', 0],
#  ['Habib is her husband', 0],
#  ['This boy is Ali', 0],
#  ['His father is Habib', 0],
#  ['This girl is Hafiza', 0],
#  ['Her mother is Halima', 0],
#  ['Ali has a sister', 0],
#  ['Her name is Hafiza', 0],
#  ['Hafiza has a brother', 0],
#  ['His name is Ali', 0],
#  ['Habib and Halima have a son', 0],
#  ['His name is Ali', 0],
#  ['Halima and Habib have a daughter', 0],
#  ['Her name is Hafiza', 0],
#  ['Look at these pictures and repeat the sentences after your teacher', 0],
#  ['He is a boy She is a girl', 0],
#  ['He is a man She is a woman', 0],
#  ['Repeat these sentences after your teacher', 0],
#  ['This is a man', 0],
#  ['He is my father', 0],
#  ['This is a woman', 0],
#  ['She is my mother', 0],
#  ['This is a boy', 0],
#  ['He is my brother', 0],
#  ['This is a girl', 0],
#  ['She is my sister', 0],
#  ['This is a boy', 0],
#  ['He is my son', 0],
#  ['This is a girl', 0],
#  ['She is my daughter', 0],
#  ['This is a man', 0],
#  ['He is my husband', 0],
#  ['Read the sentences of part E and write them in your notebooks', 0],
#  ['Teacher  Good bye boys girls', 0],
#  ['Student  Good bye teacher', 0],
#  ['Repeat these words after your teacher the words are singular and plural',
#   0],
#  ['A  boy girl family', 0],
#  ['B  boys girls families', 0],
#  ['A  man woman child', 0],
#  ['men women children', 0],
#  ['Repeat these sentences after your teacher', 0],
#  ['This is a boy', 0],
#  ['These are boys', 0],
#  ['This is a girl', 0],
#  ['These are girls', 0],
#  ['This is a man', 0],
#  ['These are men', 0],
#  ['This is a woman', 0],
#  ['These are women', 0],
#  ['In pairs  Student A reads one of the above singular sentences  student B reads its plural form',
#   0],
#  ['Student A  reads  This is a boy', 0],
#  ['Student B  reads  These are boys', 0],
#  ['Note  All students take turns', 0],
#  ['Write the words of part A in your notebooks', 0],
#  ['  N          woman    boy  girl man', 0],
#  ['Please answer this question', 0],
#  ['What is the plural for boy?', 0],
#  ['The plural for boy is boys', 0],
#  ['What is the plural for girl?', 0],
#  ['The plural for girl is girls', 0],
#  ['Match singular sentences with plural', 0],
#  ['Follow the example', 0],
#  ['This boy is a student', 0],
#  ['They are men', 0],
#  ['That boy is a child', 0],
#  ['They are women', 0],
#  ['This girl is a student', 0],
#  ['They are my brothers', 0],
#  ['That girl is a child', 0],
#  ['These boys are students', 0],
#  ['He is a man', 0],
#  ['These boys are children', 0],
#  ['She is a woman', 0],
#  ['These girls are students', 0],
#  ['He is my brother', 0],
#  ['Those girls are children', 0],
#  ['This woman is a teacher', 0],
#  ['These women are teachers', 0],
#  ['Match the words with the pictures', 0],
#  ['D.Change these words to plural  read and write them', 0],
#  ['E.Change these sentences to their singular form', 0],
#  ['These women are teachers', 0],
#  ['This woman is a teacher', 0],
#  ['They are my brothers', 0],
#  ['Those girls are students', 0],
#  ['Those girls are children', 0],
#  ['Those boys are students', 0],
#  ['They are men', 0],
#  ['They are women', 0],
#  ['In pairs  Student A says a singular word or a sentence  student B changes it to plural',
#   0],
#  ['C         B           V', 0],
#  ['R Q i V', 0],
#  ['Student A   says  woman', 0],
#  ['Student B   says  women', 0],
#  ['Student A  He is a boy', 0],
#  ['Student B  They are boys', 0],
#  ['Write the plural form of nouns in part  C  in your notebooks.Follow the example',
#   0],
#  ['Example  Teacher   Teachers', 0],
#  ['face   head  mouth  lips  ear  eye  nose  neck', 0],
#  ['How are you?', 0],
#  ['We are fine  thank you', 0],
#  ['How are you?', 0],
#  ['I am fine  thank you', 0],
#  ['Look at these pictures and repeat their names after your teacher', 0],
#  ['Look at the above pictures and name each of them', 0],
#  ['In pairs  Student A points to a part of his her body and asks a question Student B answers',
#   0],
#  ['Student A  What is this?', 0],
#  ['Student B  That is your  ', 0],
#  ['Look at the picture of the boy  listen and repeat the sentences after your teacher',
#   0],
#  ['This is a boy', 0],
#  ['This is his head', 0],
#  ['This is his mouth', 0],
#  ['These are his lips', 0],
#  ['These are his teeth', 0],
#  ['This is his neck', 0],
#  ['This is his nose', 0],
#  ['These are his ears', 0],
#  ['These are his eyes', 0],
#  ['This is his face', 0],
#  ['face nose mouth', 0],
#  ['Point to the parts of your body and make sentences', 0],
#  ['I am Saber', 0],
#  ['This is my head', 0],
#  ['These are my eyes', 0],
#  ['Note  All students take turns', 0],
#  ['In pairs  Student A points to a part of his her body and asks a question',
#   0],
#  ['Student B answers the question', 0],
#  ['Follow the example', 0],
#  ['points to his head', 0],
#  ['What is this?', 0],
#  ['That is your head', 0],
#  ['points to his eyes', 0],
#  ['What are these?', 0],
#  ['Those are your eyes', 0],
#  ['Write the names of parts of your body in your notebook', 0],
#  ['I will see you tomorrow students', 0],
#  ['We will see you tomorrow teacher', 0],
#  ['Look at the picture and read the words after your', 0],
#  ['Look at the above pictures and read the words below them', 0],
#  ['Look at the picture and read these sentences', 0],
#  ['That is a girl', 0],
#  ['That is her head', 0],
#  ['That is her face', 0],
#  ['That is her nose', 0],
#  ['That is her mouth', 0],
#  ['That is her neck', 0],
#  ['Those are her ears', 0],
#  ['These are her eyes', 0],
#  ['These are her lips', 0],
#  ['These are her theeth', 0],
#  ['The sex are her teeth', 0],
#  ['This is her arm', 0],
#  ['Point to the parts of your body and read these sentences', 0],
#  ['This is my ear', 0],
#  ['These are my ears', 0],
#  ['This is my tooth', 0],
#  ['These are my teeth', 0],
#  ['This is my lip', 0],
#  ['These are my lips', 0],
#  ['This is my eye', 0],
#  ['These are my eyes', 0],
#  ['In pairs  Student A points to a part of his her body and asks a question  student B answers the question',
#   0],
#  ['Student A   asks  What is this?', 0],
#  ['Student B   answers  That is your face', 0],
#  ['Note  All students take turns', 0],
#  ['Change these words in English in your notebook', 0],
#  ['Match the words with the pictures', 0],
#  ['Match the singular words with their plurals', 0],
#  ['eye ear tooth lip finger', 0],
#  ['lips eyes ears teeth feet', 0],
#  ['Circle the correct word for each picture and read the word', 0],
#  ['eye foot lip', 0],
#  ['teeth neck nose', 0],
#  ['mouth nose neck', 0],
#  ['mouth face ear', 0],
#  ['nose teeth ear', 0],
#  ['eye nose head', 0],
#  ['lips neck head', 0],
#  ['nose face lips', 0],
#  ['mouth neck teeth', 0],
#  ['Write the plural forms of the following words in your notebooks', 0],
#  ['Example  lip lips face eye', 0],
#  ['Review of Units', 0],
#  ['How are you this morning afternoon?', 0],
#  ['We are fine  thank you', 0],
#  ['How are you teacher?', 0],
#  ['I am fine  thank you', 0],
#  ['Look at these pictures and name them', 0],
#  ['Look at these pictures and read their names', 0],
#  ['Read these Senterces and match them with their pictures', 0],
#  ['That is a pear', 0],
#  ['That is a peach', 0],
#  ['That is a banana', 0],
#  ['That is a melon', 0],
#  ['That is a watermelon', 0],
#  ['That is a carrot', 0],
#  ['That is a turnip', 0],
#  ['That is a tomato', 0],
#  ['That is a potato', 0],
#  ['That is a radish', 0],
#  ['Look at the pictures  answer the questions like the given example', 0],
#  ['Is that a banana?', 0],
#  ['No  it is not a banana', 0],
#  ['It is a water melon', 0],
#  ['Is that a pear?', 0],
#  ['Is that a melon?', 0],
#  ['Is that a peach?', 0],
#  ['Is that a watermelon?', 0],
#  ['Write the words of part C in your notebook and draw    of your favorite pictures',
#   0],
#  ['Color the pictures', 0],
#  ['Review of Units', 0],
#  ['A woman has a child', 0],
#  ['Her child is a girl', 0],
#  ['What do we call the woman s child?', 0],
#  ['The woman s child is her daughter', 0],
#  ['Yes  Now this woman has another child', 0],
#  ['He is a boy', 0],
#  ['What do we call this child', 0],
#  ['This child is the woman s son', 0],
#  ['Look at the family diagram and read the words related to each picture', 0],
#  ['Read these words and sentences with correct pronunciation', 0],
#  ['She  He  They  I  You  We', 0],
#  ['She is his wife', 0],
#  ['He is her husband', 0],
#  ['They have a daughter and a son', 0],
#  ['I have a brother', 0],
#  ['You are my sister', 0],
#  ['We are a family', 0],
#  ['It is our house', 0],
#  ['It is your house', 0],
#  ['Look at these pictures and name them', 0],
#  ['E.Look at the pictures and read their names with the correct pronunciation',
#   0],
#  ['F.Read the words and match them with their pictures', 0],
#  ['head  lips boy', 0],
#  ['man teeth nose woman', 0],
#  ['girl ear mouth neck', 0],
#  ['Look at the pictures  read the sentences and check', 0],
#  ['the correct sentence', 0],
#  ['This is my hand', 0],
#  ['This is my eye', 0],
#  ['This is my nose', 0],
#  ['This is your nose', 0],
#  ['This is your ear', 0],
#  ['This is your lip', 0],
#  ['That is his head', 0],
#  ['That is his neck', 0],
#  ['That is his nose', 0],
#  ['It is her ear', 0],
#  ['It is her nose', 0],
#  ['It is her arm', 0],
#  ['Those are her ears', 0],
#  ['Those are her eyes', 0],
#  ['Those are her lips', 0],
#  ['Write the words of part E in your notebook', 0],
#  ['of your favorite pictures and color them', 0],
#  ['Father r   Finger', 0],
#  ['I have to eat the cherry', 0],
#  ['Fish k B Foot  feet', 0],
#  ['S  P His', 0],
#  ['Onion e  K w  Orange', 0],
#  ['Pear k      Pen', 0],
#  ['Not  is not', 0],
#  ['N  Shopkeeper b a  Sister', 0],
#  ['C U    Son', 0],
#  ['G        I Sun', 0],
#  ['V Tailor b    Teacher', 0],
#  ['Good morning students', 0],
#  ['Students  Good morning teacher', 0],
#  ['Teacher  Please look at this picture', 0],
#  ['Students  It is a cat  an ant', 0],
#  ['Teacher  Thank you', 0]]

# %%
# read the grade twelve file
grade_ten_sentence = read_and_clean("../data/gradetwelveafghan.txt")

# %%
label = 1
new_examples2 = []
for i in grade_ten_sentence:  
    if len(word_tokenize(i))>2:
        new_examples2 = new_examples2 + [[i, label]]

# %%
# new_examples2 = new_examples2[16:] # slicing the few sentences in the beginning to remove the contents page.

# %%
new_examples2 = new_examples2[1200:] # slicing further to avoid overfitting due to data imbalance

# %% [markdown]
# ### Checking for Data Imbalance:

# %%
len(new_examples1)
# Out:
# 923

# %%
len(new_examples2)
# Out:
# 1901

# %%
len(new_examples1)+len(new_examples2)
# Out:
# 2824

# %% [markdown]
# ### Checking the Readability Scores using the Textstat Library:

# %%
fs = open('../data/gradefourafghan.txt', 'r') 
bookone = fs.read()

# %%
# https://pypi.org/project/textstat/
bookonescore = round(textstat.flesch_kincaid_grade(bookone))
bookonescore
# Out:
# 4

# %%
fs = open('../data/gradetwelveafghan.txt', 'r') 
booktwo = fs.read()

# %%
# https://pypi.org/project/textstat/
booktwoscore = round(textstat.flesch_kincaid_grade(booktwo))
booktwoscore
# Out:
# 6

# %% [markdown]
# ### Organising the Labelled Data together using a Pandas Dataframe

# %%
dataset = pd.DataFrame(columns = ["text", "label"]) 
dataset = dataset.append(pd.DataFrame(new_examples2+new_examples1, columns = ["text", "label"]))

# %% [markdown]
# ### Splitting the Data into Train and Test Sets

# %%
# https://realpython.com/train-test-split-python-data/
from sklearn.model_selection import train_test_split
train_texts, test_texts, train_labels, test_labels = train_test_split(list(dataset["text"]), list(dataset["label"]), test_size=.1)

# %% [markdown]
# ### Tokenization:

# %%
# https://huggingface.co/docs/transformers/custom_datasets
from transformers import DistilBertTokenizerFast
import torch
from transformers import DistilBertForSequenceClassification, Trainer, TrainingArguments

# https://huggingface.co/transformers/training.html
# https://analyticsindiamag.com/python-guide-to-huggingface-distilbert-smaller-faster-cheaper-distilled-bert/
from datasets import load_metric 
tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-uncased')
# downloading the distilbert model
model = DistilBertForSequenceClassification.from_pretrained("distilbert-base-uncased")
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.bias', 'vocab_projector.weight', 'vocab_projector.bias', 'vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'pre_classifier.weight', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# https://github.com/rasbt/stat453-deep-learning-ss21/blob/main/L19/distilbert-classifier/01_distilbert-simple.ipynb
# https://huggingface.co/docs/transformers/custom_datasets

# converting the text to numbers
train_encodings = tokenizer(train_texts, truncation=True, padding=True)
test_encodings = tokenizer(test_texts, truncation=True, padding=True)

# %% [markdown]
# ### Data Loader Developed Using Dataset Class:

# %%
# https://github.com/rasbt/stat453-deep-learning-ss21/blob/main/L19/distilbert-classifier/01_distilbert-simple.ipynb
# https://huggingface.co/docs/transformers/custom_datasets

# creating a dataset class so we can provide this dataframe to the model

class IMDbDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

train_dataset = IMDbDataset(train_encodings, train_labels)
test_dataset = IMDbDataset(test_encodings, test_labels)

# %% [markdown]
# ### Train Model:

# %%
# https://huggingface.co/docs/transformers/custom_datasets

# getting all the arguments for the model
training_args = TrainingArguments(
    output_dir='results',          # output directory
    num_train_epochs=6,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
)

# https://huggingface.co/transformers/training.html

# metric to compute accuracy 
metric = load_metric("accuracy") 

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

# creating the trainer which trains the model on data
trainer = Trainer(
    model=model,                          
    args=training_args,                  # training arguments, defined above
    train_dataset=train_dataset,         # training dataset
    eval_dataset=test_dataset,           # evaluation dataset
    compute_metrics=compute_metrics
)
# start training
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 2541
#   Num Epochs = 6
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 954
#     <div>
#
#       <progress value='954' max='954' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [954/954 1:47:42, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.103800</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to results/checkpoint-500
# Configuration saved in results/checkpoint-500/config.json
# Model weights saved in results/checkpoint-500/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=954, training_loss=0.055429412009081254, metrics={'train_runtime': 6470.4598, 'train_samples_per_second': 2.356, 'train_steps_per_second': 0.147, 'total_flos': 197226363272400.0, 'train_loss': 0.055429412009081254, 'epoch': 6.0})

# %% [markdown]
# ### Evaluate:

# %%
# start evaluation
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 283
#   Batch size = 64
#     <div>
#
#       <progress value='5' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5/5 00:13]
#     </div>
# {'eval_loss': 0.1513858139514923,
#  'eval_accuracy': 0.9717314487632509,
#  'eval_runtime': 18.5818,
#  'eval_samples_per_second': 15.23,
#  'eval_steps_per_second': 0.269,
#  'epoch': 6.0}

# %% [markdown]
# `- The model accuracy is 98% for 5 epochs`
#
# `- The model accuracy is 98% for 10 epochs`
#
# `- The model accuracy is 97% for 6 epochs (balanced dataset)`

# %% [markdown]
# ### Adding in Some New Strings to Test the Model:

# %%
# https://huggingface.co/transformers/model_doc/distilbert.html#distilbertforsequenceclassification

inputs = tokenizer("I am under siege. I agree with you on that.", return_tensors="pt") 
labels = torch.tensor([1]).unsqueeze(0) 
outputs = model(**inputs, labels=labels)
loss = outputs.loss
logits = outputs.logits

# %%
logits
# Out:
# tensor([[-3.9833,  5.1887]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# We can now check which label the model is more confident about. We take the confidence of the first cluster, and then the second cluster. If the confidence of the first cluster is greater then the confidence of second cluster, it'll print out '0'. If the confidence of the first cluster is not greater than the second, it'll print out '1'

# %%
if logits[0][0] > logits[0][1]: 
  print(0)
else:
  print(1)
# Out:
# 1

# %% [markdown]
# ### Cross-checking it with the Textstat Library:

# %%
# https://pypi.org/project/textstat/
trump = round(textstat.flesch_kincaid_grade("I am under siege. I agree with you on that."))
trump
# Out:
# -1

# %% [markdown]
# #### `(All observations and findings shall be included in the critical essay).`

# %% [markdown]
# ### Citation List:
#
# #### Websites:
#
# 1) Alammar, J., 2021. A Visual Guide to Using BERT for the First Time. [online] Jalammar.github.io. Available at: <https://jalammar.github.io/a-visual-guide-to-using-bert-for-the-first-time/> [Accessed 4 December 2021].
#
# 2) Davis, A., 2021. The fundamentals of programming - Python Video Tutorial | LinkedIn Learning, formerly Lynda.com. [online] LinkedIn. Available at: <https://www.linkedin.com/learning/programming-foundations-fundamentals-3/the-fundamentals-of-programming?autoAdvance=true&autoSkip=false&autoplay=true&resume=true&u=57077561> [Accessed 24 October 2021].
#
# 3) Dib, F., 2021. regex101: build, test, and debug regex. [online] regex101. Available at: <https://regex101.com/> [Accessed 4 December 2021].
#
# 4) Huggingface.co. 2021. DistilBERT. [online] Available at: <https://huggingface.co/transformers/model_doc/distilbert.html#distilbertforsequenceclassification> [Accessed 11 December 2021].
#
# 5) Huggingface.co. 2021. Fine-tuning a pretrained model. [online] Available at: <https://huggingface.co/transformers/training.html> [Accessed 9 December 2021].
#
# 6) Huggingface.co. 2021. How to fine-tune a model for common downstream tasks. [online] Available at: <https://huggingface.co/docs/transformers/custom_datasets> [Accessed 5 December 2021].
#
# 7) Libgen.is. 2021. Library Genesis. [online] Available at: <https://www.libgen.is/> [Accessed 4 November 2021].
#
# 8) McCallum, L., 2021. NLP Week 4.1 - Classification Task Notebook. [online] GitHub. Available at: <https://git.arts.ac.uk/lmccallum/nlp-21-22/blob/master/NLP%20Week%204.1%20-%20Classification%20Task.ipynb> [Accessed 16 November 2021].
#
# 9) Nisbet, J., 2021. Python for students - Python Video Tutorial | LinkedIn Learning, formerly Lynda.com. [online] LinkedIn. Available at: <https://www.linkedin.com/learning/python-for-students/python-for-students?autoAdvance=true&autoSkip=false&autoplay=true&resume=false&u=57077561> [Accessed 18 October 2021].
#
# 10) Portilla, J., 2021. Natural Language Processing with Python. [online] Udemy. Available at: <https://www.udemy.com/course/nlp-natural-language-processing-with-python/?ranMID=39197&ranEAID=JVFxdTr9V80&ranSiteID=JVFxdTr9V80-gIa4CDf8o_3HXX8ZIg_F1g&LSNPUBID=JVFxdTr9V80&utm_source=aff-campaign&utm_medium=udemyads> [Accessed 27 October 2021].
#
# 11) Python, R., 2021. Split Your Dataset With scikit-learn's train_test_split() – Real Python. [online] Realpython.com. Available at: <https://realpython.com/train-test-split-python-data/> [Accessed 5 December 2021].
#
# 12) Raschka, S., 2021. L19.6 DistilBert Movie Review Classifier in PyTorch. [online] Youtube.com. Available at: <https://www.youtube.com/watch?v=emDmznRlsWw> [Accessed 5 December 2021].
#
# 13) Raschka, S., 2021. Simple distilBERT Repository. [online] GitHub. Available at: <https://github.com/rasbt/stat453-deep-learning-ss21/blob/main/L19/distilbert-classifier/01_distilbert-simple.ipynb> [Accessed 5 December 2021].
#
# 14) Rose, D., 2021. Artificial Intelligence Foundations: Neural Networks Video Tutorial | LinkedIn Learning, formerly Lynda.com. [online] LinkedIn. Available at: <https://www.linkedin.com/learning/artificial-intelligence-foundations-neural-networks/welcome?autoAdvance=true&autoSkip=false&autoplay=true&resume=true&u=57077561> [Accessed 6 December 2021].
#
# 15) Medium. 2021. TDS Tutorial: Fine-Tuning Hugging Face Model with Custom Dataset. [online] Available at: <https://towardsdatascience.com/fine-tuning-hugging-face-model-with-custom-dataset-82b8092f5333> [Accessed 6 December 2021].
#
# 16) PyPI. 2021. clean-text. [online] Available at: <https://pypi.org/project/clean-text/> [Accessed 14 November 2021].
#
# 17) PyPI. 2021. textstat. [online] Available at: <https://pypi.org/project/textstat/> [Accessed 15 November 2021].
#
# 18) Sanh, V., 2021. 🏎 Smaller, faster, cheaper, lighter: Introducing DistilBERT, a distilled version of BERT. [online] Medium. Available at: <https://medium.com/huggingface/distilbert-8cf3380435b5> [Accessed 6 December 2021].
#
# 19) Stack Abuse. 2021. Using Regex for Text Manipulation in Python. [online] Available at: <https://stackabuse.com/using-regex-for-text-manipulation-in-python/> [Accessed 16 November 2021].
#
# 20) Verma, A., 2021. Python Guide to HuggingFace DistilBERT - Smaller, Faster & Cheaper Distilled BERT. [online] Analytics India Magazine. Available at: <https://analyticsindiamag.com/python-guide-to-huggingface-distilbert-smaller-faster-cheaper-distilled-bert/> [Accessed 6 December 2021].
#
# 21) Zamzar.com. 2021. Zamzar - video converter, audio converter, image converter, eBook converter. [online] Available at: <https://www.zamzar.com/> [Accessed 7 November 2021].
